# %%
import pandas as pd

import os

import numpy as np

import networkx as nx

import matplotlib.pyplot as plt
from collections import Counter
from IPython.display import clear_output
import xlsxwriter

# %%
#importo il grafo completo
first_graph = nx.read_gpickle('data/graphs/positive/positive_graph.gpickle')

# %%
isolates = list(nx.isolates(first_graph))

# %%
#rimuovo i singoletti
first_graph.remove_nodes_from(list(nx.isolates(first_graph)))

# %%
topics = list(dict((np.load('data/topics/topic_ids.npy',allow_pickle=True)).tolist()).values())
[topics.append(item[1]) for item in np.load('data/topics/keywords.npy', allow_pickle=True).tolist()]
[topics.append(item) for item in list(dict((np.load('data/topics/categories_ids.npy',allow_pickle=True)).tolist()).values())]
topic_set = set(topics)
topic_set
# Out:
# {'Action game',
#  'Action-adventure game',
#  'Action/Adventure',
#  'American football',
#  'Animated cartoon',
#  'Anime/Animation',
#  'Autos & Vehicles',
#  'Baseball',
#  'Basketball',
#  'Boxing',
#  'Casual game',
#  "Children's music",
#  'Christian music',
#  'Classical music',
#  'Classics',
#  'Comedy',
#  'Country',
#  'Cricket',
#  'Documentary',
#  'Drama',
#  'Education',
#  'Electronic music',
#  'Entertainment',
#  'Family',
#  'Fashion',
#  'Film & Animation',
#  'Fitness',
#  'Food',
#  'Football',
#  'Foreign',
#  'Gaming',
#  'Golf',
#  'Health',
#  'Hip hop music',
#  'Hobby',
#  'Horror',
#  'Howto & Style',
#  'Humor',
#  'Ice hockey',
#  'Independent music',
#  'Jazz',
#  'Knowledge',
#  'Lifestyle',
#  'Mixed martial arts',
#  'Motorsport',
#  'Movies',
#  'Music',
#  'Music of Asia',
#  'Music of Latin America',
#  'Music video game',
#  'News & Politics',
#  'Nonprofits & Activism',
#  'People & Blogs',
#  'Performing arts',
#  'Pets',
#  'Pets & Animals',
#  'Physical attractiveness [Beauty]',
#  'Pop music',
#  'Professional wrestling',
#  'Puzzle video game',
#  'Racing video game',
#  'Reggae',
#  'Rhythm and blues',
#  'Rock music',
#  'Role-playing video game',
#  'Sc',
#  'Science & Technology',
#  'Short Movies',
#  'Shorts',
#  'Shows',
#  'Simulation video game',
#  'Societ',
#  'Soul music',
#  'Sports',
#  'Sports game',
#  'Strategy video game',
#  'Technology',
#  'Tennis',
#  'Thriller',
#  'Tourism',
#  'Trailer',
#  'Travel & Events',
#  'Vehicles',
#  'Videoblogging',
#  'Volleyball',
#  'challenge',
#  'cheap',
#  'cruelty-free',
#  'fashion',
#  'favourites',
#  'get ready with me',
#  'hair',
#  'luxury',
#  'new product launch',
#  'private life/information',
#  'review',
#  'social media',
#  'tutorial',
#  'vegan'}

# %%
brands = [item[-1] for item in np.load('data/topics/makeup_brands.npy', allow_pickle=True).tolist() if item[-1]!=""]
brand_set = set(brands)
brand_set
# Out:
# {'100% pure',
#  'aether beauty',
#  'afterglow cosmetics',
#  'albion',
#  'alima pure',
#  'almay',
#  'anastasia beverly hills',
#  'annabelle',
#  'antonym',
#  'aqua net',
#  'ardency inn',
#  'armani',
#  'aromi',
#  'astor',
#  'au naturale',
#  'avon products',
#  'axiology',
#  'bain de soleil',
#  'bajaj consumer care',
#  'balmshell',
#  'barefaced chic',
#  'bareminerals',
#  'barry m',
#  'bayankala',
#  'beautyblender',
#  'beautycounter',
#  'becca',
#  'bellapierre',
#  'ben nye',
#  'benefit cosmetics',
#  'besame',
#  'bh cosmetics',
#  'biotherm',
#  'bite beauty',
#  'black radiance',
#  'blinc',
#  'bobbi brown',
#  'bondi sands',
#  'boot',
#  'bourjois paris',
#  'burberry',
#  "burt's bees",
#  'butter london',
#  'buxom',
#  'by terry',
#  'cailyn cosmetics',
#  'calvin klein',
#  'candy girl',
#  'cargo cosmetics',
#  'carmex',
#  'cate mcnabb',
#  'cativa natureza',
#  'catrice',
#  'chanel',
#  'chantecaille',
#  'charlotte tilbury',
#  'chi chi cosmetics',
#  'ciate',
#  'clarins',
#  'clinique',
#  'clove & hallow',
#  'coloured raine',
#  'colourpop cosmetics',
#  'concrete minerals',
#  'coppertone',
#  'copycat beauty',
#  'cover fx',
#  'covergirl',
#  'cristtee',
#  'crã¨me simon',
#  'cutex',
#  'cyo cosmetics',
#  'dc cosmetics',
#  'deck of scarlet',
#  'dhc corporation',
#  'disney',
#  'dolce & gabbana',
#  'doll 10',
#  'dose of colors',
#  'douglas holding',
#  'dr lewinns',
#  'duwop',
#  'edward bess',
#  'elate',
#  'elf',
#  'elizabeth arden',
#  'ellis faas',
#  'emani',
#  'essence',
#  'essie',
#  'estã©e lauder',
#  'etude house',
#  'everyday minerals',
#  'eyeko',
#  'fabergã©',
#  'face atelier',
#  'fair & lovely',
#  'fairy girl',
#  'fake bake',
#  'fashionista',
#  'fenty beauty',
#  'fiona stiles',
#  'flower',
#  'forest essentials',
#  'forever living products',
#  'fourth ray beauty',
#  'gabriel cosmetics',
#  'gale hayman',
#  'gerard cosmetics',
#  'ghost',
#  'girlactik',
#  'glossier',
#  'glow recipe',
#  'gosh',
#  'grande cosmetics',
#  'hada labo',
#  'halo beauty',
#  'hard candy',
#  'haus laboratories',
#  'hello kitty',
#  'hermã¨s',
#  'holo taco',
#  'hourglass',
#  'huda beauty',
#  'hynt beauty',
#  'ilia',
#  'illamasqua',
#  'imedeen',
#  'inglot cosmetics',
#  'inika',
#  'inoherb',
#  'isadora cosmetics',
#  'it cosmetics',
#  'jaclyn hill cosmetics',
#  'jane',
#  'jane iredale',
#  'japonesque',
#  'jeffree star cosmetics',
#  'jo malone london',
#  'jordana',
#  'josie maran',
#  'jouer',
#  'juviaâ€™s place',
#  'kat von d',
#  "kiehl's",
#  'kim chi chic beauty',
#  'kjaer weis',
#  'kkw beauty',
#  'korres',
#  'kosas',
#  'kryolan',
#  'kylie cosmetics',
#  "l'oreal paris",
#  'la girl',
#  'lakmã© cosmetics',
#  'lancã´me',
#  'lashxlr8',
#  'laura mercier cosmetics',
#  'le couvent des minimes',
#  'lierac',
#  'lierac paris',
#  'lilah b.',
#  'lily lolo',
#  'lime crime',
#  'limecrime',
#  'linda hallberg',
#  'lip smacker',
#  'lit cosmetics',
#  'little miss',
#  'lotta luv beauty',
#  'lubriderm',
#  'lunar beauty',
#  'lush',
#  'mac cosmetics',
#  'madara cosmetics',
#  'madison reed',
#  'makeup geek',
#  'mandom',
#  'marc jacobs beauty',
#  'marcelle',
#  'max factor',
#  'maybelline',
#  'mehron',
#  'melt',
#  'milani',
#  'milk makeup',
#  'mineral fusion',
#  'miss sporty',
#  'nabla cosmetics',
#  'nars cosmetics',
#  'natasha denona',
#  'natura & co',
#  'natural wonder',
#  'neutrogena',
#  'new york nailcare',
#  'nivea',
#  'no. 7',
#  'nude by nature',
#  'nudestix',
#  'nyc new york color',
#  'nyx professional makeup',
#  'occ',
#  'opi products',
#  'origins',
#  'pacifica',
#  'palladio',
#  'parachute',
#  'pat mcgrath',
#  'pechoin',
#  'perfekt',
#  'physicians formula',
#  'pixi',
#  'playboy',
#  'prestige',
#  'princess pat',
#  'pupa milano',
#  'pur cosmetics',
#  'q-ki',
#  'red apple lipstick',
#  'revlon',
#  'rimmel',
#  'rituel de fille',
#  'rms beauty',
#  'rouge bunny rouge',
#  'royal cosmetics',
#  'sally hansen',
#  'sappho',
#  'schwan-stabilo',
#  'shanghai vive',
#  'shiro',
#  'shiseido',
#  'silk naturals',
#  'sk-ii',
#  'sleek',
#  'sol body',
#  'sonia kashuk',
#  'space.nk',
#  'st. tropez',
#  'stella mccartney',
#  'stila',
#  'stratton',
#  'sugarpill',
#  'surya brasil',
#  'suva beauty',
#  'tarte cosmetics',
#  'tati beauty',
#  'the body shop',
#  'the royal horticultural society',
#  'thebalm',
#  'thrive causemetics',
#  'too faced',
#  'trixie cosmetics',
#  'tropic skincare',
#  'ultima ii',
#  'urban decay',
#  'vapour',
#  'w3ll people',
#  'w7',
#  'wander beauty',
#  'wet n wild',
#  'youngblood',
#  'yves saint laurent',
#  'zoeva',
#  'zuii organic'}

# %%
df_youtubers = pd.read_csv('data/get_youtubers_output/youtubers.csv')
youtubers_set = set(df_youtubers['display_name'].values)
youtubers_set
# Out:
# {'Alissa Ashley',
#  'Amanda Ensing',
#  'Bretman Rock',
#  'Carli Bybel',
#  'Casey Holmes',
#  'Chrisspy',
#  'Christen Dominique',
#  'Claire Marshall',
#  'Cydnee Black',
#  'Desi Perkins',
#  'EMAN',
#  'Emily Noel',
#  'From Head To Toe',
#  'Ingrid Nilsen',
#  'Irene Khan (irenesarah)',
#  'Irishcel507',
#  'ItsMyRayeRaye',
#  'Jackie Aina',
#  'Jaclyn Hill',
#  'James Charles',
#  'Jessica Braun',
#  'KathleenLights',
#  'Katy',
#  'Kayleigh Noelle',
#  'Laura Lee',
#  'LearningToBeFearless',
#  'Leesha',
#  'Luhhsetty',
#  'Madison Miller',
#  'MakeupByAlli',
#  'Manny Mua',
#  'Marlena Stell',
#  'Melissa Alatorre',
#  'MonicaStyle Muse',
#  'Nabela Noor',
#  'Nicole Guerriero',
#  'Nyma Tang',
#  'Olivia Jade',
#  'PatrickStarrr',
#  'RawBeautyKristi',
#  'Roxette Arisa',
#  'Sarahy Delarosa',
#  'Sazan Hendrix',
#  'Shameless Maya',
#  'Sona Gasparian',
#  'SoothingSista',
#  'Summer Mckeen',
#  'Symphani Soto',
#  'Tati',
#  'Taylor Wynn',
#  'Teaira Walker',
#  'Teni Panosian',
#  'Thrift Thick',
#  'Vintageortacky / Cora Diane',
#  'Zabrena',
#  'danielle rae',
#  'iluvsarahii',
#  'itsjudytime',
#  'jeffreestar',
#  'maybellinenewyork'}

# %%
#preparo il counter
dict_attrs = dict()
for idx, attrs in enumerate(first_graph.nodes.values()):
    for attr in attrs.keys():
        dict_attrs.update({attr:0})

# %%
for idx, attrs in enumerate(first_graph.nodes.values()):
    print('{}/{}'.format(idx,len(first_graph.nodes)))
    clear_output(wait=True)
    for key_attr, key_value in zip (attrs.keys(),attrs.values()):
        dict_attrs[key_attr] += key_value
# Out:
# 6200/6201

# %%
rank_topics=[]
rank_brands=[]
rank_youtubers=[]
for key_item,key_value in zip (dict_attrs.keys(),dict_attrs.values()):
    if key_item in topic_set:
        rank_topics.append((key_item,key_value))
    if key_item in brand_set:
        rank_brands.append((key_item,key_value))
    if key_item in youtubers_set:
        rank_youtubers.append((key_item,key_value))

# %%
rank_topics = sorted(rank_topics, key=lambda x:x[1],reverse = True)
rank_youtubers = sorted(rank_youtubers, key=lambda x:x[1],reverse = True)
rank_brands = sorted(rank_brands, key=lambda x:x[1],reverse = True)

# %%
print("Top 3 topics: {}".format(rank_topics[:3]))
print("Top 3 youtubers: {}".format(rank_youtubers[:3]))
print("Top 3 brands: {}".format(rank_brands[:3]))
# Out:
# Top 3 topics: [('tutorial', 1144), ('review', 654), ('private life/information', 584)]
# Top 3 youtubers: [('Nyma Tang', 153), ('Nicole Guerriero', 152), ('Christen Dominique', 150)]
# Top 3 brands: [('perfekt', 1219), ('it cosmetics', 598), ('colourpop cosmetics', 348)]

# %%
assortativity_coefficients = np.load('analysis/positive/assortativity_coefficients.npy',allow_pickle=True)
assortativity_coefficients=dict(assortativity_coefficients.tolist())

# %%
print("TOPICS RANKING")
rows=[]
for idx, t in enumerate(rank_topics):
    rows.append((idx+1,t[0],assortativity_coefficients[t[0]]))
    
df =pd.DataFrame(rows, columns=["Position","Topic","Assortativity coefficient"])
df
# Out:
# TOPICS RANKING
#     Position                     Topic Assortativity coefficient
# 0          1                  tutorial        0.5254855672297947
# 1          2                    review        0.4248212389771477
# 2          3  private life/information        0.5557464703998106
# 3          4                   fashion       0.38774459822980634
# 4          5         get ready with me        0.4276902783714379
# 5          6                      hair        0.2928368331795206
# 6          7              social media       0.11654533497136642
# 7          8        new product launch        0.1686512931324108
# 8          9                 challenge       0.12456668734089153
# 9         10                     cheap     -0.001973217381186296
# 10        11                     vegan                       1.0
# 11        12                    luxury    -9.055217467666167e-05

# %%
print("YOUTUBERS RANKING")
rows=[]
for idx, t in enumerate(rank_youtubers):
    rows.append((idx+1,t[0],assortativity_coefficients[t[0]]))
    
df =pd.DataFrame(rows, columns=["Position","Youtuber","Assortativity coefficient"])
df
# Out:
# YOUTUBERS RANKING
#     Position                     Youtuber Assortativity coefficient
# 0          1                    Nyma Tang         0.938268271639038
# 1          2             Nicole Guerriero        0.7986207544955999
# 2          3           Christen Dominique        0.7652025005241786
# 3          4                  itsjudytime        0.9425630875192883
# 4          5  Vintageortacky / Cora Diane        0.9361901123764901
# 5          6                Alissa Ashley        0.9401270349635725
# 6          7                Teni Panosian        0.7798063492697369
# 7          8                  Jackie Aina        0.8766323880080795
# 8          9                  Irishcel507        0.8998285626729111
# 9         10                    Laura Lee        0.9091078921639355
# 10        11                 MakeupByAlli        0.7526671761835697
# 11        12         LearningToBeFearless        0.9019628863405132
# 12        13                 Cydnee Black        0.9536565146230138
# 13        14                Marlena Stell        0.9419828186643906
# 14        15              Claire Marshall        0.9136606053659843
# 15        16                Summer Mckeen        0.9701158706491837
# 16        17                  Jaclyn Hill        0.8819177055761802
# 17        18      Irene Khan (irenesarah)        0.9221228182720388
# 18        19                         EMAN        0.7637548879798493
# 19        20                 Casey Holmes        0.8456610736802156
# 20        21                      Zabrena        0.7779207754439037
# 21        22                James Charles        0.9645166564186317
# 22        23                Symphani Soto        0.7795789359328662
# 23        24                  iluvsarahii        0.7784554676567473
# 24        25              Sarahy Delarosa        0.7937008300448358
# 25        26               Shameless Maya        0.8251927759364562
# 26        27             Melissa Alatorre        0.8912434546695339
# 27        28                  jeffreestar        0.9503029597346306
# 28        29             From Head To Toe        0.9164867984781324
# 29        30                     Chrisspy        0.7536249758333413
# 30        31               KathleenLights        0.8390181972835038
# 31        32                PatrickStarrr        0.7886505007278226
# 32        33                Sazan Hendrix        0.9511031859462813
# 33        34                Ingrid Nilsen        0.8139409155511964
# 34        35                    Luhhsetty        0.9411103065342566
# 35        36              RawBeautyKristi        0.8721777591338916
# 36        37                Amanda Ensing        0.7440727694994356
# 37        38                   Emily Noel        0.5285758697913738
# 38        39                 Bretman Rock        0.9779833926141414
# 39        40                         Tati        0.8718547822520003
# 40        41                SoothingSista        0.9798767926514032
# 41        42               Sona Gasparian        0.7479769333811561
# 42        43                Teaira Walker         0.662887569559451
# 43        44                 Desi Perkins        0.8410176828908726
# 44        45             MonicaStyle Muse        0.7972626228221158
# 45        46                  Nabela Noor        0.9289054134531352
# 46        47                       Leesha        0.9120325391013768
# 47        48                         Katy        0.7143613544434045
# 48        49                    Manny Mua        0.9252664209127264
# 49        50                  Taylor Wynn        0.7281181862940463
# 50        51               Madison Miller        0.7372025441404539
# 51        52                  Carli Bybel        0.8209143671257118
# 52        53                 Thrift Thick        0.9021293613449126
# 53        54                Jessica Braun         0.822051534785468
# 54        55            maybellinenewyork         0.845100634824967
# 55        56                 danielle rae        0.8213832688983739
# 56        57              Kayleigh Noelle        0.7220163886308125
# 57        58                ItsMyRayeRaye        0.6475292797322124
# 58        59                Roxette Arisa         0.567013867204202
# 59        60                  Olivia Jade                       nan

# %%
print("BRANDS RANKING")
rows=[]
for idx, t in enumerate(rank_brands):
    rows.append((idx+1,t[0],assortativity_coefficients[t[0]]))
    
df =pd.DataFrame(rows, columns=["Position","Brand","Assortativity coefficient"])
df
# Out:
# BRANDS RANKING
#      Position                    Brand Assortativity coefficient
# 0           1                  perfekt        0.7955693663437021
# 1           2             it cosmetics        0.5487611354357026
# 2           3      colourpop cosmetics         0.665305920710244
# 3           4            mac cosmetics        0.6570848953060058
# 4           5  anastasia beverly hills        0.6945854844271027
# ..        ...                      ...                       ...
# 141       142              lip smacker                       nan
# 142       143                  kryolan                       nan
# 143       144              burt's bees                       nan
# 144       145            avon products                       nan
# 145       146             sonia kashuk                       nan
#
# [146 rows x 3 columns]

# %% [markdown]
# ## Famous topic communities

# %%
partition_louvain = np.load("analysis/positive/partition_louvain.npy", allow_pickle=True).tolist()

community_preferences_counter=dict()
community_preferences=dict()

for c in np.unique(list(partition_louvain.values())):
    dict_attrs = dict()
    for idx, attrs in enumerate(first_graph.nodes.values()):
        for attr in attrs.keys():
            dict_attrs.update({attr:0})
        break
    insert = False
    for key, val in zip(list(partition_louvain.keys()),list(partition_louvain.values())):
        if val == c and key not in isolates:
            insert = True
            for key_attr, key_value in zip (first_graph.nodes[key].keys(),first_graph.nodes[key].values()):
                dict_attrs[key_attr] += key_value
    if insert:
        community_preferences_counter.update({c:dict_attrs})

for c in community_preferences_counter:
    rank_topics=[]
    rank_brands=[]
    rank_youtubers=[]
    for key_item,key_value in zip (community_preferences_counter[c].keys(),community_preferences_counter[c].values()):
        if key_item in topic_set:
            rank_topics.append((key_item,key_value))
        if key_item in brand_set:
            rank_brands.append((key_item,key_value))
        if key_item in youtubers_set:
            rank_youtubers.append((key_item,key_value))
    rank_topics = sorted(rank_topics, key=lambda x:x[1],reverse = True)
    rank_youtubers = sorted(rank_youtubers, key=lambda x:x[1],reverse = True)
    rank_brands = sorted(rank_brands, key=lambda x:x[1],reverse = True)
    community_preferences.update({c:{"youtubers":rank_youtubers[:3],"topics":rank_topics[:3],"brands":rank_brands[:3]}})

# %%
counter = Counter(partition_louvain.values())
for c in community_preferences:
    print("__________________________________________________")
    print("COMMUNITY {} with {} users".format(c,counter[c]))
    print("Favourite youtubers: {}".format([item[0] for item in community_preferences[c]['youtubers'] if item[1]!=0]))
    print("Favourite topics: {}".format([item[0] for item in community_preferences[c]['topics'] if item[1]!=0]))
    print("Favourite brands: {}".format([item[0] for item in community_preferences[c]['brands'] if item[1]!=0]))
# Out:
# __________________________________________________
# COMMUNITY 3 with 189 users
# Favourite youtubers: ['Claire Marshall', 'Nabela Noor', 'itsjudytime']
# Favourite topics: ['fashion', 'private life/information', 'tutorial']
# Favourite brands: ['perfekt', 'hourglass', 'halo beauty']
# __________________________________________________
# COMMUNITY 5 with 136 users
# Favourite youtubers: ['RawBeautyKristi', 'Taylor Wynn', 'Jaclyn Hill']
# Favourite topics: ['private life/information', 'review', 'get ready with me']
# Favourite brands: ['perfekt', 'it cosmetics', 'mac cosmetics']
# __________________________________________________
# COMMUNITY 6 with 214 users
# Favourite youtubers: ['Laura Lee', 'Ingrid Nilsen', 'Christen Dominique']
# Favourite topics: ['fashion', 'tutorial', 'private life/information']
# Favourite brands: ['perfekt', 'jouer', 'it cosmetics']
# __________________________________________________
# COMMUNITY 7 with 349 users
# Favourite youtubers: ['LearningToBeFearless', 'Symphani Soto', 'ItsMyRayeRaye']
# Favourite topics: ['private life/information', 'get ready with me', 'fashion']
# Favourite brands: ['armani', 'halo beauty', 'thrive causemetics']
# __________________________________________________
# COMMUNITY 8 with 230 users
# Favourite youtubers: ['Jaclyn Hill', 'danielle rae', 'Madison Miller']
# Favourite topics: ['tutorial', 'fashion', 'get ready with me']
# Favourite brands: ['perfekt', 'it cosmetics', 'hourglass']
# __________________________________________________
# COMMUNITY 9 with 157 users
# Favourite youtubers: ['Tati', 'Carli Bybel', 'Jackie Aina']
# Favourite topics: ['fashion', 'private life/information', 'tutorial']
# Favourite brands: ['perfekt', 'tati beauty', 'anastasia beverly hills']
# __________________________________________________
# COMMUNITY 13 with 64 users
# Favourite youtubers: ['MonicaStyle Muse', 'Cydnee Black', 'Irishcel507']
# Favourite topics: ['fashion', 'tutorial', 'get ready with me']
# Favourite brands: ['colourpop cosmetics', 'it cosmetics', 'elf']
# __________________________________________________
# COMMUNITY 18 with 113 users
# Favourite youtubers: ['Zabrena', 'Taylor Wynn', 'Emily Noel']
# Favourite topics: ['tutorial', 'private life/information', 'review']
# Favourite brands: ['mac cosmetics', 'rimmel', 'perfekt']
# __________________________________________________
# COMMUNITY 19 with 150 users
# Favourite youtubers: ['Vintageortacky / Cora Diane', 'Leesha', 'KathleenLights']
# Favourite topics: ['fashion', 'tutorial', 'review']
# Favourite brands: ['urban decay', 'ciate', 'disney']
# __________________________________________________
# COMMUNITY 20 with 126 users
# Favourite youtubers: ['PatrickStarrr', 'MakeupByAlli', 'Nicole Guerriero']
# Favourite topics: ['get ready with me', 'tutorial', 'fashion']
# Favourite brands: ['perfekt', 'it cosmetics', 'nars cosmetics']
# __________________________________________________
# COMMUNITY 21 with 112 users
# Favourite youtubers: ['Jackie Aina']
# Favourite topics: ['review', 'tutorial', 'fashion']
# Favourite brands: ['too faced', 'perfekt', 'pixi']
# __________________________________________________
# COMMUNITY 22 with 119 users
# Favourite youtubers: ['Casey Holmes', 'Madison Miller', 'Jaclyn Hill']
# Favourite topics: ['review', 'tutorial', 'fashion']
# Favourite brands: ['perfekt', 'bite beauty', 'clinique']
# __________________________________________________
# COMMUNITY 29 with 200 users
# Favourite youtubers: ['MakeupByAlli', 'Teaira Walker', 'Emily Noel']
# Favourite topics: ['fashion', 'tutorial', 'review']
# Favourite brands: ['benefit cosmetics', 'rimmel', 'too faced']
# __________________________________________________
# COMMUNITY 32 with 147 users
# Favourite youtubers: ['Irene Khan (irenesarah)', 'Irishcel507', 'itsjudytime']
# Favourite topics: ['tutorial', 'hair', 'get ready with me']
# Favourite brands: ['essence', 'it cosmetics', 'perfekt']
# __________________________________________________
# COMMUNITY 33 with 69 users
# Favourite youtubers: ['Desi Perkins']
# Favourite topics: ['fashion', 'challenge', 'hair']
# Favourite brands: ['perfekt', 'the body shop', 'jaclyn hill cosmetics']
# __________________________________________________
# COMMUNITY 35 with 78 users
# Favourite youtubers: ['Shameless Maya', 'Ingrid Nilsen']
# Favourite topics: ['tutorial', 'social media']
# Favourite brands: ['nyc new york color', 'it cosmetics', 'laura mercier cosmetics']
# __________________________________________________
# COMMUNITY 39 with 105 users
# Favourite youtubers: ['Melissa Alatorre', 'EMAN', 'Nicole Guerriero']
# Favourite topics: ['tutorial', 'review', 'get ready with me']
# Favourite brands: ['it cosmetics', 'halo beauty', 'laura mercier cosmetics']
# __________________________________________________
# COMMUNITY 40 with 161 users
# Favourite youtubers: ['Nyma Tang', 'Desi Perkins', 'Katy']
# Favourite topics: ['review', 'tutorial', 'get ready with me']
# Favourite brands: ['it cosmetics', 'fenty beauty', 'anastasia beverly hills']
# __________________________________________________
# COMMUNITY 41 with 233 users
# Favourite youtubers: ['Teni Panosian', 'Katy', 'Emily Noel']
# Favourite topics: ['private life/information', 'tutorial', 'fashion']
# Favourite brands: ['colourpop cosmetics', 'benefit cosmetics', 'it cosmetics']
# __________________________________________________
# COMMUNITY 42 with 171 users
# Favourite youtubers: ['Sarahy Delarosa', 'Sona Gasparian', 'Jackie Aina']
# Favourite topics: ['tutorial', 'review', 'get ready with me']
# Favourite brands: ['it cosmetics', 'perfekt', 'armani']
# __________________________________________________
# COMMUNITY 46 with 48 users
# Favourite youtubers: ['James Charles']
# Favourite topics: ['social media', 'tutorial']
# Favourite brands: ['little miss']
# __________________________________________________
# COMMUNITY 47 with 76 users
# Favourite youtubers: ['Leesha', 'Ingrid Nilsen']
# Favourite topics: ['hair', 'review', 'private life/information']
# Favourite brands: ['too faced', 'disney', 'copycat beauty']
# __________________________________________________
# COMMUNITY 48 with 128 users
# Favourite youtubers: ['Nicole Guerriero', 'Casey Holmes', 'Madison Miller']
# Favourite topics: ['tutorial', 'review', 'hair']
# Favourite brands: ['yves saint laurent', 'korres', 'bondi sands']
# __________________________________________________
# COMMUNITY 50 with 347 users
# Favourite youtubers: ['Christen Dominique', 'EMAN', 'iluvsarahii']
# Favourite topics: ['tutorial', 'private life/information', 'review']
# Favourite brands: ['perfekt', 'it cosmetics', 'halo beauty']
# __________________________________________________
# COMMUNITY 52 with 82 users
# Favourite youtubers: ['SoothingSista', 'Claire Marshall']
# Favourite topics: ['review', 'private life/information', 'fashion']
# Favourite brands: ['ghost', 'pat mcgrath', 'perfekt']
# __________________________________________________
# COMMUNITY 58 with 95 users
# Favourite youtubers: ['Luhhsetty', 'Shameless Maya', 'Jaclyn Hill']
# Favourite topics: ['private life/information', 'hair', 'tutorial']
# Favourite brands: ['clarins', 'black radiance', 'sleek']
# __________________________________________________
# COMMUNITY 61 with 130 users
# Favourite youtubers: ['Amanda Ensing', 'Roxette Arisa', 'Irene Khan (irenesarah)']
# Favourite topics: ['private life/information', 'tutorial', 'review']
# Favourite brands: ['it cosmetics', 'mac cosmetics', 'jaclyn hill cosmetics']
# __________________________________________________
# COMMUNITY 64 with 5 users
# Favourite youtubers: ['James Charles']
# Favourite topics: ['hair']
# Favourite brands: []
# __________________________________________________
# COMMUNITY 69 with 158 users
# Favourite youtubers: ['KathleenLights', 'Kayleigh Noelle', 'Sona Gasparian']
# Favourite topics: ['tutorial', 'fashion', 'review']
# Favourite brands: ['perfekt', 'colourpop cosmetics', 'anastasia beverly hills']
# __________________________________________________
# COMMUNITY 71 with 5 users
# Favourite youtubers: ['Taylor Wynn']
# Favourite topics: ['get ready with me']
# Favourite brands: ['colourpop cosmetics', 'essie', 'laura mercier cosmetics']
# __________________________________________________
# COMMUNITY 73 with 180 users
# Favourite youtubers: ['jeffreestar', 'Manny Mua', 'Jaclyn Hill']
# Favourite topics: ['review', 'tutorial', 'new product launch']
# Favourite brands: ['it cosmetics', 'jeffree star cosmetics', 'perfekt']
# __________________________________________________
# COMMUNITY 82 with 148 users
# Favourite youtubers: ['Marlena Stell', 'Thrift Thick', 'KathleenLights']
# Favourite topics: ['tutorial', 'review', 'fashion']
# Favourite brands: ['makeup geek', 'anastasia beverly hills', 'colourpop cosmetics']
# __________________________________________________
# COMMUNITY 85 with 62 users
# Favourite youtubers: ['Bretman Rock']
# Favourite topics: ['tutorial', 'challenge', 'get ready with me']
# Favourite brands: ['milani', 'mac cosmetics']
# __________________________________________________
# COMMUNITY 86 with 133 users
# Favourite youtubers: ['Cydnee Black', 'Emily Noel']
# Favourite topics: ['tutorial', 'review', 'get ready with me']
# Favourite brands: ['mac cosmetics', 'it cosmetics', 'armani']
# __________________________________________________
# COMMUNITY 87 with 5 users
# Favourite youtubers: ['MakeupByAlli']
# Favourite topics: []
# Favourite brands: ['bite beauty', 'essie', 'it cosmetics']
# __________________________________________________
# COMMUNITY 88 with 5 users
# Favourite youtubers: ['Jaclyn Hill']
# Favourite topics: []
# Favourite brands: ['chanel', 'kylie cosmetics', 'parachute']
# __________________________________________________
# COMMUNITY 89 with 105 users
# Favourite youtubers: ['iluvsarahii', 'Katy', 'Christen Dominique']
# Favourite topics: ['review', 'fashion', 'social media']
# Favourite brands: ['it cosmetics', 'perfekt', 'halo beauty']
# __________________________________________________
# COMMUNITY 96 with 5 users
# Favourite youtubers: ['Sazan Hendrix']
# Favourite topics: ['tutorial']
# Favourite brands: ['colourpop cosmetics', 'buxom', 'tarte cosmetics']
# __________________________________________________
# COMMUNITY 100 with 144 users
# Favourite youtubers: ['Chrisspy', 'Melissa Alatorre', 'Emily Noel']
# Favourite topics: ['tutorial', 'private life/information', 'review']
# Favourite brands: ['maybelline', 'colourpop cosmetics', 'it cosmetics']
# __________________________________________________
# COMMUNITY 102 with 148 users
# Favourite youtubers: ['itsjudytime', 'Zabrena', 'Teni Panosian']
# Favourite topics: ['review', 'fashion', 'challenge']
# Favourite brands: ['maybelline', 'milani', 'physicians formula']
# __________________________________________________
# COMMUNITY 103 with 61 users
# Favourite youtubers: ['maybellinenewyork', 'Chrisspy']
# Favourite topics: ['tutorial', 'review', 'private life/information']
# Favourite brands: ['halo beauty', 'maybelline']
# __________________________________________________
# COMMUNITY 106 with 5 users
# Favourite youtubers: ['Laura Lee']
# Favourite topics: ['tutorial', 'fashion']
# Favourite brands: ['perfekt', 'jouer', 'colourpop cosmetics']
# __________________________________________________
# COMMUNITY 114 with 134 users
# Favourite youtubers: ['Irishcel507', 'Alissa Ashley', 'Chrisspy']
# Favourite topics: ['review', 'fashion', 'tutorial']
# Favourite brands: ['perfekt', 'clinique', 'it cosmetics']
# __________________________________________________
# COMMUNITY 120 with 132 users
# Favourite youtubers: ['Summer Mckeen', 'Ingrid Nilsen']
# Favourite topics: ['private life/information', 'fashion', 'hair']
# Favourite brands: ['perfekt', 'maybelline', 'nyc new york color']
# __________________________________________________
# COMMUNITY 128 with 85 users
# Favourite youtubers: ['Sazan Hendrix', 'Roxette Arisa']
# Favourite topics: ['tutorial', 'social media', 'challenge']
# Favourite brands: ['clarins', 'buxom', 'rimmel']
# __________________________________________________
# COMMUNITY 137 with 142 users
# Favourite youtubers: ['Alissa Ashley', 'PatrickStarrr', 'Teni Panosian']
# Favourite topics: ['review', 'tutorial', 'private life/information']
# Favourite brands: ['clinique', 'mac cosmetics', 'perfekt']
# __________________________________________________
# COMMUNITY 139 with 10 users
# Favourite youtubers: ['Thrift Thick', 'itsjudytime']
# Favourite topics: ['fashion', 'review', 'get ready with me']
# Favourite brands: ['milk makeup', 'charlotte tilbury', 'yves saint laurent']
# __________________________________________________
# COMMUNITY 146 with 5 users
# Favourite youtubers: ['James Charles']
# Favourite topics: ['tutorial']
# Favourite brands: []
# __________________________________________________
# COMMUNITY 163 with 5 users
# Favourite youtubers: ['Jessica Braun']
# Favourite topics: []
# Favourite brands: []
# __________________________________________________
# COMMUNITY 164 with 5 users
# Favourite youtubers: ['Taylor Wynn']
# Favourite topics: ['private life/information']
# Favourite brands: ['bite beauty', 'colourpop cosmetics', 'it cosmetics']
# __________________________________________________
# COMMUNITY 169 with 14 users
# Favourite youtubers: ['Emily Noel']
# Favourite topics: ['review', 'tutorial']
# Favourite brands: ['benefit cosmetics', 'pixi', 'colourpop cosmetics']
# __________________________________________________
# COMMUNITY 180 with 163 users
# Favourite youtubers: ['From Head To Toe', 'Jessica Braun', 'KathleenLights']
# Favourite topics: ['fashion', 'tutorial', 'private life/information']
# Favourite brands: ['bite beauty', 'the body shop', 'chanel']
# __________________________________________________
# COMMUNITY 185 with 13 users
# Favourite youtubers: ['Thrift Thick']
# Favourite topics: ['review', 'get ready with me']
# Favourite brands: ['too faced', 'charlotte tilbury', 'it cosmetics']
# __________________________________________________
# COMMUNITY 188 with 20 users
# Favourite youtubers: ['Bretman Rock']
# Favourite topics: []
# Favourite brands: []
# __________________________________________________
# COMMUNITY 244 with 10 users
# Favourite youtubers: ['Symphani Soto', 'Bretman Rock']
# Favourite topics: []
# Favourite brands: []
# __________________________________________________
# COMMUNITY 261 with 5 users
# Favourite youtubers: ['Taylor Wynn']
# Favourite topics: ['review']
# Favourite brands: ['perfekt', "l'oreal paris", 'neutrogena']
# __________________________________________________
# COMMUNITY 265 with 38 users
# Favourite youtubers: ['James Charles']
# Favourite topics: []
# Favourite brands: []
# __________________________________________________
# COMMUNITY 279 with 21 users
# Favourite youtubers: ['Thrift Thick']
# Favourite topics: ['review', 'get ready with me']
# Favourite brands: ['too faced', 'it cosmetics', 'charlotte tilbury']
# __________________________________________________
# COMMUNITY 371 with 5 users
# Favourite youtubers: ['Taylor Wynn']
# Favourite topics: []
# Favourite brands: ['physicians formula', 'it cosmetics', 'laura mercier cosmetics']
# __________________________________________________
# COMMUNITY 386 with 5 users
# Favourite youtubers: ['Nicole Guerriero']
# Favourite topics: []
# Favourite brands: ['colourpop cosmetics', 'kkw beauty', 'perfekt']
# __________________________________________________
# COMMUNITY 390 with 5 users
# Favourite youtubers: ['Zabrena']
# Favourite topics: ['review']
# Favourite brands: ['bite beauty', 'nyx professional makeup', 'covergirl']
# __________________________________________________
# COMMUNITY 393 with 5 users
# Favourite youtubers: ['itsjudytime']
# Favourite topics: []
# Favourite brands: []
# __________________________________________________
# COMMUNITY 405 with 5 users
# Favourite youtubers: ['Symphani Soto']
# Favourite topics: ['tutorial']
# Favourite brands: ['too faced', 'becca', 'yves saint laurent']
# __________________________________________________
# COMMUNITY 408 with 5 users
# Favourite youtubers: ['Taylor Wynn']
# Favourite topics: ['review']
# Favourite brands: ['colourpop cosmetics', 'essie', 'perfekt']
# __________________________________________________
# COMMUNITY 419 with 5 users
# Favourite youtubers: ['Bretman Rock']
# Favourite topics: ['fashion']
# Favourite brands: []
# __________________________________________________
# COMMUNITY 425 with 5 users
# Favourite youtubers: ['Carli Bybel']
# Favourite topics: ['private life/information']
# Favourite brands: ['bondi sands']
# __________________________________________________
# COMMUNITY 539 with 5 users
# Favourite youtubers: ['jeffreestar']
# Favourite topics: ['review']
# Favourite brands: ['kylie cosmetics']
# __________________________________________________
# COMMUNITY 541 with 5 users
# Favourite youtubers: ['MakeupByAlli']
# Favourite topics: []
# Favourite brands: []
# __________________________________________________
# COMMUNITY 548 with 5 users
# Favourite youtubers: ['James Charles']
# Favourite topics: ['challenge']
# Favourite brands: []
# __________________________________________________
# COMMUNITY 598 with 5 users
# Favourite youtubers: ['Zabrena']
# Favourite topics: ['tutorial']
# Favourite brands: ['la girl', 'colourpop cosmetics', 'rimmel']
# __________________________________________________
# COMMUNITY 610 with 5 users
# Favourite youtubers: ['Sona Gasparian']
# Favourite topics: []
# Favourite brands: ['armani', 'fenty beauty']
# __________________________________________________
# COMMUNITY 676 with 5 users
# Favourite youtubers: ['Katy']
# Favourite topics: []
# Favourite brands: ['perfekt']
# __________________________________________________
# COMMUNITY 700 with 4 users
# Favourite youtubers: ['Irene Khan (irenesarah)']
# Favourite topics: ['review']
# Favourite brands: ['bite beauty', 'perfekt', 'benefit cosmetics']
# __________________________________________________
# COMMUNITY 712 with 5 users
# Favourite youtubers: ['MakeupByAlli']
# Favourite topics: ['fashion', 'get ready with me', 'hair']
# Favourite brands: ['laura mercier cosmetics', 'flower']
# __________________________________________________
# COMMUNITY 761 with 5 users
# Favourite youtubers: ['From Head To Toe']
# Favourite topics: []
# Favourite brands: ['pixi', 'by terry']
# __________________________________________________
# COMMUNITY 795 with 5 users
# Favourite youtubers: ['Sona Gasparian']
# Favourite topics: ['tutorial']
# Favourite brands: ['armani', 'laura mercier cosmetics', 'kylie cosmetics']
# __________________________________________________
# COMMUNITY 843 with 5 users
# Favourite youtubers: ['Thrift Thick']
# Favourite topics: []
# Favourite brands: ['too faced', 'colourpop cosmetics', 'nyx professional makeup']
# __________________________________________________
# COMMUNITY 861 with 5 users
# Favourite youtubers: ['Taylor Wynn']
# Favourite topics: ['review']
# Favourite brands: ['it cosmetics', 'nars cosmetics', 'milani']
# __________________________________________________
# COMMUNITY 870 with 5 users
# Favourite youtubers: ['Nabela Noor']
# Favourite topics: []
# Favourite brands: ['huda beauty', 'fenty beauty']
# __________________________________________________
# COMMUNITY 898 with 4 users
# Favourite youtubers: ['Teni Panosian']
# Favourite topics: ['review', 'tutorial']
# Favourite brands: ['perfekt', 'dose of colors']
# __________________________________________________
# COMMUNITY 957 with 10 users
# Favourite youtubers: ['James Charles']
# Favourite topics: ['review']
# Favourite brands: ['anastasia beverly hills']
# __________________________________________________
# COMMUNITY 1141 with 5 users
# Favourite youtubers: ['Teni Panosian']
# Favourite topics: ['vegan']
# Favourite brands: []
# __________________________________________________
# COMMUNITY 1177 with 9 users
# Favourite youtubers: ['Nabela Noor']
# Favourite topics: []
# Favourite brands: ['it cosmetics']
# __________________________________________________
# COMMUNITY 1189 with 5 users
# Favourite youtubers: ['ItsMyRayeRaye']
# Favourite topics: []
# Favourite brands: ['halo beauty', 'sol body', 'elf']
# __________________________________________________
# COMMUNITY 1324 with 5 users
# Favourite youtubers: ['MakeupByAlli']
# Favourite topics: ['social media']
# Favourite brands: ['physicians formula', 'cover fx', 'becca']
# __________________________________________________
# COMMUNITY 1331 with 5 users
# Favourite youtubers: ['Zabrena', 'EMAN']
# Favourite topics: ['tutorial']
# Favourite brands: ['la girl', 'pixi', 'nyx professional makeup']
# __________________________________________________
# COMMUNITY 1346 with 5 users
# Favourite youtubers: ['James Charles']
# Favourite topics: ['private life/information']
# Favourite brands: []
# __________________________________________________
# COMMUNITY 1440 with 5 users
# Favourite youtubers: ['Desi Perkins']
# Favourite topics: ['tutorial']
# Favourite brands: ['kylie cosmetics', 'benefit cosmetics', 'mac cosmetics']
# __________________________________________________
# COMMUNITY 1465 with 5 users
# Favourite youtubers: ['Nabela Noor']
# Favourite topics: []
# Favourite brands: ['it cosmetics']
# __________________________________________________
# COMMUNITY 1517 with 5 users
# Favourite youtubers: ['Sazan Hendrix']
# Favourite topics: []
# Favourite brands: ['anastasia beverly hills', 'too faced', 'colourpop cosmetics']
# __________________________________________________
# COMMUNITY 1593 with 3 users
# Favourite youtubers: ['Emily Noel']
# Favourite topics: []
# Favourite brands: ['bite beauty', 'elf', 'revlon']
# __________________________________________________
# COMMUNITY 1893 with 5 users
# Favourite youtubers: ['Sona Gasparian']
# Favourite topics: ['tutorial']
# Favourite brands: ['glossier', 'fenty beauty', 'it cosmetics']
# __________________________________________________
# COMMUNITY 1916 with 5 users
# Favourite youtubers: ['MakeupByAlli']
# Favourite topics: ['private life/information']
# Favourite brands: ['neutrogena']
# __________________________________________________
# COMMUNITY 1973 with 4 users
# Favourite youtubers: ['Emily Noel']
# Favourite topics: []
# Favourite brands: ['revlon', 'benefit cosmetics', 'covergirl']
# __________________________________________________
# COMMUNITY 2214 with 5 users
# Favourite youtubers: ['Thrift Thick', 'Katy']
# Favourite topics: ['review']
# Favourite brands: ['too faced', 'colourpop cosmetics', 'makeup geek']
# __________________________________________________
# COMMUNITY 2621 with 2 users
# Favourite youtubers: ['Nabela Noor']
# Favourite topics: ['get ready with me']
# Favourite brands: ['perfekt', 'anastasia beverly hills', 'too faced']
# __________________________________________________
# COMMUNITY 2796 with 5 users
# Favourite youtubers: ['James Charles']
# Favourite topics: []
# Favourite brands: []
# __________________________________________________
# COMMUNITY 3015 with 5 users
# Favourite youtubers: ['Emily Noel']
# Favourite topics: ['fashion']
# Favourite brands: ['benefit cosmetics', 'covergirl', 'bobbi brown']

# %% [markdown]
# ## Possible overlapping communities

# %%
overlapping_matrix= []
for c_1 in community_preferences:
    yt_1 = [item[0] for item in community_preferences[c_1]['youtubers'] if item[1]!=0]
    tp_1 = [item[0] for item in community_preferences[c_1]['topics'] if item[1]!=0]
    br_1 = [item[0] for item in community_preferences[c_1]['brands'] if item[1]!=0]
    overlapping_matrix.append([])
    for c_2 in community_preferences:
        yt_2 = [item[0] for item in community_preferences[c_2]['youtubers'] if item[1]!=0]
        tp_2 = [item[0] for item in community_preferences[c_2]['topics'] if item[1]!=0]
        br_2 = [item[0] for item in community_preferences[c_2]['brands'] if item[1]!=0]
        over = (len(set(yt_1).intersection(set(yt_2)))+len(set(tp_1).intersection(set(tp_2)))+len(set(br_1).intersection(set(br_2))))/(len(set(yt_1).union(set(yt_2)))+len(set(tp_1).union(set(tp_2)))+len(set(br_1).union(set(br_2))))
        overlapping_matrix[-1].append(over)

# %%
keys = community_preferences.keys()
workbook = xlsxwriter.Workbook('analysis/positive/overlapping_matrix.xlsx') 
worksheet = workbook.add_worksheet('Overlapping matrix') 
currency_format = workbook.add_format({'num_format': '0.00'})
cell_format_yellow = workbook.add_format()
cell_format_yellow.set_bg_color('yellow')
cell_format_yellow.set_num_format('0.00')
cell_format_red = workbook.add_format()
cell_format_red.set_bg_color('red')
cell_format_red.set_num_format('0.00')
for idx,val in enumerate(keys):
    worksheet.write(0, idx+1,val)
    worksheet.write(idx+1,0,val)
for row_idx, row in enumerate(overlapping_matrix):
    for col_idx, col in enumerate(overlapping_matrix):
        if overlapping_matrix[row_idx][col_idx] >=0.5 and overlapping_matrix[row_idx][col_idx] < 0.8:
            worksheet.write(row_idx+1, col_idx+1,overlapping_matrix[row_idx][col_idx],cell_format_yellow)
        elif overlapping_matrix[row_idx][col_idx] >=0.8:
            worksheet.write(row_idx+1, col_idx+1,overlapping_matrix[row_idx][col_idx],cell_format_red)
        else:
            worksheet.write(row_idx+1, col_idx+1,overlapping_matrix[row_idx][col_idx],currency_format)
workbook.close()
