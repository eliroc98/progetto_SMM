# %%
import pandas as pd

import os

import numpy as np

import tensorflow_hub as hub
import tensorflow as tf
from tensorflow import keras

from IPython.display import clear_output

# %%
last_csv = int(np.load('data/get_comment_threads_output/last_csv.npy'))

# %%
file_index = 0

# %%
df_comments = pd.read_csv('data/get_comment_threads_output/df_comment_thread_{}.csv'.format(last_csv))

# %%
df_comments
# Out:
#             video_id           comment_thread_id        top_level_comment_id  \
# 0        WyUyJKm-MiY  UgxmeuEGKaTnjr18AVZ4AaABAg  UgxmeuEGKaTnjr18AVZ4AaABAg
# 1        WyUyJKm-MiY  UgzlwPwyC3XlmzgzBr54AaABAg  UgzlwPwyC3XlmzgzBr54AaABAg
# 2        WyUyJKm-MiY  UgynycPfXmKJePLzAEp4AaABAg  UgynycPfXmKJePLzAEp4AaABAg
# 3        WyUyJKm-MiY  UgwamwomyWMY8bpiPjp4AaABAg  UgwamwomyWMY8bpiPjp4AaABAg
# 4        WyUyJKm-MiY  Ugx7NWDtnzTkeACe5yJ4AaABAg  Ugx7NWDtnzTkeACe5yJ4AaABAg
# ...              ...                         ...                         ...
# 2056377  lOIFYf3sSnw  Ugw50lN281elkmpu2014AaABAg  Ugw50lN281elkmpu2014AaABAg
# 2056378  lOIFYf3sSnw  Ugx0MzMiJfba86UFRBp4AaABAg  Ugx0MzMiJfba86UFRBp4AaABAg
# 2056379  lOIFYf3sSnw  UgzRG-y0DoBkLtpLl1J4AaABAg  UgzRG-y0DoBkLtpLl1J4AaABAg
# 2056380  lOIFYf3sSnw  UgwgoR1qaPAv3NPtEih4AaABAg  UgwgoR1qaPAv3NPtEih4AaABAg
# 2056381  lOIFYf3sSnw  UgyISvh5VI0F6SYtawl4AaABAg  UgyISvh5VI0F6SYtawl4AaABAg
#
#         author_display_name         author_channel_id  \
# 0              Imaan Jaffri  UCX6Ub2LzGnU6qjXVDS47EdQ
# 1               Karlee Nash  UCB9XxMYxVDoeLLVzf8M5M8A
# 2              Bernice Ayer  UC_FRgaHgKVLno4V_1iA3rlA
# 3             Molly Seymour  UCAn0o15lbsbLudv6J3hO3Kw
# 4         Charbonelle Weese  UC4Qnz1VN47C4rqXSYT7Nj8g
# ...                     ...                       ...
# 2056377           Lovely .A  UCQlbYd6E5ttfF60VOQrh60g
# 2056378      Diana Thompson  UCRw9Um0-V_84eBgt56hVJfg
# 2056379                AA W  UCn47Oo7c8MRtrlUXbAW4JYA
# 2056380      Brianna Taylor  UCeTugksWfd72bshf3HDBq8g
# 2056381          SimplyRach  UCTcsiYTBJcaTv35eGxGWIvg
#
#                                              text_original
# 0        After listening to that podcast... Nathan dodg...
# 1                     Jeffree:Eyebrows never heard of her😂
# 2                                                   Hi bae
# 3        Jeffree: WTF I HAVE SOO Many subs!\nMe: i have...
# 4              Love the wig! Looking beautiful as always 😍
# ...                                                    ...
# 2056377  I have a pimple in the same place I feel speci...
# 2056378  Wooiiiii now listen Jackie , there was no need...
# 2056379  After 2 kids, Jackie is bad for my bladder 😂😂😂...
# 2056380  The talking pimple got you a foreverrrr subscr...
# 2056381  No cheese? 🤔🤔🤔 That must be some Cali stuff bc...
#
# [2056382 rows x 6 columns]

# %%
model = tf.keras.models.load_model('sentiment_analysis_model.h5',custom_objects={'KerasLayer':hub.KerasLayer})

# %%
#fai counter
def compute_sentiment(df):
    total_predictions = []
    dataset = tf.data.Dataset.from_tensor_slices(df['text_original'])
    dataset = dataset.batch(32).prefetch(1)
    idx=0
    for item in dataset:
        predictions = model.predict(item)
        for pred in predictions:
            print('Comment: {}/{}'.format(idx,len(df.values)))
            clear_output(wait=True)
            idx+=1
            total_predictions.append(1 if pred>=0.5 else 0)
    df_computed = df.copy()
    df_computed = df_computed.assign(sentiment=pd.Series(total_predictions))
    return df_computed

# %%
df_sentiment = compute_sentiment(df_comments)
# Out:
# Comment: 2056381/2056382

# %%
df_sentiment
# Out:
#             video_id           comment_thread_id        top_level_comment_id  \
# 0        WyUyJKm-MiY  UgxmeuEGKaTnjr18AVZ4AaABAg  UgxmeuEGKaTnjr18AVZ4AaABAg
# 1        WyUyJKm-MiY  UgzlwPwyC3XlmzgzBr54AaABAg  UgzlwPwyC3XlmzgzBr54AaABAg
# 2        WyUyJKm-MiY  UgynycPfXmKJePLzAEp4AaABAg  UgynycPfXmKJePLzAEp4AaABAg
# 3        WyUyJKm-MiY  UgwamwomyWMY8bpiPjp4AaABAg  UgwamwomyWMY8bpiPjp4AaABAg
# 4        WyUyJKm-MiY  Ugx7NWDtnzTkeACe5yJ4AaABAg  Ugx7NWDtnzTkeACe5yJ4AaABAg
# ...              ...                         ...                         ...
# 2056377  lOIFYf3sSnw  Ugw50lN281elkmpu2014AaABAg  Ugw50lN281elkmpu2014AaABAg
# 2056378  lOIFYf3sSnw  Ugx0MzMiJfba86UFRBp4AaABAg  Ugx0MzMiJfba86UFRBp4AaABAg
# 2056379  lOIFYf3sSnw  UgzRG-y0DoBkLtpLl1J4AaABAg  UgzRG-y0DoBkLtpLl1J4AaABAg
# 2056380  lOIFYf3sSnw  UgwgoR1qaPAv3NPtEih4AaABAg  UgwgoR1qaPAv3NPtEih4AaABAg
# 2056381  lOIFYf3sSnw  UgyISvh5VI0F6SYtawl4AaABAg  UgyISvh5VI0F6SYtawl4AaABAg
#
#         author_display_name         author_channel_id  \
# 0              Imaan Jaffri  UCX6Ub2LzGnU6qjXVDS47EdQ
# 1               Karlee Nash  UCB9XxMYxVDoeLLVzf8M5M8A
# 2              Bernice Ayer  UC_FRgaHgKVLno4V_1iA3rlA
# 3             Molly Seymour  UCAn0o15lbsbLudv6J3hO3Kw
# 4         Charbonelle Weese  UC4Qnz1VN47C4rqXSYT7Nj8g
# ...                     ...                       ...
# 2056377           Lovely .A  UCQlbYd6E5ttfF60VOQrh60g
# 2056378      Diana Thompson  UCRw9Um0-V_84eBgt56hVJfg
# 2056379                AA W  UCn47Oo7c8MRtrlUXbAW4JYA
# 2056380      Brianna Taylor  UCeTugksWfd72bshf3HDBq8g
# 2056381          SimplyRach  UCTcsiYTBJcaTv35eGxGWIvg
#
#                                              text_original  sentiment
# 0        After listening to that podcast... Nathan dodg...          0
# 1                     Jeffree:Eyebrows never heard of her😂          0
# 2                                                   Hi bae          1
# 3        Jeffree: WTF I HAVE SOO Many subs!\nMe: i have...          1
# 4              Love the wig! Looking beautiful as always 😍          0
# ...                                                    ...        ...
# 2056377  I have a pimple in the same place I feel speci...          1
# 2056378  Wooiiiii now listen Jackie , there was no need...          1
# 2056379  After 2 kids, Jackie is bad for my bladder 😂😂😂...          0
# 2056380  The talking pimple got you a foreverrrr subscr...          0
# 2056381  No cheese? 🤔🤔🤔 That must be some Cali stuff bc...          0
#
# [2056382 rows x 7 columns]

# %%
#seleziono video_id,top_level_comment_id,author_display_name,sentiment

# %%
df_sentiment_reduced = df_sentiment[df_sentiment.columns[[0,2,3,6]]]
df_sentiment_reduced
# Out:
#             video_id        top_level_comment_id author_display_name  \
# 0        WyUyJKm-MiY  UgxmeuEGKaTnjr18AVZ4AaABAg        Imaan Jaffri
# 1        WyUyJKm-MiY  UgzlwPwyC3XlmzgzBr54AaABAg         Karlee Nash
# 2        WyUyJKm-MiY  UgynycPfXmKJePLzAEp4AaABAg        Bernice Ayer
# 3        WyUyJKm-MiY  UgwamwomyWMY8bpiPjp4AaABAg       Molly Seymour
# 4        WyUyJKm-MiY  Ugx7NWDtnzTkeACe5yJ4AaABAg   Charbonelle Weese
# ...              ...                         ...                 ...
# 2056377  lOIFYf3sSnw  Ugw50lN281elkmpu2014AaABAg           Lovely .A
# 2056378  lOIFYf3sSnw  Ugx0MzMiJfba86UFRBp4AaABAg      Diana Thompson
# 2056379  lOIFYf3sSnw  UgzRG-y0DoBkLtpLl1J4AaABAg                AA W
# 2056380  lOIFYf3sSnw  UgwgoR1qaPAv3NPtEih4AaABAg      Brianna Taylor
# 2056381  lOIFYf3sSnw  UgyISvh5VI0F6SYtawl4AaABAg          SimplyRach
#
#          sentiment
# 0                0
# 1                0
# 2                1
# 3                1
# 4                0
# ...            ...
# 2056377          1
# 2056378          1
# 2056379          0
# 2056380          0
# 2056381          0
#
# [2056382 rows x 4 columns]

# %%
df_sentiment.to_csv('data/get_comment_threads_output/comments_thread_sentiment_complete_{}.csv'.format(file_index), index = False)
df_sentiment_reduced.to_csv('data/get_videos_details/comments_thread_sentiment_reduced_{}.csv'.format(file_index), index = False)
