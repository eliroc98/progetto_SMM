# %%
import pandas as pd

import requests 

import os

import json

import googleapiclient.discovery
import googleapiclient.errors

import numpy as np

# %%
chiave_yt = json.load(open('key.json', 'r'))['youtube']['key'][0]
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=chiave_yt)

# %%
#insert initial quota value
quota = 0

# %%
df_videos = pd.read_csv('data/get_youtuber_videos_output/youtuber_videos.csv')

# %%
def get_infos(response):
    info_comment_list=[]
    video_id=next_page_token = thread_comment_id = top_level_comment_id = author_display_name = author_channel_id = author_channel_id = text_original=None
    try:
        next_page_token = response['nextPageToken']
    except KeyError as e:
        #print(response)
        next_page_token = None
        print('Page token non esistente')
    items = response['items']
    for item in items:
        thread_comment_id = item['id']
        try:
            video_id = item['snippet']['videoId']
            top_level_comment = item['snippet']['topLevelComment']
            top_level_comment_id = top_level_comment['id']
            top_level_comment_snippet = top_level_comment['snippet']
            author_display_name = top_level_comment_snippet['authorDisplayName']
            text_original = top_level_comment_snippet['textOriginal']
            author_channel_id = top_level_comment_snippet['authorChannelId']['value']
        except KeyError as e:
            print(e.args[0])
            print('Problem with commentThread {}'.format(thread_comment_id))
        info_comment_list.append([video_id,thread_comment_id,top_level_comment_id,author_display_name,author_channel_id,text_original])
    return next_page_token, info_comment_list

# %%
#############################################################################

# %%
#round 1
#la prossima volta togli e decommenta quello sotto

# %%
last_csv = int(np.load('data/get_comment_threads_output/last_csv.npy'))
next_page_token = str(np.load('data/get_comment_threads_output/next_page_token.npy'))
last_video_idx = int(np.load('data/get_comment_threads_output/video_to_start.npy'))
videos_not_finished = (np.load('data/get_comment_threads_output/videos_not_finished.npy')).tolist()
videos_disabled_comments = (np.load('data/get_comment_threads_output/videos_disabled_comments.npy')).tolist()
print("Starting with video #{}, next_page_token: {}".format(last_video_idx,next_page_token))
print("Writing on {} csv".format(last_csv+1))
# Out:
# Starting with video #409, next_page_token: QURTSl9pMl9FSF9GQTlJekVfNmN6OVd2bHVLdUtWODNRQnhkSlgzc2dXMFdWMUxqS0VhbnJyR01TZURQV0dydEtOVXE2QUlZOHM0cjBYWmpRMGxLM2NZamRSc0FSWk4zSjI2RjZQREJ3WGlsSWpLekx1SmJ2dy1ady1nbVhDdXZlMF9MZXZRd3BtUlBUTGM=
# Writing on 1 csv

# %%
df_videos_0 = df_videos[last_video_idx:]

# %%
#per i video con più di 10000 commenti, salvo l'indice del video con il next page token

# %%
comments = []
comments_count = 0

# %%
df_videos_0
# Out:
#                     channel_id     video_id
# 409   UCzJIliq68IHSn-Kwgjeg2AQ  lOIFYf3sSnw
# 410   UCzJIliq68IHSn-Kwgjeg2AQ  mTLdodmyDn4
# 411   UCzJIliq68IHSn-Kwgjeg2AQ  TabnUbhkexU
# 412   UCzJIliq68IHSn-Kwgjeg2AQ  HTLM_Qgujvw
# 413   UCzJIliq68IHSn-Kwgjeg2AQ  9ijqGhmlOLA
# ...                        ...          ...
# 2588  UCq7EY7H2XF6TV7Z5mLv-aNg  bm-3Qrr7EUA
# 2589  UCq7EY7H2XF6TV7Z5mLv-aNg  hkxRjDS_Cjw
# 2590  UCq7EY7H2XF6TV7Z5mLv-aNg  8kElrRAa1ws
# 2591  UCq7EY7H2XF6TV7Z5mLv-aNg  7x6tX5T7LOs
# 2592  UCq7EY7H2XF6TV7Z5mLv-aNg  NSdUFKOkKnc
#
# [2184 rows x 2 columns]

# %%
for video in df_videos_0['video_id'].values:
    print('________________________________________________________')
    print('{} video: {}'.format(last_video_idx, video))
    video_comments_count = 0
    while next_page_token != None and video_comments_count<10000:
        print('Reached quotas: {}'.format(quota))
        if quota > 9900:
            print('Quota exceeded')
            break
        else:
            request = youtube.commentThreads().list(
                part="snippet",
                maxResults=100,
                pageToken=next_page_token,
                videoId=video
            )
            try:
                response = request.execute()
                quota += 3
                next_page_token, results = get_infos(response)
                video_comments_count+=len(results)
                comments_count+=video_comments_count
                comments.append(results)
            except:
                videos_disabled_comments.append(video)
                next_page_token = None
                print('Video has disabled comments')
    if quota > 9900:
        break
    if next_page_token == None or video_comments_count>=10000:
        if next_page_token != None:
            print('Reached max comment count')
            videos_not_finished.append([video, next_page_token])
        last_video_idx += 1
        next_page_token = ' '
        print('Total comments for {}: {}'.format(video, video_comments_count))

print("Done with {} comments, video to start: {}\n with next_page_token: {}".format(comments_count,last_video_idx, next_page_token))
# Out:
# ________________________________________________________
# 409 video: lOIFYf3sSnw
# Reached quotas: 0
# Reached quotas: 3
# Reached quotas: 6
# Reached quotas: 9
# Reached quotas: 12
# Reached quotas: 15
# Reached quotas: 18
# Reached quotas: 21
# Reached quotas: 24
# Reached quotas: 27
# Reached quotas: 30
# Page token non esistente
# Total comments for lOIFYf3sSnw: 1070
# ________________________________________________________
# 410 video: mTLdodmyDn4
# Reached quotas: 33
# Reached quotas: 36
# Reached quotas: 39
# Reached quotas: 42
# Reached quotas: 45
# Reached quotas: 48
# Reached quotas: 51
# Reached quotas: 54
# Reached quotas: 57
# Reached quotas: 60
# Reached quotas: 63
# Reached quotas: 66
# Reached quotas: 69
# Reached quotas: 72
# Reached quotas: 75
# Reached quotas: 78
# Page token non esistente
# Total comments for mTLdodmyDn4: 1558
# ________________________________________________________
# 411 video: TabnUbhkexU
# Reached quotas: 81
# Reached quotas: 84
# Reached quotas: 87
# Reached quotas: 90
# Reached quotas: 93
# Reached quotas: 96
# Reached quotas: 99
# Reached quotas: 102
# Reached quotas: 105
# Reached quotas: 108
# Reached quotas: 111
# Page token non esistente
# Total comments for TabnUbhkexU: 1023
# ________________________________________________________
# 412 video: HTLM_Qgujvw
# Reached quotas: 114
# Reached quotas: 117
# Reached quotas: 120
# Reached quotas: 123
# Reached quotas: 126
# Reached quotas: 129
# Reached quotas: 132
# Reached quotas: 135
# Reached quotas: 138
# Reached quotas: 141
# Reached quotas: 144
# Reached quotas: 147
# Reached quotas: 150
# Reached quotas: 153
# Reached quotas: 156
# Page token non esistente
# Total comments for HTLM_Qgujvw: 1446
# ________________________________________________________
# 413 video: 9ijqGhmlOLA
# Reached quotas: 159
# Reached quotas: 162
# Reached quotas: 165
# Reached quotas: 168
# Reached quotas: 171
# Reached quotas: 174
# Reached quotas: 177
# Reached quotas: 180
# Reached quotas: 183
# Reached quotas: 186
# Reached quotas: 189
# Reached quotas: 192
# Reached quotas: 195
# Reached quotas: 198
# Reached quotas: 201
# Reached quotas: 204
# Reached quotas: 207
# Reached quotas: 210
# Reached quotas: 213
# Page token non esistente
# Total comments for 9ijqGhmlOLA: 1883
# ________________________________________________________
# 414 video: iusd9m4q0AE
# Reached quotas: 216
# Reached quotas: 219
# Reached quotas: 222
# Reached quotas: 225
# Reached quotas: 228
# Reached quotas: 231
# Reached quotas: 234
# Reached quotas: 237
# Reached quotas: 240
# Reached quotas: 243
# Reached quotas: 246
# Reached quotas: 249
# Reached quotas: 252
# Reached quotas: 255
# Reached quotas: 258
# Reached quotas: 261
# Reached quotas: 264
# Reached quotas: 267
# Reached quotas: 270
# Reached quotas: 273
# Reached quotas: 276
# Reached quotas: 279
# Reached quotas: 282
# Reached quotas: 285
# Reached quotas: 288
# Reached quotas: 291
# Reached quotas: 294
# Reached quotas: 297
# Reached quotas: 300
# Reached quotas: 303
# Reached quotas: 306
# Reached quotas: 309
# Reached quotas: 312
# Reached quotas: 315
# Reached quotas: 318
# Reached quotas: 321
# Reached quotas: 324
# Reached quotas: 327
# Reached quotas: 330
# Reached quotas: 333
# Reached quotas: 336
# Reached quotas: 339
# Reached quotas: 342
# Reached quotas: 345
# Reached quotas: 348
# Reached quotas: 351
# Reached quotas: 354
# Reached quotas: 357
# Reached quotas: 360
# Reached quotas: 363
# Reached quotas: 366
# Reached quotas: 369
# Reached quotas: 372
# Reached quotas: 375
# Reached quotas: 378
# Reached quotas: 381
# Reached quotas: 384
# Reached quotas: 387
# Reached quotas: 390
# Reached quotas: 393
# Reached quotas: 396
# Reached quotas: 399
# Reached quotas: 402
# Reached quotas: 405
# Reached quotas: 408
# Reached quotas: 411
# Reached quotas: 414
# Reached quotas: 417
# Reached quotas: 420
# Reached quotas: 423
# Reached quotas: 426
# Reached quotas: 429
# Reached quotas: 432
# Reached quotas: 435
# Reached quotas: 438
# Reached quotas: 441
# Reached quotas: 444
# Reached quotas: 447
# Reached quotas: 450
# Reached quotas: 453
# Reached quotas: 456
# Reached quotas: 459
# Reached quotas: 462
# Reached quotas: 465
# Reached quotas: 468
# Reached quotas: 471
# Reached quotas: 474
# Reached quotas: 477
# Page token non esistente
# Total comments for iusd9m4q0AE: 8780
# ________________________________________________________
# 415 video: k_26RjEuhSs
# Reached quotas: 480
# Reached quotas: 483
# Reached quotas: 486
# Reached quotas: 489
# Reached quotas: 492
# Reached quotas: 495
# Reached quotas: 498
# Reached quotas: 501
# Reached quotas: 504
# Reached quotas: 507
# Reached quotas: 510
# Reached quotas: 513
# Reached quotas: 516
# Reached quotas: 519
# Reached quotas: 522
# Reached quotas: 525
# Page token non esistente
# Total comments for k_26RjEuhSs: 1571
# ________________________________________________________
# 416 video: GjtpDEiSNyM
# Reached quotas: 528
# Reached quotas: 531
# Reached quotas: 534
# Reached quotas: 537
# Reached quotas: 540
# Reached quotas: 543
# Reached quotas: 546
# Reached quotas: 549
# Page token non esistente
# Total comments for GjtpDEiSNyM: 766
# ________________________________________________________
# 417 video: Akp-RR0pJk4
# Reached quotas: 552
# Reached quotas: 555
# Reached quotas: 558
# Reached quotas: 561
# Reached quotas: 564
# Reached quotas: 567
# Reached quotas: 570
# Reached quotas: 573
# Reached quotas: 576
# Reached quotas: 579
# Reached quotas: 582
# Reached quotas: 585
# Reached quotas: 588
# Reached quotas: 591
# Reached quotas: 594
# Reached quotas: 597
# Reached quotas: 600
# Reached quotas: 603
# Reached quotas: 606
# Reached quotas: 609
# Reached quotas: 612
# Reached quotas: 615
# Reached quotas: 618
# Reached quotas: 621
# Reached quotas: 624
# Page token non esistente
# Total comments for Akp-RR0pJk4: 2471
# ________________________________________________________
# 418 video: frIIX3u_95s
# Reached quotas: 627
# Reached quotas: 630
# Reached quotas: 633
# Reached quotas: 636
# Reached quotas: 639
# Reached quotas: 642
# Reached quotas: 645
# Reached quotas: 648
# Reached quotas: 651
# Reached quotas: 654
# Reached quotas: 657
# Reached quotas: 660
# Reached quotas: 663
# Reached quotas: 666
# Reached quotas: 669
# Reached quotas: 672
# Reached quotas: 675
# Reached quotas: 678
# Reached quotas: 681
# Reached quotas: 684
# Reached quotas: 687
# Page token non esistente
# Total comments for frIIX3u_95s: 2042
# ________________________________________________________
# 419 video: gWYgNMuhHao
# Reached quotas: 690
# Reached quotas: 693
# Reached quotas: 696
# Reached quotas: 699
# Reached quotas: 702
# Reached quotas: 705
# Reached quotas: 708
# Reached quotas: 711
# Reached quotas: 714
# Reached quotas: 717
# Reached quotas: 720
# Reached quotas: 723
# Reached quotas: 726
# Reached quotas: 729
# Reached quotas: 732
# Reached quotas: 735
# Reached quotas: 738
# Reached quotas: 741
# Reached quotas: 744
# Reached quotas: 747
# Reached quotas: 750
# Page token non esistente
# Total comments for gWYgNMuhHao: 2057
# ________________________________________________________
# 420 video: TqpCke-u95c
# Reached quotas: 753
# Reached quotas: 756
# Reached quotas: 759
# Reached quotas: 762
# Reached quotas: 765
# Reached quotas: 768
# Reached quotas: 771
# Reached quotas: 774
# Reached quotas: 777
# Reached quotas: 780
# Reached quotas: 783
# Reached quotas: 786
# Reached quotas: 789
# Reached quotas: 792
# Reached quotas: 795
# Reached quotas: 798
# Reached quotas: 801
# Page token non esistente
# Total comments for TqpCke-u95c: 1652
# ________________________________________________________
# 421 video: 4xk5NsfmnOc
# Reached quotas: 804
# Reached quotas: 807
# Reached quotas: 810
# Reached quotas: 813
# Reached quotas: 816
# Reached quotas: 819
# Reached quotas: 822
# Reached quotas: 825
# Reached quotas: 828
# Reached quotas: 831
# Reached quotas: 834
# Reached quotas: 837
# Reached quotas: 840
# Reached quotas: 843
# Reached quotas: 846
# Reached quotas: 849
# Reached quotas: 852
# Reached quotas: 855
# Reached quotas: 858
# Page token non esistente
# Total comments for 4xk5NsfmnOc: 1886
# ________________________________________________________
# 422 video: zCO_S07UTSY
# Reached quotas: 861
# Reached quotas: 864
# Reached quotas: 867
# Reached quotas: 870
# Reached quotas: 873
# Reached quotas: 876
# Reached quotas: 879
# Reached quotas: 882
# Reached quotas: 885
# Reached quotas: 888
# Reached quotas: 891
# Reached quotas: 894
# Reached quotas: 897
# Reached quotas: 900
# Reached quotas: 903
# Reached quotas: 906
# Reached quotas: 909
# Reached quotas: 912
# Reached quotas: 915
# Reached quotas: 918
# Reached quotas: 921
# Reached quotas: 924
# Reached quotas: 927
# Reached quotas: 930
# Reached quotas: 933
# Reached quotas: 936
# Page token non esistente
# Total comments for zCO_S07UTSY: 2545
# ________________________________________________________
# 423 video: Pj_n-SeQ0eQ
# Reached quotas: 939
# Reached quotas: 942
# Reached quotas: 945
# Reached quotas: 948
# Reached quotas: 951
# Reached quotas: 954
# Reached quotas: 957
# Reached quotas: 960
# Reached quotas: 963
# Reached quotas: 966
# Reached quotas: 969
# Reached quotas: 972
# Reached quotas: 975
# Reached quotas: 978
# Reached quotas: 981
# Reached quotas: 984
# Reached quotas: 987
# Reached quotas: 990
# Reached quotas: 993
# Reached quotas: 996
# Reached quotas: 999
# Reached quotas: 1002
# Reached quotas: 1005
# Reached quotas: 1008
# Reached quotas: 1011
# Reached quotas: 1014
# Reached quotas: 1017
# Reached quotas: 1020
# Page token non esistente
# Total comments for Pj_n-SeQ0eQ: 2728
# ________________________________________________________
# 424 video: 4o_wtihWlnc
# Reached quotas: 1023
# Reached quotas: 1026
# Reached quotas: 1029
# Reached quotas: 1032
# Reached quotas: 1035
# Page token non esistente
# authorChannelId
# Problem with commentThread Ugw79r6N3h-xTP3oEUB4AaABAg
# authorChannelId
# Problem with commentThread UgyTc7i3Y3nY8QffmQ14AaABAg
# Total comments for 4o_wtihWlnc: 468
# ________________________________________________________
# 425 video: 03Vgs2_SRxk
# Reached quotas: 1038
# Reached quotas: 1041
# Reached quotas: 1044
# Page token non esistente
# Total comments for 03Vgs2_SRxk: 290
# ________________________________________________________
# 426 video: gfKcCkz2T0E
# Reached quotas: 1047
# Reached quotas: 1050
# Reached quotas: 1053
# Reached quotas: 1056
# Reached quotas: 1059
# Reached quotas: 1062
# Reached quotas: 1065
# Reached quotas: 1068
# Page token non esistente
# Total comments for gfKcCkz2T0E: 703
# ________________________________________________________
# 427 video: BR5TYc6Wb4E
# Reached quotas: 1071
# authorChannelId
# Problem with commentThread Ugz6Xe9goBF59efqh9V4AaABAg
# Reached quotas: 1074
# Reached quotas: 1077
# Reached quotas: 1080
# Reached quotas: 1083
# Page token non esistente
# Total comments for BR5TYc6Wb4E: 498
# ________________________________________________________
# 428 video: Gw873D150ck
# Reached quotas: 1086
# Reached quotas: 1089
# Reached quotas: 1092
# Reached quotas: 1095
# Reached quotas: 1098
# Page token non esistente
# Total comments for Gw873D150ck: 429
# ________________________________________________________
# 429 video: xBR-5dAbNKs
# Reached quotas: 1101
# Reached quotas: 1104
# Reached quotas: 1107
# Reached quotas: 1110
# Reached quotas: 1113
# Reached quotas: 1116
# Reached quotas: 1119
# Reached quotas: 1122
# Reached quotas: 1125
# Reached quotas: 1128
# Reached quotas: 1131
# Page token non esistente
# Total comments for xBR-5dAbNKs: 1060
# ________________________________________________________
# 430 video: t5RjN6LF4eA
# Reached quotas: 1134
# Reached quotas: 1137
# Reached quotas: 1140
# Reached quotas: 1143
# Reached quotas: 1146
# Reached quotas: 1149
# Reached quotas: 1152
# Page token non esistente
# Total comments for t5RjN6LF4eA: 615
# ________________________________________________________
# 431 video: dqxwGNCHugI
# Reached quotas: 1155
# Reached quotas: 1158
# Reached quotas: 1161
# Reached quotas: 1164
# Reached quotas: 1167
# Page token non esistente
# Total comments for dqxwGNCHugI: 430
# ________________________________________________________
# 432 video: mi3KVs2xHrc
# Reached quotas: 1170
# Reached quotas: 1173
# Reached quotas: 1176
# Reached quotas: 1179
# Reached quotas: 1182
# Reached quotas: 1185
# Page token non esistente
# Total comments for mi3KVs2xHrc: 545
# ________________________________________________________
# 433 video: ukfGhnJ0lQc
# Reached quotas: 1188
# Reached quotas: 1191
# Reached quotas: 1194
# Reached quotas: 1197
# Reached quotas: 1200
# Reached quotas: 1203
# Reached quotas: 1206
# Reached quotas: 1209
# Reached quotas: 1212
# Reached quotas: 1215
# Reached quotas: 1218
# Reached quotas: 1221
# Page token non esistente
# Total comments for ukfGhnJ0lQc: 1128
# ________________________________________________________
# 434 video: G7vF6Ni02OE
# Reached quotas: 1224
# Reached quotas: 1227
# Reached quotas: 1230
# Reached quotas: 1233
# Reached quotas: 1236
# Reached quotas: 1239
# Reached quotas: 1242
# Reached quotas: 1245
# Page token non esistente
# Total comments for G7vF6Ni02OE: 771
# ________________________________________________________
# 435 video: 7adNdp3GNuY
# Reached quotas: 1248
# Reached quotas: 1251
# Reached quotas: 1254
# Reached quotas: 1257
# Reached quotas: 1260
# Reached quotas: 1263
# Page token non esistente
# Total comments for 7adNdp3GNuY: 501
# ________________________________________________________
# 436 video: Yarv54M89-8
# Reached quotas: 1266
# Reached quotas: 1269
# Reached quotas: 1272
# Reached quotas: 1275
# Reached quotas: 1278
# Reached quotas: 1281
# Page token non esistente
# Total comments for Yarv54M89-8: 509
# ________________________________________________________
# 437 video: bqfGHrQtztY
# Reached quotas: 1284
# Reached quotas: 1287
# Page token non esistente
# Total comments for bqfGHrQtztY: 181
# ________________________________________________________
# 438 video: Owc8Mn7uOuk
# Reached quotas: 1290
# Reached quotas: 1293
# Reached quotas: 1296
# Page token non esistente
# Total comments for Owc8Mn7uOuk: 293
# ________________________________________________________
# 439 video: gVMzFJ2w9sM
# Reached quotas: 1299
# Reached quotas: 1302
# Reached quotas: 1305
# Reached quotas: 1308
# Reached quotas: 1311
# Page token non esistente
# Total comments for gVMzFJ2w9sM: 466
# ________________________________________________________
# 440 video: TzCNL1mr0Mk
# Reached quotas: 1314
# Reached quotas: 1317
# Reached quotas: 1320
# Reached quotas: 1323
# Reached quotas: 1326
# Reached quotas: 1329
# Page token non esistente
# Total comments for TzCNL1mr0Mk: 592
# ________________________________________________________
# 441 video: y9Wa1obebnU
# Reached quotas: 1332
# Reached quotas: 1335
# Reached quotas: 1338
# Reached quotas: 1341
# Reached quotas: 1344
# Reached quotas: 1347
# Reached quotas: 1350
# Reached quotas: 1353
# Reached quotas: 1356
# Reached quotas: 1359
# Reached quotas: 1362
# Page token non esistente
# Total comments for y9Wa1obebnU: 1096
# ________________________________________________________
# 442 video: UHh-ax_bYKs
# Reached quotas: 1365
# Reached quotas: 1368
# Reached quotas: 1371
# Reached quotas: 1374
# Reached quotas: 1377
# Page token non esistente
# Total comments for UHh-ax_bYKs: 476
# ________________________________________________________
# 443 video: r1Jjqs7YvtA
# Reached quotas: 1380
# Reached quotas: 1383
# Reached quotas: 1386
# Reached quotas: 1389
# Page token non esistente
# Total comments for r1Jjqs7YvtA: 347
# ________________________________________________________
# 444 video: mfWU4kCHNV8
# Reached quotas: 1392
# Reached quotas: 1395
# Reached quotas: 1398
# Reached quotas: 1401
# Reached quotas: 1404
# Reached quotas: 1407
# Reached quotas: 1410
# Page token non esistente
# Total comments for mfWU4kCHNV8: 643
# ________________________________________________________
# 445 video: gGH5r0Qimjc
# Reached quotas: 1413
# Reached quotas: 1416
# Reached quotas: 1419
# Page token non esistente
# Total comments for gGH5r0Qimjc: 292
# ________________________________________________________
# 446 video: cTvLG-zHrKA
# Reached quotas: 1422
# Reached quotas: 1425
# Reached quotas: 1428
# Reached quotas: 1431
# Reached quotas: 1434
# Reached quotas: 1437
# Reached quotas: 1440
# Reached quotas: 1443
# Page token non esistente
# Total comments for cTvLG-zHrKA: 715
# ________________________________________________________
# 447 video: DdGaZ2itlc0
# Reached quotas: 1446
# Reached quotas: 1449
# Reached quotas: 1452
# Reached quotas: 1455
# Reached quotas: 1458
# Page token non esistente
# Total comments for DdGaZ2itlc0: 430
# ________________________________________________________
# 448 video: iKJgAL8qHEU
# Reached quotas: 1461
# Reached quotas: 1464
# Reached quotas: 1467
# Reached quotas: 1470
# Page token non esistente
# Total comments for iKJgAL8qHEU: 306
# ________________________________________________________
# 449 video: X1TR6DXKeIE
# Reached quotas: 1473
# Reached quotas: 1476
# Reached quotas: 1479
# Reached quotas: 1482
# Reached quotas: 1485
# Reached quotas: 1488
# Reached quotas: 1491
# Reached quotas: 1494
# Reached quotas: 1497
# Page token non esistente
# Total comments for X1TR6DXKeIE: 830
# ________________________________________________________
# 450 video: hnqmfb1MeSQ
# Reached quotas: 1500
# Reached quotas: 1503
# Reached quotas: 1506
# Reached quotas: 1509
# Page token non esistente
# Total comments for hnqmfb1MeSQ: 343
# ________________________________________________________
# 451 video: Eyhs6h77Acs
# Reached quotas: 1512
# Reached quotas: 1515
# Reached quotas: 1518
# Reached quotas: 1521
# Page token non esistente
# Total comments for Eyhs6h77Acs: 332
# ________________________________________________________
# 452 video: Mpp-SXMZoeo
# Reached quotas: 1524
# Reached quotas: 1527
# Reached quotas: 1530
# Reached quotas: 1533
# Reached quotas: 1536
# Reached quotas: 1539
# Reached quotas: 1542
# Reached quotas: 1545
# Page token non esistente
# Total comments for Mpp-SXMZoeo: 735
# ________________________________________________________
# 453 video: hagaKrOgUcc
# Reached quotas: 1548
# Reached quotas: 1551
# Reached quotas: 1554
# Reached quotas: 1557
# Reached quotas: 1560
# Reached quotas: 1563
# Page token non esistente
# Total comments for hagaKrOgUcc: 553
# ________________________________________________________
# 454 video: 2P4GmvIlN_Y
# Reached quotas: 1566
# Reached quotas: 1569
# Reached quotas: 1572
# Reached quotas: 1575
# Reached quotas: 1578
# Reached quotas: 1581
# Reached quotas: 1584
# Page token non esistente
# Total comments for 2P4GmvIlN_Y: 659
# ________________________________________________________
# 455 video: UjWRFYIfnp8
# Reached quotas: 1587
# Reached quotas: 1590
# Reached quotas: 1593
# Reached quotas: 1596
# Reached quotas: 1599
# Page token non esistente
# Total comments for UjWRFYIfnp8: 455
# ________________________________________________________
# 456 video: fWtwuxv8TCs
# Reached quotas: 1602
# Reached quotas: 1605
# Reached quotas: 1608
# Reached quotas: 1611
# Reached quotas: 1614
# Reached quotas: 1617
# Page token non esistente
# Total comments for fWtwuxv8TCs: 544
# ________________________________________________________
# 457 video: f9aDKYs7No0
# Reached quotas: 1620
# Reached quotas: 1623
# Reached quotas: 1626
# Reached quotas: 1629
# Page token non esistente
# Total comments for f9aDKYs7No0: 389
# ________________________________________________________
# 458 video: 75iO7EAw1jM
# Reached quotas: 1632
# Reached quotas: 1635
# Reached quotas: 1638
# Reached quotas: 1641
# Reached quotas: 1644
# Page token non esistente
# Total comments for 75iO7EAw1jM: 463
# ________________________________________________________
# 459 video: _8Cad0ARXrk
# Reached quotas: 1647
# Reached quotas: 1650
# Reached quotas: 1653
# Reached quotas: 1656
# Reached quotas: 1659
# Page token non esistente
# Total comments for _8Cad0ARXrk: 457
# ________________________________________________________
# 460 video: mnfVeqaRLDk
# Reached quotas: 1662
# Reached quotas: 1665
# Reached quotas: 1668
# Reached quotas: 1671
# Reached quotas: 1674
# Reached quotas: 1677
# Reached quotas: 1680
# Reached quotas: 1683
# Page token non esistente
# Total comments for mnfVeqaRLDk: 762
# ________________________________________________________
# 461 video: gkWQ1u92ylI
# Reached quotas: 1686
# Reached quotas: 1689
# Reached quotas: 1692
# Reached quotas: 1695
# Reached quotas: 1698
# Reached quotas: 1701
# Reached quotas: 1704
# Page token non esistente
# Total comments for gkWQ1u92ylI: 635
# ________________________________________________________
# 462 video: eobXWCV2Tg0
# Reached quotas: 1707
# Reached quotas: 1710
# Reached quotas: 1713
# Reached quotas: 1716
# Reached quotas: 1719
# Reached quotas: 1722
# Page token non esistente
# Total comments for eobXWCV2Tg0: 543
# ________________________________________________________
# 463 video: g_fJha5v-Ic
# Reached quotas: 1725
# Reached quotas: 1728
# Reached quotas: 1731
# Reached quotas: 1734
# Reached quotas: 1737
# Page token non esistente
# Total comments for g_fJha5v-Ic: 421
# ________________________________________________________
# 464 video: EGOZBSsBUCs
# Reached quotas: 1740
# Reached quotas: 1743
# Reached quotas: 1746
# Reached quotas: 1749
# Page token non esistente
# Total comments for EGOZBSsBUCs: 308
# ________________________________________________________
# 465 video: OEaKPhvEC1w
# Reached quotas: 1752
# Reached quotas: 1755
# Reached quotas: 1758
# Reached quotas: 1761
# Reached quotas: 1764
# Page token non esistente
# Total comments for OEaKPhvEC1w: 411
# ________________________________________________________
# 466 video: _QnWdYwYgM8
# Reached quotas: 1767
# Reached quotas: 1770
# Reached quotas: 1773
# Reached quotas: 1776
# Reached quotas: 1779
# Reached quotas: 1782
# Reached quotas: 1785
# Page token non esistente
# Total comments for _QnWdYwYgM8: 608
# ________________________________________________________
# 467 video: M6Wr-EWivGo
# Reached quotas: 1788
# Reached quotas: 1791
# Reached quotas: 1794
# Reached quotas: 1797
# Reached quotas: 1800
# Reached quotas: 1803
# Page token non esistente
# Total comments for M6Wr-EWivGo: 549
# ________________________________________________________
# 468 video: YlolSAoCVDw
# Reached quotas: 1806
# Reached quotas: 1809
# Reached quotas: 1812
# Reached quotas: 1815
# Reached quotas: 1818
# Reached quotas: 1821
# Page token non esistente
# Total comments for YlolSAoCVDw: 504
# ________________________________________________________
# 469 video: pNZpyiTVBxk
# Reached quotas: 1824
# Reached quotas: 1827
# Reached quotas: 1830
# Reached quotas: 1833
# Reached quotas: 1836
# Reached quotas: 1839
# Reached quotas: 1842
# Reached quotas: 1845
# Reached quotas: 1848
# Page token non esistente
# Total comments for pNZpyiTVBxk: 850
# ________________________________________________________
# 470 video: ed0wOLMAUjA
# Reached quotas: 1851
# Reached quotas: 1854
# Reached quotas: 1857
# Reached quotas: 1860
# Reached quotas: 1863
# Reached quotas: 1866
# Reached quotas: 1869
# Reached quotas: 1872
# Reached quotas: 1875
# Page token non esistente
# Total comments for ed0wOLMAUjA: 871
# ________________________________________________________
# 471 video: 6opLTOeOapM
# Reached quotas: 1878
# Reached quotas: 1881
# Reached quotas: 1884
# Reached quotas: 1887
# Page token non esistente
# Total comments for 6opLTOeOapM: 318
# ________________________________________________________
# 472 video: q-b-OabYgQI
# Reached quotas: 1890
# Reached quotas: 1893
# Reached quotas: 1896
# Reached quotas: 1899
# Reached quotas: 1902
# Page token non esistente
# Total comments for q-b-OabYgQI: 433
# ________________________________________________________
# 473 video: JrWvIztmX24
# Reached quotas: 1905
# Reached quotas: 1908
# Reached quotas: 1911
# Reached quotas: 1914
# Reached quotas: 1917
# Reached quotas: 1920
# Page token non esistente
# Total comments for JrWvIztmX24: 529
# ________________________________________________________
# 474 video: 1hj5I4clRCM
# Reached quotas: 1923
# Reached quotas: 1926
# Reached quotas: 1929
# Page token non esistente
# Total comments for 1hj5I4clRCM: 249
# ________________________________________________________
# 475 video: KlJCBLGeZqs
# Reached quotas: 1932
# Reached quotas: 1935
# Reached quotas: 1938
# Reached quotas: 1941
# Reached quotas: 1944
# Reached quotas: 1947
# Reached quotas: 1950
# Reached quotas: 1953
# Reached quotas: 1956
# Reached quotas: 1959
# Reached quotas: 1962
# Reached quotas: 1965
# Reached quotas: 1968
# Reached quotas: 1971
# Page token non esistente
# Total comments for KlJCBLGeZqs: 1388
# ________________________________________________________
# 476 video: i-EN7Zl6fTA
# Reached quotas: 1974
# Reached quotas: 1977
# Reached quotas: 1980
# Page token non esistente
# Total comments for i-EN7Zl6fTA: 279
# ________________________________________________________
# 477 video: Tp6I2F6Rg0o
# Reached quotas: 1983
# Reached quotas: 1986
# Reached quotas: 1989
# Reached quotas: 1992
# Page token non esistente
# Total comments for Tp6I2F6Rg0o: 377
# ________________________________________________________
# 478 video: XLxdj3INwbU
# Reached quotas: 1995
# Reached quotas: 1998
# Reached quotas: 2001
# Page token non esistente
# Total comments for XLxdj3INwbU: 274
# ________________________________________________________
# 479 video: 2pbyxAxyD74
# Reached quotas: 2004
# Reached quotas: 2007
# Reached quotas: 2010
# Reached quotas: 2013
# Reached quotas: 2016
# Page token non esistente
# Total comments for 2pbyxAxyD74: 479
# ________________________________________________________
# 480 video: wc37pMnALVw
# Reached quotas: 2019
# Reached quotas: 2022
# Reached quotas: 2025
# Reached quotas: 2028
# Reached quotas: 2031
# Reached quotas: 2034
# Reached quotas: 2037
# Reached quotas: 2040
# Page token non esistente
# Total comments for wc37pMnALVw: 766
# ________________________________________________________
# 481 video: KmGUg8sGGCM
# Reached quotas: 2043
# Reached quotas: 2046
# Reached quotas: 2049
# Reached quotas: 2052
# Page token non esistente
# Total comments for KmGUg8sGGCM: 381
# ________________________________________________________
# 482 video: vYfHIq_CzIg
# Reached quotas: 2055
# Reached quotas: 2058
# Page token non esistente
# Total comments for vYfHIq_CzIg: 174
# ________________________________________________________
# 483 video: H6KzdwwObdA
# Reached quotas: 2061
# Reached quotas: 2064
# Reached quotas: 2067
# Reached quotas: 2070
# Page token non esistente
# Total comments for H6KzdwwObdA: 380
# ________________________________________________________
# 484 video: vpqx-3dfiP8
# Reached quotas: 2073
# Reached quotas: 2076
# Reached quotas: 2079
# Reached quotas: 2082
# Reached quotas: 2085
# Reached quotas: 2088
# Reached quotas: 2091
# Page token non esistente
# Total comments for vpqx-3dfiP8: 622
# ________________________________________________________
# 485 video: h-TqLkfloec
# Reached quotas: 2094
# Reached quotas: 2097
# Reached quotas: 2100
# Page token non esistente
# Total comments for h-TqLkfloec: 232
# ________________________________________________________
# 486 video: 0UeymMQoPTk
# Reached quotas: 2103
# Reached quotas: 2106
# Reached quotas: 2109
# Reached quotas: 2112
# Reached quotas: 2115
# Reached quotas: 2118
# Reached quotas: 2121
# Page token non esistente
# Total comments for 0UeymMQoPTk: 669
# ________________________________________________________
# 487 video: LRzKHjhJ4B0
# Reached quotas: 2124
# Reached quotas: 2127
# Reached quotas: 2130
# Reached quotas: 2133
# Reached quotas: 2136
# Reached quotas: 2139
# Reached quotas: 2142
# Reached quotas: 2145
# Page token non esistente
# Total comments for LRzKHjhJ4B0: 797
# ________________________________________________________
# 488 video: I5Rdwu4FIfE
# Reached quotas: 2148
# Reached quotas: 2151
# Reached quotas: 2154
# Reached quotas: 2157
# Page token non esistente
# Total comments for I5Rdwu4FIfE: 374
# ________________________________________________________
# 489 video: Ex6g3dNHzeY
# Reached quotas: 2160
# Reached quotas: 2163
# Reached quotas: 2166
# Reached quotas: 2169
# Reached quotas: 2172
# Reached quotas: 2175
# Page token non esistente
# Total comments for Ex6g3dNHzeY: 533
# ________________________________________________________
# 490 video: r-Kplr4uU-I
# Reached quotas: 2178
# Reached quotas: 2181
# Reached quotas: 2184
# Reached quotas: 2187
# Reached quotas: 2190
# Reached quotas: 2193
# Page token non esistente
# Total comments for r-Kplr4uU-I: 596
# ________________________________________________________
# 491 video: 2VjXSumRW1s
# Reached quotas: 2196
# Reached quotas: 2199
# Reached quotas: 2202
# Reached quotas: 2205
# Reached quotas: 2208
# Reached quotas: 2211
# Reached quotas: 2214
# Reached quotas: 2217
# Reached quotas: 2220
# Reached quotas: 2223
# Reached quotas: 2226
# Reached quotas: 2229
# Reached quotas: 2232
# Reached quotas: 2235
# Reached quotas: 2238
# Reached quotas: 2241
# Reached quotas: 2244
# Reached quotas: 2247
# Reached quotas: 2250
# Reached quotas: 2253
# Reached quotas: 2256
# Reached quotas: 2259
# Reached quotas: 2262
# Reached quotas: 2265
# Reached quotas: 2268
# Page token non esistente
# Total comments for 2VjXSumRW1s: 2405
# ________________________________________________________
# 492 video: WeEWjLUt2MU
# Reached quotas: 2271
# Reached quotas: 2274
# Reached quotas: 2277
# Reached quotas: 2280
# Reached quotas: 2283
# Reached quotas: 2286
# Reached quotas: 2289
# Page token non esistente
# Total comments for WeEWjLUt2MU: 628
# ________________________________________________________
# 493 video: ITzzN4gAA68
# Reached quotas: 2292
# Reached quotas: 2295
# Reached quotas: 2298
# Reached quotas: 2301
# Page token non esistente
# Total comments for ITzzN4gAA68: 393
# ________________________________________________________
# 494 video: YnYbXmACDHs
# Reached quotas: 2304
# Reached quotas: 2307
# Reached quotas: 2310
# Reached quotas: 2313
# Reached quotas: 2316
# Reached quotas: 2319
# Reached quotas: 2322
# Reached quotas: 2325
# Reached quotas: 2328
# Reached quotas: 2331
# Reached quotas: 2334
# Reached quotas: 2337
# Page token non esistente
# Total comments for YnYbXmACDHs: 1151
# ________________________________________________________
# 495 video: DSPiW6yY26Q
# Reached quotas: 2340
# Reached quotas: 2343
# Reached quotas: 2346
# Reached quotas: 2349
# Reached quotas: 2352
# Reached quotas: 2355
# Reached quotas: 2358
# Reached quotas: 2361
# Reached quotas: 2364
# Page token non esistente
# Total comments for DSPiW6yY26Q: 821
# ________________________________________________________
# 496 video: 0qQ-2jq0auU
# Reached quotas: 2367
# Reached quotas: 2370
# Reached quotas: 2373
# Reached quotas: 2376
# Reached quotas: 2379
# Reached quotas: 2382
# Reached quotas: 2385
# Page token non esistente
# Total comments for 0qQ-2jq0auU: 618
# ________________________________________________________
# 497 video: PgVJfLgCqCA
# Reached quotas: 2388
# Reached quotas: 2391
# Reached quotas: 2394
# Reached quotas: 2397
# Reached quotas: 2400
# Reached quotas: 2403
# Reached quotas: 2406
# Reached quotas: 2409
# Reached quotas: 2412
# Reached quotas: 2415
# Reached quotas: 2418
# Page token non esistente
# Total comments for PgVJfLgCqCA: 1006
# ________________________________________________________
# 498 video: CTPC2gND4NQ
# Reached quotas: 2421
# Reached quotas: 2424
# Reached quotas: 2427
# Reached quotas: 2430
# Reached quotas: 2433
# Reached quotas: 2436
# Reached quotas: 2439
# Reached quotas: 2442
# Reached quotas: 2445
# Reached quotas: 2448
# Reached quotas: 2451
# Reached quotas: 2454
# Reached quotas: 2457
# Reached quotas: 2460
# Reached quotas: 2463
# Reached quotas: 2466
# Reached quotas: 2469
# Reached quotas: 2472
# Reached quotas: 2475
# Reached quotas: 2478
# Reached quotas: 2481
# Reached quotas: 2484
# Reached quotas: 2487
# Reached quotas: 2490
# Reached quotas: 2493
# Reached quotas: 2496
# Reached quotas: 2499
# Reached quotas: 2502
# Reached quotas: 2505
# Page token non esistente
# Total comments for CTPC2gND4NQ: 2824
# ________________________________________________________
# 499 video: zFfLdPVMYjo
# Reached quotas: 2508
# Reached quotas: 2511
# Reached quotas: 2514
# Reached quotas: 2517
# Reached quotas: 2520
# Reached quotas: 2523
# Reached quotas: 2526
# Reached quotas: 2529
# Reached quotas: 2532
# Reached quotas: 2535
# Reached quotas: 2538
# Reached quotas: 2541
# Page token non esistente
# Total comments for zFfLdPVMYjo: 1158
# ________________________________________________________
# 500 video: _E5qvVfO0Xg
# Reached quotas: 2544
# Reached quotas: 2547
# Reached quotas: 2550
# Reached quotas: 2553
# Reached quotas: 2556
# Reached quotas: 2559
# Reached quotas: 2562
# Reached quotas: 2565
# Reached quotas: 2568
# Reached quotas: 2571
# Reached quotas: 2574
# Reached quotas: 2577
# Reached quotas: 2580
# Page token non esistente
# Total comments for _E5qvVfO0Xg: 1255
# ________________________________________________________
# 501 video: KL_kfiMsvcQ
# Reached quotas: 2583
# Reached quotas: 2586
# Reached quotas: 2589
# Reached quotas: 2592
# Page token non esistente
# Total comments for KL_kfiMsvcQ: 391
# ________________________________________________________
# 502 video: yMIDG2nYcGU
# Reached quotas: 2595
# Reached quotas: 2598
# Reached quotas: 2601
# Reached quotas: 2604
# Reached quotas: 2607
# Reached quotas: 2610
# Reached quotas: 2613
# Reached quotas: 2616
# Reached quotas: 2619
# Reached quotas: 2622
# Reached quotas: 2625
# Reached quotas: 2628
# Reached quotas: 2631
# Page token non esistente
# Total comments for yMIDG2nYcGU: 1259
# ________________________________________________________
# 503 video: MUMoEICzW6w
# Reached quotas: 2634
# Reached quotas: 2637
# Reached quotas: 2640
# Reached quotas: 2643
# Reached quotas: 2646
# Reached quotas: 2649
# Reached quotas: 2652
# Page token non esistente
# Total comments for MUMoEICzW6w: 657
# ________________________________________________________
# 504 video: CBDbRcHVd6Y
# Reached quotas: 2655
# Reached quotas: 2658
# Reached quotas: 2661
# Reached quotas: 2664
# Reached quotas: 2667
# Reached quotas: 2670
# Reached quotas: 2673
# Reached quotas: 2676
# Reached quotas: 2679
# Reached quotas: 2682
# Reached quotas: 2685
# Reached quotas: 2688
# Page token non esistente
# Total comments for CBDbRcHVd6Y: 1129
# ________________________________________________________
# 505 video: GrcRYNcPmFg
# Reached quotas: 2691
# Reached quotas: 2694
# Reached quotas: 2697
# Reached quotas: 2700
# Reached quotas: 2703
# Reached quotas: 2706
# Reached quotas: 2709
# Reached quotas: 2712
# Page token non esistente
# Total comments for GrcRYNcPmFg: 752
# ________________________________________________________
# 506 video: VWM9ThxEcuw
# Reached quotas: 2715
# Reached quotas: 2718
# Reached quotas: 2721
# Reached quotas: 2724
# Reached quotas: 2727
# Page token non esistente
# Total comments for VWM9ThxEcuw: 463
# ________________________________________________________
# 507 video: bgieZx0CwAo
# Reached quotas: 2730
# Reached quotas: 2733
# Reached quotas: 2736
# Page token non esistente
# Total comments for bgieZx0CwAo: 207
# ________________________________________________________
# 508 video: oI-AUpUJRkQ
# Reached quotas: 2739
# Reached quotas: 2742
# Reached quotas: 2745
# Reached quotas: 2748
# Reached quotas: 2751
# Reached quotas: 2754
# Reached quotas: 2757
# Reached quotas: 2760
# Reached quotas: 2763
# Reached quotas: 2766
# Reached quotas: 2769
# Reached quotas: 2772
# Reached quotas: 2775
# Reached quotas: 2778
# Reached quotas: 2781
# Reached quotas: 2784
# Reached quotas: 2787
# Reached quotas: 2790
# Reached quotas: 2793
# Reached quotas: 2796
# Reached quotas: 2799
# Reached quotas: 2802
# Page token non esistente
# Total comments for oI-AUpUJRkQ: 2128
# ________________________________________________________
# 509 video: zX7VkSjofKA
# Reached quotas: 2805
# Reached quotas: 2808
# Reached quotas: 2811
# Reached quotas: 2814
# Reached quotas: 2817
# Page token non esistente
# Total comments for zX7VkSjofKA: 411
# ________________________________________________________
# 510 video: DufFnrSg5bU
# Reached quotas: 2820
# Reached quotas: 2823
# Reached quotas: 2826
# Reached quotas: 2829
# Reached quotas: 2832
# Reached quotas: 2835
# Reached quotas: 2838
# Page token non esistente
# Total comments for DufFnrSg5bU: 625
# ________________________________________________________
# 511 video: pKFrCF9AJBM
# Reached quotas: 2841
# Reached quotas: 2844
# Reached quotas: 2847
# Reached quotas: 2850
# Reached quotas: 2853
# Reached quotas: 2856
# Page token non esistente
# Total comments for pKFrCF9AJBM: 534
# ________________________________________________________
# 512 video: PuQdYRQnGfg
# Reached quotas: 2859
# Reached quotas: 2862
# Reached quotas: 2865
# Reached quotas: 2868
# Reached quotas: 2871
# Reached quotas: 2874
# Reached quotas: 2877
# Reached quotas: 2880
# Reached quotas: 2883
# Reached quotas: 2886
# Reached quotas: 2889
# Reached quotas: 2892
# Page token non esistente
# Total comments for PuQdYRQnGfg: 1135
# ________________________________________________________
# 513 video: aC4PRQ-wRAo
# Reached quotas: 2895
# Reached quotas: 2898
# Reached quotas: 2901
# Reached quotas: 2904
# Reached quotas: 2907
# Page token non esistente
# Total comments for aC4PRQ-wRAo: 498
# ________________________________________________________
# 514 video: 5031-rmWWgs
# Reached quotas: 2910
# Reached quotas: 2913
# Reached quotas: 2916
# Reached quotas: 2919
# Page token non esistente
# Total comments for 5031-rmWWgs: 340
# ________________________________________________________
# 515 video: h0M6CQIANjY
# Reached quotas: 2922
# Reached quotas: 2925
# Reached quotas: 2928
# Reached quotas: 2931
# Reached quotas: 2934
# Reached quotas: 2937
# Page token non esistente
# Total comments for h0M6CQIANjY: 534
# ________________________________________________________
# 516 video: ptHmzPB0EHE
# Reached quotas: 2940
# Reached quotas: 2943
# Reached quotas: 2946
# Reached quotas: 2949
# Reached quotas: 2952
# Reached quotas: 2955
# Page token non esistente
# Total comments for ptHmzPB0EHE: 598
# ________________________________________________________
# 517 video: 4SWIRJj8dbY
# Reached quotas: 2958
# Reached quotas: 2961
# Reached quotas: 2964
# Reached quotas: 2967
# Reached quotas: 2970
# Reached quotas: 2973
# Page token non esistente
# Total comments for 4SWIRJj8dbY: 521
# ________________________________________________________
# 518 video: ePbUu_T15Wo
# Reached quotas: 2976
# Reached quotas: 2979
# Reached quotas: 2982
# Reached quotas: 2985
# Reached quotas: 2988
# Reached quotas: 2991
# Reached quotas: 2994
# Reached quotas: 2997
# Reached quotas: 3000
# Reached quotas: 3003
# Reached quotas: 3006
# Reached quotas: 3009
# Reached quotas: 3012
# Reached quotas: 3015
# Page token non esistente
# Total comments for ePbUu_T15Wo: 1319
# ________________________________________________________
# 519 video: y7vNoDIcnN0
# Reached quotas: 3018
# Reached quotas: 3021
# Reached quotas: 3024
# Reached quotas: 3027
# Reached quotas: 3030
# Reached quotas: 3033
# Reached quotas: 3036
# Page token non esistente
# Total comments for y7vNoDIcnN0: 693
# ________________________________________________________
# 520 video: brhuSKtg_ZQ
# Reached quotas: 3039
# Reached quotas: 3042
# Reached quotas: 3045
# Reached quotas: 3048
# Reached quotas: 3051
# Reached quotas: 3054
# Reached quotas: 3057
# Page token non esistente
# Total comments for brhuSKtg_ZQ: 603
# ________________________________________________________
# 521 video: -FrUv2z50jA
# Reached quotas: 3060
# Reached quotas: 3063
# Reached quotas: 3066
# Reached quotas: 3069
# Reached quotas: 3072
# Page token non esistente
# Total comments for -FrUv2z50jA: 407
# ________________________________________________________
# 522 video: aI6W_gml_MQ
# Reached quotas: 3075
# Reached quotas: 3078
# Reached quotas: 3081
# Reached quotas: 3084
# Reached quotas: 3087
# Reached quotas: 3090
# Reached quotas: 3093
# Page token non esistente
# Total comments for aI6W_gml_MQ: 630
# ________________________________________________________
# 523 video: TRDpFNJ4O5A
# Reached quotas: 3096
# Reached quotas: 3099
# Reached quotas: 3102
# Reached quotas: 3105
# Reached quotas: 3108
# Reached quotas: 3111
# Reached quotas: 3114
# Reached quotas: 3117
# Page token non esistente
# Total comments for TRDpFNJ4O5A: 756
# ________________________________________________________
# 524 video: yKyBtY9b7sk
# Reached quotas: 3120
# Reached quotas: 3123
# Reached quotas: 3126
# Page token non esistente
# Total comments for yKyBtY9b7sk: 203
# ________________________________________________________
# 525 video: r-FV8mUkaDY
# Reached quotas: 3129
# Reached quotas: 3132
# Reached quotas: 3135
# Reached quotas: 3138
# Reached quotas: 3141
# Page token non esistente
# Total comments for r-FV8mUkaDY: 481
# ________________________________________________________
# 526 video: XeFt4sKSqLs
# Reached quotas: 3144
# Reached quotas: 3147
# Reached quotas: 3150
# Reached quotas: 3153
# Reached quotas: 3156
# Reached quotas: 3159
# Reached quotas: 3162
# Reached quotas: 3165
# Reached quotas: 3168
# Reached quotas: 3171
# Reached quotas: 3174
# Reached quotas: 3177
# Reached quotas: 3180
# Reached quotas: 3183
# Reached quotas: 3186
# Reached quotas: 3189
# Page token non esistente
# Total comments for XeFt4sKSqLs: 1517
# ________________________________________________________
# 527 video: 5asDnuNHZ6k
# Reached quotas: 3192
# Reached quotas: 3195
# Reached quotas: 3198
# Reached quotas: 3201
# Reached quotas: 3204
# Reached quotas: 3207
# Page token non esistente
# Total comments for 5asDnuNHZ6k: 575
# ________________________________________________________
# 528 video: q7QLKWl2WL8
# Reached quotas: 3210
# Reached quotas: 3213
# Reached quotas: 3216
# Reached quotas: 3219
# Reached quotas: 3222
# Reached quotas: 3225
# Page token non esistente
# Total comments for q7QLKWl2WL8: 504
# ________________________________________________________
# 529 video: VMlFMIKVvFc
# Reached quotas: 3228
# Reached quotas: 3231
# Reached quotas: 3234
# Reached quotas: 3237
# Reached quotas: 3240
# Reached quotas: 3243
# Reached quotas: 3246
# Reached quotas: 3249
# Reached quotas: 3252
# Reached quotas: 3255
# Reached quotas: 3258
# Reached quotas: 3261
# Reached quotas: 3264
# Reached quotas: 3267
# Page token non esistente
# Total comments for VMlFMIKVvFc: 1378
# ________________________________________________________
# 530 video: YnMMYsawh64
# Reached quotas: 3270
# Reached quotas: 3273
# Reached quotas: 3276
# Reached quotas: 3279
# Reached quotas: 3282
# Reached quotas: 3285
# Reached quotas: 3288
# Page token non esistente
# Total comments for YnMMYsawh64: 646
# ________________________________________________________
# 531 video: OZJcnCFr8hY
# Reached quotas: 3291
# Reached quotas: 3294
# Reached quotas: 3297
# Reached quotas: 3300
# Reached quotas: 3303
# Reached quotas: 3306
# Page token non esistente
# Total comments for OZJcnCFr8hY: 549
# ________________________________________________________
# 532 video: xCD8iPnaraY
# Reached quotas: 3309
# Reached quotas: 3312
# Reached quotas: 3315
# Reached quotas: 3318
# Page token non esistente
# Total comments for xCD8iPnaraY: 383
# ________________________________________________________
# 533 video: 5rXQQtykd40
# Reached quotas: 3321
# Reached quotas: 3324
# Reached quotas: 3327
# Reached quotas: 3330
# Reached quotas: 3333
# Reached quotas: 3336
# Page token non esistente
# Total comments for 5rXQQtykd40: 513
# ________________________________________________________
# 534 video: X9CKxM6SH_g
# Reached quotas: 3339
# Reached quotas: 3342
# Reached quotas: 3345
# Reached quotas: 3348
# Reached quotas: 3351
# Page token non esistente
# Total comments for X9CKxM6SH_g: 414
# ________________________________________________________
# 535 video: DirLXYjdA5o
# Reached quotas: 3354
# Reached quotas: 3357
# Reached quotas: 3360
# Reached quotas: 3363
# Reached quotas: 3366
# Reached quotas: 3369
# Reached quotas: 3372
# Reached quotas: 3375
# Reached quotas: 3378
# Page token non esistente
# Total comments for DirLXYjdA5o: 820
# ________________________________________________________
# 536 video: o8ry8XEkkzQ
# Reached quotas: 3381
# Reached quotas: 3384
# Reached quotas: 3387
# Page token non esistente
# Total comments for o8ry8XEkkzQ: 280
# ________________________________________________________
# 537 video: h3Jpz3pDmf8
# Reached quotas: 3390
# Reached quotas: 3393
# Reached quotas: 3396
# Reached quotas: 3399
# Reached quotas: 3402
# Reached quotas: 3405
# Page token non esistente
# Total comments for h3Jpz3pDmf8: 587
# ________________________________________________________
# 538 video: j4MkTdGFGsk
# Reached quotas: 3408
# Reached quotas: 3411
# Reached quotas: 3414
# Reached quotas: 3417
# Reached quotas: 3420
# Reached quotas: 3423
# Reached quotas: 3426
# Reached quotas: 3429
# Reached quotas: 3432
# Reached quotas: 3435
# Reached quotas: 3438
# Reached quotas: 3441
# Reached quotas: 3444
# Reached quotas: 3447
# Reached quotas: 3450
# Reached quotas: 3453
# Page token non esistente
# Total comments for j4MkTdGFGsk: 1570
# ________________________________________________________
# 539 video: xGaf4Tkan30
# Reached quotas: 3456
# Reached quotas: 3459
# Reached quotas: 3462
# Reached quotas: 3465
# Reached quotas: 3468
# Reached quotas: 3471
# Reached quotas: 3474
# Reached quotas: 3477
# Page token non esistente
# Total comments for xGaf4Tkan30: 798
# ________________________________________________________
# 540 video: S7P85ICKx28
# Reached quotas: 3480
# Reached quotas: 3483
# Reached quotas: 3486
# Reached quotas: 3489
# Page token non esistente
# Total comments for S7P85ICKx28: 342
# ________________________________________________________
# 541 video: 3GGTp-kJm44
# Reached quotas: 3492
# Reached quotas: 3495
# Reached quotas: 3498
# Reached quotas: 3501
# Reached quotas: 3504
# Reached quotas: 3507
# Page token non esistente
# Total comments for 3GGTp-kJm44: 501
# ________________________________________________________
# 542 video: GaMwgiM9QXc
# Reached quotas: 3510
# Reached quotas: 3513
# Reached quotas: 3516
# Reached quotas: 3519
# Reached quotas: 3522
# Page token non esistente
# Total comments for GaMwgiM9QXc: 451
# ________________________________________________________
# 543 video: zsGv-7ZH10o
# Reached quotas: 3525
# Reached quotas: 3528
# Reached quotas: 3531
# Reached quotas: 3534
# Reached quotas: 3537
# Reached quotas: 3540
# Page token non esistente
# Total comments for zsGv-7ZH10o: 560
# ________________________________________________________
# 544 video: Fr1Qm4ySIWk
# Reached quotas: 3543
# Reached quotas: 3546
# Reached quotas: 3549
# Reached quotas: 3552
# Reached quotas: 3555
# Reached quotas: 3558
# Reached quotas: 3561
# Page token non esistente
# Total comments for Fr1Qm4ySIWk: 694
# ________________________________________________________
# 545 video: ctH56NTUN3U
# Reached quotas: 3564
# Reached quotas: 3567
# Reached quotas: 3570
# Reached quotas: 3573
# Reached quotas: 3576
# Reached quotas: 3579
# Reached quotas: 3582
# Reached quotas: 3585
# Reached quotas: 3588
# Reached quotas: 3591
# Reached quotas: 3594
# Reached quotas: 3597
# Reached quotas: 3600
# Page token non esistente
# Total comments for ctH56NTUN3U: 1205
# ________________________________________________________
# 546 video: JIP6O9k0aMg
# Reached quotas: 3603
# Reached quotas: 3606
# Reached quotas: 3609
# Reached quotas: 3612
# Reached quotas: 3615
# Reached quotas: 3618
# Reached quotas: 3621
# Reached quotas: 3624
# Reached quotas: 3627
# Page token non esistente
# Total comments for JIP6O9k0aMg: 878
# ________________________________________________________
# 547 video: c3z3H66oH9o
# Reached quotas: 3630
# Reached quotas: 3633
# Reached quotas: 3636
# Reached quotas: 3639
# Reached quotas: 3642
# Reached quotas: 3645
# Reached quotas: 3648
# Reached quotas: 3651
# Reached quotas: 3654
# Page token non esistente
# Total comments for c3z3H66oH9o: 894
# ________________________________________________________
# 548 video: XqsptoHWrwE
# Reached quotas: 3657
# Reached quotas: 3660
# Reached quotas: 3663
# Reached quotas: 3666
# Reached quotas: 3669
# Reached quotas: 3672
# Reached quotas: 3675
# Reached quotas: 3678
# Reached quotas: 3681
# Page token non esistente
# Total comments for XqsptoHWrwE: 850
# ________________________________________________________
# 549 video: rGHyq-DHVR8
# Reached quotas: 3684
# Reached quotas: 3687
# Reached quotas: 3690
# Reached quotas: 3693
# Reached quotas: 3696
# Reached quotas: 3699
# Reached quotas: 3702
# Page token non esistente
# Total comments for rGHyq-DHVR8: 668
# ________________________________________________________
# 550 video: pBiqjbxcnBI
# Reached quotas: 3705
# Reached quotas: 3708
# Reached quotas: 3711
# Reached quotas: 3714
# Reached quotas: 3717
# Reached quotas: 3720
# Reached quotas: 3723
# Reached quotas: 3726
# Reached quotas: 3729
# Reached quotas: 3732
# Reached quotas: 3735
# Reached quotas: 3738
# Reached quotas: 3741
# Reached quotas: 3744
# Reached quotas: 3747
# Reached quotas: 3750
# Reached quotas: 3753
# Reached quotas: 3756
# Reached quotas: 3759
# Reached quotas: 3762
# Reached quotas: 3765
# Reached quotas: 3768
# Reached quotas: 3771
# Reached quotas: 3774
# Reached quotas: 3777
# Reached quotas: 3780
# Reached quotas: 3783
# Page token non esistente
# Total comments for pBiqjbxcnBI: 2686
# ________________________________________________________
# 551 video: 6gUDEWmHvOc
# Reached quotas: 3786
# Reached quotas: 3789
# Reached quotas: 3792
# Reached quotas: 3795
# Reached quotas: 3798
# Reached quotas: 3801
# Reached quotas: 3804
# Reached quotas: 3807
# Reached quotas: 3810
# Reached quotas: 3813
# Reached quotas: 3816
# Reached quotas: 3819
# Page token non esistente
# Total comments for 6gUDEWmHvOc: 1169
# ________________________________________________________
# 552 video: tckr3e3rOUA
# Reached quotas: 3822
# Reached quotas: 3825
# Reached quotas: 3828
# Reached quotas: 3831
# Page token non esistente
# Total comments for tckr3e3rOUA: 350
# ________________________________________________________
# 553 video: Ek79_IiTp3s
# Reached quotas: 3834
# Reached quotas: 3837
# Reached quotas: 3840
# Reached quotas: 3843
# Reached quotas: 3846
# Page token non esistente
# Total comments for Ek79_IiTp3s: 431
# ________________________________________________________
# 554 video: ler-dKVgYFU
# Reached quotas: 3849
# Reached quotas: 3852
# Reached quotas: 3855
# Reached quotas: 3858
# Reached quotas: 3861
# Reached quotas: 3864
# Page token non esistente
# Total comments for ler-dKVgYFU: 583
# ________________________________________________________
# 555 video: dmulG3LPaX0
# Reached quotas: 3867
# Reached quotas: 3870
# Reached quotas: 3873
# Reached quotas: 3876
# Reached quotas: 3879
# Reached quotas: 3882
# Page token non esistente
# Total comments for dmulG3LPaX0: 563
# ________________________________________________________
# 556 video: I_NnRuhNdOg
# Reached quotas: 3885
# Reached quotas: 3888
# Reached quotas: 3891
# Reached quotas: 3894
# Reached quotas: 3897
# ...
# Reached quotas: 8112
# Reached quotas: 8115
# Reached quotas: 8118
# Reached quotas: 8121
# Reached quotas: 8124
# Page token non esistente
# Total comments for K7lqf-dmhM4: 482
# ________________________________________________________
# 761 video: qF76gfBD2_A
# Reached quotas: 8127
# Reached quotas: 8130
# Reached quotas: 8133
# Reached quotas: 8136
# Reached quotas: 8139
# Page token non esistente
# Total comments for qF76gfBD2_A: 406
# ________________________________________________________
# 762 video: U4w98bJsHwY
# Reached quotas: 8142
# Reached quotas: 8145
# Reached quotas: 8148
# Reached quotas: 8151
# Reached quotas: 8154
# Reached quotas: 8157
# Reached quotas: 8160
# Reached quotas: 8163
# Reached quotas: 8166
# Page token non esistente
# Total comments for U4w98bJsHwY: 898
# ________________________________________________________
# 763 video: 9VPNyYDsaCo
# Reached quotas: 8169
# Reached quotas: 8172
# Reached quotas: 8175
# Reached quotas: 8178
# Reached quotas: 8181
# Page token non esistente
# Total comments for 9VPNyYDsaCo: 418
# ________________________________________________________
# 764 video: 0u9mvbAsbcY
# Reached quotas: 8184
# Reached quotas: 8187
# Reached quotas: 8190
# Reached quotas: 8193
# Reached quotas: 8196
# Reached quotas: 8199
# Reached quotas: 8202
# Reached quotas: 8205
# Page token non esistente
# Total comments for 0u9mvbAsbcY: 773
# ________________________________________________________
# 765 video: yVQmhs-y66s
# Reached quotas: 8208
# Reached quotas: 8211
# Reached quotas: 8214
# Page token non esistente
# Total comments for yVQmhs-y66s: 228
# ________________________________________________________
# 766 video: xBFqPD0w22o
# Reached quotas: 8217
# Reached quotas: 8220
# Reached quotas: 8223
# Reached quotas: 8226
# Reached quotas: 8229
# Page token non esistente
# Total comments for xBFqPD0w22o: 491
# ________________________________________________________
# 767 video: xG0m3SQyPrc
# Reached quotas: 8232
# Reached quotas: 8235
# Reached quotas: 8238
# Reached quotas: 8241
# Reached quotas: 8244
# Reached quotas: 8247
# Reached quotas: 8250
# Reached quotas: 8253
# Reached quotas: 8256
# Page token non esistente
# Total comments for xG0m3SQyPrc: 876
# ________________________________________________________
# 768 video: IEZ_a8IEAwM
# Reached quotas: 8259
# Reached quotas: 8262
# Reached quotas: 8265
# Reached quotas: 8268
# Page token non esistente
# Total comments for IEZ_a8IEAwM: 303
# ________________________________________________________
# 769 video: k9xMnJSMKgA
# Reached quotas: 8271
# Reached quotas: 8274
# Reached quotas: 8277
# Reached quotas: 8280
# Reached quotas: 8283
# Reached quotas: 8286
# Reached quotas: 8289
# Reached quotas: 8292
# Reached quotas: 8295
# Reached quotas: 8298
# Reached quotas: 8301
# Reached quotas: 8304
# Reached quotas: 8307
# Reached quotas: 8310
# Reached quotas: 8313
# Reached quotas: 8316
# Page token non esistente
# Total comments for k9xMnJSMKgA: 1565
# ________________________________________________________
# 770 video: Nl2qBUJVNeM
# Reached quotas: 8319
# Reached quotas: 8322
# Reached quotas: 8325
# Reached quotas: 8328
# Reached quotas: 8331
# Reached quotas: 8334
# Reached quotas: 8337
# Reached quotas: 8340
# Reached quotas: 8343
# Reached quotas: 8346
# Reached quotas: 8349
# Reached quotas: 8352
# Reached quotas: 8355
# Reached quotas: 8358
# Reached quotas: 8361
# Reached quotas: 8364
# Reached quotas: 8367
# Reached quotas: 8370
# Reached quotas: 8373
# Reached quotas: 8376
# Reached quotas: 8379
# Reached quotas: 8382
# Reached quotas: 8385
# Reached quotas: 8388
# Reached quotas: 8391
# Reached quotas: 8394
# Reached quotas: 8397
# Reached quotas: 8400
# Reached quotas: 8403
# Reached quotas: 8406
# Reached quotas: 8409
# Reached quotas: 8412
# Reached quotas: 8415
# Reached quotas: 8418
# Reached quotas: 8421
# Reached quotas: 8424
# Reached quotas: 8427
# Reached quotas: 8430
# Reached quotas: 8433
# Reached quotas: 8436
# Reached quotas: 8439
# Reached quotas: 8442
# Reached quotas: 8445
# Reached quotas: 8448
# Reached quotas: 8451
# Reached quotas: 8454
# Reached quotas: 8457
# Reached quotas: 8460
# Reached quotas: 8463
# Reached quotas: 8466
# Reached quotas: 8469
# Reached quotas: 8472
# authorChannelId
# Problem with commentThread Ugw4HPqfAi7kWm4HsfF4AaABAg
# Reached quotas: 8475
# Reached quotas: 8478
# Reached quotas: 8481
# Reached quotas: 8484
# Reached quotas: 8487
# Reached quotas: 8490
# Reached quotas: 8493
# Reached quotas: 8496
# Reached quotas: 8499
# Reached quotas: 8502
# Reached quotas: 8505
# Reached quotas: 8508
# Reached quotas: 8511
# Reached quotas: 8514
# Reached quotas: 8517
# Reached quotas: 8520
# Reached quotas: 8523
# Reached quotas: 8526
# Reached quotas: 8529
# Reached quotas: 8532
# Reached quotas: 8535
# Reached quotas: 8538
# Reached quotas: 8541
# Reached quotas: 8544
# Reached quotas: 8547
# Reached quotas: 8550
# Reached quotas: 8553
# Reached quotas: 8556
# Reached quotas: 8559
# Reached quotas: 8562
# Reached quotas: 8565
# Reached quotas: 8568
# Reached quotas: 8571
# Reached quotas: 8574
# Reached quotas: 8577
# Reached quotas: 8580
# Reached quotas: 8583
# Reached quotas: 8586
# Reached quotas: 8589
# Reached quotas: 8592
# Reached quotas: 8595
# Reached quotas: 8598
# Reached quotas: 8601
# Reached quotas: 8604
# authorChannelId
# Problem with commentThread UgxofyDgxY3HF9gQu_J4AaABAg
# Reached quotas: 8607
# Reached quotas: 8610
# Reached quotas: 8613
# Reached quotas: 8616
# Reached max comment count
# Total comments for Nl2qBUJVNeM: 10000
# ________________________________________________________
# 771 video: XYYDahkQJ_E
# Reached quotas: 8619
# Reached quotas: 8622
# Reached quotas: 8625
# Reached quotas: 8628
# Reached quotas: 8631
# Reached quotas: 8634
# Reached quotas: 8637
# Reached quotas: 8640
# Reached quotas: 8643
# Reached quotas: 8646
# Reached quotas: 8649
# Reached quotas: 8652
# Reached quotas: 8655
# Reached quotas: 8658
# Reached quotas: 8661
# Reached quotas: 8664
# Reached quotas: 8667
# Reached quotas: 8670
# Reached quotas: 8673
# Reached quotas: 8676
# Reached quotas: 8679
# Reached quotas: 8682
# Page token non esistente
# Total comments for XYYDahkQJ_E: 2170
# ________________________________________________________
# 772 video: rcx1ExValUI
# Reached quotas: 8685
# Reached quotas: 8688
# Reached quotas: 8691
# Reached quotas: 8694
# Reached quotas: 8697
# Reached quotas: 8700
# Reached quotas: 8703
# Reached quotas: 8706
# Reached quotas: 8709
# Reached quotas: 8712
# Reached quotas: 8715
# Reached quotas: 8718
# Reached quotas: 8721
# Reached quotas: 8724
# Reached quotas: 8727
# Reached quotas: 8730
# Reached quotas: 8733
# Reached quotas: 8736
# Reached quotas: 8739
# Reached quotas: 8742
# Page token non esistente
# Total comments for rcx1ExValUI: 1955
# ________________________________________________________
# 773 video: kFCF6oZZrHM
# Reached quotas: 8745
# Reached quotas: 8748
# Reached quotas: 8751
# Reached quotas: 8754
# Reached quotas: 8757
# Reached quotas: 8760
# Reached quotas: 8763
# Reached quotas: 8766
# Reached quotas: 8769
# Reached quotas: 8772
# Reached quotas: 8775
# Reached quotas: 8778
# Reached quotas: 8781
# Reached quotas: 8784
# Reached quotas: 8787
# Reached quotas: 8790
# Reached quotas: 8793
# Reached quotas: 8796
# Reached quotas: 8799
# Reached quotas: 8802
# Reached quotas: 8805
# Reached quotas: 8808
# Reached quotas: 8811
# Reached quotas: 8814
# Reached quotas: 8817
# Reached quotas: 8820
# Reached quotas: 8823
# Reached quotas: 8826
# Reached quotas: 8829
# Reached quotas: 8832
# Reached quotas: 8835
# Reached quotas: 8838
# Reached quotas: 8841
# Reached quotas: 8844
# Reached quotas: 8847
# Reached quotas: 8850
# Reached quotas: 8853
# Reached quotas: 8856
# Reached quotas: 8859
# Reached quotas: 8862
# Reached quotas: 8865
# Reached quotas: 8868
# Reached quotas: 8871
# Reached quotas: 8874
# Reached quotas: 8877
# Reached quotas: 8880
# Reached quotas: 8883
# Reached quotas: 8886
# Reached quotas: 8889
# Reached quotas: 8892
# Reached quotas: 8895
# Reached quotas: 8898
# Reached quotas: 8901
# Reached quotas: 8904
# Reached quotas: 8907
# Reached quotas: 8910
# Reached quotas: 8913
# Reached quotas: 8916
# Reached quotas: 8919
# Reached quotas: 8922
# Reached quotas: 8925
# Reached quotas: 8928
# Reached quotas: 8931
# Reached quotas: 8934
# Reached quotas: 8937
# Reached quotas: 8940
# Reached quotas: 8943
# Reached quotas: 8946
# Reached quotas: 8949
# Reached quotas: 8952
# Reached quotas: 8955
# Reached quotas: 8958
# Reached quotas: 8961
# Reached quotas: 8964
# Reached quotas: 8967
# Reached quotas: 8970
# Reached quotas: 8973
# Reached quotas: 8976
# Reached quotas: 8979
# Reached quotas: 8982
# Reached quotas: 8985
# Reached quotas: 8988
# Reached quotas: 8991
# Reached quotas: 8994
# Reached quotas: 8997
# Reached quotas: 9000
# Reached quotas: 9003
# Reached quotas: 9006
# Reached quotas: 9009
# Reached quotas: 9012
# Reached quotas: 9015
# Reached quotas: 9018
# Reached quotas: 9021
# Reached quotas: 9024
# Reached quotas: 9027
# Reached quotas: 9030
# Reached quotas: 9033
# Reached quotas: 9036
# Reached quotas: 9039
# Reached quotas: 9042
# Reached max comment count
# Total comments for kFCF6oZZrHM: 10000
# ________________________________________________________
# 774 video: vF_bMn-Aj2w
# Reached quotas: 9045
# Reached quotas: 9048
# Reached quotas: 9051
# Reached quotas: 9054
# Reached quotas: 9057
# Reached quotas: 9060
# Reached quotas: 9063
# Reached quotas: 9066
# Reached quotas: 9069
# Reached quotas: 9072
# Reached quotas: 9075
# Reached quotas: 9078
# Reached quotas: 9081
# Reached quotas: 9084
# Reached quotas: 9087
# Reached quotas: 9090
# Reached quotas: 9093
# Reached quotas: 9096
# Reached quotas: 9099
# Reached quotas: 9102
# Reached quotas: 9105
# Reached quotas: 9108
# Reached quotas: 9111
# Reached quotas: 9114
# Reached quotas: 9117
# Reached quotas: 9120
# Reached quotas: 9123
# Reached quotas: 9126
# Reached quotas: 9129
# Reached quotas: 9132
# Reached quotas: 9135
# Reached quotas: 9138
# Reached quotas: 9141
# Reached quotas: 9144
# Reached quotas: 9147
# Reached quotas: 9150
# Reached quotas: 9153
# Reached quotas: 9156
# Reached quotas: 9159
# Reached quotas: 9162
# Reached quotas: 9165
# Reached quotas: 9168
# Reached quotas: 9171
# Reached quotas: 9174
# Reached quotas: 9177
# Reached quotas: 9180
# Reached quotas: 9183
# Reached quotas: 9186
# Reached quotas: 9189
# Reached quotas: 9192
# Reached quotas: 9195
# Reached quotas: 9198
# Reached quotas: 9201
# Reached quotas: 9204
# Reached quotas: 9207
# Reached quotas: 9210
# Reached quotas: 9213
# Reached quotas: 9216
# Reached quotas: 9219
# Reached quotas: 9222
# Reached quotas: 9225
# Reached quotas: 9228
# Reached quotas: 9231
# Reached quotas: 9234
# Reached quotas: 9237
# Reached quotas: 9240
# Reached quotas: 9243
# Reached quotas: 9246
# Reached quotas: 9249
# Reached quotas: 9252
# Reached quotas: 9255
# Reached quotas: 9258
# Reached quotas: 9261
# Reached quotas: 9264
# Reached quotas: 9267
# Reached quotas: 9270
# Reached quotas: 9273
# Reached quotas: 9276
# Reached quotas: 9279
# Reached quotas: 9282
# Reached quotas: 9285
# Reached quotas: 9288
# Reached quotas: 9291
# Reached quotas: 9294
# Reached quotas: 9297
# Reached quotas: 9300
# Reached quotas: 9303
# Reached quotas: 9306
# Reached quotas: 9309
# Reached quotas: 9312
# Reached quotas: 9315
# Reached quotas: 9318
# Reached quotas: 9321
# Reached quotas: 9324
# Reached quotas: 9327
# Reached quotas: 9330
# Reached quotas: 9333
# Reached quotas: 9336
# Reached quotas: 9339
# Reached quotas: 9342
# Reached max comment count
# Total comments for vF_bMn-Aj2w: 10000
# ________________________________________________________
# 775 video: cjKoqcgqwz8
# Reached quotas: 9345
# Reached quotas: 9348
# Reached quotas: 9351
# Reached quotas: 9354
# Reached quotas: 9357
# Reached quotas: 9360
# Reached quotas: 9363
# Reached quotas: 9366
# Reached quotas: 9369
# Reached quotas: 9372
# Reached quotas: 9375
# Reached quotas: 9378
# Reached quotas: 9381
# Reached quotas: 9384
# Reached quotas: 9387
# Reached quotas: 9390
# Reached quotas: 9393
# Reached quotas: 9396
# Reached quotas: 9399
# Reached quotas: 9402
# Reached quotas: 9405
# Reached quotas: 9408
# Reached quotas: 9411
# Reached quotas: 9414
# Reached quotas: 9417
# Reached quotas: 9420
# Reached quotas: 9423
# Reached quotas: 9426
# Reached quotas: 9429
# Reached quotas: 9432
# Reached quotas: 9435
# Reached quotas: 9438
# Reached quotas: 9441
# Reached quotas: 9444
# Reached quotas: 9447
# Reached quotas: 9450
# Reached quotas: 9453
# Reached quotas: 9456
# Page token non esistente
# Total comments for cjKoqcgqwz8: 3782
# ________________________________________________________
# 776 video: _chxeu8lXvI
# Reached quotas: 9459
# Reached quotas: 9462
# Reached quotas: 9465
# Reached quotas: 9468
# Reached quotas: 9471
# Reached quotas: 9474
# Reached quotas: 9477
# Reached quotas: 9480
# Reached quotas: 9483
# Reached quotas: 9486
# Reached quotas: 9489
# Reached quotas: 9492
# Reached quotas: 9495
# Reached quotas: 9498
# Reached quotas: 9501
# Reached quotas: 9504
# Reached quotas: 9507
# Reached quotas: 9510
# Reached quotas: 9513
# Reached quotas: 9516
# Reached quotas: 9519
# Reached quotas: 9522
# Reached quotas: 9525
# Reached quotas: 9528
# Reached quotas: 9531
# Reached quotas: 9534
# Reached quotas: 9537
# Reached quotas: 9540
# Reached quotas: 9543
# Reached quotas: 9546
# Reached quotas: 9549
# Reached quotas: 9552
# Reached quotas: 9555
# Reached quotas: 9558
# Reached quotas: 9561
# Reached quotas: 9564
# Reached quotas: 9567
# Reached quotas: 9570
# Reached quotas: 9573
# Reached quotas: 9576
# Reached quotas: 9579
# Reached quotas: 9582
# Reached quotas: 9585
# Reached quotas: 9588
# Reached quotas: 9591
# Reached quotas: 9594
# Reached quotas: 9597
# Reached quotas: 9600
# Reached quotas: 9603
# Reached quotas: 9606
# Reached quotas: 9609
# Reached quotas: 9612
# Reached quotas: 9615
# Reached quotas: 9618
# Reached quotas: 9621
# Reached quotas: 9624
# Reached quotas: 9627
# Reached quotas: 9630
# Reached quotas: 9633
# Reached quotas: 9636
# Reached quotas: 9639
# Reached quotas: 9642
# Reached quotas: 9645
# Reached quotas: 9648
# Reached quotas: 9651
# Page token non esistente
# Total comments for _chxeu8lXvI: 6428
# ________________________________________________________
# 777 video: Lm7Yo4gGYpY
# Reached quotas: 9654
# Reached quotas: 9657
# Reached quotas: 9660
# Reached quotas: 9663
# Reached quotas: 9666
# Reached quotas: 9669
# Reached quotas: 9672
# Reached quotas: 9675
# Reached quotas: 9678
# Reached quotas: 9681
# Reached quotas: 9684
# Reached quotas: 9687
# Reached quotas: 9690
# Page token non esistente
# Total comments for Lm7Yo4gGYpY: 1245
# ________________________________________________________
# 778 video: ouPNHGUNX_I
# Reached quotas: 9693
# Video has disabled comments
# Total comments for ouPNHGUNX_I: 0
# ________________________________________________________
# 779 video: v92cvrnEzwM
# Reached quotas: 9693
# Reached quotas: 9696
# Reached quotas: 9699
# Reached quotas: 9702
# Reached quotas: 9705
# Reached quotas: 9708
# Reached quotas: 9711
# Reached quotas: 9714
# Reached quotas: 9717
# Reached quotas: 9720
# Reached quotas: 9723
# Reached quotas: 9726
# Reached quotas: 9729
# Reached quotas: 9732
# Reached quotas: 9735
# Reached quotas: 9738
# Reached quotas: 9741
# Reached quotas: 9744
# Reached quotas: 9747
# Reached quotas: 9750
# Page token non esistente
# Total comments for v92cvrnEzwM: 1942
# ________________________________________________________
# 780 video: sXk2FKp8STw
# Reached quotas: 9753
# Video has disabled comments
# Total comments for sXk2FKp8STw: 0
# ________________________________________________________
# 781 video: REWS3npz8e8
# Reached quotas: 9753
# Reached quotas: 9756
# Reached quotas: 9759
# Reached quotas: 9762
# Reached quotas: 9765
# Reached quotas: 9768
# Reached quotas: 9771
# Reached quotas: 9774
# Reached quotas: 9777
# Reached quotas: 9780
# Reached quotas: 9783
# Reached quotas: 9786
# Reached quotas: 9789
# Reached quotas: 9792
# Reached quotas: 9795
# Reached quotas: 9798
# Reached quotas: 9801
# Reached quotas: 9804
# Reached quotas: 9807
# Reached quotas: 9810
# Reached quotas: 9813
# Reached quotas: 9816
# Reached quotas: 9819
# Reached quotas: 9822
# Reached quotas: 9825
# Reached quotas: 9828
# Reached quotas: 9831
# Reached quotas: 9834
# Reached quotas: 9837
# Reached quotas: 9840
# Reached quotas: 9843
# Reached quotas: 9846
# Reached quotas: 9849
# Reached quotas: 9852
# Reached quotas: 9855
# Reached quotas: 9858
# Reached quotas: 9861
# Reached quotas: 9864
# Reached quotas: 9867
# Reached quotas: 9870
# Reached quotas: 9873
# Reached quotas: 9876
# Reached quotas: 9879
# Reached quotas: 9882
# Reached quotas: 9885
# Reached quotas: 9888
# Reached quotas: 9891
# Reached quotas: 9894
# Reached quotas: 9897
# Reached quotas: 9900
# Reached quotas: 9903
# Quota exceeded
# Done with 5197179 comments, video to start: 781
#  with next_page_token: QURTSl9pMnJqMWdmS2d2bndjN0tMODd2ZkJKS1pCbm9sX25fVy0zeV84X2dtUTRnMXJmdk5fQmgyX1FMb05IUEtWTXRaN25NWGF6RjF5SzZvVk1JanNVc2hvZEZ5UTU3X0Y5b19jS1NYLVp0SmdPbDhBMkd4UnVwWW43U3dGMF85Uk9fZUt6OUlsbExTS28=

# %%
np.save('data/get_comment_threads_output/next_page_token.npy',next_page_token)
np.save('data/get_comment_threads_output/video_to_start.npy',last_video_idx)
np.save('data/get_comment_threads_output/videos_not_finished.npy',videos_not_finished)
np.save('data/get_comment_threads_output/videos_disabled_comments.npy',videos_disabled_comments)

# %%
print(next_page_token, last_video_idx)
# Out:
# QURTSl9pMnJqMWdmS2d2bndjN0tMODd2ZkJKS1pCbm9sX25fVy0zeV84X2dtUTRnMXJmdk5fQmgyX1FMb05IUEtWTXRaN25NWGF6RjF5SzZvVk1JanNVc2hvZEZ5UTU3X0Y5b19jS1NYLVp0SmdPbDhBMkd4UnVwWW43U3dGMF85Uk9fZUt6OUlsbExTS28= 781

# %%
format_ok_comments = []
for outer_comment in comments:
    for comment in outer_comment:
        format_ok_comments.append(comment)

# %%
format_ok_comments
# Out:
# [['lOIFYf3sSnw',
#   'UgzB4FfWZ4Qo6bWz-Qx4AaABAg',
#   'UgzB4FfWZ4Qo6bWz-Qx4AaABAg',
#   'Adrienna Sanchez',
#   'UCf6BmGmDiZNJRtElp8JN6rA',
#   'Jackie i thought we were protesting Gucci please let this be poochie PWEASE'],
#  ['lOIFYf3sSnw',
#   'UgzfU4jGzdCh429h6PR4AaABAg',
#   'UgzfU4jGzdCh429h6PR4AaABAg',
#   'Mia M',
#   'UCOmMImoNnK3ic9at-owrA6g',
#   'I eat only cheese-less pizza! 🙌🏽'],
#  ['lOIFYf3sSnw',
#   'UgzOl3Wi4EgvZ0A6OBJ4AaABAg',
#   'UgzOl3Wi4EgvZ0A6OBJ4AaABAg',
#   'NazneenR1',
#   'UCEaTiiOj-ucuw45RR_MilgQ',
#   'Curious to know what Jackie uses to spot treat her breakouts 🤔'],
#  ['lOIFYf3sSnw',
#   'Ugy2Yx_WfYLtPY1A_JB4AaABAg',
#   'Ugy2Yx_WfYLtPY1A_JB4AaABAg',
#   'Tameka Green',
#   'UCMMMLrdLzGR4ihGSKREXiFA',
#   'Jackie I’ve watched your video and love watching what you stand for. Don’t give up let the hater’s  kick rocks. I pray for more blessing on you. Thank you your fan. ❤️👏🏾🍾'],
#  ['lOIFYf3sSnw',
#   'UgzFiQsQdq1UJM5D0894AaABAg',
#   'UgzFiQsQdq1UJM5D0894AaABAg',
#   'Arnetha Earl',
#   'UCWEVEOmPeCtmW1arIVJbEAg',
#   '"Will I be greasy lol "'],
#  ['lOIFYf3sSnw',
#   'Ugy3sppUv-0SkjNvMop4AaABAg',
#   'Ugy3sppUv-0SkjNvMop4AaABAg',
#   'vamperkillzshy',
#   'UCFZ3wYFkOdyQr1cCFZNddCg',
#   'When someone complains of one little pimple lol'],
#  ['lOIFYf3sSnw',
#   'Ugz_co1s9NHspCSBXVB4AaABAg',
#   'Ugz_co1s9NHspCSBXVB4AaABAg',
#   'The',
#   'UCfB8TUhY2dujHNe-LdBBfZA',
#   'Yo that jab at summer bunni 😂💀'],
#  ['lOIFYf3sSnw',
#   'UgxnmEi16HYle3ltiTp4AaABAg',
#   'UgxnmEi16HYle3ltiTp4AaABAg',
#   'Kueen Kettely',
#   'UC-sOOfBhw-gvHNTE3RVc2ow',
#   'Was that Nicki Minaj talking and laughing...the pimple...😆😂😆😆😂  💘 u Jackie...Definitely will try this foundation'],
#  ['lOIFYf3sSnw',
#   'UgyPIz_XSF029UcHXxh4AaABAg',
#   'UgyPIz_XSF029UcHXxh4AaABAg',
#   'Throw on some Makeup',
#   'UCGkXo-wJLAtFqQodK4TrFcw',
#   'The pimple part I—- 💀💀💀💀'],
#  ['lOIFYf3sSnw',
#   'Ugx3Rhl_sIA9xEcxcsV4AaABAg',
#   'Ugx3Rhl_sIA9xEcxcsV4AaABAg',
#   'Stephanie Velazquez de Garrick',
#   'UCx8DYk2WGejTsgXkQu0lvag',
#   'LOL sis the finish clearly says Natural, not matte. I think you’re looking at the original description and those shade descriptions didn’t change 😂😂 take your L and go hahaha Love you!'],
#  ['lOIFYf3sSnw',
#   'UgxAOpn7P3n__MCWvmR4AaABAg',
#   'UgxAOpn7P3n__MCWvmR4AaABAg',
#   'Thee Walkers',
#   'UC2lfDaB8M08kz-xrH0Uz-xg',
#   'It looks good af for it to be a hydrating foundation'],
#  ['lOIFYf3sSnw',
#   'UgySkno-wjv7DHPHUnx4AaABAg',
#   'UgySkno-wjv7DHPHUnx4AaABAg',
#   'SANIA ARSHAD BASHIR MALIK',
#   'UCR3GTMmIgG2rmQktpEIOMEg',
#   'Hey everyone subscribe to my Chanel for no reason please🙏🙏🙏🙏'],
#  ['lOIFYf3sSnw',
#   'UgymzfotXIEundqfvlp4AaABAg',
#   'UgymzfotXIEundqfvlp4AaABAg',
#   'Queeneth Gwatidzo',
#   'UCQqaj5Jd6qNaKxk01F6tClg',
#   'Oh my days you are a vibe!! I love you and your personality, the talking pimple had me in stitches 😂😂'],
#  ['lOIFYf3sSnw',
#   'UgzJa9HMCkK6Yr1Uwdh4AaABAg',
#   'UgzJa9HMCkK6Yr1Uwdh4AaABAg',
#   'MsCeCe T',
#   'UCDvFoFPeY8fXcCQIBDnU4VA',
#   'I can do relate to the mouth area ..my hyperpigmentation is soooo bad I haven’t been able to find the best full coverage foundation sometimes even the color corrector doesn’t last 😩😩'],
#  ['lOIFYf3sSnw',
#   'UgxQt0K77ohb708aNHR4AaABAg',
#   'UgxQt0K77ohb708aNHR4AaABAg',
#   'Lunaedea7',
#   'UCH-PVao3AjPog3lTvoqe2Ug',
#   'This is no longer a makeup channel- it’s a full on comedy channel, lmao! When your pimple started whispering I did a whole spit take right into my phone HAHAHA'],
#  ['lOIFYf3sSnw',
#   'UgztdVqfoierNy8dlph4AaABAg',
#   'UgztdVqfoierNy8dlph4AaABAg',
#   'nannypans',
#   'UCRihwMLU7CsfIRdD5J3JO5A',
#   'Hmmm where were all these criticisms on the matte foundation when you gave it a glowing review?  I’d like to see updated opinions from gurus on these foundations.  That’s an idea for more content and it makes your opinions seem more genuine.'],
#  ['lOIFYf3sSnw',
#   'UgwhTYw9gWrQLW51DsR4AaABAg',
#   'UgwhTYw9gWrQLW51DsR4AaABAg',
#   'Josie C',
#   'UCEcn6fZOjim5WPqExrbBJlw',
#   "I don't have much pigmentation so i don't know but if a foundation is full coverage enough then you wouldn't need to colour correct?"],
#  ['lOIFYf3sSnw',
#   'Ugzf1Duwcg-uTuyi3pR4AaABAg',
#   'Ugzf1Duwcg-uTuyi3pR4AaABAg',
#   'Emily Ceballos',
#   'UCN_7aTN6v7r5zh34P14E_EA',
#   'she hit us with the that’s so raven editing thank u'],
#  ['lOIFYf3sSnw',
#   'UgxqjMVAn5V3e47OezV4AaABAg',
#   'UgxqjMVAn5V3e47OezV4AaABAg',
#   'Cory Davis',
#   'UCSu_p5fKwcv0jIL7DIRd5-w',
#   'Say it with me now:\nJackie Jackie Jackie, Jackie Jackie, JaCKie JacKIe! Love you girl <3'],
#  ['lOIFYf3sSnw',
#   'UgxMqLJh6RBPvLFaZC14AaABAg',
#   'UgxMqLJh6RBPvLFaZC14AaABAg',
#   'iHypnxtic',
#   'UC1AYITJvheHrOYtLRtipYxg',
#   'We out here still wearing Gucci? 🤦🏾\u200d♀️🤦🏾\u200d♀️'],
#  ['lOIFYf3sSnw',
#   'UgxuKWgAllb53kLWMNN4AaABAg',
#   'UgxuKWgAllb53kLWMNN4AaABAg',
#   "Porsha' Yancey",
#   'UCu141TWCxnyIZvAqfTzY02w',
#   'Jackie I love you keep up the good work.'],
#  ['lOIFYf3sSnw',
#   'UgzhFJ-HQMuXJxmxvP94AaABAg',
#   'UgzhFJ-HQMuXJxmxvP94AaABAg',
#   'Iamtoastii',
#   'UC50vpCxuvt6zuTMjfD868ng',
#   'Would you ever go vegan ?? ♥️ love you'],
#  ['lOIFYf3sSnw',
#   'UgzfPVU0r709YXqZMbB4AaABAg',
#   'UgzfPVU0r709YXqZMbB4AaABAg',
#   'Tiff Benson',
#   'UC4lKHUYqvm74znBF6qSnYig',
#   '😍 Love me some Jackie Ainaaaaaaa! Jackie Jackie Jackie Jackie --  Jackie Jackie Jackie --  Jackie Jackie Jackie Jackie!  😘'],
#  ['lOIFYf3sSnw',
#   'UgwgffFsRF0Wuo_AhWh4AaABAg',
#   'UgwgffFsRF0Wuo_AhWh4AaABAg',
#   'ChantalRochelle',
#   'UC6cZOoyEncwn_W4dQWRtJVQ',
#   '9:13.'],
#  ['lOIFYf3sSnw',
#   'Ugw8bY-oIr1aqLzcw4N4AaABAg',
#   'Ugw8bY-oIr1aqLzcw4N4AaABAg',
#   'Gloria Campos',
#   'UC2la3AG5s39FB14TEHT0M1g',
#   'Bare face with just the complexion products I get MAD Beyoncé vibes'],
#  ['lOIFYf3sSnw',
#   'Ugx3N-5uJgahS2YErSx4AaABAg',
#   'Ugx3N-5uJgahS2YErSx4AaABAg',
#   'Monique Alecia',
#   'UCPp8qrxYJArRgfNGxyJFlsA',
#   'OMGGG  nahh the pimple close up finished me lmaoo'],
#  ['lOIFYf3sSnw',
#   'Ugz3H7vuVmCprJ6bQMp4AaABAg',
#   'Ugz3H7vuVmCprJ6bQMp4AaABAg',
#   'Halima Omar',
#   'UCeYWepTWez14B5qKZBU0q6A',
#   "JACKIE! WHY DIDN'T YOU FILM THE EYES!!!! MAKE REFILM IT . THANKS"],
#  ['lOIFYf3sSnw',
#   'UgwA7HzkqhcJnrS-1DJ4AaABAg',
#   'UgwA7HzkqhcJnrS-1DJ4AaABAg',
#   'freakyfro99',
#   'UCjPzt8kqdEdtLmHRU9Y_Q2A',
#   '"Who needs cheese anywaaaaay"\n\n\n This offends my French ancestry, cheese is life!'],
#  ['lOIFYf3sSnw',
#   'UgyJyoUcVr6ffWCawqd4AaABAg',
#   'UgyJyoUcVr6ffWCawqd4AaABAg',
#   'Alexa Calderon',
#   'UCVxbgPomGrGT9Jp_T-IqC3A',
#   'Me and my coworker were started doing your intro together and we were dancing 🕺 in the front of our store 😂😂 you are very loved ❤️❤️'],
#  ['lOIFYf3sSnw',
#   'UgxztIEtRrtiL-S84sB4AaABAg',
#   'UgxztIEtRrtiL-S84sB4AaABAg',
#   'Peace & Soul',
#   'UCaAgawA83hnKLDETO_kI1mA',
#   'You are cracking me up. Lol!I may get a sample the foundation looks nice!'],
#  ['lOIFYf3sSnw',
#   'UgwWBVVJhxdXD3jZh1x4AaABAg',
#   'UgwWBVVJhxdXD3jZh1x4AaABAg',
#   'JAPANTHEUNICO',
#   'UC2AZao8y1s6Eq9ha61fW3eg',
#   'Was that pimple Miles Jai? 😂😂😂😂'],
#  ['lOIFYf3sSnw',
#   'Ugwqd_34NRv8-jbKK8B4AaABAg',
#   'Ugwqd_34NRv8-jbKK8B4AaABAg',
#   'Twenty4kay',
#   'UCtRVEVj4ZOx2hJYByEF4dxw',
#   'This eye look ...stunning'],
#  ['lOIFYf3sSnw',
#   'UgxnXrqsR1qWd18LEaR4AaABAg',
#   'UgxnXrqsR1qWd18LEaR4AaABAg',
#   'Ashley Goodrich',
#   'UCidPxNLGnFY2FhFu1TyUnww',
#   'Just Check back with the OG colors🙏🏽🙏🏽🙏🏽'],
#  ['lOIFYf3sSnw',
#   'UgxY58Dg_EUk5T61OMZ4AaABAg',
#   'UgxY58Dg_EUk5T61OMZ4AaABAg',
#   'Kaela Pierott',
#   'UCx32fO1Y_uVmLHgw7ygU3aA',
#   'am I weird that I actually have combo skin more on the dry side... and I actually prefer the Matte formula bc in my opinion it’s more full coverage.. I feel like the hydrating moves...'],
#  ['lOIFYf3sSnw',
#   'UgxO8MgHPFiWS0jiSPV4AaABAg',
#   'UgxO8MgHPFiWS0jiSPV4AaABAg',
#   'Abigail Gibson',
#   'UC4zoTQ8UQVNWXFFJp_pGXcA',
#   'Loved how she made the pimple talk and shit plus I love her intro Jackie Jackie Jackie jackie'],
#  ['lOIFYf3sSnw',
#   'Ugwhqqnit0k-BSqAmn94AaABAg',
#   'Ugwhqqnit0k-BSqAmn94AaABAg',
#   'Shelby Conrad',
#   'UCLEZ6DTwPkcNSgYfn5r01KQ',
#   'cheese-less pizza is a godsend I FEEL YOU SIS'],
#  ['lOIFYf3sSnw',
#   'Ugx_Zqo4lEPkgRndITh4AaABAg',
#   'Ugx_Zqo4lEPkgRndITh4AaABAg',
#   'Isaiah Jerome',
#   'UCFdyWRmfBTvig_a3WXtLF6g',
#   '👑👑👑👑👑'],
#  ['lOIFYf3sSnw',
#   'UgyrU1r5Pmuht1q-QwF4AaABAg',
#   'UgyrU1r5Pmuht1q-QwF4AaABAg',
#   'Yolisa B',
#   'UCPR05cTLSrZHiDYuVpsLrBw',
#   'That pimple 😭🤣🤣🤣🤣'],
#  ['lOIFYf3sSnw',
#   'UgxAJnSrSuDda9p91ux4AaABAg',
#   'UgxAJnSrSuDda9p91ux4AaABAg',
#   'Super hero sisters Xox',
#   'UCzn1eIw8XLNqq9W8lscTzCA',
#   'Who else got a ferry ad on this vid 🤷\u200d♀️'],
#  ['lOIFYf3sSnw',
#   'UgxOoeoJRBCWo7DtT3l4AaABAg',
#   'UgxOoeoJRBCWo7DtT3l4AaABAg',
#   'Gina Coates',
#   'UCVhSZ00Bf3v3T4ffz3aeEdA',
#   'You’re too much 😂😂😂😂'],
#  ['lOIFYf3sSnw',
#   'UgzB7EyVfRs08wSTSBt4AaABAg',
#   'UgzB7EyVfRs08wSTSBt4AaABAg',
#   'Pamela Smith',
#   'UC8uM9w12o72CURcVgbank0Q',
#   'I love that nacklace!'],
#  ['lOIFYf3sSnw',
#   'UgzNitsU8o6nZ544TR14AaABAg',
#   'UgzNitsU8o6nZ544TR14AaABAg',
#   'Beautiful Jo',
#   'UCoPNpSM4Om9lKEU4Vr2bf5Q',
#   'Auntyyyyy I’m distracted by the ROCK 😍😍 come through ❤️'],
#  ['lOIFYf3sSnw',
#   'UgwfFx8cqO0RrY9vTyh4AaABAg',
#   'UgwfFx8cqO0RrY9vTyh4AaABAg',
#   'Marielena Gastelum',
#   'UCiXqCH1_PoeWjtlL9LCzIrg',
#   'the pimple bit killed meeeee sis 😂'],
#  ['lOIFYf3sSnw',
#   'UgxOPB-9qpuLOMrdlkJ4AaABAg',
#   'UgxOPB-9qpuLOMrdlkJ4AaABAg',
#   'um t',
#   'UCf4D2fcifpp5Kfda0K8Rbyg',
#   "In general dewy foundations yen to lean more yellow or warm. I've noticed this in chanel as one example."],
#  ['lOIFYf3sSnw',
#   'Ugw8AukidadWYFv38F54AaABAg',
#   'Ugw8AukidadWYFv38F54AaABAg',
#   "Ja'Mari",
#   'UCUuAux7MofYRlIGBCpyMmHQ',
#   'Will it work good with oily skin?'],
#  ['lOIFYf3sSnw',
#   'UgyklLFQn65enRh5PfZ4AaABAg',
#   'UgyklLFQn65enRh5PfZ4AaABAg',
#   'Robyn Jacques',
#   'UCtbDLN_RNReH8PjpmGHm1ig',
#   '15:30 Beyoncé???????'],
#  ['lOIFYf3sSnw',
#   'UgyDf5WT5qSaYjHyRg94AaABAg',
#   'UgyDf5WT5qSaYjHyRg94AaABAg',
#   'Sheldon Williams',
#   'UCeKaS7QUlVkj0jKHI-v8ELg',
#   '“Will I Be Greasy” should be a continuous segment on your channel from now on. Lol'],
#  ['lOIFYf3sSnw',
#   'UgxLdbZ3EjQNK8SQx-B4AaABAg',
#   'UgxLdbZ3EjQNK8SQx-B4AaABAg',
#   'Mykenya Simmons',
#   'UCN9AXb95MRBhGmHBot3tH2A',
#   'Nah you are getting too good with these edits😩😂😂😂🤣🤣🤣'],
#  ['lOIFYf3sSnw',
#   'Ugw3ilbNDZHr81YvTYR4AaABAg',
#   'Ugw3ilbNDZHr81YvTYR4AaABAg',
#   'Nabila Khademi',
#   'UCd6t6XOI9p7HINHRJNWPXPA',
#   'The FUCKING PIMPLE MOMENT 😭😂😭😂😭😂😭 OMFG I LOVE U JACKIE!!'],
#  ['lOIFYf3sSnw',
#   'Ugww4R9Uhtgpem8RR_d4AaABAg',
#   'Ugww4R9Uhtgpem8RR_d4AaABAg',
#   'Nma O',
#   'UCekkSYjmjTHPsSNIYqxmVCw',
#   'I eat my Pizza the same say, just no meat!'],
#  ['lOIFYf3sSnw',
#   'UgxNnu1JIVrAVQDDGvp4AaABAg',
#   'UgxNnu1JIVrAVQDDGvp4AaABAg',
#   'Chris Walton',
#   'UCoGAxeepguvek-sLhik1g_Q',
#   'Ugh, you make my day Jackie 😭🙌🏽'],
#  ['lOIFYf3sSnw',
#   'Ugy9i5S3q1vUXn4i7Bl4AaABAg',
#   'Ugy9i5S3q1vUXn4i7Bl4AaABAg',
#   'Chandra Preston',
#   'UCZx2VDAq8znI9R-os8v88-g',
#   'THANK YOU JACKIE FOR YOUR HONEST OPINION💕💕'],
#  ['lOIFYf3sSnw',
#   'UgzFNw5oyKcglT3sDDx4AaABAg',
#   'UgzFNw5oyKcglT3sDDx4AaABAg',
#   'itsmemydarling',
#   'UCrPUpc9ZW5T7xe6sU5NwNUA',
#   'Can we get an updated video of your favorite brushes pls?'],
#  ['lOIFYf3sSnw',
#   'UgwY0xlu8CwGgPoc9Id4AaABAg',
#   'UgwY0xlu8CwGgPoc9Id4AaABAg',
#   'Samantha H',
#   'UCiraX2l6XD1CAD4BLAk1vew',
#   'can someone tell me what brush she’s using? i like how it’s applying'],
#  ['lOIFYf3sSnw',
#   'UgyAv6nea7_epxzkVGh4AaABAg',
#   'UgyAv6nea7_epxzkVGh4AaABAg',
#   'debbie v',
#   'UCR3hMJtfkgJlO9vTaZk11Qg',
#   'IM NOT GOING ANY FREAKING WHERE SKSJK'],
#  ['lOIFYf3sSnw',
#   'Ugy5hNOAhat4b7UlM-54AaABAg',
#   'Ugy5hNOAhat4b7UlM-54AaABAg',
#   'Seon Gates',
#   'UCHrz0zE0kZeTO9zxMGdf3Lw',
#   '“That’s on period love, literally madness.” 😂😂'],
#  ['lOIFYf3sSnw',
#   'Ugzz3VRdWxXu1NU5zlp4AaABAg',
#   'Ugzz3VRdWxXu1NU5zlp4AaABAg',
#   'Alexa Garcia',
#   'UCanVdtvdANv7-CsVM-NdoYA',
#   'Yaaassss to cheeseless pizza. Everyone judges me, but don’t nobody need all that cheese.'],
#  ['lOIFYf3sSnw',
#   'UgwOsq1GpLZlo79E0wV4AaABAg',
#   'UgwOsq1GpLZlo79E0wV4AaABAg',
#   'Kaela Noyes',
#   'UCjYZw-ioaN_fJccG7VvLaKA',
#   'I neeeeed an eye tutorial for this look girlllll'],
#  ['lOIFYf3sSnw',
#   'Ugx2urg2ZBd7a8RS5MV4AaABAg',
#   'Ugx2urg2ZBd7a8RS5MV4AaABAg',
#   'Таня Уздемир',
#   'UC7ScCS_6l4l9GK8Jh9RV5yA',
#   "She's so disgusting 🤮🤮🤮🤮"],
#  ['lOIFYf3sSnw',
#   'UgzptXVbU7deFRxsnCx4AaABAg',
#   'UgzptXVbU7deFRxsnCx4AaABAg',
#   'Alexa Garcia',
#   'UCanVdtvdANv7-CsVM-NdoYA',
#   'Niacinamide and Zinc have changed the game for my oily skin. I use them during the day and it literally feels like I’ve powdered my skin without drying it out. It mattifies but doesn’t take moisture away.'],
#  ['lOIFYf3sSnw',
#   'Ugzi-3VQn5B6lBSK2h94AaABAg',
#   'Ugzi-3VQn5B6lBSK2h94AaABAg',
#   'Andriana LaTay',
#   'UC8XODc-auARSBxmUFmBRReA',
#   'Yoooo Jackie is funny af 🤣🤣'],
#  ['lOIFYf3sSnw',
#   'UgymoEpr5VoZryKyjoV4AaABAg',
#   'UgymoEpr5VoZryKyjoV4AaABAg',
#   'shechrissss',
#   'UC61JhvoTCcGqEf2MxUR4pVw',
#   "420  was definitely neutral in the original launch! you're not trippin. love your content and what you stand for :)"],
#  ['lOIFYf3sSnw',
#   'UgwknM2Ok-T5phO1Igd4AaABAg',
#   'UgwknM2Ok-T5phO1Igd4AaABAg',
#   'Jose Rosario',
#   'UCV_dQlUAUPYZ3tJFY1hAhLA',
#   'Was that Nicki Minaj’s voice 🤣'],
#  ['lOIFYf3sSnw',
#   'Ugzko-OHxVHdfJX6IAV4AaABAg',
#   'Ugzko-OHxVHdfJX6IAV4AaABAg',
#   'ScottyUnfamous',
#   'UClCaeEW1Sojb9ldhCyg6hnA',
#   'Jackie, please do a tutorial on that eye look coz I actually had to pause the video when i saw it and clutch my pearls. You. Look. BOMB!'],
#  ['lOIFYf3sSnw',
#   'UgxCH6CAg8DJqbUYgMZ4AaABAg',
#   'UgxCH6CAg8DJqbUYgMZ4AaABAg',
#   'Skysthelimit212',
#   'UC-uugusSMCjOdCyyEICooUw',
#   'I wasnt going to buy this until Jackie reviewed it'],
#  ['lOIFYf3sSnw',
#   'UgyEjdXip41lOXS0vbV4AaABAg',
#   'UgyEjdXip41lOXS0vbV4AaABAg',
#   'cachetona',
#   'UCVUSOb9HtxPSNlU_Ebw2_yw',
#   'Jackkky I fffkkin hate you so much 9:13 😂😂😂😂💀😭'],
#  ['lOIFYf3sSnw',
#   'UgxJjwD3DOk3JIhKspJ4AaABAg',
#   'UgxJjwD3DOk3JIhKspJ4AaABAg',
#   'TP Anderson',
#   'UCmIpSoER0tr5roqj3rXgB1Q',
#   'Woooow. Great.'],
#  ['lOIFYf3sSnw',
#   'UgyMD6qMiV0mtKx9UdV4AaABAg',
#   'UgyMD6qMiV0mtKx9UdV4AaABAg',
#   'Anna Rain',
#   'UCW4pSo_SfFfGY-cs3abrwJg',
#   'Omfg the pimple had me fucking dying😂😂😂😂😂😂😂😂😂 your editing has been super funny lately 🙌🏼💯 like your most recent videos have me dying😂😂😂😂😂 editing skills on point🙌🏼💯💯'],
#  ['lOIFYf3sSnw',
#   'UgzWWvU52wdSSGvqQY54AaABAg',
#   'UgzWWvU52wdSSGvqQY54AaABAg',
#   'Maraya Payne',
#   'UCg74qHJgBAcuXAMB1lKiI1Q',
#   'The silver powder by Mario bedescu is magic! Any pimple that pops up I put some on before bed and next day it’s almost gone. I’ve had a large painful pimple on my chin it hurt so bad. Two nights of silver powder and it’s pretty much gone! I had this stupid pimple for a whole two weeks too . Try it if you get random pop up ones, it’s so handy to have !'],
#  ['lOIFYf3sSnw',
#   'UgxW8PM5OYvHSxEqlDh4AaABAg',
#   'UgxW8PM5OYvHSxEqlDh4AaABAg',
#   'Addie Gay',
#   'UC6QiF23ObwUrl2PzroRRNzQ',
#   'Literally bought the foundation after this 🤷\u200d♀️'],
#  ['lOIFYf3sSnw',
#   'Ugw0l346fhak2KueHtB4AaABAg',
#   'Ugw0l346fhak2KueHtB4AaABAg',
#   'Anna Rain',
#   'UCW4pSo_SfFfGY-cs3abrwJg',
#   'I swear I sing with you every intro🙌🏼💯❤️❤️❤️'],
#  ['lOIFYf3sSnw',
#   'UgzR3QlKu6ONnvgi0Kt4AaABAg',
#   'UgzR3QlKu6ONnvgi0Kt4AaABAg',
#   'Lovely Leina',
#   'UC0WA3Qb44oTQSroh_G-3osw',
#   '“I’m not going any freaking wheeeeerreeeee” 💀💀💀'],
#  ['lOIFYf3sSnw',
#   'UgwQ-LReI-l5KDI43qB4AaABAg',
#   'UgwQ-LReI-l5KDI43qB4AaABAg',
#   'Nancy Purter',
#   'UCnjk7Ksr6h381ZdmidwfoXg',
#   'Love you BIG ♥️♥️♥️'],
#  ['lOIFYf3sSnw',
#   'UgzHrrLhWg3f_VPNnq54AaABAg',
#   'UgzHrrLhWg3f_VPNnq54AaABAg',
#   'Thelma Moore',
#   'UCDceUGZC93cn1jY50GfO_yg',
#   'Aunty Jackie!!! You almost killed meeeee!! I literally choked and had to wheeze for air when you did that pimple close up😭😂🤣🤣🤣😂'],
#  ['lOIFYf3sSnw',
#   'UgxEZKIcD1YP2NFYOi54AaABAg',
#   'UgxEZKIcD1YP2NFYOi54AaABAg',
#   'The Plannernista',
#   'UCm8DWde69R4gIcKwjbe_7Yw',
#   'I am going to try this because the Soft matte makes my skin look and feel really dry.'],
#  ['lOIFYf3sSnw',
#   'UgyqV0kNIkHynKnB8NF4AaABAg',
#   'UgyqV0kNIkHynKnB8NF4AaABAg',
#   'Germiah Seymore',
#   'UCDovEXJNYKcsDaD-wms8-LQ',
#   'At this point, I just need to know who your editor is 😂😂😭'],
#  ['lOIFYf3sSnw',
#   'Ugx2MhI8hoIqcmFt_mJ4AaABAg',
#   'Ugx2MhI8hoIqcmFt_mJ4AaABAg',
#   'Ariana Maria',
#   'UC-INfnrGAukRa0wqSr4qxYw',
#   'jackie came back on camera with the full face and eyes MY MOUTH DROPPED'],
#  ['lOIFYf3sSnw',
#   'UgxusMqGOA9yeMKt8_F4AaABAg',
#   'UgxusMqGOA9yeMKt8_F4AaABAg',
#   "Sada' Demoin",
#   'UCjke5g-WfZgnMtdVAOZ5xFQ',
#   'The editing is bomb!! And now I want to try the foundation cause it really does look good on you!!'],
#  ['lOIFYf3sSnw',
#   'Ugz-5K9l4coM1Ex1IlV4AaABAg',
#   'Ugz-5K9l4coM1Ex1IlV4AaABAg',
#   'DELA DIAMOND',
#   'UC0BcyGV0TzLr_DdchAfegOA',
#   'I love how you support people it’s so wonderful'],
#  ['lOIFYf3sSnw',
#   'UgyKcZPVAW0ACOkqO3p4AaABAg',
#   'UgyKcZPVAW0ACOkqO3p4AaABAg',
#   'Becca Flaig',
#   'UCj2b4DAzJuJM-1IXIH32c2A',
#   '“Long perioladically time” has me dead😂😂'],
#  ['lOIFYf3sSnw',
#   'Ugz9Je1wva-SnrlkUt94AaABAg',
#   'Ugz9Je1wva-SnrlkUt94AaABAg',
#   'Elise G',
#   'UC9V7z7oVsTnxM4Z_TBk8OGw',
#   'When she changed in to that black probe and suddenly went from Jackie Aina  to James Bond Jackie'],
#  ['lOIFYf3sSnw',
#   'Ugz48IKBB5BGxl7-zYR4AaABAg',
#   'Ugz48IKBB5BGxl7-zYR4AaABAg',
#   'Elisa Lewis',
#   'UC1ehFtovLwaGhkJlA8ZjowQ',
#   'You always have me in stitches'],
#  ['lOIFYf3sSnw',
#   'UgyGpcIC0cEpurGVfZB4AaABAg',
#   'UgyGpcIC0cEpurGVfZB4AaABAg',
#   'DivabyDesign mua',
#   'UC1Js8UCYLVH7vq9p2K4uHVA',
#   'Ok auntie!!! You have gots to do a video on how you got your eye look💜💗💜💓💜'],
#  ['lOIFYf3sSnw',
#   'UgwhfBnDwjmKxNS3khd4AaABAg',
#   'UgwhfBnDwjmKxNS3khd4AaABAg',
#   'Purplekitty',
#   'UCpfSZ5bv2LTbJ0ioB3itMxA',
#   "This is why I prefer  Fenty. They listen to what the customers want.\nThey take a cue around at what isn't working from other beauty brands, (Kardashians) and do the opposite"],
#  ['lOIFYf3sSnw',
#   'UgyZ0DgxF3NuoP4qarJ4AaABAg',
#   'UgyZ0DgxF3NuoP4qarJ4AaABAg',
#   'MianaAjanae',
#   'UCZsTEEt38lBrc-3tuz1SWjQ',
#   'Wooowwwww I love this what I needed'],
#  ['lOIFYf3sSnw',
#   'UgxOqiq9fvKkpwDXUlx4AaABAg',
#   'UgxOqiq9fvKkpwDXUlx4AaABAg',
#   'Hxllelujah',
#   'UCAY2EKUGDQndC4dMeuA6JBQ',
#   'Jackie you can’t do that when I’m not ready'],
#  ['lOIFYf3sSnw',
#   'UgzG4JZrDSL5XxB3mmV4AaABAg',
#   'UgzG4JZrDSL5XxB3mmV4AaABAg',
#   'SimaRalph',
#   'UCH2Hyxg9rAVOzQp2BKRX5Zg',
#   "I can't give up cheese😫"],
#  ['lOIFYf3sSnw',
#   'UgzmJkLks27lKHML5h14AaABAg',
#   'UgzmJkLks27lKHML5h14AaABAg',
#   'Colzie Tucker',
#   'UC-Nuu1Xyyat1pVN5mEf3dog',
#   'That pimple talk though!!!!!! Lol'],
#  ['lOIFYf3sSnw',
#   'UgzB_CLZ0fi1phU6ttJ4AaABAg',
#   'UgzB_CLZ0fi1phU6ttJ4AaABAg',
#   'Mariah Noel',
#   'UCqftKDEO0-UZAP3tdwfbugg',
#   'Here for you sis love you'],
#  ['lOIFYf3sSnw',
#   'Ugw6wamYNCXSj8-89Fx4AaABAg',
#   'Ugw6wamYNCXSj8-89Fx4AaABAg',
#   'MosDefSteph510',
#   'UCUx0dwNWbTrYtDjmCH9HExg',
#   'Ok cheese less pizza? Girl why?!!! No ma’am 🤣'],
#  ['lOIFYf3sSnw',
#   'UgwVxe-A_0NTfON6DvB4AaABAg',
#   'UgwVxe-A_0NTfON6DvB4AaABAg',
#   'Jade Eichelberger',
#   'UCqZFnHdNtpDdWX_zNC_o8FA',
#   'Someone called you the Beyoncé of YouTube beauty gurus, and I couldn’t agree more.'],
#  ['lOIFYf3sSnw',
#   'UgwqnL1VFZinrN2_qCF4AaABAg',
#   'UgwqnL1VFZinrN2_qCF4AaABAg',
#   'Lyric Hoxter',
#   'UChVvkIxZCnm0fDtXfHPwOVQ',
#   'The pimple edit KILLED ME 😂😂😂😂'],
#  ['lOIFYf3sSnw',
#   'UgzBacLQ8P5Lg05WQdV4AaABAg',
#   'UgzBacLQ8P5Lg05WQdV4AaABAg',
#   'Shay Khan',
#   'UCkoa6kzHvvbMecFfkp-P8RQ',
#   'That pimple talking TOOK ME OUTTTTTT'],
#  ['lOIFYf3sSnw',
#   'UgxHTh1-kGFTsOkr9bp4AaABAg',
#   'UgxHTh1-kGFTsOkr9bp4AaABAg',
#   'Tywan Brown',
#   'UCXS9Ry87VNx6DBgEQgQjQsg',
#   'I’m super happy that she mad this foundation, us dry skin girls need luv too 😂 I don’t like to look extra Dewy/Luminous I like more of a soft matte, natural finish type foundation but with coverage. I do have a few matte (what I consider matte on my skin) foundations that I luv I just have to switch up my primers and stuff. \nThis foundation is Bomb 👍🏾'],
#  ['lOIFYf3sSnw',
#   'UgzbXPhgl_2IQaVKash4AaABAg',
#   'UgzbXPhgl_2IQaVKash4AaABAg',
#   'Alyssa',
#   'UCSUSyyvl1q5BfrQZkKIbstw',
#   'Would love to see you do a comparison of all three fenty primers!'],
#  ['lOIFYf3sSnw',
#   'Ugxp4b-FzbBlYx8NHCB4AaABAg',
#   'Ugxp4b-FzbBlYx8NHCB4AaABAg',
#   'Clare',
#   'UCI_3LKxouopFTLMaJH1c3Yg',
#   'jackie u radiate so much amazingness <3'],
#  ['lOIFYf3sSnw',
#   'Ugzox4-OWOFqpso9sv14AaABAg',
#   'Ugzox4-OWOFqpso9sv14AaABAg',
#   'Amza Mamza',
#   'UCK_MuMOO9bwQJg3M5y7CkBA',
#   'Gucci?'],
#  ['lOIFYf3sSnw',
#   'UgwUt1WT5punutMZNDN4AaABAg',
#   'UgwUt1WT5punutMZNDN4AaABAg',
#   'jose ortiz',
#   'UCKHmZIHb9R_GT_Q8w8Ms5Mg',
#   'Wear the super red blush under a powder foundation, I’ve seen Wayne Goss do that a lot'],
#  ['lOIFYf3sSnw',
#   'UgwWVlO8rkyVKhsh9-Z4AaABAg',
#   'UgwWVlO8rkyVKhsh9-Z4AaABAg',
#   'Lovely Jones',
#   'UCBD2gg_xs7-8_8EEpq9ueQg',
#   'I feel the same way about pimples but when you had it talking I screamt 🤣🤣🤣'],
#  ['lOIFYf3sSnw',
#   'UgzTghn83UvirQ7QJTZ4AaABAg',
#   'UgzTghn83UvirQ7QJTZ4AaABAg',
#   'QveenGrace',
#   'UCUsN9QrAkHme4GKxqgCeR9A',
#   'Your energy is unmatched 😭'],
#  ['lOIFYf3sSnw',
#   'UgxmvDSWM_l1Z9-r95t4AaABAg',
#   'UgxmvDSWM_l1Z9-r95t4AaABAg',
#   'Ivy Omari',
#   'UCon4g_0bQoXragB0lw8ue1Q',
#   'The pimple bit had me dying 😂😂 love you Jackie ❤'],
#  ['lOIFYf3sSnw',
#   'Ugzh9xiMAUwERn5H6eN4AaABAg',
#   'Ugzh9xiMAUwERn5H6eN4AaABAg',
#   'Jasmine',
#   'UC0bFvL8955DJ6L5G59W_sIg',
#   'Yes I would have to agree I like the hydrating foundation way more than the soft matte and I’m an oily girl... I feel like it’s very versatile! 😊'],
#  ['lOIFYf3sSnw',
#   'Ugwhhspf2Kolm44qkWh4AaABAg',
#   'Ugwhhspf2Kolm44qkWh4AaABAg',
#   'zucchinigreen',
#   'UC2R5A6hmCqf6yh5ZyrQ24iw',
#   "Loving the 90's steez with the duckbill clips and center part.\n\nCute!"],
#  ['lOIFYf3sSnw',
#   'UgwT_shJL9VzQstLgRR4AaABAg',
#   'UgwT_shJL9VzQstLgRR4AaABAg',
#   'Starr Jauregui',
#   'UCIg-cvW_B8fMCMz2eTu3vtA',
#   'I get pizza without cheese all the time!'],
#  ['lOIFYf3sSnw',
#   'UgyjeIu1E6zPf7nhONF4AaABAg',
#   'UgyjeIu1E6zPf7nhONF4AaABAg',
#   'Rikki Bergeron',
#   'UCrhofuZe5OKIGxZwwYAqdDg',
#   'I LOVE cheeseless pizza! I think it makes the sauce test better!'],
#  ['lOIFYf3sSnw',
#   'UgyHCTD6ZsgZViIy1Mp4AaABAg',
#   'UgyHCTD6ZsgZViIy1Mp4AaABAg',
#   'Sylverlistic',
#   'UC8gtgadeDjB6qXSKnIhjZ7w',
#   'pick a struggle lol'],
#  ['lOIFYf3sSnw',
#   'UgyPfTEFrdpRYRYvD_N4AaABAg',
#   'UgyPfTEFrdpRYRYvD_N4AaABAg',
#   "Ra'quel",
#   'UC3r0sshYg5IywFYFf-AoZ3g',
#   'ahahaha ! "you in di way" i love Jackie'],
#  ['lOIFYf3sSnw',
#   'UgwfLMOQtrg1SXzCrw14AaABAg',
#   'UgwfLMOQtrg1SXzCrw14AaABAg',
#   'Moochie xo',
#   'UC_1R6h7hsuQfE_1uEtZJvYg',
#   'lmfao Jackie you have to stop lmaooooo that pimple !!!'],
#  ['lOIFYf3sSnw',
#   'UgxeMUcXzUVu9kV8qVd4AaABAg',
#   'UgxeMUcXzUVu9kV8qVd4AaABAg',
#   'Arriana Perez',
#   'UCpJ4CpjZcwBgromvabGdiUg',
#   '“ if I feel froggy imma leap”😂😂😂'],
#  ['lOIFYf3sSnw',
#   'Ugyv1TxByBu9FBo5K7p4AaABAg',
#   'Ugyv1TxByBu9FBo5K7p4AaABAg',
#   'Oshard Henry',
#   'UCrVabma67JvFu9ASVtEnXnQ',
#   'I can’t 😂'],
#  ['lOIFYf3sSnw',
#   'UgwZam8VzWQLXcnunr94AaABAg',
#   'UgwZam8VzWQLXcnunr94AaABAg',
#   'Alexxa Ferguson',
#   'UCEvS9tdaWD-wbyN2WW-3LKQ',
#   'Hey babes you was not losing it 420 and 430 was described as neutral shades previously ... Love you lots 💙'],
#  ['lOIFYf3sSnw',
#   'Ugw9u9ieILNrIVIZMud4AaABAg',
#   'Ugw9u9ieILNrIVIZMud4AaABAg',
#   'Patricia Griffin',
#   'UCbmei3WrdEfhU1bPXv2H4Yg',
#   'I feel you on Mr. Pimple Hahaha...lol 😂🤣😅...'],
#  ['lOIFYf3sSnw',
#   'Ugx1szqBwYjaBkJcLlh4AaABAg',
#   'Ugx1szqBwYjaBkJcLlh4AaABAg',
#   'Nature Duran-Smith',
#   'UCS6U6ijArxainRSAJLerzig',
#   'we love a fiancé 😍'],
#  ['lOIFYf3sSnw',
#   'UgwvrA_ZIYbS6NZ6dPF4AaABAg',
#   'UgwvrA_ZIYbS6NZ6dPF4AaABAg',
#   'kristal Rodgers',
#   'UCxDD7CQwF_x9TIjmHuvDmUA',
#   'This editing 😂😂😂😂'],
#  ['lOIFYf3sSnw',
#   'UgyAhW_iFMAqao9Q-mF4AaABAg',
#   'UgyAhW_iFMAqao9Q-mF4AaABAg',
#   'TKtheBardess',
#   'UClZ5RuPRoYnNPCOutn648Dg',
#   "as another oily baby.....you didn't have to do this!!! but i just started the vid, i'll wait and see. But I'm nervous."],
#  ['lOIFYf3sSnw',
#   'UgyppTpkCjfIc60mB3F4AaABAg',
#   'UgyppTpkCjfIc60mB3F4AaABAg',
#   'Melanie Griffiths',
#   'UCGxyV6LnCZHMAvhvGNddtAw',
#   'Is it just me or is this a hella shiney foundation or what? Wow. RawBeautyKristie had the same issue. Way too "dewy"  she has dry skin and said it was actually a bit much for her. But that she needed to use it more to really figure it out.'],
#  ['lOIFYf3sSnw',
#   'Ugz2xUXDxoSuNGEvswZ4AaABAg',
#   'Ugz2xUXDxoSuNGEvswZ4AaABAg',
#   'Amanda Same',
#   'UC2-6OlskTb-J8SkTbDCTEUQ',
#   'The close up edit of the pimple had me CHOKINGGG'],
#  ['lOIFYf3sSnw',
#   'UgwvNFte4W2OUwHJNrd4AaABAg',
#   'UgwvNFte4W2OUwHJNrd4AaABAg',
#   'Erin',
#   'UCdhhf8kvoPHCdvB-DxbArXw',
#   'When the pimple started talking 💀'],
#  ['lOIFYf3sSnw',
#   'UgwLGZMbPHhWIVHLjVR4AaABAg',
#   'UgwLGZMbPHhWIVHLjVR4AaABAg',
#   'Destiny Latrice',
#   'UCUBBGZSiAu1Lmc8JipybMPg',
#   'We got an upload!!! We got an upload!!! 😂❤️hey auntie...... the consistency is everything 😍'],
#  ['lOIFYf3sSnw',
#   'Ugz_BhIen8znZpPF4mZ4AaABAg',
#   'Ugz_BhIen8znZpPF4mZ4AaABAg',
#   'JoJo Bc',
#   'UChCO0zCsRfqii-6x8Lb4uUw',
#   'HahahAA she inspires me to be myself lollll'],
#  ['lOIFYf3sSnw',
#   'Ugy7-IlZDFyc3LNVGM14AaABAg',
#   'Ugy7-IlZDFyc3LNVGM14AaABAg',
#   'JoJo Bc',
#   'UChCO0zCsRfqii-6x8Lb4uUw',
#   'Theeee PIMPLE ? yeah, it took me outtt'],
#  ['lOIFYf3sSnw',
#   'Ugz7jEUvFU8bGOCCX2p4AaABAg',
#   'Ugz7jEUvFU8bGOCCX2p4AaABAg',
#   'variant',
#   'UCuEn2VYPTUDbYzBu0_eid4Q',
#   'jaaaaackie how could you edit a mouth on that pimple lmaoooo'],
#  ['lOIFYf3sSnw',
#   'UgzVDeR_zN8BXRG2Ar54AaABAg',
#   'UgzVDeR_zN8BXRG2Ar54AaABAg',
#   'Mychaela Baldwin',
#   'UCBeoV-MT4HHUmucBhgR9QCg',
#   'I laughed so hard at the talking pimple 😂😂😂😂😂'],
#  ['lOIFYf3sSnw',
#   'Ugylq4fhH2zzbsr4gwR4AaABAg',
#   'Ugylq4fhH2zzbsr4gwR4AaABAg',
#   'missedjam',
#   'UCRe1YbMn6dXL8Vet72D12Yg',
#   'Can you do a tutorial on that eye look? It is bomb!'],
#  ['lOIFYf3sSnw',
#   'Ugx4uVFUZSB2Zu7oqzN4AaABAg',
#   'Ugx4uVFUZSB2Zu7oqzN4AaABAg',
#   'Freebie Babe',
#   'UCLXS92S07XAWMPgsr9bBvPA',
#   'Omg that eyeshadow. 😍'],
#  ['lOIFYf3sSnw',
#   'UgxBtT31J5MfqrmDd-N4AaABAg',
#   'UgxBtT31J5MfqrmDd-N4AaABAg',
#   'kukachoo42',
#   'UC11YDMlQxDoali_LS2E_Blg',
#   'cheeseless pizza is an awesome vegan option!'],
#  ['lOIFYf3sSnw',
#   'UgzAwlYKwEBPLOWNb854AaABAg',
#   'UgzAwlYKwEBPLOWNb854AaABAg',
#   'C for Chi',
#   'UCtBJAt9Nsgvv0Qcb2ww3VrQ',
#   '450 is lighter than 430😀'],
#  ['lOIFYf3sSnw',
#   'Ugxi2KaKeo4jz5pwdox4AaABAg',
#   'Ugxi2KaKeo4jz5pwdox4AaABAg',
#   'Agnes Kraiss',
#   'UCEJgAuUz5oSTqB2AIgstlPw',
#   '"I\'m not going any freaking where..." 😂😂😂😂😂\nLoved this video, especially when comparing the two foundations - super helpful!'],
#  ['lOIFYf3sSnw',
#   'UgwKqn3W2Prpdtv1HYl4AaABAg',
#   'UgwKqn3W2Prpdtv1HYl4AaABAg',
#   '3 X In a Row',
#   'UCcaFFlBUJApzpuNvlFVN0pg',
#   'That Nicki Minaj clip was everything'],
#  ['lOIFYf3sSnw',
#   'UgzouMVjHtJ3eqTHjMZ4AaABAg',
#   'UgzouMVjHtJ3eqTHjMZ4AaABAg',
#   'C for Chi',
#   'UCtBJAt9Nsgvv0Qcb2ww3VrQ',
#   'Will I be greasy? 🤸\u200d♂️😁'],
#  ['lOIFYf3sSnw',
#   'Ugxxe-oOeo6Vd54u97V4AaABAg',
#   'Ugxxe-oOeo6Vd54u97V4AaABAg',
#   'Sabrina Beberman',
#   'UC-Ll8ASiBMaWydgjZjwaEQg',
#   'I love the eyeshadow. I just subscribed to you and you have a fun personality, and I think that your a beautiful strong woman. Keep up with the awesome videos.'],
#  ['lOIFYf3sSnw',
#   'UgyOqe70Si-Xo7tCzDd4AaABAg',
#   'UgyOqe70Si-Xo7tCzDd4AaABAg',
#   'kukachoo42',
#   'UC11YDMlQxDoali_LS2E_Blg',
#   'jackies editing has gotten weirder and weirder'],
#  ['lOIFYf3sSnw',
#   'Ugw07dUwhIOdkuuJAVp4AaABAg',
#   'Ugw07dUwhIOdkuuJAVp4AaABAg',
#   '936rtgirl',
#   'UClkzvp3zNfJRr5aRVaDLbtw',
#   'Bruh you and that pimple...you on it 😂'],
#  ['lOIFYf3sSnw',
#   'UgzngSzk2c2FDhHhczt4AaABAg',
#   'UgzngSzk2c2FDhHhczt4AaABAg',
#   'Luza LUZAAA',
#   'UCUEcl1F94o7315KbGCUqLRg',
#   'I love it😍'],
#  ['lOIFYf3sSnw',
#   'UgwShnPSAe9qthFuFTp4AaABAg',
#   'UgwShnPSAe9qthFuFTp4AaABAg',
#   'L P',
#   'UCJhJZsD56_sC_iIFx9rvW5w',
#   'So, would you try the hydrating primer with the original formula?'],
#  ['lOIFYf3sSnw',
#   'UgzXudsDuA9YGcaHtbZ4AaABAg',
#   'UgzXudsDuA9YGcaHtbZ4AaABAg',
#   'Breeviews',
#   'UCTKed57vQ9-NUKes0IV_Dcw',
#   'Wait there’s STILL Shakeys pizza out there🍕!!!'],
#  ['lOIFYf3sSnw',
#   'UgyY577bvi0nJsGuDZZ4AaABAg',
#   'UgyY577bvi0nJsGuDZZ4AaABAg',
#   'Hindsight is 2020',
#   'UCPZCC-sXzieDTp1HW-E3Pww',
#   'LOL! Will I be greasy?'],
#  ['lOIFYf3sSnw',
#   'UgzLWXoZiaWmx9X4i6Z4AaABAg',
#   'UgzLWXoZiaWmx9X4i6Z4AaABAg',
#   'Jessica Williams',
#   'UCoF2zTL0E_CXSvOs-ubOpRw',
#   'This video was great. I love the positivity Jackie. Thank you!!'],
#  ['lOIFYf3sSnw',
#   'Ugw1ZAhkbW2gOHO6FYt4AaABAg',
#   'Ugw1ZAhkbW2gOHO6FYt4AaABAg',
#   'CocktailsMakeupandLife',
#   'UCVOt3LVg47QI_aVghTOsedg',
#   'Whoever edits your vids is the real MVP, that talking pimple tho😄'],
#  ['lOIFYf3sSnw',
#   'UgzdQu3f9raypokcIiZ4AaABAg',
#   'UgzdQu3f9raypokcIiZ4AaABAg',
#   'Samira Belle',
#   'UCeVER_HGMXWBaClYPv8DRqw',
#   'LMAO JACKIE! That pimple had me dead. I also had a pimple when I posted my review on the foundation. I liked the foundation tho and ya girl has oily skin. Rih comes through'],
#  ['lOIFYf3sSnw',
#   'UgzOIqmxSxJ4deiN0y94AaABAg',
#   'UgzOIqmxSxJ4deiN0y94AaABAg',
#   'Tobiloba Oluwawole',
#   'UCLav2YgpFTwq5MOhLQBCExQ',
#   'Cheese less is beautiful ❤️'],
#  ['lOIFYf3sSnw',
#   'Ugz8H_EcDCPCoi_z3Np4AaABAg',
#   'Ugz8H_EcDCPCoi_z3Np4AaABAg',
#   'Rachel Baker',
#   'UCEyOb_q3_qucsAXtBi0iwmw',
#   'Babe I LOVE cheeseless pizza I feel seen'],
#  ['lOIFYf3sSnw',
#   'UgwPo_VAQS99HgPaz6t4AaABAg',
#   'UgwPo_VAQS99HgPaz6t4AaABAg',
#   'Lana Rhoades',
#   'UCW5REhjQGqC60A8IW_AQPBQ',
#   'Omg you’re so funny lmfao ! The complexion looks good sis 😍😍😍😍😍'],
#  ['lOIFYf3sSnw',
#   'UgxzaXsJePDgZuqvuPF4AaABAg',
#   'UgxzaXsJePDgZuqvuPF4AaABAg',
#   'Marissa Kay',
#   'UC63lQvTN3bGJa1ki6uWqDww',
#   'Love you'],
#  ['lOIFYf3sSnw',
#   'Ugyvj_IGQ4Ctxs2FCT94AaABAg',
#   'Ugyvj_IGQ4Ctxs2FCT94AaABAg',
#   'Rachel Lawrence',
#   'UCNzq1-YOycnBaLrulY4VMxQ',
#   'Lolololololol'],
#  ['lOIFYf3sSnw',
#   'UgzWqBa7zscaWedhqXV4AaABAg',
#   'UgzWqBa7zscaWedhqXV4AaABAg',
#   'Tamika B. The Bright Side',
#   'UCdKt6sz-ZMKHq-5sL2OE0WQ',
#   "Ok Jackie I'm sick of you and these annoying video edits! 🤣🤣🤣 Making me bust out laughing at work!🤣 Yeah Fenty needs to pick a struggle, dewy or matte! The look turned out gorgeous with the Colored Rain palette!💖"],
#  ['lOIFYf3sSnw',
#   'Ugye-OpZumAHgwZamN54AaABAg',
#   'Ugye-OpZumAHgwZamN54AaABAg',
#   'PandaLover1912',
#   'UCR93dFfxv8S5INYxw-kj9CQ',
#   'The pimple said she wasn’t go any freaking where... I felt that on a spiritual level 😭💀'],
#  ['lOIFYf3sSnw',
#   'UgyVCjyRhufu67RXW514AaABAg',
#   'UgyVCjyRhufu67RXW514AaABAg',
#   'Talya Green',
#   'UCDCu4wAnqEB7kLgSNp2XgFg',
#   'I’m so glad those of us with thirsty skin are getting foundation options! 🙌🏾'],
#  ['lOIFYf3sSnw',
#   'UgzXGWlW5IA_eYA-8N54AaABAg',
#   'UgzXGWlW5IA_eYA-8N54AaABAg',
#   'Myranda T',
#   'UCeB1KwzNXJeVBlbR99xcftg',
#   'I love cheese but I hate cheese on my pizza so I always take it off. I didn’t know you could order cheeseless pizza'],
#  ['lOIFYf3sSnw',
#   'Ugx9s1tdClU74E9QWZZ4AaABAg',
#   'Ugx9s1tdClU74E9QWZZ4AaABAg',
#   'Daniella Cruz',
#   'UCW4mBVj2hkiguPKDTUZcqzg',
#   'Foundation looks amazing on you. Keep trying with your usual products primers etc and than you will know for sure if you can continue liking this. I’m going to buy this foundation for my birthday. Shade 300'],
#  ['lOIFYf3sSnw',
#   'UgygIuxmLfWVFXR8bHx4AaABAg',
#   'UgygIuxmLfWVFXR8bHx4AaABAg',
#   'Jess Campbell',
#   'UCuD6Nz100KVENAd7DcToBiw',
#   'I love Jackie Aina...i watch more than once.'],
#  ['lOIFYf3sSnw',
#   'UgwX4MiaouRzCnk_Knx4AaABAg',
#   'UgwX4MiaouRzCnk_Knx4AaABAg',
#   'karen love',
#   'UChXcymKlX7NAfTJgfzbitcA',
#   "Believe it or not, the primer bottle can be opened. It is actually a screw top. I opened mine to get every last drop of product out! That foundation is a perfect match. It looks like you don't have on foundation."],
#  ['lOIFYf3sSnw',
#   'UgyJ9RNt8P5KQPyrrId4AaABAg',
#   'UgyJ9RNt8P5KQPyrrId4AaABAg',
#   'Victoryforu',
#   'UCjsTl5WRBiuI2jIklRhw9nQ',
#   'Sis said will I be greasy! Can relate.'],
#  ['lOIFYf3sSnw',
#   'UgyRG68VMGJ2o6bnNO54AaABAg',
#   'UgyRG68VMGJ2o6bnNO54AaABAg',
#   'KAIYA HAMILTON',
#   'UC7Bx80fWEq5pyYZjxkO6nnQ',
#   'Have you ever tried the Urbanskin Rx for your uneven skin tone? I have the same problem.'],
#  ['lOIFYf3sSnw',
#   'UgyumANawGrsCE7EW3B4AaABAg',
#   'UgyumANawGrsCE7EW3B4AaABAg',
#   'Chloe Taylor',
#   'UC0mFBQG1MEBxu5kO1WFxq-A',
#   'Cheeseless pizza? Ya hi  9 - 1 fucking 1!'],
#  ['lOIFYf3sSnw',
#   'Ugy3_PTohUIfT_JhPzF4AaABAg',
#   'Ugy3_PTohUIfT_JhPzF4AaABAg',
#   'Jamilex F.',
#   'UCNqUXCyFQ3mMg2-k1uKflzg',
#   'YOU DID NOT JUST ZOOM INTO YOUR ZIT 😂😂😂'],
#  ['lOIFYf3sSnw',
#   'Ugwud_OhQqx3XFuqFB14AaABAg',
#   'Ugwud_OhQqx3XFuqFB14AaABAg',
#   'Nobi_Bklyn',
#   'UCgwpHE15x7Il9UeZ1y8f45Q',
#   'love you Jackie with your beautiful self, thanks for the positive force you are 👋🏾♥️'],
#  ['lOIFYf3sSnw',
#   'UgyIsWONAjlha8qaNTF4AaABAg',
#   'UgyIsWONAjlha8qaNTF4AaABAg',
#   'Megan Rigney',
#   'UCyFXOXD79dpMhjik7BzF0rQ',
#   '“You betta pick a struggle” 😂'],
#  ['lOIFYf3sSnw',
#   'UgyndL8UCPMRdWVY8xV4AaABAg',
#   'UgyndL8UCPMRdWVY8xV4AaABAg',
#   'Niki Nicole',
#   'UCdNSuHvUAfw2ic4LvUHk1zQ',
#   'The Family Guy Pimple LOL!!!!!!!! LMAO......🤣'],
#  ['lOIFYf3sSnw',
#   'Ugx-pZqlxz7pvweglbN4AaABAg',
#   'Ugx-pZqlxz7pvweglbN4AaABAg',
#   'Slizzy Nguyenner',
#   'UCxNh9IvRi-8uA8Dw9jzCTIw',
#   'Absolutely stunning!!'],
#  ['lOIFYf3sSnw',
#   'UgzyubaJsrDMYwTYeyF4AaABAg',
#   'UgzyubaJsrDMYwTYeyF4AaABAg',
#   'Megan Ruther',
#   'UCnCSfgdgrFMNCtzPrChzBJA',
#   "Damn I wish I could give up cheese on my Pizza but that's all I like! What is this witchcraft? Lol I'm weak wish I could give up dairy"],
#  ['lOIFYf3sSnw',
#   'Ugx3uimIVg7fS_NkKQ14AaABAg',
#   'Ugx3uimIVg7fS_NkKQ14AaABAg',
#   'DreaVibez',
#   'UCYoqTo4rvkxOYy6badfcfGg',
#   'That pimple Lawd 😂😂 love this review!!'],
#  ['lOIFYf3sSnw',
#   'UgxRVIRaftiVSgLWNi94AaABAg',
#   'UgxRVIRaftiVSgLWNi94AaABAg',
#   'Michaela Thomas',
#   'UCe4ZxvWjt500ApVJA0ud0OQ',
#   'That pimple sent me'],
#  ['lOIFYf3sSnw',
#   'UgxtSIpDCd8FLvCZ4OR4AaABAg',
#   'UgxtSIpDCd8FLvCZ4OR4AaABAg',
#   'Yaya Lee',
#   'UC35ufjsZjHA9HWNycZeYgIA',
#   'Girl cheeseless pizza is so bomb.'],
#  ['lOIFYf3sSnw',
#   'UgzhgA97pE2F3T7Pg1R4AaABAg',
#   'UgzhgA97pE2F3T7Pg1R4AaABAg',
#   'Let’s Try -N -See w Dyna B',
#   'UCq_EyXe3OF1ezT1kOB5Whgw',
#   'This pimple changed my life lol'],
#  ['lOIFYf3sSnw',
#   'Ugz3Hl9UJywh71V61nJ4AaABAg',
#   'Ugz3Hl9UJywh71V61nJ4AaABAg',
#   'Medina Rainey',
#   'UCTczyYfVPr6YU4PmGd9v7ng',
#   "They def changed the descriptions but I also think the initial descriptions weren't accurate. I was initially drawn to 420 because it used to be described as a neutral undertone but couldn't wear it because it was too warm."],
#  ['lOIFYf3sSnw',
#   'Ugy_RzKT9iqUBcGfqJF4AaABAg',
#   'Ugy_RzKT9iqUBcGfqJF4AaABAg',
#   'Takisha Johnson',
#   'UC7ef0prCNRQ0id2SpU8rLQg',
#   'Yo face is BANGIN!💜'],
#  ['lOIFYf3sSnw',
#   'Ugx-xbain_vQkjTJZHp4AaABAg',
#   'Ugx-xbain_vQkjTJZHp4AaABAg',
#   'Lateisha Mason',
#   'UCKmhwjTxhsTXvnCfHwWdwzw',
#   'Can we get that makeup tutorial or do we need to square up lol'],
#  ['lOIFYf3sSnw',
#   'UgwJByxgm2RdphKljUp4AaABAg',
#   'UgwJByxgm2RdphKljUp4AaABAg',
#   'Escorpio 11.20',
#   'UCTSchMruG0JpHGt3GZndgNg',
#   'Finally...someone that noticed they’ve changed the description on SEVERAL shades. I kept saying, “Why is no one talking about this?” I was matched for 320 which when launched was described as neutral. I tried to 330 which was too yellow & 345 is too dark. 🙄 Now i mix all 3.'],
#  ['lOIFYf3sSnw',
#   'UgwNzDr9U_MY4gtWeRV4AaABAg',
#   'UgwNzDr9U_MY4gtWeRV4AaABAg',
#   'Andjarin K GSessio',
#   'UCRsCMjksHPLKtsHOPxnS4Uw',
#   "Lmao ma'am the sniffing part😂"],
#  ['lOIFYf3sSnw',
#   'UgwXzFkgbv2SAaloeJx4AaABAg',
#   'UgwXzFkgbv2SAaloeJx4AaABAg',
#   'Raven Darkholme',
#   'UCxS98hQvncAeOgurTWGKdGA',
#   'CHEESELESS PIZZA IS WHERE ITS AT! Pro-tip: Get extra sauce on the bottom so your toppings have something to stick to!'],
#  ['lOIFYf3sSnw',
#   'UgwUnWBU4yK466FEPB94AaABAg',
#   'UgwUnWBU4yK466FEPB94AaABAg',
#   'Mariana Souza',
#   'UCmFfrTG3UpZXjnNArNJN2JQ',
#   'I love it! Honestly that’s one of the best looking foundations on your skin, auntie. I absolutely love it. I’m a very oily girl too and thought maybe this wouldn’t work but now want to give it s try. You look absolutely gorgeous, after the wear test too ❤️'],
#  ['lOIFYf3sSnw',
#   'UgyOPlP9-gep6hZnh4h4AaABAg',
#   'UgyOPlP9-gep6hZnh4h4AaABAg',
#   'Henrique Gomes',
#   'UCL2wK-dDvSAplir7wi2t_RQ',
#   'I laughed so hard on the "will I be greasy?" Part hahahaha'],
#  ['lOIFYf3sSnw',
#   'UgzKVM-yRhS-xrpPlwt4AaABAg',
#   'UgzKVM-yRhS-xrpPlwt4AaABAg',
#   'HENNESSEY',
#   'UC_q0wHXkr4NlyxJIcm08x6w',
#   'Girl I saw that 450 looking lighter'],
#  ['lOIFYf3sSnw',
#   'UgwLKy0FtsfjC1InJSd4AaABAg',
#   'UgwLKy0FtsfjC1InJSd4AaABAg',
#   'Holly Newport',
#   'UCW293eZNCe7UlL7It4xBNXA',
#   'I got the ad for Fenty before the video😂'],
#  ['lOIFYf3sSnw',
#   'Ugz_ZrAL_83l87sYTf54AaABAg',
#   'Ugz_ZrAL_83l87sYTf54AaABAg',
#   'Michelle Borsco',
#   'UC9-9ITiNkbco81IQwtrAkVw',
#   'I always get chicken on my pizza lol ask, a lot have it now'],
#  ['lOIFYf3sSnw',
#   'UgyYeatR4fM87JY8nrp4AaABAg',
#   'UgyYeatR4fM87JY8nrp4AaABAg',
#   'Kim Richey',
#   'UCx_AWLhBoGH6AzpoAX8xi4A',
#   "..and 👏👏👏👏👏👏👏 all around for Jackie's editing SKILLS! SOooo friggin good!"],
#  ['lOIFYf3sSnw',
#   'Ugz9hJ4aV_iB-M42kil4AaABAg',
#   'Ugz9hJ4aV_iB-M42kil4AaABAg',
#   'Erica Jane',
#   'UC-Z3yA0T1ErffvDb_RC6izw',
#   'Nooo that does not look matte at all....I better stay away 😬'],
#  ['lOIFYf3sSnw',
#   'UgzTpuPyal9R9POyp_Z4AaABAg',
#   'UgzTpuPyal9R9POyp_Z4AaABAg',
#   'Kimmy Ball',
#   'UCveK6iVXTtNEhjjFLbyLXXQ',
#   'Why do setting sprays have  to smell so bad??'],
#  ['lOIFYf3sSnw',
#   'UgyWuZSgguYrBdW6Pk14AaABAg',
#   'UgyWuZSgguYrBdW6Pk14AaABAg',
#   'Gabby U.S',
#   'UC3dWFM0upTR9Z-c49FhuD6Q',
#   "When I applied the soft matte, it would emphasize the texture I didn't know I had. It was a mess to say the least."],
#  ['lOIFYf3sSnw',
#   'UgxmpYK8yQvVr5Z4H0F4AaABAg',
#   'UgxmpYK8yQvVr5Z4H0F4AaABAg',
#   'January Giles',
#   'UCAEtAERs2WDcMyipkMNBeYw',
#   'We NEED a tutorial on that eye look!!!'],
#  ['lOIFYf3sSnw',
#   'UgyMGDmXoEsPgCqBbX14AaABAg',
#   'UgyMGDmXoEsPgCqBbX14AaABAg',
#   'Indy Edwards',
#   'UC0__8MV2DFBvFO3Zt9N0tFQ',
#   'His mama named  Matt, imma call him Matt!” Coming to America references 🤣🤣🤣🤣'],
#  ['lOIFYf3sSnw',
#   'Ugya9YeSGOBrxZftM9h4AaABAg',
#   'Ugya9YeSGOBrxZftM9h4AaABAg',
#   'Ameliag Green',
#   'UCUs9JPCoDO9d4eVIOxzK7xw',
#   'Jackie please do a MN meet and greet!!!!!!!!!!!'],
#  ['lOIFYf3sSnw',
#   'UgxolhfVTeHCSoFlral4AaABAg',
#   'UgxolhfVTeHCSoFlral4AaABAg',
#   'Raven Farmer',
#   'UCc3ANMtUU9HJyiIW1wBbP3A',
#   'Noooo Auntie Jackie is eating pork 😭 no pork on my fork and why don’t you chill with the BEEF and get some chicken instead 😂'],
#  ['lOIFYf3sSnw',
#   'UgzrA_92YKM5rVMU1uR4AaABAg',
#   'UgzrA_92YKM5rVMU1uR4AaABAg',
#   'thtgirlhannahhh',
#   'UCq1--kxTUAn0S9hSIiAPS3A',
#   'Literally one of my favorite youtubers because you are knowledgeable, beautiful AND funny 😭 I am obsessed 😍'],
#  ['lOIFYf3sSnw',
#   'Ugx4d5iUwb0V7d7ahRJ4AaABAg',
#   'Ugx4d5iUwb0V7d7ahRJ4AaABAg',
#   'Irmitaaa Bonitaaa',
#   'UC1lLAyMv5_L_4c-gOh6Srww',
#   'Oh I love you ❤️'],
#  ['lOIFYf3sSnw',
#   'UgwptHff0barkPireQt4AaABAg',
#   'UgwptHff0barkPireQt4AaABAg',
#   'Sierra Stewart',
#   'UCcKer2Z_HnLNmPry3jHvDLg',
#   'I hollered when the pimple started talking 🤣'],
#  ['lOIFYf3sSnw',
#   'Ugya913Dd6lfiuQ-Zjx4AaABAg',
#   'Ugya913Dd6lfiuQ-Zjx4AaABAg',
#   'Chloe Simmone',
#   'UCr4FlK2tvJZlAvaaQtU9YaA',
#   'i’m LOVING this hair on you'],
#  ['lOIFYf3sSnw',
#   'UgwqlhjHTkYoDM6GRMF4AaABAg',
#   'UgwqlhjHTkYoDM6GRMF4AaABAg',
#   'mitztheo',
#   'UCbK7OWlWWoFMXrE_CuHVWGw',
#   '"I\'m not going any freaking where!"💀😂'],
#  ['lOIFYf3sSnw',
#   'Ugx4W9jn10HhDhNNRHZ4AaABAg',
#   'Ugx4W9jn10HhDhNNRHZ4AaABAg',
#   'Godiva Chanel',
#   'UCpGQ-PdVgBFwXct1LKLjJKA',
#   'I thought 430 was too dark when you swatched it!!!'],
#  ['lOIFYf3sSnw',
#   'UgzQR4qDzTUsZohLxLF4AaABAg',
#   'UgzQR4qDzTUsZohLxLF4AaABAg',
#   'Nicci M',
#   'UCRKILhHypzvHaogly3LOENQ',
#   '😂😂😂😂 the talking pimple got me!!!! Amazing review as always. Love your content!!!!'],
#  ['lOIFYf3sSnw',
#   'UgzwgjcFObClb8AMU9x4AaABAg',
#   'UgzwgjcFObClb8AMU9x4AaABAg',
#   'fifthstr',
#   'UCJRz3Zi4EA-LHoOC3OUoLOQ',
#   'Lmao I have a pimple in the same spot Jackie! Is it a hormone pimple? Are we all on the same cycle?'],
#  ['lOIFYf3sSnw',
#   'UgzIoGRqeLSmcg9_Kj94AaABAg',
#   'UgzIoGRqeLSmcg9_Kj94AaABAg',
#   'Latifa Martin',
#   'UCIAdnl8uMpRG3QhqcsPhPCw',
#   'Did you get your luggage that the airline lost last week'],
#  ['lOIFYf3sSnw',
#   'Ugwj6EsE9rZC9AWAMtt4AaABAg',
#   'Ugwj6EsE9rZC9AWAMtt4AaABAg',
#   'Locrecia Pelham',
#   'UCvaSMoQCTImCh0WGKVR4f5g',
#   'Gonna pick up the foundation and the power blush highlighter in red based on your excellent review.  So proud of you young lady!!!!'],
#  ['lOIFYf3sSnw',
#   'UgwnDqwR4zAuD9WvOo54AaABAg',
#   'UgwnDqwR4zAuD9WvOo54AaABAg',
#   'Law Abiding Citizen',
#   'UCMYXaP7MHwngLUK_1ghdghA',
#   'lol. Me either Jackie . . . what is chakras🤷🏾\u200d♀️🤔🤪😱'],
#  ['lOIFYf3sSnw',
#   'UgxQWnNg56LVIi9zIbt4AaABAg',
#   'UgxQWnNg56LVIi9zIbt4AaABAg',
#   'Antionette Young',
#   'UCLI6T0N3pbj7yAGWriHaFOg',
#   'Jackie you are deffo not crazy I use 420 too and I’m definitely sure it was neutral.\nAlso I love your channel you’re amazing!!!!!!'],
#  ['lOIFYf3sSnw',
#   'Ugwj51KVAtVyaG2OaYZ4AaABAg',
#   'Ugwj51KVAtVyaG2OaYZ4AaABAg',
#   'Evlynn',
#   'UCjvn1u5dRlmFS77RaKTqkQw',
#   'Am I the only one who had tears off of that pimple part 😂😂😂'],
#  ['lOIFYf3sSnw',
#   'UgytKDexP6vm2DgFzCJ4AaABAg',
#   'UgytKDexP6vm2DgFzCJ4AaABAg',
#   'Deanashea',
#   'UCPHjSEDfCgCGf_1q6Pc3f6Q',
#   'Lol 😆'],
#  ['lOIFYf3sSnw',
#   'UgzoTilcYKFkDlNscDZ4AaABAg',
#   'UgzoTilcYKFkDlNscDZ4AaABAg',
#   'Danielle Joseph',
#   'UCKz3iablRo8SbRtwhrOwZhg',
#   "Now that I'm getting older I tend to steer clear of matte matte foundations."],
#  ['lOIFYf3sSnw',
#   'Ugw3rk4B-Xo_2bvTs794AaABAg',
#   'Ugw3rk4B-Xo_2bvTs794AaABAg',
#   'Priscilla Talks',
#   'UCj-3fWQ1TG683OKyPny1ufg',
#   'talking my language w the chakras 😂🧚🏾\u200d♀️'],
#  ['lOIFYf3sSnw',
#   'UgzE4W62uONOfNql2QB4AaABAg',
#   'UgzE4W62uONOfNql2QB4AaABAg',
#   'Tia Leachman',
#   'UC6HPfPsIJA1DGMG_lTv02jA',
#   '@ 9:15 😂😭😂😭😂 Jackie ur so stupid!! I love you 😂😭❤️😭😂'],
#  ['lOIFYf3sSnw',
#   'UgwLVK9mZjP-qJJEGj14AaABAg',
#   'UgwLVK9mZjP-qJJEGj14AaABAg',
#   'Modern Oldsoul',
#   'UC4pAN3C1qwjrMO2ZcOZsgMg',
#   'Gotta love Jackie... I was tryna wait on the fenty blushes, butttt im goin to get this foundation 🏃🏾\u200d♀️🏃🏾\u200d♀️🏃🏾\u200d♀️'],
#  ['lOIFYf3sSnw',
#   'UgzS1LlQUsDEq5pX0Fh4AaABAg',
#   'UgzS1LlQUsDEq5pX0Fh4AaABAg',
#   'Manuel Molini',
#   'UC7dLR4DqbSFyeoLXgYdmUbA',
#   'Jackie, bless u momma!'],
#  ['lOIFYf3sSnw',
#   'UgwepIKZ11q-WDohM4h4AaABAg',
#   'UgwepIKZ11q-WDohM4h4AaABAg',
#   'Beauty ByTatted',
#   'UCBT_x4lCCNPYunWTO02nQfA',
#   'Move your in the way 😩😩'],
#  ['lOIFYf3sSnw',
#   'UgzBU5NEOsZ72eUjdhV4AaABAg',
#   'UgzBU5NEOsZ72eUjdhV4AaABAg',
#   'Shiblaqbri',
#   'UCL4HKWvX5OFKXFCfWcalOAA',
#   'That pimple saying she not going nowhere. Sis, my pimples felt that 😂😂😂 I didn’t think I’d like this launch just cause my skin is also oily but it’s definitely still wearable'],
#  ['lOIFYf3sSnw',
#   'UgxL_wUYScEDbCY1PAx4AaABAg',
#   'UgxL_wUYScEDbCY1PAx4AaABAg',
#   'Looks By Ceda',
#   'UCA4oLxrWyZRxKGmsUaikMxw',
#   'I’m here for the editing, then the makeup lol!  Great video!'],
#  ['lOIFYf3sSnw',
#   'UgyyTdyqFNI807J6_314AaABAg',
#   'UgyyTdyqFNI807J6_314AaABAg',
#   'Charla',
#   'UCFNozM-XGB90mR8gNTZzBYA',
#   'Omg. I do cheeseless pizza too and you are so right about those toppings. That eyeshadow look is so pretty.'],
#  ['lOIFYf3sSnw',
#   'UgyInGMdef94EvTiSWp4AaABAg',
#   'UgyInGMdef94EvTiSWp4AaABAg',
#   'Jess Knight',
#   'UCGsfSRxNELTMZdWtdrVDCrg',
#   'Cheeseless pizza (no toppings)  is a Rhode Island classic!'],
#  ['lOIFYf3sSnw',
#   'Ugwx0D3D0L5ndpI9c_B4AaABAg',
#   'Ugwx0D3D0L5ndpI9c_B4AaABAg',
#   'Sherreen Golding',
#   'UCz34KeqW7-T87WNmmPYA9xg',
#   '“I’m shooketh aback” - Love it!!!!\nYou look amazing at minutes to midnight👌🏾💐\nThanks for doing this video because I have the same oily combination skin, so I’m dubious about hydrating foundation, but I tried Laura Mercier’s hydrating foundation and got the same long lasting result you got with Fenty.'],
#  ['lOIFYf3sSnw',
#   'UgyQPD2OER3C0bW_gwl4AaABAg',
#   'UgyQPD2OER3C0bW_gwl4AaABAg',
#   'Maya Vines',
#   'UC9t7CSbfzEPR_jaaFjZIq_Q',
#   '9:09 currently having the same problem with my pimple 🙃😂'],
#  ['lOIFYf3sSnw',
#   'UgwLOVXrPgLbkxSsXKF4AaABAg',
#   'UgwLOVXrPgLbkxSsXKF4AaABAg',
#   'Nicole Daniels',
#   'UCN9XN-XUR4bHGh72D2rWb3A',
#   "Wow I love cheeseless pizza too I always get a Pacific Veggie thin crust pizza with no cheese Frum Domino's and you're right it is good! That Foundation does look really good on you."],
#  ['lOIFYf3sSnw',
#   'UgzqzCWaUJkNpexH6Rp4AaABAg',
#   'UgzqzCWaUJkNpexH6Rp4AaABAg',
#   'niki saun',
#   'UCrrfSBkH6cQtzV9bG2un3hA',
#   'That pimple shot had me rolling lol'],
#  ['lOIFYf3sSnw',
#   'UgxUvq6G-fuQaXC3UZh4AaABAg',
#   'UgxUvq6G-fuQaXC3UZh4AaABAg',
#   'Dominique Boyer',
#   'UCXm13W-LgzzuCZTuFvtoiPg',
#   "I love this hair length, the middle part, the finished makeup, your face. You're just so beautiful!"],
#  ['lOIFYf3sSnw',
#   'UgxefMMbtuuV1grjxsx4AaABAg',
#   'UgxefMMbtuuV1grjxsx4AaABAg',
#   'Mia Shalice',
#   'UCgUXamYzumuDr_XiZy87Z6g',
#   'Bruhhh the pimple talking killed me😂'],
#  ['lOIFYf3sSnw',
#   'UgxO0n4xpzVVZJHq7N94AaABAg',
#   'UgxO0n4xpzVVZJHq7N94AaABAg',
#   'DDORNE01',
#   'UCsbUtDz7dBywIIgRxQEeLwQ',
#   'That pimple moment was hilarious 😜 the soft matte wear foundation is still my go to. 1 or 2 pumps and my oily skin is matte for the whole day. This video does make me want to try this though.'],
#  ['lOIFYf3sSnw',
#   'UgxKB66-1Ut7OGUfo9F4AaABAg',
#   'UgxKB66-1Ut7OGUfo9F4AaABAg',
#   'Max Vargas',
#   'UC21liluj59oGN4fa1ZdYWFA',
#   'Lol the drinking water after 🤣🤣'],
#  ['lOIFYf3sSnw',
#   'UgzEychTrP_8X9rmZIR4AaABAg',
#   'UgzEychTrP_8X9rmZIR4AaABAg',
#   'gwen27405',
#   'UCLPUwFz1NjAMF7KLmqEw8kQ',
#   'U crazy😂😂😂😂 that pimple!'],
#  ['lOIFYf3sSnw',
#   'UgzU9LOLdkD7nssUziR4AaABAg',
#   'UgzU9LOLdkD7nssUziR4AaABAg',
#   'Terrica Turner',
#   'UCzxD6euWI1wF_ksufHYfulg',
#   'The red blush is so loud it barks 😂🚨'],
#  ['lOIFYf3sSnw',
#   'UgztSHKggD7HeQCIFpZ4AaABAg',
#   'UgztSHKggD7HeQCIFpZ4AaABAg',
#   'Lily',
#   'UC2dXYAnpzjpXUDhEPFyALVw',
#   'that eye look😍😍😍😍'],
#  ['lOIFYf3sSnw',
#   'UgxqZ-r5XFcCbUODUER4AaABAg',
#   'UgxqZ-r5XFcCbUODUER4AaABAg',
#   'BlueLotus Luv',
#   'UCZQWQVfklSDzG_ZKgXdYvcw',
#   'They did change the shades. You’re not trippin auntie lol'],
#  ['lOIFYf3sSnw',
#   'Ugw6bJHagAsGLu-G2_V4AaABAg',
#   'Ugw6bJHagAsGLu-G2_V4AaABAg',
#   'Fabulous with Fati',
#   'UCPC4qIWDwi3fZ56AB-7ppVQ',
#   'I cant wait...just ordered your palette'],
#  ['lOIFYf3sSnw',
#   'UgzLzNwZJHKIp0kI93h4AaABAg',
#   'UgzLzNwZJHKIp0kI93h4AaABAg',
#   'elba bellisario',
#   'UCUrHzF7nvki4L23bi-NOp6A',
#   'omg thank god for this vid, i have oilyyyyyy skin but i really wanted to try this foundation, now i will !!! amazing video as always Jackie 💘💘💘'],
#  ['lOIFYf3sSnw',
#   'UgzzUJlGRWsu4j9TKx54AaABAg',
#   'UgzzUJlGRWsu4j9TKx54AaABAg',
#   'Gemma Diaz',
#   'UCn2n927CSN4oviZFC4qUO0A',
#   '9:11 my acne for the past year 😩'],
#  ['lOIFYf3sSnw',
#   'UgwEWLSHv_PXFXsvo8F4AaABAg',
#   'UgwEWLSHv_PXFXsvo8F4AaABAg',
#   'Divine Diva',
#   'UCn6YqQMGEnK8NyDL5dq1oLQ',
#   'Good review. I totally prefer buildable coverage. Also ..\n\nWho needs cheese?😱😱😱\nMe sis. I need cheese. I always need cheese.😩'],
#  ['lOIFYf3sSnw',
#   'UgygAWyB5rJ_9BtjB3x4AaABAg',
#   'UgygAWyB5rJ_9BtjB3x4AaABAg',
#   'Elizabeth Lovell',
#   'UCjEd_aAggqo6Mow20DEQldQ',
#   'Never mind how long it lasted etc., you look absolutely stunning!  You are great to watch too; your personality shines!'],
#  ['lOIFYf3sSnw',
#   'Ugy0vt2eCwEcbQS0xa54AaABAg',
#   'Ugy0vt2eCwEcbQS0xa54AaABAg',
#   'Karen Payne',
#   'UCzkH41rPoH_drUK-kiacsqw',
#   'I have oily/combo skin as well so if you like it I know I can wear it too then. Will be going to sefora'],
#  ['lOIFYf3sSnw',
#   'UgwrkfGxMD3uWVsAsBt4AaABAg',
#   'UgwrkfGxMD3uWVsAsBt4AaABAg',
#   'Tiffany‘s Beauty Trends',
#   'UC3nZZobPh8-Qb5w5k0jkYbQ',
#   'Jackie. You are just the loveliest, most beautiful, best personality in an influencer today. I just got your collab with AB and yes I’m slow, but it is so worth it!❤️'],
#  ['lOIFYf3sSnw',
#   'Ugz0DrHb5Txxc3OjCph4AaABAg',
#   'Ugz0DrHb5Txxc3OjCph4AaABAg',
#   'Carolyn H.',
#   'UCjve-gVmOl0mSz6guMLQPpw',
#   'They renamed the undertones when they extended the shades in the beginning of the year- also everything about the hydrating (coverage, wear, and finish) is the same as the original. The only difference is they added hyaluronic acid for drier skin types.\n *i work at sephora and was trained by the Fenty artists, so this is what I was told 🤷🏻\u200d♀️*'],
#  ['lOIFYf3sSnw',
# ...
#  ['lOIFYf3sSnw',
#   'UgzQq6Ka4co0jRZqhwZ4AaABAg',
#   'UgzQq6Ka4co0jRZqhwZ4AaABAg',
#   'Farah M',
#   'UCheJmQ1C8-Yt6CQQoFiu3dw',
#   '9:13 LMAO me when my parents ask me when I’m moving out'],
#  ['lOIFYf3sSnw',
#   'Ugykr5xTJv_zX3WhNvd4AaABAg',
#   'Ugykr5xTJv_zX3WhNvd4AaABAg',
#   'Moniqué Onyxx',
#   'UCPc5X-9gHObeI_wnnT816HA',
#   'JACKIEEEEE! 😫😫😫😫\nI’ve had to pause!!!!\nThe pimple talking - GIRLLLLLL - I’m howling!'],
#  ['lOIFYf3sSnw',
#   'UgxSFg1xzHlJV_xKFhR4AaABAg',
#   'UgxSFg1xzHlJV_xKFhR4AaABAg',
#   'Sierra Dorham',
#   'UCDdZoPX9ru1z9SEHn5i_4iA',
#   'I cannot find a decent color match in either one :(  So sad'],
#  ['lOIFYf3sSnw',
#   'UgxHbWUSbxTRNq4HIHV4AaABAg',
#   'UgxHbWUSbxTRNq4HIHV4AaABAg',
#   'Ms. D Dodson',
#   'UCrGq8hrtV73264qdQLAKrKQ',
#   'I howled at that talking pimple!!! 😂😂😂 omg!!!'],
#  ['lOIFYf3sSnw',
#   'UgyalIpXrJaHgQYwOhl4AaABAg',
#   'UgyalIpXrJaHgQYwOhl4AaABAg',
#   'Chrissy',
#   'UCJhvAPwumXNpMbErgpH4VDA',
#   'The evil pimple took me out with that laugh 😂😂😂😂'],
#  ['lOIFYf3sSnw',
#   'UgyUjn_RCIfxe9x5cNR4AaABAg',
#   'UgyUjn_RCIfxe9x5cNR4AaABAg',
#   'Rachel Nicole',
#   'UCqhOjwo-8I8pq-EtQ9DP5Gg',
#   'That edit on the pimple is gold! 😂'],
#  ['lOIFYf3sSnw',
#   'UgxtkZyjNsCqOrR-2TN4AaABAg',
#   'UgxtkZyjNsCqOrR-2TN4AaABAg',
#   'Olympia B',
#   'UCgVwzD23DU91J0OpuaxUpuA',
#   'My 4 year old just now: "Let\'s watch Jackie mama! Let\'s watch Jackie Jackie Jackie!"'],
#  ['lOIFYf3sSnw',
#   'UgzF2ahM3lnAWgTaA9d4AaABAg',
#   'UgzF2ahM3lnAWgTaA9d4AaABAg',
#   'Meg',
#   'UCTik0HmJFUTK-jecFG4zlBw',
#   "I'm earlier than usual👀 12 mins"],
#  ['lOIFYf3sSnw',
#   'Ugwg-bkBesvSvEkV89t4AaABAg',
#   'Ugwg-bkBesvSvEkV89t4AaABAg',
#   'Sara Qureshi',
#   'UCgx4zFwY7sDtvZ6TZ4-3ivQ',
#   'I legit  screamed at "will I be greasy" 🎶'],
#  ['lOIFYf3sSnw',
#   'Ugwy4xqZicNWmuL3tDV4AaABAg',
#   'Ugwy4xqZicNWmuL3tDV4AaABAg',
#   'Mia Nicole',
#   'UC4Vkfe-P1AdAHyzeT8H7_-w',
#   'That pimple talking tho 😂😂😂'],
#  ['lOIFYf3sSnw',
#   'UgwWofCSQ4b-EalGeWB4AaABAg',
#   'UgwWofCSQ4b-EalGeWB4AaABAg',
#   'dirtycarfloornerds',
#   'UCFFgVQmL3Ufj6aHdcjzAhEQ',
#   'Tell that zit to calm ALL THE WAY DOWN!'],
#  ['lOIFYf3sSnw',
#   'Ugwhgx6hTT9SFXcnSBN4AaABAg',
#   'Ugwhgx6hTT9SFXcnSBN4AaABAg',
#   'Miss Rogers',
#   'UCVVmUMPOF4aAUBCkTXXxIkA',
#   'Jackie can you do the sheseido foundation?'],
#  ['lOIFYf3sSnw',
#   'UgyEoQLru5jCozwa5W14AaABAg',
#   'UgyEoQLru5jCozwa5W14AaABAg',
#   'Sherilyn Laurie',
#   'UCpwBMaWljQt6A2UfBK9KNOQ',
#   'I can’t wait for the next episode of “Will I Be Greasy?”'],
#  ['lOIFYf3sSnw',
#   'UgwHJ6Z0XpZGlMDnKJB4AaABAg',
#   'UgwHJ6Z0XpZGlMDnKJB4AaABAg',
#   'kiskis',
#   'UC6NVoPUngJsSXjad82h4eBA',
#   'as a dry skin broke girl, im gonna have to wait til my matte foundation runs out 😢'],
#  ['lOIFYf3sSnw',
#   'UgwyEIfGn4o2Wq08kTh4AaABAg',
#   'UgwyEIfGn4o2Wq08kTh4AaABAg',
#   'Korrice Guy',
#   'UCe1125-UFht_8w-UA-1UBVQ',
#   'Lmao when that pimple started talking 🤣🤣🤣😭😭😭😭😭'],
#  ['lOIFYf3sSnw',
#   'UgzxSesjy3c_Q1QrL714AaABAg',
#   'UgzxSesjy3c_Q1QrL714AaABAg',
#   'Rosalin Olds',
#   'UCU9zxKGVb5frOZJWhsgSAsw',
#   'You are right Auntie Jackie they did change the undertone description'],
#  ['lOIFYf3sSnw',
#   'Ugy6H2-pIiqVq3No41B4AaABAg',
#   'Ugy6H2-pIiqVq3No41B4AaABAg',
#   'Jules F',
#   'UCiUhREbzcL-1PU-fvBz4wRA',
#   'these edits, chiiiiiiild! 😂'],
#  ['lOIFYf3sSnw',
#   'UgxnGBYM-2MG-tp8hJ54AaABAg',
#   'UgxnGBYM-2MG-tp8hJ54AaABAg',
#   'Adia',
#   'UCRXSeEcH4AqpgqATA2X_Psw',
#   "I'm on vacation but I still gotta watch aunty jackie"],
#  ['lOIFYf3sSnw',
#   'UgwJN_4PIazjjq9znd94AaABAg',
#   'UgwJN_4PIazjjq9znd94AaABAg',
#   'Ananya B',
#   'UCXnZJQCs0ZleK6VcdTHXg0w',
#   'Watching all the ads so you can get that coinnnnn Aunty! 💞💞'],
#  ['lOIFYf3sSnw',
#   'UgzMFQ5ZYZCKoKponM94AaABAg',
#   'UgzMFQ5ZYZCKoKponM94AaABAg',
#   'Pandakookie21',
#   'UCjVAo9ePKtvcz3TG90fM5DQ',
#   "I hope you're okay queen twt was DRY without you!"],
#  ['lOIFYf3sSnw',
#   'UgxxjVc2qJP5FnrBbgZ4AaABAg',
#   'UgxxjVc2qJP5FnrBbgZ4AaABAg',
#   'riccaa26',
#   'UCC-EBr7J12JDz9eUwnhA3BQ',
#   'Thank you and please don’t post over the weekend just incase this hurricane really comes 😭😭😭'],
#  ['lOIFYf3sSnw',
#   'Ugzh_ZZ0QK6KUuVGHCJ4AaABAg',
#   'Ugzh_ZZ0QK6KUuVGHCJ4AaABAg',
#   'Sameen Khurshid',
#   'UCW7J9CvgTHx9ZFKnFFTEDJQ',
#   'that pimple laughing killed me'],
#  ['lOIFYf3sSnw',
#   'UgxPIcNdpAQYjwRu_dd4AaABAg',
#   'UgxPIcNdpAQYjwRu_dd4AaABAg',
#   'Keamone F.',
#   'UCqxUJn55fBLh_ctpPCOvTHA',
#   'You’re actually right! I noticed they changed the undertones a while back because I’m 440 which was described as a neutral with slight red undertones and now it’s described as warm 🤷🏾\u200d♀️ I guess they realized the descriptions weren’t hitting? Idk sis. Either way I loved it though!'],
#  ['lOIFYf3sSnw',
#   'UgyF73gJSYReG2yQSll4AaABAg',
#   'UgyF73gJSYReG2yQSll4AaABAg',
#   'mayasboringlife',
#   'UCsE2yLaZl1hnWZFXWZ90PLw',
#   'I was JUST having an anxiety attack, but then your notification popped up and I forgot all about it. This just what I needed'],
#  ['lOIFYf3sSnw',
#   'UgzoThboOvhGzQaF4Sl4AaABAg',
#   'UgzoThboOvhGzQaF4Sl4AaABAg',
#   'Rnjones2011',
#   'UCngcasJb2Ay2SQzh2zUzG8w',
#   'Fuck the haters girl. Keep that drive and ambition and stunt on em!'],
#  ['lOIFYf3sSnw',
#   'UgzwCDG_IjQJQdme28p4AaABAg',
#   'UgzwCDG_IjQJQdme28p4AaABAg',
#   'only check this account for skid row carnival',
#   'UCU5pSrf6qGyTv6aLRNvYqCg',
#   'please do a kosas tinted face oil review <333 LOVED this video!'],
#  ['lOIFYf3sSnw',
#   'UgxepBSGeyT4H_tk1yB4AaABAg',
#   'UgxepBSGeyT4H_tk1yB4AaABAg',
#   'SchalaZeal',
#   'UC3M79FayMa5re1_prZTnS-w',
#   'Notification Squaaaaawd!!! 🥰'],
#  ['lOIFYf3sSnw',
#   'UgzA_39Z9P7v-LXRVSF4AaABAg',
#   'UgzA_39Z9P7v-LXRVSF4AaABAg',
#   'Ale Jay',
#   'UCDJ7jU-bV_OfTg039JAFahQ',
#   'I LOVE this foundation. Riri definitely looked out for us dry, desert, Sahara skin people 😩💀 it’s so bomb!!!'],
#  ['lOIFYf3sSnw',
#   'Ugwo8TxCMwqT_Hdq7WZ4AaABAg',
#   'Ugwo8TxCMwqT_Hdq7WZ4AaABAg',
#   'sanona129',
#   'UCt2YxXwhBRyXrVHAsS0H4Gw',
#   'Ms Jackie always love and appreciate your honesty and candor in your videos. I’ve learned so much from your reviews. Thank you. This is definitely off the makeup subject but that necklace is gorgeous. Can I take a guess...David Yurmin?'],
#  ['lOIFYf3sSnw',
#   'Ugz-1Sq6RVSWeH9RBOd4AaABAg',
#   'Ugz-1Sq6RVSWeH9RBOd4AaABAg',
#   'Sophia',
#   'UCxAorIFJOXc2C5rX1BNOeRQ',
#   'When you watch the video before you get the notification....When you stay ready, you dont have to get ready!'],
#  ['lOIFYf3sSnw',
#   'UgxbmlO39jh1DkH294F4AaABAg',
#   'UgxbmlO39jh1DkH294F4AaABAg',
#   'MaJa Earth',
#   'UCNjKWjpu_s7pLE0WzsnXVxQ',
#   'Girrl your skin is so flawless!!!!'],
#  ['lOIFYf3sSnw',
#   'UgwBZcRGrV1InyucGgN4AaABAg',
#   'UgwBZcRGrV1InyucGgN4AaABAg',
#   'BeautyAndFaith',
#   'UCLD6usLkkHFfM_jqmtNQ30Q',
#   'That rock on your finger though! It’s GORGEOUS!!! 😍😁'],
#  ['lOIFYf3sSnw',
#   'Ugwq2Lx0P0XuS7HF3D94AaABAg',
#   'Ugwq2Lx0P0XuS7HF3D94AaABAg',
#   'Nicole Mileyy',
#   'UCfTyrJoQDe-RQGopH2mLXNg',
#   'I live on YouTube because I didn’t even get the notification yet 😩🙌🏾'],
#  ['lOIFYf3sSnw',
#   'UgxsrjAHzPrT2k0H0LV4AaABAg',
#   'UgxsrjAHzPrT2k0H0LV4AaABAg',
#   'verenice',
#   'UCAj_FHjGEv5brHZeynaKXtQ',
#   'Jackieeee, love your reviews 💕'],
#  ['lOIFYf3sSnw',
#   'UgzeyDgbqWK1O8vz8I14AaABAg',
#   'UgzeyDgbqWK1O8vz8I14AaABAg',
#   'its24KGold',
#   'UCOeGDaGA6Sbj5HIK9Cp9YCg',
#   'I was hoping you wouldnt review this... my bank account is about to hate me.'],
#  ['lOIFYf3sSnw',
#   'UgwDF4BGrUPwafsVTcZ4AaABAg',
#   'UgwDF4BGrUPwafsVTcZ4AaABAg',
#   'Stacyann J',
#   'UCtrFa32ODhO4hgFDCIYYjbQ',
#   '4 countries in 2weeks goals !'],
#  ['lOIFYf3sSnw',
#   'UgzFcSa_kOpixx8Zhsh4AaABAg',
#   'UgzFcSa_kOpixx8Zhsh4AaABAg',
#   'CarmenBoone87',
#   'UCCHUL2j0TscLKACt0qPK25Q',
#   "I'm such a dry skin girl.... But I'm still not all the way here for Dewey foundations. Maybe the primer will make a difference 🤷🏽\u200d♀️"],
#  ['lOIFYf3sSnw',
#   'UgzY1eJ7kgokQvfzVZN4AaABAg',
#   'UgzY1eJ7kgokQvfzVZN4AaABAg',
#   'mari del rio',
#   'UCW1oD7vTRiqeLCBw0RlHBCw',
#   'Twenty'],
#  ['lOIFYf3sSnw',
#   'Ugxoxr2A7yHNBkqOjdx4AaABAg',
#   'Ugxoxr2A7yHNBkqOjdx4AaABAg',
#   'Fartuna Haji',
#   'UC7lGKQvJ1PT5ERBKCPOWLWQ',
#   'I hope to pick up this foundation tomorrow 😍'],
#  ['lOIFYf3sSnw',
#   'UgylS-mSxZxFmSWJmdh4AaABAg',
#   'UgylS-mSxZxFmSWJmdh4AaABAg',
#   'Hayden Laver',
#   'UCItMlwcbVO45LyRRfoMAgNA',
#   'jackiejackiejackiejackieeee JACKIEJACKIEJACKIIIEEEE'],
#  ['lOIFYf3sSnw',
#   'UgyjoDHJl2yOO6ZTJGp4AaABAg',
#   'UgyjoDHJl2yOO6ZTJGp4AaABAg',
#   'The chronicles of Danielle',
#   'UCvuQx5yYzDjP8yySsfqjbVA',
#   'Small youtuber here'],
#  ['lOIFYf3sSnw',
#   'UgzPZzjemptKFLyy0cV4AaABAg',
#   'UgzPZzjemptKFLyy0cV4AaABAg',
#   'Yesenia Emma',
#   'UCAW65IJXyo0ZTILa-JXeEUw',
#   'I HAVE BEEN WAITING FOR THIS'],
#  ['lOIFYf3sSnw',
#   'UgwWyIMUHdhscWN6S3N4AaABAg',
#   'UgwWyIMUHdhscWN6S3N4AaABAg',
#   'Chanel West',
#   'UC7CbSFkBaI0zFDfJxYcr8RA',
#   'When the pimple said “I’m not going any freaking where 🤣🤣😭 omggg I died'],
#  ['lOIFYf3sSnw',
#   'UgxlJqXNr5so4NCGgEZ4AaABAg',
#   'UgxlJqXNr5so4NCGgEZ4AaABAg',
#   'Brayln Lentz',
#   'UCz85tzCpnjcU1-PmR8Hnj8w',
#   'I cant help but to do the into with you 😂'],
#  ['lOIFYf3sSnw',
#   'UgxDmTY7bgnIZxsvU4Z4AaABAg',
#   'UgxDmTY7bgnIZxsvU4Z4AaABAg',
#   'Lisa McDuffy',
#   'UCF7CK2F0ks6Rzf23RrVqDcg',
#   'Hey girl, hey!!!! ❤️'],
#  ['lOIFYf3sSnw',
#   'Ugy7RHKAeq1WXJgCDKh4AaABAg',
#   'Ugy7RHKAeq1WXJgCDKh4AaABAg',
#   'Christina Cherice',
#   'UCB8is8OZ521XZVmk_RNFwbw',
#   'Jackiee Jackiee Jackiee Jackieeee jaccckkieee Jackieeeeee😝'],
#  ['lOIFYf3sSnw',
#   'UgwXC88gFpvtBCE3zKN4AaABAg',
#   'UgwXC88gFpvtBCE3zKN4AaABAg',
#   'Demure Drey',
#   'UC6iyQBlhKZZ_AysYumVLUWg',
#   'I’m in love with that shirt 😍'],
#  ['lOIFYf3sSnw',
#   'Ugz8Bg3z96XM-DN_trx4AaABAg',
#   'Ugz8Bg3z96XM-DN_trx4AaABAg',
#   'Soitsjka Belfor',
#   'UC1p-BGDv-M1RU9STveSCchg',
#   "It's 10:10 PM in Suriname\nThank you Jackie, cause I have been dying for you to give your opinion on this foundation!!"],
#  ['lOIFYf3sSnw',
#   'Ugx6fV6qcvXm62tPkCJ4AaABAg',
#   'Ugx6fV6qcvXm62tPkCJ4AaABAg',
#   'Kinda Goth',
#   'UCcv_xbEtnpDGXRc6YI-HgzQ',
#   'Holaaa ❤'],
#  ['lOIFYf3sSnw',
#   'UgxoObWDlnlIi1iseXd4AaABAg',
#   'UgxoObWDlnlIi1iseXd4AaABAg',
#   'Brittany Vinson',
#   'UC5BJekSNlxrnu5bP1-wobFQ',
#   'In Jesus name I pray Amen'],
#  ['lOIFYf3sSnw',
#   'UgxLT_Yb4ZBipR2MDj54AaABAg',
#   'UgxLT_Yb4ZBipR2MDj54AaABAg',
#   'The Comedic MUE',
#   'UCBvHZCjRBiwDIvMgj2qMJIw',
#   "I just ordered this..  you didn't give your review so I went in blind with my color match  😥"],
#  ['lOIFYf3sSnw',
#   'Ugyiv4-jAqG7rferxY54AaABAg',
#   'Ugyiv4-jAqG7rferxY54AaABAg',
#   'Dwanna Graham',
#   'UCt3-SVN4ODNQg9WuzwkZK7g',
#   '😍😍😍'],
#  ['lOIFYf3sSnw',
#   'UgxNrCIGxmYY8XNBErN4AaABAg',
#   'UgxNrCIGxmYY8XNBErN4AaABAg',
#   'Madele Makeup',
#   'UCWj90zVa8Eljuz7LOM9jCmQ',
#   'clicked as soon as i saw the notification!'],
#  ['lOIFYf3sSnw',
#   'UgxLCocsmMCZZP3b2sV4AaABAg',
#   'UgxLCocsmMCZZP3b2sV4AaABAg',
#   'Skincare Papi',
#   'UCC9GUhOTFQWxW6GiZWjE89w',
#   'youtube: jackie aina\n\nme: period\n\n\n\nedit: tysm 💕🥰'],
#  ['lOIFYf3sSnw',
#   'UgzeNl7j0mYKshdKo594AaABAg',
#   'UgzeNl7j0mYKshdKo594AaABAg',
#   'J O Y C E .D',
#   'UCKaR44sX7jb_ltYYB3PiYEA',
#   'Jackie 😩... Its 4am... I have a baby, so you know sleep is a luxury. I SHOULD BE SLEEPING!!!! but Notiification goes off... what is sleep? Never heard of it! *plugs in earphones*'],
#  ['lOIFYf3sSnw',
#   'UgzSSMuds9E8idEehd94AaABAg',
#   'UgzSSMuds9E8idEehd94AaABAg',
#   'Yee -haw',
#   'UCR--3Nb7TtUCyDyLW2iT1nQ',
#   '❤️❤️❤️❤️❤️❤️❤️❤️'],
#  ['lOIFYf3sSnw',
#   'UgwNDDQaR-z2tAy-9bV4AaABAg',
#   'UgwNDDQaR-z2tAy-9bV4AaABAg',
#   'Gee Smith',
#   'UCiqe-LHIlCMzcfmsFQuDvOw',
#   "In 2 years maybe we'll get a stick foundation from Fenty, something that is a middle ground between the two existing ones."],
#  ['lOIFYf3sSnw',
#   'Ugxlz9xACWV-tfll8lx4AaABAg',
#   'Ugxlz9xACWV-tfll8lx4AaABAg',
#   'Sarah Said',
#   'UC7rlV3XEtUh9MmL3Xy5twCw',
#   'This is the only review live been waiting for❤️❤️'],
#  ['lOIFYf3sSnw',
#   'UgzM57-z4kLmq4DJmix4AaABAg',
#   'UgzM57-z4kLmq4DJmix4AaABAg',
#   'Monsieur James',
#   'UCpb2Et5sXRc3XF9SuGaa71A',
#   'LOVE YOU JACKIE please can you look my work on Instagram it’s @jamescloud_\n\nLove you ♥️☀️🙌🏼'],
#  ['lOIFYf3sSnw',
#   'UgyaiyySn6aR656AfPl4AaABAg',
#   'UgyaiyySn6aR656AfPl4AaABAg',
#   'Sarah Said',
#   'UC7rlV3XEtUh9MmL3Xy5twCw',
#   'This is the only review I’ve been waiting for❤️❤️'],
#  ['lOIFYf3sSnw',
#   'UgxHEkt5LC3rCqh89414AaABAg',
#   'UgxHEkt5LC3rCqh89414AaABAg',
#   'Tiffany Major',
#   'UCrOORhBqyHoV94nPqnwGtKA',
#   'I love your abh palette sooo much!💖✨💗'],
#  ['lOIFYf3sSnw',
#   'UgyQhlHcJLOa86QhfTt4AaABAg',
#   'UgyQhlHcJLOa86QhfTt4AaABAg',
#   'CallherMimi',
#   'UCzM2GnWERt3KTuvOheL8uJA',
#   'Thanks for this review. I been debating whether to try it because of my oily skin. Maybe I’ll do a review on this.'],
#  ['lOIFYf3sSnw',
#   'UgzFEmCsu8qLN1zLCTB4AaABAg',
#   'UgzFEmCsu8qLN1zLCTB4AaABAg',
#   'Swaggy Bish',
#   'UCLHec8xqXWjLlLQjY6SwsKQ',
#   '❤️❤️❤️❤️🎉'],
#  ['lOIFYf3sSnw',
#   'UgxUrzq-aoWIbV2e__p4AaABAg',
#   'UgxUrzq-aoWIbV2e__p4AaABAg',
#   'Vene Trussell',
#   'UCfHSRZ7i-cG4euTePc3BTMw',
#   "I totally want to try this foundation even though I'm oily. I really want to try it with their mattifying primer."],
#  ['lOIFYf3sSnw',
#   'Ugy6VoIFajloAelj9uN4AaABAg',
#   'Ugy6VoIFajloAelj9uN4AaABAg',
#   'stephneeeeeeee',
#   'UCKGDDFyfULuUEIiOKCtnsyQ',
#   'Yay! Been waiting for this one 🤗'],
#  ['lOIFYf3sSnw',
#   'Ugw42HenM6zrVoU4e3F4AaABAg',
#   'Ugw42HenM6zrVoU4e3F4AaABAg',
#   'artistrybyallie',
#   'UCr0Iho-Eqc6BIdJ8m_mRZxQ',
#   'Hey Jackie!!! There’s a mattifying primer that dropped recently too!!'],
#  ['lOIFYf3sSnw',
#   'UgyGkkw2rcovsJIWMM94AaABAg',
#   'UgyGkkw2rcovsJIWMM94AaABAg',
#   'Makayla Charles',
#   'UCAe1hPoYYt6nM7TsRcePfdw',
#   'The video we’ve all been waiting forrrrr!!! I LIVE for your Foundation reviews! Love you Aunt Jackie!'],
#  ['lOIFYf3sSnw',
#   'UgwIzSq46N3Q2dCyDWx4AaABAg',
#   'UgwIzSq46N3Q2dCyDWx4AaABAg',
#   'Siyah Ntombela',
#   'UCa0ip__cIcssaUGfEkLoS-g',
#   'It’s 3am in South Africa 🇿🇦 but we’re here💃💃💃'],
#  ['lOIFYf3sSnw',
#   'UgzDifhQkb_ab2SiY6F4AaABAg',
#   'UgzDifhQkb_ab2SiY6F4AaABAg',
#   'Valencia Penn',
#   'UCxVokfGOYTpCbilJYMpeABw',
#   'I just love her'],
#  ['lOIFYf3sSnw',
#   'UgycQz370S9lj9igR5p4AaABAg',
#   'UgycQz370S9lj9igR5p4AaABAg',
#   'Flor Rangel',
#   'UCM8u04xJCXRyo4BRH8QMurw',
#   'Hi, ungrateful heathens! ❤'],
#  ['lOIFYf3sSnw',
#   'UgwhnVHp4ygHxgj6Nux4AaABAg',
#   'UgwhnVHp4ygHxgj6Nux4AaABAg',
#   'VincygirlRo',
#   'UCr_YzREjw4eQrOObDR8VIDA',
#   'Y’all subscribe to a Caribbean YouTuber 🇻🇨❗️😊'],
#  ['lOIFYf3sSnw',
#   'UgyahN_EzSoCY4eguKZ4AaABAg',
#   'UgyahN_EzSoCY4eguKZ4AaABAg',
#   'Jennifer’s Daughter',
#   'UCiMyDor36ni2Rdf5RKLoUUw',
#   'That notification hit different when you really been waiting for this Fenty Foundation review from the good sis Jackie-O 🙌🏾'],
#  ['lOIFYf3sSnw',
#   'UgzOxiIcqn7n3IEQm5x4AaABAg',
#   'UgzOxiIcqn7n3IEQm5x4AaABAg',
#   'Teka Morrison',
#   'UCf5GqKyCZU-1z72u-WOgNZQ',
#   'jackie jackie jackie lol'],
#  ['lOIFYf3sSnw',
#   'UgwaCH7DfGGOyiEf98t4AaABAg',
#   'UgwaCH7DfGGOyiEf98t4AaABAg',
#   'chinyere melville',
#   'UCTzUcCAT8rhWI1WrAP3wiPw',
#   "Me: I'm going to sleep \n\nAuntie Jackie: I'm dropping a video\n\nMe: 😳😳😳😳😳😳😳😳😳"],
#  ['lOIFYf3sSnw',
#   'Ugxo87r2jM7_mHfEwFB4AaABAg',
#   'Ugxo87r2jM7_mHfEwFB4AaABAg',
#   'Kristen Ukeomah',
#   'UCF-GtfUzWWloFsny-xBGzVw',
#   'Yessss 🤪'],
#  ['lOIFYf3sSnw',
#   'UgzhahAKBQFAYSkIGO14AaABAg',
#   'UgzhahAKBQFAYSkIGO14AaABAg',
#   'Happy Budda',
#   'UCb0pVvwdL3TGsXtZmK151Cw',
#   "Yes! Ah I can't wait to watch this! Hello, gorgeous!!! My skin is on the dry side, so I'm grateful to hear your thoughts on this product. Sending you lots of love, good vibes, and positive energy, Jackie dear!!! Take care!!!"],
#  ['lOIFYf3sSnw',
#   'UgytdbY8J-ukhL-QzYd4AaABAg',
#   'UgytdbY8J-ukhL-QzYd4AaABAg',
#   'Chrissy Boateng',
#   'UC_BOTIoPJ3yPo2iu8dVM6PQ',
#   'Hii Aunite ❤️❤️❤️. We love you . Thank you for all that you do ❤️❤️❤️'],
#  ['lOIFYf3sSnw',
#   'UgwDzXNRKz5d_F6rzaJ4AaABAg',
#   'UgwDzXNRKz5d_F6rzaJ4AaABAg',
#   'Clark Kent',
#   'UCXoRZCX3rtEyLCLMd14fv-w',
#   'Sending positive & love vibes!! Forget & ignore the negativity.'],
#  ['lOIFYf3sSnw',
#   'Ugw7NpIdF-A9JdZWBI14AaABAg',
#   'Ugw7NpIdF-A9JdZWBI14AaABAg',
#   'Flo Melvin',
#   'UCijPuNbwV80BFEMtdoVyIIw',
#   'I love you Jackie!!! You’re an amazing artist love from London💞💞🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f'],
#  ...]

# %%
df_comment_thread = pd.DataFrame(format_ok_comments,columns=['video_id','comment_thread_id','top_level_comment_id','author_display_name','author_channel_id','text_original'])

# %%
df_comment_thread
# Out:
#            video_id           comment_thread_id        top_level_comment_id  \
# 0       lOIFYf3sSnw  UgzB4FfWZ4Qo6bWz-Qx4AaABAg  UgzB4FfWZ4Qo6bWz-Qx4AaABAg
# 1       lOIFYf3sSnw  UgzfU4jGzdCh429h6PR4AaABAg  UgzfU4jGzdCh429h6PR4AaABAg
# 2       lOIFYf3sSnw  UgzOl3Wi4EgvZ0A6OBJ4AaABAg  UgzOl3Wi4EgvZ0A6OBJ4AaABAg
# 3       lOIFYf3sSnw  Ugy2Yx_WfYLtPY1A_JB4AaABAg  Ugy2Yx_WfYLtPY1A_JB4AaABAg
# 4       lOIFYf3sSnw  UgzFiQsQdq1UJM5D0894AaABAg  UgzFiQsQdq1UJM5D0894AaABAg
# ...             ...                         ...                         ...
# 312174  REWS3npz8e8  Ugw2jw2wWevow18vTpl4AaABAg  Ugw2jw2wWevow18vTpl4AaABAg
# 312175  REWS3npz8e8  UgyDCiLJAiZpBNM2KwN4AaABAg  UgyDCiLJAiZpBNM2KwN4AaABAg
# 312176  REWS3npz8e8  UgyWlQHMb9CBgEicZq14AaABAg  UgyWlQHMb9CBgEicZq14AaABAg
# 312177  REWS3npz8e8  UgxyRRlBlAAzm90xgal4AaABAg  UgxyRRlBlAAzm90xgal4AaABAg
# 312178  REWS3npz8e8  Ugz4N37OCV4DTKY-OKN4AaABAg  Ugz4N37OCV4DTKY-OKN4AaABAg
#
#        author_display_name         author_channel_id  \
# 0         Adrienna Sanchez  UCf6BmGmDiZNJRtElp8JN6rA
# 1                    Mia M  UCOmMImoNnK3ic9at-owrA6g
# 2                NazneenR1  UCEaTiiOj-ucuw45RR_MilgQ
# 3             Tameka Green  UCMMMLrdLzGR4ihGSKREXiFA
# 4             Arnetha Earl  UCWEVEOmPeCtmW1arIVJbEAg
# ...                    ...                       ...
# 312174         Selena Soto  UCa2RuWl1Xy4RGQUl1EE4pLA
# 312175     Juli Villagomez  UCDwHGHkymAi9jd4aUwBE93g
# 312176           Tay Bratz  UCtKbrKGkY71_tSxuNGiy6DQ
# 312177         pinkfloyd11  UC4CO8K3xkCAvgqRzZJAee7w
# 312178            Pualilia  UC4_O9qrgDBKKnxNE285MfnQ
#
#                                             text_original
# 0       Jackie i thought we were protesting Gucci plea...
# 1                        I eat only cheese-less pizza! 🙌🏽
# 2       Curious to know what Jackie uses to spot treat...
# 3       Jackie I’ve watched your video and love watchi...
# 4                                 "Will I be greasy lol "
# ...                                                   ...
# 312174  I LOVE Korean pears! They’re soooo good! Lol I...
# 312175                                        i feel like
# 312176  Sis already on her second child... ik they wil...
# 312177                                   Condolences ❤️❤️
# 312178        My mouth is watering! What vinegar is it???
#
# [312179 rows x 6 columns]

# %%
last_csv
# Out:
# 0

# %%
last_csv+=1
last_csv
# Out:
# 1

# %%
df_comment_thread.to_csv('data/get_comment_threads_output/df_comment_thread_{}.csv'.format(last_csv), index = False)

# %%
np.save('data/get_comment_threads_output/last_csv.npy',last_csv)

# %%
df = pd.read_csv('data/get_comment_threads_output/df_comment_thread_{}.csv'.format(last_csv))
df
# Out:
#            video_id           comment_thread_id        top_level_comment_id  \
# 0       lOIFYf3sSnw  UgzB4FfWZ4Qo6bWz-Qx4AaABAg  UgzB4FfWZ4Qo6bWz-Qx4AaABAg
# 1       lOIFYf3sSnw  UgzfU4jGzdCh429h6PR4AaABAg  UgzfU4jGzdCh429h6PR4AaABAg
# 2       lOIFYf3sSnw  UgzOl3Wi4EgvZ0A6OBJ4AaABAg  UgzOl3Wi4EgvZ0A6OBJ4AaABAg
# 3       lOIFYf3sSnw  Ugy2Yx_WfYLtPY1A_JB4AaABAg  Ugy2Yx_WfYLtPY1A_JB4AaABAg
# 4       lOIFYf3sSnw  UgzFiQsQdq1UJM5D0894AaABAg  UgzFiQsQdq1UJM5D0894AaABAg
# ...             ...                         ...                         ...
# 312174  REWS3npz8e8  Ugw2jw2wWevow18vTpl4AaABAg  Ugw2jw2wWevow18vTpl4AaABAg
# 312175  REWS3npz8e8  UgyDCiLJAiZpBNM2KwN4AaABAg  UgyDCiLJAiZpBNM2KwN4AaABAg
# 312176  REWS3npz8e8  UgyWlQHMb9CBgEicZq14AaABAg  UgyWlQHMb9CBgEicZq14AaABAg
# 312177  REWS3npz8e8  UgxyRRlBlAAzm90xgal4AaABAg  UgxyRRlBlAAzm90xgal4AaABAg
# 312178  REWS3npz8e8  Ugz4N37OCV4DTKY-OKN4AaABAg  Ugz4N37OCV4DTKY-OKN4AaABAg
#
#        author_display_name         author_channel_id  \
# 0         Adrienna Sanchez  UCf6BmGmDiZNJRtElp8JN6rA
# 1                    Mia M  UCOmMImoNnK3ic9at-owrA6g
# 2                NazneenR1  UCEaTiiOj-ucuw45RR_MilgQ
# 3             Tameka Green  UCMMMLrdLzGR4ihGSKREXiFA
# 4             Arnetha Earl  UCWEVEOmPeCtmW1arIVJbEAg
# ...                    ...                       ...
# 312174         Selena Soto  UCa2RuWl1Xy4RGQUl1EE4pLA
# 312175     Juli Villagomez  UCDwHGHkymAi9jd4aUwBE93g
# 312176           Tay Bratz  UCtKbrKGkY71_tSxuNGiy6DQ
# 312177         pinkfloyd11  UC4CO8K3xkCAvgqRzZJAee7w
# 312178            Pualilia  UC4_O9qrgDBKKnxNE285MfnQ
#
#                                             text_original
# 0       Jackie i thought we were protesting Gucci plea...
# 1                        I eat only cheese-less pizza! 🙌🏽
# 2       Curious to know what Jackie uses to spot treat...
# 3       Jackie I’ve watched your video and love watchi...
# 4                                 "Will I be greasy lol "
# ...                                                   ...
# 312174  I LOVE Korean pears! They’re soooo good! Lol I...
# 312175                                        i feel like
# 312176  Sis already on her second child... ik they wil...
# 312177                                   Condolences ❤️❤️
# 312178        My mouth is watering! What vinegar is it???
#
# [312179 rows x 6 columns]
