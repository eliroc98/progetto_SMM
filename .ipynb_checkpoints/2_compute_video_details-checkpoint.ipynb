# %%
import pandas as pd

import os

import numpy as np

import pickle

import ast

import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import string
nlp = spacy.load("en_core_web_md")

from sklearn.feature_extraction.text import TfidfVectorizer

from IPython.display import clear_output

# %%
df_videos_details = pd.read_csv('data/get_videos_details/videos_details.csv')

# %%
df_videos_details
# Out:
#          video_id                                              title  \
# 0     WyUyJKm-MiY  Reacting to MEAN Tik Toks About Me (This Cross...
# 1     5mUQo6lQG-U  Why My New Palette is CANCELLED... and Reveali...
# 2     QhbR5TEAMco                Meet My 2 NEW Pomeranian Puppies! 🐶
# 3     3qYykmHx5gc     Reacting To Tik Toks About Me (They Broke In!)
# 4     SxixuClI2vA  Sailor Moon x ColourPop Makeup… Is It Jeffree ...
# ...           ...                                                ...
# 1595  A-ZXP9vN7hg  Living In Norway, Underwater Restaurant, New R...
# 1596  LYHs9j3-bG4  I Tried Dark Contact Lenses For the First Time...
# 1597  qrWkDwpqAEI  NEW Pat McGrath Full Foundation Review + Naomi...
# 1598  6OUQi5ymq7o                     Learning To Love Myself | GRWM
# 1599  EuqQv-7AJ1o            Is Social Media Ruining Our Minds? GRWM
#
#                                             description  category_id  \
# 0     Today we are diving into the OTHER side of Tik...           24
# 1     Hey everyone, welcome BACK to my channel! Toda...           26
# 2     Hey everyone!!! Today I'm so excited to introd...           26
# 3     Follow my official Tik Tok account: https://ww...           24
# 4     Hey everyone... Welcome BACK to my channel! To...           26
# ...                                                 ...          ...
# 1595  Hi Friends!!\nHere is a lil blog of what we’ve...           26
# 1596  Hi Friends!!\nI got a bunch of requests to fil...           26
# 1597  Hey baes!!!\nFor todays video I wanted to recr...           26
# 1598  Hey babes!!\nFor todays video I’m sharing with...           26
# 1599  Hi Friends!!!\nToday I just wanted to slightly...           26
#
#                                      relevant_topic_ids  \
# 0                                                   NaN
# 1                            ['/m/019_rr', '/m/019_rr']
# 2     ['/m/019_rr', '/m/068hy', '/m/019_rr', '/m/068...
# 3                            ['/m/019_rr', '/m/019_rr']
# 4                            ['/m/019_rr', '/m/019_rr']
# ...                                                 ...
# 1595                         ['/m/019_rr', '/m/019_rr']
# 1596                         ['/m/019_rr', '/m/019_rr']
# 1597                         ['/m/019_rr', '/m/019_rr']
# 1598                         ['/m/019_rr', '/m/019_rr']
# 1599                         ['/m/019_rr', '/m/019_rr']
#
#                               relevant_topic_categories
# 0                                                   NaN
# 1     ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 2     ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 3     ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 4     ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# ...                                                 ...
# 1595  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 1596  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 1597  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 1598  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 1599  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
#
# [1600 rows x 6 columns]

# %%
topics = dict()
with open('data/youtube_topicIDs.txt', 'r') as f:
    for line in f.readlines():
        key, value = line.split(',')[0], line.split(',')[1][:-1]
        topics.update({key:value})

np.save('data/topic_ids.npy', topics, allow_pickle=True)
#t = np.load('data/topic_ids.npy',allow_pickle=True).tolist()

# %%
keywords = []
with open('data/key_words.txt', 'r') as f:
    for line in f.readlines():
        keywords.append(line.strip())

np.save('data/keywords.npy', keywords, allow_pickle=True)

# %%
makeup_brands = []
with open('data/makeup_brands.txt', 'r') as f:
    for line in f.readlines():
        makeup_brands.append(line.strip().lower())

np.save('data/makeup_brands.npy', makeup_brands, allow_pickle=True)

# %%
categories = dict()
with open('data/youtube_categoryIDs.txt', 'r') as f:
    for line in f.readlines():
        key, value = line.split('-')[0].strip(), line.split('-')[1][:-1].strip()
        categories.update({key:value})


np.save('data/categories_ids.npy', categories, allow_pickle=True)
#t = np.load('data/topic_ids.npy',allow_pickle=True).tolist()

# %%
def tokenizer(sentence):
    arr = []
    for w in sentence.split(' '):
        arr.append(w.translate(str.maketrans('', '', string.punctuation)).strip().lower())
    return arr

# %%
def compute_details(df):
    df_arr_computed = []
    for idx, row in enumerate(df.values):
        print('Video: {}/{}'.format(idx,len(df.values)))
        clear_output(wait=True)
        line=[row[0],row[1],row[2]]
        try:
            line.append(categories[str(row[3])])
        except:
            line.append(None)
            #print('NaN value')
        try:
            l = row[4]
            l = ast.literal_eval(l)
            l = [n.strip() for n in l]
            tps = [topics[item] for item in l]
            line.append(tps)
        except:
            line.append(None)
            #print('NaN value')
        try:
            v = row[5]
            v = ast.literal_eval(v)
            v = [n.split('/')[-1] for n in v]
            line.append(v)
        except:
            line.append(None)
            #print('NaN value')
        #vedo se il titolo contiene keywords
        if type(row[1]) is str:
            title_topics = set()
            matches = ["get", "ready", "with", "me"]
            if all(x in row[1].lower() for x in matches):
                print('get ready with me')
                title_topics.add('get ready with me')
            matches = ["how", "to"]
            if all(x in row[1].lower() for x in matches):
                print('how to')
                title_topics.add('how to')
            for keyword in keywords:
                if keyword in tokenizer(row[1]):
                    if keyword == 'tik':
                        title_topics.add('tik tok')
                    if keyword == 'chit':
                        title_topics.add('chit chat')
                    if keyword not in ['tok', 'toks','chat','tik','chit']:
                        title_topics.add(keyword)
            line.append(list(title_topics))
        else:
            line.append([])
        #vedo se la descrizione contiene brand
        if type(row[2]) is str:
            cited_brand = set()
            for brand in makeup_brands:
                matches = brand.split(' ')
                if all(x in row[2].lower() for x in matches):
                    cited_brand.add(brand)
            line.append(list(cited_brand))
        else:
            line.append([])
        df_arr_computed.append(line)
    c =[item for item in df.columns]
    c.append('title_topics')
    c.append('cited_brand')
    df_computed = pd.DataFrame(df_arr_computed, columns = c)
    return df_computed

# %%
df_computed = compute_details(df_videos_details)
# Out:
# Video: 1599/1600

# %%
df_computed
# Out:
#          video_id                                              title  \
# 0     WyUyJKm-MiY  Reacting to MEAN Tik Toks About Me (This Cross...
# 1     5mUQo6lQG-U  Why My New Palette is CANCELLED... and Reveali...
# 2     QhbR5TEAMco                Meet My 2 NEW Pomeranian Puppies! 🐶
# 3     3qYykmHx5gc     Reacting To Tik Toks About Me (They Broke In!)
# 4     SxixuClI2vA  Sailor Moon x ColourPop Makeup… Is It Jeffree ...
# ...           ...                                                ...
# 1595  A-ZXP9vN7hg  Living In Norway, Underwater Restaurant, New R...
# 1596  LYHs9j3-bG4  I Tried Dark Contact Lenses For the First Time...
# 1597  qrWkDwpqAEI  NEW Pat McGrath Full Foundation Review + Naomi...
# 1598  6OUQi5ymq7o                     Learning To Love Myself | GRWM
# 1599  EuqQv-7AJ1o            Is Social Media Ruining Our Minds? GRWM
#
#                                             description    category_id  \
# 0     Today we are diving into the OTHER side of Tik...  Entertainment
# 1     Hey everyone, welcome BACK to my channel! Toda...  Howto & Style
# 2     Hey everyone!!! Today I'm so excited to introd...  Howto & Style
# 3     Follow my official Tik Tok account: https://ww...  Entertainment
# 4     Hey everyone... Welcome BACK to my channel! To...  Howto & Style
# ...                                                 ...            ...
# 1595  Hi Friends!!\nHere is a lil blog of what we’ve...  Howto & Style
# 1596  Hi Friends!!\nI got a bunch of requests to fil...  Howto & Style
# 1597  Hey baes!!!\nFor todays video I wanted to recr...  Howto & Style
# 1598  Hey babes!!\nFor todays video I’m sharing with...  Howto & Style
# 1599  Hi Friends!!!\nToday I just wanted to slightly...  Howto & Style
#
#                       relevant_topic_ids     relevant_topic_categories  \
# 0                                   None                          None
# 1                 [Lifestyle, Lifestyle]       [Lifestyle_(sociology)]
# 2     [Lifestyle, Pets, Lifestyle, Pets]  [Lifestyle_(sociology), Pet]
# 3                 [Lifestyle, Lifestyle]       [Lifestyle_(sociology)]
# 4                 [Lifestyle, Lifestyle]       [Lifestyle_(sociology)]
# ...                                  ...                           ...
# 1595              [Lifestyle, Lifestyle]       [Lifestyle_(sociology)]
# 1596              [Lifestyle, Lifestyle]       [Lifestyle_(sociology)]
# 1597              [Lifestyle, Lifestyle]       [Lifestyle_(sociology)]
# 1598              [Lifestyle, Lifestyle]       [Lifestyle_(sociology)]
# 1599              [Lifestyle, Lifestyle]       [Lifestyle_(sociology)]
#
#                     title_topics  \
# 0            [tik tok, reacting]
# 1           [revealing, palette]
# 2                             []
# 3            [tik tok, reacting]
# 4                     [approved]
# ...                          ...
# 1595                      [vlog]
# 1596                          []
# 1597  [foundation, review, look]
# 1598                      [grwm]
# 1599                      [grwm]
#
#                                             cited_brand
# 0     [jeffree star, jeffree star cosmetics, it cosm...
# 1     [jeffree star, jeffree star cosmetics, it cosm...
# 2     [jeffree star, la girl, jeffree star cosmetics...
# 3     [jeffree star, jeffree star cosmetics, it cosm...
# 4     [jeffree star, colourpop, colourpop cosmetics,...
# ...                                                 ...
# 1595                                                 []
# 1596                                                 []
# 1597                                      [pat mcgrath]
# 1598  [elf, red apple lipstick, urban decay, natura ...
# 1599                                                 []
#
# [1600 rows x 8 columns]

# %%
df_computed.to_csv('data/get_videos_details/videos_details_computed.csv', index = False)
