# %%
import os

import numpy as np

import networkx as nx

import matplotlib.pyplot as plt

from IPython.display import clear_output

# %%
first_graph = nx.read_gpickle('data/first_graph_node_attributes_coded.gpickle')

# %%
gephi_graph = nx.read_gpickle('data/gephi_graph_node_attributes.gpickle')

# %%
gephi_graph = nx.read_gexf('data/gephi_graph.gexf')

# %%
first_graph_1 = nx.read_gpickle('data/first_graph_1.gpickle')

# %%
positive_first_graph = nx.Graph()
negative_first_graph = nx.Graph()
positive_gephi_graph = nx.Graph()
negative_gephi_graph = nx.Graph()

# %%
for edge in gephi_graph.edges:
    print(edge)
    #print(gephi_graph.get_edge_data(edge[0],edge[1]))
    
    print(gephi_graph[edge[0]][edge[1]]['weight'])
# Out:
# ('Amber Radtke', 'Katie Boyd')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-25c54c163048> in <module>
#       3     #print(gephi_graph.get_edge_data(edge[0],edge[1]))
#       4
# ----> 5     print(gephi_graph[edge[0]][edge[1]]['weight'])
#
# KeyError: 'weight'

# %%
weights = nx.get_edge_attributes(first_graph,'weight')
for e in first_graph.edges:
    print(weights[e])
    break
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-f5fc7f034349> in <module>
#       1 weights = nx.get_edge_attributes(first_graph,'weight')
#       2 for e in first_graph.edges:
# ----> 3     print(weights[e])
#       4     break
#
# KeyError: ('Amber Radtke', 'Katie Boyd')

# %%
len(weights)
# Out:
# 490745

# %%
len(first_graph.edges)
# Out:
# 2865239

# %%
first_graph['Cat Duquette']['Lucy Clark']['sentiment']
# Out:
# 1

# %%
edges = list(np.load('data/percentile/percentile_6_1.npy', allow_pickle = True))

# %%
edges
# Out:
# [array([('terri-ann byrne', 'Sumaiya Mahmud', 0.6666666666666666),
#         {'youtubers': ['perfekt', 'KathleenLights'], 'topics': ['lifestyle'], 'brands': ['colourpop cosmetics'], 'sentiment': 0}],
#        dtype=object),
#  array([('terri-ann byrne', 'Carmen Quinones', 0.6666666666666666),
#         {'youtubers': ['perfekt', 'KathleenLights'], 'topics': ['lifestyle'], 'brands': ['colourpop cosmetics'], 'sentiment': 0}],
#        dtype=object),
#  array([('terri-ann byrne', 'Raghad Mosaed', 0.6666666666666666),
#         {'youtubers': ['perfekt', 'KathleenLights'], 'topics': ['lifestyle'], 'brands': ['colourpop cosmetics'], 'sentiment': 0}],
#        dtype=object),
#  array([('terri-ann byrne', 'Isabella Larrazabal', 0.6666666666666666),
#         {'youtubers': ['perfekt', 'KathleenLights'], 'topics': ['lifestyle'], 'brands': ['colourpop cosmetics'], 'sentiment': 0}],
#        dtype=object),
#  array([('terri-ann byrne', 'Tara Is Bored', 0.6666666666666666),
# ...
