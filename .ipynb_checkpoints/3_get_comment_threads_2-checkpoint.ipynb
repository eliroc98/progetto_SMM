# %%
import pandas as pd

import requests 

import os

import json

import googleapiclient.discovery
import googleapiclient.errors

import numpy as np

# %%
chiave_yt = json.load(open('key.json', 'r'))['youtube']['key'][1]
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=chiave_yt)

# %%
quota
# Out:
# 1581

# %%
#insert initial quota value
#MODIFICA MAXQUOTA A 9900!!
quota = 0

# %%
df_videos = pd.read_csv('data/get_youtuber_videos_output/youtuber_videos.csv')

# %%
def get_infos(response):
    info_comment_list=[]
    video_id=next_page_token = thread_comment_id = top_level_comment_id = author_display_name = author_channel_id = author_channel_id = text_original=None
    try:
        next_page_token = response['nextPageToken']
    except KeyError as e:
        #print(response)
        next_page_token = None
        print('Page token non esistente')
    items = response['items']
    for item in items:
        thread_comment_id = item['id']
        try:
            video_id = item['snippet']['videoId']
            top_level_comment = item['snippet']['topLevelComment']
            top_level_comment_id = top_level_comment['id']
            top_level_comment_snippet = top_level_comment['snippet']
            author_display_name = top_level_comment_snippet['authorDisplayName']
            text_original = top_level_comment_snippet['textOriginal']
            author_channel_id = top_level_comment_snippet['authorChannelId']['value']
        except KeyError as e:
            print(e.args[0])
            print('Problem with commentThread {}'.format(thread_comment_id))
        info_comment_list.append([video_id,thread_comment_id,top_level_comment_id,author_display_name,author_channel_id,text_original])
    return next_page_token, info_comment_list

# %%
#############################################################################

# %%
#round 1
#la prossima volta togli e decommenta quello sotto

# %%
last_csv = int(np.load('data/get_comment_threads_output/last_csv.npy'))
next_page_token = str(np.load('data/get_comment_threads_output/next_page_token.npy'))
last_video_idx = int(np.load('data/get_comment_threads_output/video_to_start.npy'))
videos_not_finished = (np.load('data/get_comment_threads_output/videos_not_finished.npy')).tolist()
videos_disabled_comments = (np.load('data/get_comment_threads_output/videos_disabled_comments.npy')).tolist()
print("Starting with video #{}, next_page_token: {}".format(last_video_idx,next_page_token))
print("Writing on {} csv".format(last_csv+1))
# Out:
# Starting with video #2399, next_page_token: QURTSl9pMGRlWWU5S2k3SzZsR1VoaUdad2FmejFMYl8xMC1sa3dWRk5uRnZJUlpPODdGcW5HQ3U2a1h2MllRVFZIbzFJM3oyWVFHcE5mZ3NkY0tqWXlRMTFTb1V2RHhzREtWbkRXb25IWEpSWUhRWU52MmF0NkM0eDMtUmhoNDNJb200bGxJMXgtN3RDdkJoSGRJdFZ3RmxmS3BMOUxUbWlRR0NnOV9faEtUVQ==
# Writing on 5 csv

# %%
df_videos_0 = df_videos[last_video_idx:]

# %%
#per i video con più di 10000 commenti, salvo l'indice del video con il next page token

# %%
comments = []
comments_count = 0

# %%
df_videos_0
# Out:
#                     channel_id     video_id
# 2399  UCOtoxvHLKrIlWbt4MRBWfbQ  lSlKqgyE2Zo
# 2400  UCOtoxvHLKrIlWbt4MRBWfbQ  _5ki0E6arN0
# 2401  UCOtoxvHLKrIlWbt4MRBWfbQ  5ac6JqEeD1U
# 2402  UCOtoxvHLKrIlWbt4MRBWfbQ  xa7XZF4wA70
# 2403  UCOtoxvHLKrIlWbt4MRBWfbQ  0ztsAOrPdzQ
# ...                        ...          ...
# 2588  UCq7EY7H2XF6TV7Z5mLv-aNg  bm-3Qrr7EUA
# 2589  UCq7EY7H2XF6TV7Z5mLv-aNg  hkxRjDS_Cjw
# 2590  UCq7EY7H2XF6TV7Z5mLv-aNg  8kElrRAa1ws
# 2591  UCq7EY7H2XF6TV7Z5mLv-aNg  7x6tX5T7LOs
# 2592  UCq7EY7H2XF6TV7Z5mLv-aNg  NSdUFKOkKnc
#
# [194 rows x 2 columns]

# %%
for video in df_videos_0['video_id'].values:
    print('________________________________________________________')
    print('{} video: {}'.format(last_video_idx, video))
    video_comments_count = 0
    while next_page_token != None and video_comments_count<10000:
        print('Reached quotas: {}'.format(quota))
        if quota > 9900:
            print('Quota exceeded')
            break
        else:
            request = youtube.commentThreads().list(
                part="snippet",
                maxResults=100,
                pageToken=next_page_token,
                videoId=video
            )
            try:
                response = request.execute()
                quota += 3
                next_page_token, results = get_infos(response)
                video_comments_count+=len(results)
                comments_count+=video_comments_count
                comments.append(results)
            except:
                videos_disabled_comments.append(video)
                next_page_token = None
                print('Video has disabled comments')
    if quota > 9900:
        break
    if next_page_token == None or video_comments_count>=10000:
        if next_page_token != None:
            print('Reached max comment count')
            videos_not_finished.append([video, next_page_token])
        last_video_idx += 1
        next_page_token = ' '
        print('Total comments for {}: {}'.format(video, video_comments_count))

print("Done with {} comments, video to start: {}\n with next_page_token: {}".format(comments_count,last_video_idx, next_page_token))
# Out:
# ________________________________________________________
# 2399 video: lSlKqgyE2Zo
# Reached quotas: 0
# Reached quotas: 3
# Reached quotas: 6
# Reached quotas: 9
# Reached quotas: 12
# Reached quotas: 15
# Reached quotas: 18
# Reached quotas: 21
# Reached quotas: 24
# Reached quotas: 27
# Reached quotas: 30
# Reached quotas: 33
# Reached quotas: 36
# Reached quotas: 39
# Reached quotas: 42
# Reached quotas: 45
# Reached quotas: 48
# Reached quotas: 51
# Reached quotas: 54
# Reached quotas: 57
# Reached quotas: 60
# Reached quotas: 63
# Reached quotas: 66
# Reached quotas: 69
# Reached quotas: 72
# Reached quotas: 75
# Reached quotas: 78
# Reached quotas: 81
# Reached quotas: 84
# Reached quotas: 87
# Reached quotas: 90
# Reached quotas: 93
# Reached quotas: 96
# Reached quotas: 99
# Reached quotas: 102
# Reached quotas: 105
# Reached quotas: 108
# Reached quotas: 111
# Reached quotas: 114
# Reached quotas: 117
# Reached quotas: 120
# Reached quotas: 123
# Reached quotas: 126
# Reached quotas: 129
# Reached quotas: 132
# Reached quotas: 135
# Page token non esistente
# Total comments for lSlKqgyE2Zo: 4558
# ________________________________________________________
# 2400 video: _5ki0E6arN0
# Reached quotas: 138
# Reached quotas: 141
# Reached quotas: 144
# Reached quotas: 147
# Reached quotas: 150
# Reached quotas: 153
# Reached quotas: 156
# Reached quotas: 159
# Reached quotas: 162
# Reached quotas: 165
# Reached quotas: 168
# Reached quotas: 171
# Reached quotas: 174
# Reached quotas: 177
# Reached quotas: 180
# Reached quotas: 183
# Reached quotas: 186
# Reached quotas: 189
# Page token non esistente
# Total comments for _5ki0E6arN0: 1777
# ________________________________________________________
# 2401 video: 5ac6JqEeD1U
# Reached quotas: 192
# Reached quotas: 195
# Reached quotas: 198
# Reached quotas: 201
# Reached quotas: 204
# Reached quotas: 207
# Reached quotas: 210
# Reached quotas: 213
# Reached quotas: 216
# Reached quotas: 219
# Reached quotas: 222
# Reached quotas: 225
# Reached quotas: 228
# Reached quotas: 231
# Reached quotas: 234
# Reached quotas: 237
# Reached quotas: 240
# Reached quotas: 243
# Reached quotas: 246
# Reached quotas: 249
# Reached quotas: 252
# Reached quotas: 255
# Page token non esistente
# Total comments for 5ac6JqEeD1U: 2158
# ________________________________________________________
# 2402 video: xa7XZF4wA70
# Reached quotas: 258
# Reached quotas: 261
# Reached quotas: 264
# Reached quotas: 267
# Reached quotas: 270
# Reached quotas: 273
# Reached quotas: 276
# Reached quotas: 279
# Reached quotas: 282
# Reached quotas: 285
# Reached quotas: 288
# Reached quotas: 291
# Reached quotas: 294
# Reached quotas: 297
# Reached quotas: 300
# Reached quotas: 303
# Reached quotas: 306
# Reached quotas: 309
# Reached quotas: 312
# Reached quotas: 315
# Reached quotas: 318
# Reached quotas: 321
# Reached quotas: 324
# Reached quotas: 327
# Reached quotas: 330
# Reached quotas: 333
# Reached quotas: 336
# Reached quotas: 339
# Reached quotas: 342
# Reached quotas: 345
# Reached quotas: 348
# Reached quotas: 351
# Reached quotas: 354
# Reached quotas: 357
# Reached quotas: 360
# Reached quotas: 363
# Reached quotas: 366
# Reached quotas: 369
# Reached quotas: 372
# Reached quotas: 375
# Reached quotas: 378
# Reached quotas: 381
# Reached quotas: 384
# Reached quotas: 387
# Reached quotas: 390
# Reached quotas: 393
# Reached quotas: 396
# Reached quotas: 399
# Reached quotas: 402
# Reached quotas: 405
# Reached quotas: 408
# Reached quotas: 411
# Reached quotas: 414
# Reached quotas: 417
# Reached quotas: 420
# Reached quotas: 423
# Reached quotas: 426
# Reached quotas: 429
# Reached quotas: 432
# Reached quotas: 435
# Reached quotas: 438
# Reached quotas: 441
# Reached quotas: 444
# Reached quotas: 447
# Reached quotas: 450
# Reached quotas: 453
# Reached quotas: 456
# Reached quotas: 459
# Reached quotas: 462
# Reached quotas: 465
# Reached quotas: 468
# Reached quotas: 471
# Reached quotas: 474
# Reached quotas: 477
# Reached quotas: 480
# Reached quotas: 483
# Page token non esistente
# Total comments for xa7XZF4wA70: 7589
# ________________________________________________________
# 2403 video: 0ztsAOrPdzQ
# Reached quotas: 486
# Reached quotas: 489
# Reached quotas: 492
# Reached quotas: 495
# Reached quotas: 498
# Reached quotas: 501
# Reached quotas: 504
# Reached quotas: 507
# Reached quotas: 510
# Reached quotas: 513
# Reached quotas: 516
# Reached quotas: 519
# Reached quotas: 522
# Reached quotas: 525
# Reached quotas: 528
# Reached quotas: 531
# Reached quotas: 534
# Reached quotas: 537
# Reached quotas: 540
# Reached quotas: 543
# Reached quotas: 546
# Reached quotas: 549
# Page token non esistente
# Total comments for 0ztsAOrPdzQ: 2153
# ________________________________________________________
# 2404 video: FTzfzj3v--0
# Reached quotas: 552
# Reached quotas: 555
# Page token non esistente
# authorChannelId
# Problem with commentThread UgxUN-Yj43d6tzCOIg54AaABAg
# Total comments for FTzfzj3v--0: 151
# ________________________________________________________
# 2405 video: eeFjBnABTmU
# Reached quotas: 558
# Reached quotas: 561
# Page token non esistente
# Total comments for eeFjBnABTmU: 160
# ________________________________________________________
# 2406 video: rLg5yIsd23o
# Reached quotas: 564
# Page token non esistente
# Total comments for rLg5yIsd23o: 82
# ________________________________________________________
# 2407 video: tCyS1mEqT7A
# Reached quotas: 567
# Reached quotas: 570
# Reached quotas: 573
# Reached quotas: 576
# Reached quotas: 579
# Reached quotas: 582
# Reached quotas: 585
# Page token non esistente
# Total comments for tCyS1mEqT7A: 675
# ________________________________________________________
# 2408 video: NHybtANqt84
# Reached quotas: 588
# Page token non esistente
# Total comments for NHybtANqt84: 71
# ________________________________________________________
# 2409 video: DeWJNR7QhdU
# Reached quotas: 591
# Reached quotas: 594
# Page token non esistente
# Total comments for DeWJNR7QhdU: 118
# ________________________________________________________
# 2410 video: oI-vlEDTl6c
# Reached quotas: 597
# Reached quotas: 600
# Page token non esistente
# Total comments for oI-vlEDTl6c: 198
# ________________________________________________________
# 2411 video: mUoT89OxfVc
# Reached quotas: 603
# Reached quotas: 606
# Page token non esistente
# Total comments for mUoT89OxfVc: 183
# ________________________________________________________
# 2412 video: CB7CFJRNhZQ
# Reached quotas: 609
# Reached quotas: 612
# Page token non esistente
# Total comments for CB7CFJRNhZQ: 107
# ________________________________________________________
# 2413 video: OrNFnFYBrqI
# Reached quotas: 615
# Reached quotas: 618
# Page token non esistente
# Total comments for OrNFnFYBrqI: 131
# ________________________________________________________
# 2414 video: sj8P-vjEPSc
# Reached quotas: 621
# Page token non esistente
# Total comments for sj8P-vjEPSc: 48
# ________________________________________________________
# 2415 video: qOjjIP4HM5g
# Reached quotas: 624
# Reached quotas: 627
# Page token non esistente
# Total comments for qOjjIP4HM5g: 156
# ________________________________________________________
# 2416 video: Ozi2pCXtU9c
# Reached quotas: 630
# Reached quotas: 633
# Page token non esistente
# Total comments for Ozi2pCXtU9c: 181
# ________________________________________________________
# 2417 video: l554_NMTqhw
# Reached quotas: 636
# Reached quotas: 639
# Reached quotas: 642
# Page token non esistente
# Total comments for l554_NMTqhw: 256
# ________________________________________________________
# 2418 video: UeQBwHi3C_Y
# Reached quotas: 645
# Page token non esistente
# Total comments for UeQBwHi3C_Y: 74
# ________________________________________________________
# 2419 video: J1MoXKJfeGA
# Reached quotas: 648
# Reached quotas: 651
# Reached quotas: 654
# Reached quotas: 657
# Page token non esistente
# Total comments for J1MoXKJfeGA: 315
# ________________________________________________________
# 2420 video: KIHO8U3dBuo
# Reached quotas: 660
# Page token non esistente
# Total comments for KIHO8U3dBuo: 68
# ________________________________________________________
# 2421 video: z8N4f31xWVU
# Reached quotas: 663
# Reached quotas: 666
# Page token non esistente
# Total comments for z8N4f31xWVU: 143
# ________________________________________________________
# 2422 video: wsW_qgX7YZ0
# Reached quotas: 669
# Reached quotas: 672
# Reached quotas: 675
# Reached quotas: 678
# Reached quotas: 681
# Page token non esistente
# Total comments for wsW_qgX7YZ0: 450
# ________________________________________________________
# 2423 video: mjmB13AKBjU
# Reached quotas: 684
# Reached quotas: 687
# Reached quotas: 690
# Reached quotas: 693
# Reached quotas: 696
# Reached quotas: 699
# Reached quotas: 702
# Page token non esistente
# Total comments for mjmB13AKBjU: 680
# ________________________________________________________
# 2424 video: jXhEhtNVsq4
# Reached quotas: 705
# Reached quotas: 708
# Page token non esistente
# Total comments for jXhEhtNVsq4: 119
# ________________________________________________________
# 2425 video: 0BjHKhehvog
# Reached quotas: 711
# Reached quotas: 714
# Page token non esistente
# Total comments for 0BjHKhehvog: 127
# ________________________________________________________
# 2426 video: fWb9QyiO-YU
# Reached quotas: 717
# Reached quotas: 720
# Page token non esistente
# Total comments for fWb9QyiO-YU: 115
# ________________________________________________________
# 2427 video: D0xY9MZNwaw
# Reached quotas: 723
# Page token non esistente
# Total comments for D0xY9MZNwaw: 94
# ________________________________________________________
# 2428 video: V-L9NwXX8cI
# Reached quotas: 726
# Reached quotas: 729
# Page token non esistente
# Total comments for V-L9NwXX8cI: 173
# ________________________________________________________
# 2429 video: q4mbpWC--ek
# Reached quotas: 732
# Reached quotas: 735
# Reached quotas: 738
# Reached quotas: 741
# Reached quotas: 744
# Page token non esistente
# Total comments for q4mbpWC--ek: 488
# ________________________________________________________
# 2430 video: srJbAnVpYfg
# Reached quotas: 747
# Reached quotas: 750
# Page token non esistente
# Total comments for srJbAnVpYfg: 122
# ________________________________________________________
# 2431 video: M1j3lEm3ZY0
# Reached quotas: 753
# Reached quotas: 756
# Page token non esistente
# Total comments for M1j3lEm3ZY0: 151
# ________________________________________________________
# 2432 video: lLHT5BMmXSw
# Reached quotas: 759
# Reached quotas: 762
# Page token non esistente
# Total comments for lLHT5BMmXSw: 142
# ________________________________________________________
# 2433 video: za3aefUQ-wA
# Reached quotas: 765
# Reached quotas: 768
# Page token non esistente
# Total comments for za3aefUQ-wA: 110
# ________________________________________________________
# 2434 video: rQwvbYG37ys
# Reached quotas: 771
# Reached quotas: 774
# Reached quotas: 777
# Page token non esistente
# Total comments for rQwvbYG37ys: 244
# ________________________________________________________
# 2435 video: W3yPUQzUeAM
# Reached quotas: 780
# Reached quotas: 783
# Reached quotas: 786
# Reached quotas: 789
# Reached quotas: 792
# Reached quotas: 795
# Reached quotas: 798
# Page token non esistente
# Total comments for W3yPUQzUeAM: 607
# ________________________________________________________
# 2436 video: PRjZjj68H_0
# Reached quotas: 801
# Reached quotas: 804
# Page token non esistente
# Total comments for PRjZjj68H_0: 175
# ________________________________________________________
# 2437 video: 6JiUWaaT2Go
# Reached quotas: 807
# Reached quotas: 810
# Reached quotas: 813
# Reached quotas: 816
# Reached quotas: 819
# Page token non esistente
# Total comments for 6JiUWaaT2Go: 468
# ________________________________________________________
# 2438 video: 6vSy97hHdRo
# Reached quotas: 822
# Reached quotas: 825
# Reached quotas: 828
# Page token non esistente
# Total comments for 6vSy97hHdRo: 234
# ________________________________________________________
# 2439 video: ZhnkddAk-ig
# Reached quotas: 831
# Reached quotas: 834
# Reached quotas: 837
# Page token non esistente
# Total comments for ZhnkddAk-ig: 214
# ________________________________________________________
# 2440 video: CzqILKAiWkE
# Reached quotas: 840
# Reached quotas: 843
# Reached quotas: 846
# Page token non esistente
# Total comments for CzqILKAiWkE: 231
# ________________________________________________________
# 2441 video: ljjlxz9AxH0
# Reached quotas: 849
# Reached quotas: 852
# Reached quotas: 855
# Reached quotas: 858
# Reached quotas: 861
# Reached quotas: 864
# Reached quotas: 867
# Reached quotas: 870
# Reached quotas: 873
# Reached quotas: 876
# Reached quotas: 879
# Reached quotas: 882
# Page token non esistente
# Total comments for ljjlxz9AxH0: 1177
# ________________________________________________________
# 2442 video: bWrBLXDvDL8
# Reached quotas: 885
# Reached quotas: 888
# Page token non esistente
# Total comments for bWrBLXDvDL8: 148
# ________________________________________________________
# 2443 video: T_JASVvW8g4
# Reached quotas: 891
# Reached quotas: 894
# Page token non esistente
# Total comments for T_JASVvW8g4: 175
# ________________________________________________________
# 2444 video: JeUumIVv0Kc
# Reached quotas: 897
# Reached quotas: 900
# Page token non esistente
# Total comments for JeUumIVv0Kc: 183
# ________________________________________________________
# 2445 video: uHPxx8MPH8k
# Reached quotas: 903
# Reached quotas: 906
# Reached quotas: 909
# Reached quotas: 912
# Page token non esistente
# Total comments for uHPxx8MPH8k: 339
# ________________________________________________________
# 2446 video: docB03GAnt8
# Reached quotas: 915
# Reached quotas: 918
# Page token non esistente
# Total comments for docB03GAnt8: 200
# ________________________________________________________
# 2447 video: uNWYzbrU_uo
# Reached quotas: 921
# Reached quotas: 924
# Page token non esistente
# Total comments for uNWYzbrU_uo: 129
# ________________________________________________________
# 2448 video: QundIvvC56A
# Reached quotas: 927
# Page token non esistente
# Total comments for QundIvvC56A: 61
# ________________________________________________________
# 2449 video: 7up0NTyrqts
# Reached quotas: 930
# Reached quotas: 933
# Page token non esistente
# Total comments for 7up0NTyrqts: 139
# ________________________________________________________
# 2450 video: yeVQiuCKCe0
# Reached quotas: 936
# Reached quotas: 939
# Page token non esistente
# Total comments for yeVQiuCKCe0: 142
# ________________________________________________________
# 2451 video: ifWGy77zNTA
# Reached quotas: 942
# Page token non esistente
# Total comments for ifWGy77zNTA: 84
# ________________________________________________________
# 2452 video: nU43GqTwjiE
# Reached quotas: 945
# Reached quotas: 948
# Page token non esistente
# Total comments for nU43GqTwjiE: 140
# ________________________________________________________
# 2453 video: 3GI48-7pfvo
# Reached quotas: 951
# Reached quotas: 954
# Page token non esistente
# Total comments for 3GI48-7pfvo: 118
# ________________________________________________________
# 2454 video: 9dVOZ2XJPwk
# Reached quotas: 957
# Reached quotas: 960
# Reached quotas: 963
# Page token non esistente
# Total comments for 9dVOZ2XJPwk: 209
# ________________________________________________________
# 2455 video: qebbdamy-eU
# Reached quotas: 966
# Reached quotas: 969
# Reached quotas: 972
# Page token non esistente
# Total comments for qebbdamy-eU: 254
# ________________________________________________________
# 2456 video: qoJintkLuro
# Reached quotas: 975
# Page token non esistente
# Total comments for qoJintkLuro: 58
# ________________________________________________________
# 2457 video: E2TjIyUYNXs
# Reached quotas: 978
# Reached quotas: 981
# Page token non esistente
# Total comments for E2TjIyUYNXs: 105
# ________________________________________________________
# 2458 video: KGMYv6CofPw
# Reached quotas: 984
# Reached quotas: 987
# Page token non esistente
# Total comments for KGMYv6CofPw: 187
# ________________________________________________________
# 2459 video: FcyD15Bb70E
# Reached quotas: 990
# Reached quotas: 993
# Page token non esistente
# Total comments for FcyD15Bb70E: 154
# ________________________________________________________
# 2460 video: 646FMuQbDOQ
# Reached quotas: 996
# Reached quotas: 999
# Page token non esistente
# Total comments for 646FMuQbDOQ: 164
# ________________________________________________________
# 2461 video: KU2TtpI3zGg
# Reached quotas: 1002
# Reached quotas: 1005
# Page token non esistente
# Total comments for KU2TtpI3zGg: 113
# ________________________________________________________
# 2462 video: wj700vFpT4g
# Reached quotas: 1008
# Reached quotas: 1011
# Page token non esistente
# Total comments for wj700vFpT4g: 136
# ________________________________________________________
# 2463 video: REschPsmx9Q
# Reached quotas: 1014
# Reached quotas: 1017
# Page token non esistente
# Total comments for REschPsmx9Q: 140
# ________________________________________________________
# 2464 video: qcU6zyu_2gE
# Reached quotas: 1020
# authorChannelId
# Problem with commentThread UgyhPRWUTOmG8kfXhBN4AaABAg
# Reached quotas: 1023
# Reached quotas: 1026
# Page token non esistente
# Total comments for qcU6zyu_2gE: 256
# ________________________________________________________
# 2465 video: pZrom_dUZZc
# Reached quotas: 1029
# Reached quotas: 1032
# Reached quotas: 1035
# Page token non esistente
# Total comments for pZrom_dUZZc: 242
# ________________________________________________________
# 2466 video: zU5V8D_e5xE
# Reached quotas: 1038
# Reached quotas: 1041
# Page token non esistente
# Total comments for zU5V8D_e5xE: 172
# ________________________________________________________
# 2467 video: WmRGtjBAdLU
# Reached quotas: 1044
# Reached quotas: 1047
# Page token non esistente
# Total comments for WmRGtjBAdLU: 129
# ________________________________________________________
# 2468 video: AoJ3ORjvoug
# Reached quotas: 1050
# Page token non esistente
# Total comments for AoJ3ORjvoug: 54
# ________________________________________________________
# 2469 video: _21x9V6kjKk
# Reached quotas: 1053
# Reached quotas: 1056
# Reached quotas: 1059
# Reached quotas: 1062
# Reached quotas: 1065
# Page token non esistente
# Total comments for _21x9V6kjKk: 488
# ________________________________________________________
# 2470 video: _Mf7EnT0tsY
# Reached quotas: 1068
# Reached quotas: 1071
# Page token non esistente
# Total comments for _Mf7EnT0tsY: 198
# ________________________________________________________
# 2471 video: UZLFpYb_iaA
# Reached quotas: 1074
# Reached quotas: 1077
# Page token non esistente
# Total comments for UZLFpYb_iaA: 136
# ________________________________________________________
# 2472 video: 3u1Gr2oxvlo
# Reached quotas: 1080
# Reached quotas: 1083
# Reached quotas: 1086
# Reached quotas: 1089
# Page token non esistente
# Total comments for 3u1Gr2oxvlo: 318
# ________________________________________________________
# 2473 video: xPObhbfZFgs
# Reached quotas: 1092
# Reached quotas: 1095
# Page token non esistente
# Total comments for xPObhbfZFgs: 135
# ________________________________________________________
# 2474 video: UENv564QXsc
# Reached quotas: 1098
# Page token non esistente
# Total comments for UENv564QXsc: 83
# ________________________________________________________
# 2475 video: xl6RVEnpSSk
# Reached quotas: 1101
# Reached quotas: 1104
# Reached quotas: 1107
# Page token non esistente
# Total comments for xl6RVEnpSSk: 232
# ________________________________________________________
# 2476 video: GjYDgePMNfU
# Reached quotas: 1110
# Page token non esistente
# Total comments for GjYDgePMNfU: 80
# ________________________________________________________
# 2477 video: Eq2GgGhM-m4
# Reached quotas: 1113
# Reached quotas: 1116
# Reached quotas: 1119
# Reached quotas: 1122
# Reached quotas: 1125
# Page token non esistente
# Total comments for Eq2GgGhM-m4: 496
# ________________________________________________________
# 2478 video: Mb0-tDBAplQ
# Reached quotas: 1128
# Reached quotas: 1131
# Page token non esistente
# Total comments for Mb0-tDBAplQ: 102
# ________________________________________________________
# 2479 video: MofdwskzjEI
# Reached quotas: 1134
# Reached quotas: 1137
# Reached quotas: 1140
# Page token non esistente
# Total comments for MofdwskzjEI: 253
# ________________________________________________________
# 2480 video: IyAl8VcD_y8
# Reached quotas: 1143
# Page token non esistente
# Total comments for IyAl8VcD_y8: 78
# ________________________________________________________
# 2481 video: 3nldN--R9YA
# Reached quotas: 1146
# Reached quotas: 1149
# Reached quotas: 1152
# Reached quotas: 1155
# Reached quotas: 1158
# Reached quotas: 1161
# Page token non esistente
# Total comments for 3nldN--R9YA: 519
# ________________________________________________________
# 2482 video: 4xEDqQL4X8Q
# Reached quotas: 1164
# Reached quotas: 1167
# Reached quotas: 1170
# Page token non esistente
# Total comments for 4xEDqQL4X8Q: 202
# ________________________________________________________
# 2483 video: AV4J5TbwCZQ
# Reached quotas: 1173
# Video has disabled comments
# Total comments for AV4J5TbwCZQ: 0
# ________________________________________________________
# 2484 video: wXvBxy573Lw
# Reached quotas: 1173
# Video has disabled comments
# Total comments for wXvBxy573Lw: 0
# ________________________________________________________
# 2485 video: E66Fs44icl0
# Reached quotas: 1173
# Video has disabled comments
# Total comments for E66Fs44icl0: 0
# ________________________________________________________
# 2486 video: f3tTbcn0gwc
# Reached quotas: 1173
# Page token non esistente
# Total comments for f3tTbcn0gwc: 21
# ________________________________________________________
# 2487 video: jD-LRpjMuqI
# Reached quotas: 1176
# Page token non esistente
# Total comments for jD-LRpjMuqI: 36
# ________________________________________________________
# 2488 video: kq6xe5GrHhg
# Reached quotas: 1179
# Page token non esistente
# Total comments for kq6xe5GrHhg: 77
# ________________________________________________________
# 2489 video: NnbPzsYU_gA
# Reached quotas: 1182
# Page token non esistente
# Total comments for NnbPzsYU_gA: 59
# ________________________________________________________
# 2490 video: peD9_FlF1Bk
# Reached quotas: 1185
# Page token non esistente
# Total comments for peD9_FlF1Bk: 85
# ________________________________________________________
# 2491 video: Q85DlBcinNI
# Reached quotas: 1188
# Reached quotas: 1191
# Reached quotas: 1194
# Reached quotas: 1197
# Page token non esistente
# Total comments for Q85DlBcinNI: 389
# ________________________________________________________
# 2492 video: qICR4jf6P4s
# Reached quotas: 1200
# Reached quotas: 1203
# Page token non esistente
# Total comments for qICR4jf6P4s: 150
# ________________________________________________________
# 2493 video: HI15b0u0684
# Reached quotas: 1206
# Page token non esistente
# Total comments for HI15b0u0684: 49
# ________________________________________________________
# 2494 video: rUwnN9NF7-E
# Reached quotas: 1209
# Page token non esistente
# Total comments for rUwnN9NF7-E: 82
# ________________________________________________________
# 2495 video: a8aeeb-9y4U
# Reached quotas: 1212
# Page token non esistente
# Total comments for a8aeeb-9y4U: 23
# ________________________________________________________
# 2496 video: CtWpBviU1Io
# Reached quotas: 1215
# Reached quotas: 1218
# Page token non esistente
# Total comments for CtWpBviU1Io: 155
# ________________________________________________________
# 2497 video: ztrO0UgoTlU
# Reached quotas: 1221
# Reached quotas: 1224
# Page token non esistente
# Total comments for ztrO0UgoTlU: 183
# ________________________________________________________
# 2498 video: PFixgb5Uabo
# Reached quotas: 1227
# Page token non esistente
# Total comments for PFixgb5Uabo: 43
# ________________________________________________________
# 2499 video: oc7NV4NUsSk
# Reached quotas: 1230
# Page token non esistente
# Total comments for oc7NV4NUsSk: 46
# ________________________________________________________
# 2500 video: lLxF7R7aoXM
# Reached quotas: 1233
# Page token non esistente
# Total comments for lLxF7R7aoXM: 64
# ________________________________________________________
# 2501 video: 4ZXdc-ry8Nk
# Reached quotas: 1236
# Page token non esistente
# Total comments for 4ZXdc-ry8Nk: 62
# ________________________________________________________
# 2502 video: YUng7dvLP14
# Reached quotas: 1239
# Reached quotas: 1242
# Page token non esistente
# Total comments for YUng7dvLP14: 148
# ________________________________________________________
# 2503 video: ps1a-ZhOTVE
# Reached quotas: 1245
# Page token non esistente
# Total comments for ps1a-ZhOTVE: 40
# ________________________________________________________
# 2504 video: kUbXGqDrcA8
# Reached quotas: 1248
# Page token non esistente
# Total comments for kUbXGqDrcA8: 75
# ________________________________________________________
# 2505 video: 3JhDKtV0vNc
# Reached quotas: 1251
# Page token non esistente
# Total comments for 3JhDKtV0vNc: 70
# ________________________________________________________
# 2506 video: VLWFAXcLLsI
# Reached quotas: 1254
# Page token non esistente
# Total comments for VLWFAXcLLsI: 67
# ________________________________________________________
# 2507 video: iFxaTOyBa1E
# Reached quotas: 1257
# Page token non esistente
# Total comments for iFxaTOyBa1E: 77
# ________________________________________________________
# 2508 video: e-3GcxwtF1I
# Reached quotas: 1260
# Page token non esistente
# Total comments for e-3GcxwtF1I: 97
# ________________________________________________________
# 2509 video: JOLxFofLE_I
# Reached quotas: 1263
# Page token non esistente
# Total comments for JOLxFofLE_I: 76
# ________________________________________________________
# 2510 video: 8J2f90UOQVU
# Reached quotas: 1266
# Page token non esistente
# Total comments for 8J2f90UOQVU: 42
# ________________________________________________________
# 2511 video: -hxYnqqH46I
# Reached quotas: 1269
# Page token non esistente
# Total comments for -hxYnqqH46I: 34
# ________________________________________________________
# 2512 video: CUMbr_Fkl5o
# Reached quotas: 1272
# Page token non esistente
# Total comments for CUMbr_Fkl5o: 31
# ________________________________________________________
# 2513 video: MniwsP5bcXc
# Reached quotas: 1275
# Page token non esistente
# Total comments for MniwsP5bcXc: 53
# ________________________________________________________
# 2514 video: VqNrKn55MJI
# Reached quotas: 1278
# Page token non esistente
# Total comments for VqNrKn55MJI: 61
# ________________________________________________________
# 2515 video: 9hAuMdcQX_Y
# Reached quotas: 1281
# Reached quotas: 1284
# Page token non esistente
# Total comments for 9hAuMdcQX_Y: 118
# ________________________________________________________
# 2516 video: 8ragvJFG3i4
# Reached quotas: 1287
# Page token non esistente
# Total comments for 8ragvJFG3i4: 42
# ________________________________________________________
# 2517 video: bsuIiWsAhW4
# Reached quotas: 1290
# Page token non esistente
# Total comments for bsuIiWsAhW4: 71
# ________________________________________________________
# 2518 video: o-1AZMErUEU
# Reached quotas: 1293
# Page token non esistente
# Total comments for o-1AZMErUEU: 72
# ________________________________________________________
# 2519 video: 9ZI5TFTVRtM
# Reached quotas: 1296
# Reached quotas: 1299
# Page token non esistente
# Total comments for 9ZI5TFTVRtM: 106
# ________________________________________________________
# 2520 video: bObGi1F5UDw
# Reached quotas: 1302
# Reached quotas: 1305
# Page token non esistente
# Total comments for bObGi1F5UDw: 187
# ________________________________________________________
# 2521 video: 8nSoNS2K_kc
# Reached quotas: 1308
# Page token non esistente
# Total comments for 8nSoNS2K_kc: 86
# ________________________________________________________
# 2522 video: dJaiTEWpudg
# Reached quotas: 1311
# Page token non esistente
# Total comments for dJaiTEWpudg: 87
# ________________________________________________________
# 2523 video: 5nUP3gMzHZs
# Reached quotas: 1314
# Page token non esistente
# Total comments for 5nUP3gMzHZs: 82
# ________________________________________________________
# 2524 video: 619Z9krTX8Y
# Reached quotas: 1317
# Page token non esistente
# Total comments for 619Z9krTX8Y: 93
# ________________________________________________________
# 2525 video: UrxzieMbzpg
# Reached quotas: 1320
# Page token non esistente
# Total comments for UrxzieMbzpg: 63
# ________________________________________________________
# 2526 video: GwrfiL-1ffQ
# Reached quotas: 1323
# Page token non esistente
# Total comments for GwrfiL-1ffQ: 83
# ________________________________________________________
# 2527 video: GjSWh3hXdqI
# Reached quotas: 1326
# Reached quotas: 1329
# Page token non esistente
# Total comments for GjSWh3hXdqI: 135
# ________________________________________________________
# 2528 video: Mv0UTDcsoS8
# Reached quotas: 1332
# Reached quotas: 1335
# Page token non esistente
# Total comments for Mv0UTDcsoS8: 106
# ________________________________________________________
# 2529 video: ueAzfuPtr0M
# Reached quotas: 1338
# Page token non esistente
# Total comments for ueAzfuPtr0M: 86
# ________________________________________________________
# 2530 video: 4i7LPPSiBu0
# Reached quotas: 1341
# Reached quotas: 1344
# Reached quotas: 1347
# Reached quotas: 1350
# Reached quotas: 1353
# Page token non esistente
# Total comments for 4i7LPPSiBu0: 488
# ________________________________________________________
# 2531 video: 12QnPX4LZWE
# Reached quotas: 1356
# Reached quotas: 1359
# Reached quotas: 1362
# Reached quotas: 1365
# Page token non esistente
# Total comments for 12QnPX4LZWE: 388
# ________________________________________________________
# 2532 video: dy0-mcFlh2A
# Reached quotas: 1368
# Reached quotas: 1371
# Page token non esistente
# Total comments for dy0-mcFlh2A: 104
# ________________________________________________________
# 2533 video: 3GnyiaSAprc
# Reached quotas: 1374
# Page token non esistente
# Total comments for 3GnyiaSAprc: 51
# ________________________________________________________
# 2534 video: ORvNOWs8nVw
# Reached quotas: 1377
# Page token non esistente
# Total comments for ORvNOWs8nVw: 38
# ________________________________________________________
# 2535 video: 0E-r8gu76h0
# Reached quotas: 1380
# Page token non esistente
# Total comments for 0E-r8gu76h0: 33
# ________________________________________________________
# 2536 video: nC806gOguDg
# Reached quotas: 1383
# Reached quotas: 1386
# Reached quotas: 1389
# Reached quotas: 1392
# Page token non esistente
# Total comments for nC806gOguDg: 355
# ________________________________________________________
# 2537 video: t6-IFabh2L0
# Reached quotas: 1395
# Page token non esistente
# Total comments for t6-IFabh2L0: 36
# ________________________________________________________
# 2538 video: WRwOckAvYQI
# Reached quotas: 1398
# Page token non esistente
# Total comments for WRwOckAvYQI: 46
# ________________________________________________________
# 2539 video: 9o8mm6kUIK0
# Reached quotas: 1401
# Page token non esistente
# Total comments for 9o8mm6kUIK0: 35
# ________________________________________________________
# 2540 video: 64qyx8HUcLY
# Reached quotas: 1404
# Page token non esistente
# Total comments for 64qyx8HUcLY: 47
# ________________________________________________________
# 2541 video: an6Ow0QhNXI
# Reached quotas: 1407
# Page token non esistente
# Total comments for an6Ow0QhNXI: 30
# ________________________________________________________
# 2542 video: wShm0HS6E7Q
# Reached quotas: 1410
# Page token non esistente
# Total comments for wShm0HS6E7Q: 37
# ________________________________________________________
# 2543 video: DeBPf6u2J68
# Reached quotas: 1413
# Reached quotas: 1416
# Reached quotas: 1419
# Page token non esistente
# Total comments for DeBPf6u2J68: 256
# ________________________________________________________
# 2544 video: spEFBJ68Qo8
# Reached quotas: 1422
# Page token non esistente
# Total comments for spEFBJ68Qo8: 40
# ________________________________________________________
# 2545 video: WkT_B2LEueA
# Reached quotas: 1425
# Page token non esistente
# Total comments for WkT_B2LEueA: 31
# ________________________________________________________
# 2546 video: jKxJoN_QEOI
# Reached quotas: 1428
# Page token non esistente
# Total comments for jKxJoN_QEOI: 32
# ________________________________________________________
# 2547 video: CqIdd5NzkB4
# Reached quotas: 1431
# Page token non esistente
# Total comments for CqIdd5NzkB4: 51
# ________________________________________________________
# 2548 video: cLASuFKSS2E
# Reached quotas: 1434
# Page token non esistente
# Total comments for cLASuFKSS2E: 51
# ________________________________________________________
# 2549 video: Te2U8O9vTXs
# Reached quotas: 1437
# Page token non esistente
# Total comments for Te2U8O9vTXs: 53
# ________________________________________________________
# 2550 video: q9BylbjwSoQ
# Reached quotas: 1440
# Page token non esistente
# Total comments for q9BylbjwSoQ: 54
# ________________________________________________________
# 2551 video: LOHM4iQAS-8
# Reached quotas: 1443
# Reached quotas: 1446
# Reached quotas: 1449
# Page token non esistente
# Total comments for LOHM4iQAS-8: 221
# ________________________________________________________
# 2552 video: pJDT6BnvHGo
# Reached quotas: 1452
# Page token non esistente
# Total comments for pJDT6BnvHGo: 37
# ________________________________________________________
# 2553 video: BK2C_mV7leQ
# Reached quotas: 1455
# Page token non esistente
# Total comments for BK2C_mV7leQ: 53
# ________________________________________________________
# 2554 video: S5otTNGdFV8
# Reached quotas: 1458
# Page token non esistente
# Total comments for S5otTNGdFV8: 54
# ________________________________________________________
# 2555 video: CS6lakzyGqA
# Reached quotas: 1461
# Page token non esistente
# Total comments for CS6lakzyGqA: 29
# ________________________________________________________
# 2556 video: 6JR3IAdXbfM
# Reached quotas: 1464
# Page token non esistente
# Total comments for 6JR3IAdXbfM: 58
# ________________________________________________________
# 2557 video: XZiH658NRbw
# Reached quotas: 1467
# Page token non esistente
# Total comments for XZiH658NRbw: 43
# ________________________________________________________
# 2558 video: OdrcPofvJfM
# Reached quotas: 1470
# Page token non esistente
# Total comments for OdrcPofvJfM: 66
# ________________________________________________________
# 2559 video: HQSgZEanrhA
# Reached quotas: 1473
# Page token non esistente
# Total comments for HQSgZEanrhA: 88
# ________________________________________________________
# 2560 video: KOsMswGKMu8
# Reached quotas: 1476
# Page token non esistente
# authorChannelId
# Problem with commentThread UgwRmTbunOef6zhiq-F4AaABAg
# Total comments for KOsMswGKMu8: 10
# ________________________________________________________
# 2561 video: 1miNGepOsbs
# Reached quotas: 1479
# Page token non esistente
# Total comments for 1miNGepOsbs: 14
# ________________________________________________________
# 2562 video: AzJpJQTrIKc
# Reached quotas: 1482
# Page token non esistente
# Total comments for AzJpJQTrIKc: 4
# ________________________________________________________
# 2563 video: Q-fOV81_Y0s
# Reached quotas: 1485
# Page token non esistente
# Total comments for Q-fOV81_Y0s: 1
# ________________________________________________________
# 2564 video: dCQmPL3FISc
# Reached quotas: 1488
# Page token non esistente
# Total comments for dCQmPL3FISc: 20
# ________________________________________________________
# 2565 video: BIv1DRfaKRI
# Reached quotas: 1491
# Page token non esistente
# Total comments for BIv1DRfaKRI: 9
# ________________________________________________________
# 2566 video: 7Js1O0tq3tc
# Reached quotas: 1494
# Page token non esistente
# Total comments for 7Js1O0tq3tc: 13
# ________________________________________________________
# 2567 video: KeZygwQsMvE
# Reached quotas: 1497
# Page token non esistente
# Total comments for KeZygwQsMvE: 32
# ________________________________________________________
# 2568 video: YhWjSd9FiwU
# Reached quotas: 1500
# Page token non esistente
# Total comments for YhWjSd9FiwU: 24
# ________________________________________________________
# 2569 video: gSWi6bBRbzU
# Reached quotas: 1503
# Page token non esistente
# Total comments for gSWi6bBRbzU: 39
# ________________________________________________________
# 2570 video: L1NbY0U0OLk
# Reached quotas: 1506
# Page token non esistente
# Total comments for L1NbY0U0OLk: 35
# ________________________________________________________
# 2571 video: fyx7cQcoW08
# Reached quotas: 1509
# Page token non esistente
# Total comments for fyx7cQcoW08: 60
# ________________________________________________________
# 2572 video: GQryLt0qiec
# Reached quotas: 1512
# Page token non esistente
# Total comments for GQryLt0qiec: 10
# ________________________________________________________
# 2573 video: h4woxE_i9UM
# Reached quotas: 1515
# Page token non esistente
# Total comments for h4woxE_i9UM: 38
# ________________________________________________________
# 2574 video: N0y8GUtbuBU
# Reached quotas: 1518
# Page token non esistente
# Total comments for N0y8GUtbuBU: 2
# ________________________________________________________
# 2575 video: aZah6047G4E
# Reached quotas: 1521
# Page token non esistente
# Total comments for aZah6047G4E: 4
# ________________________________________________________
# 2576 video: kI0MDyj1qTQ
# Reached quotas: 1524
# Page token non esistente
# Total comments for kI0MDyj1qTQ: 5
# ________________________________________________________
# 2577 video: -pE2ouetrTU
# Reached quotas: 1527
# Page token non esistente
# Total comments for -pE2ouetrTU: 36
# ________________________________________________________
# 2578 video: Su4tX5S6JEU
# Reached quotas: 1530
# Reached quotas: 1533
# Reached quotas: 1536
# Page token non esistente
# Total comments for Su4tX5S6JEU: 209
# ________________________________________________________
# 2579 video: usYVVi3euV4
# Reached quotas: 1539
# Page token non esistente
# Total comments for usYVVi3euV4: 4
# ________________________________________________________
# 2580 video: gz17x20GD9o
# Reached quotas: 1542
# Page token non esistente
# Total comments for gz17x20GD9o: 2
# ________________________________________________________
# 2581 video: U713_obaZpA
# Reached quotas: 1545
# Page token non esistente
# Total comments for U713_obaZpA: 4
# ________________________________________________________
# 2582 video: Ekm0F6pEmWo
# Reached quotas: 1548
# Page token non esistente
# Total comments for Ekm0F6pEmWo: 0
# ________________________________________________________
# 2583 video: g2J0wwZ_a4Y
# Reached quotas: 1551
# Page token non esistente
# Total comments for g2J0wwZ_a4Y: 0
# ________________________________________________________
# 2584 video: f01ovmEZhik
# Reached quotas: 1554
# Page token non esistente
# Total comments for f01ovmEZhik: 4
# ________________________________________________________
# 2585 video: v_1rItu2vlY
# Reached quotas: 1557
# Page token non esistente
# Total comments for v_1rItu2vlY: 4
# ________________________________________________________
# 2586 video: STrwfVBp7cU
# Reached quotas: 1560
# Page token non esistente
# Total comments for STrwfVBp7cU: 1
# ________________________________________________________
# 2587 video: ZqGEvLzpr0Q
# Reached quotas: 1563
# Page token non esistente
# Total comments for ZqGEvLzpr0Q: 0
# ________________________________________________________
# 2588 video: bm-3Qrr7EUA
# Reached quotas: 1566
# Page token non esistente
# Total comments for bm-3Qrr7EUA: 0
# ________________________________________________________
# 2589 video: hkxRjDS_Cjw
# Reached quotas: 1569
# Page token non esistente
# Total comments for hkxRjDS_Cjw: 6
# ________________________________________________________
# 2590 video: 8kElrRAa1ws
# Reached quotas: 1572
# Page token non esistente
# Total comments for 8kElrRAa1ws: 6
# ________________________________________________________
# 2591 video: 7x6tX5T7LOs
# Reached quotas: 1575
# Page token non esistente
# Total comments for 7x6tX5T7LOs: 0
# ________________________________________________________
# 2592 video: NSdUFKOkKnc
# Reached quotas: 1578
# Page token non esistente
# Total comments for NSdUFKOkKnc: 0
# Done with 525937 comments, video to start: 2593
#  with next_page_token:

# %%
np.save('data/get_comment_threads_output/next_page_token.npy',next_page_token)
np.save('data/get_comment_threads_output/video_to_start.npy',last_video_idx)
np.save('data/get_comment_threads_output/videos_not_finished.npy',videos_not_finished)
np.save('data/get_comment_threads_output/videos_disabled_comments.npy',videos_disabled_comments)

# %%
print(next_page_token, last_video_idx)
# Out:
#   2593

# %%
format_ok_comments = []
for outer_comment in comments:
    for comment in outer_comment:
        format_ok_comments.append(comment)

# %%
format_ok_comments
# Out:
# [['lSlKqgyE2Zo',
#   'UgyBkSueeWLhRQ8-FyR4AaABAg',
#   'UgyBkSueeWLhRQ8-FyR4AaABAg',
#   'luckydolly',
#   'UC4BuW8UZuS4WTjDtD3aY17A',
#   'I have had the same experience with a doctor. And so has my mom. She was like 6-7 months pregnant and she started bleeding. She went to the hospital and the doctor came in and just looked at her and said well you lost the baby ok. Then just walked out. Doctors like this shouldn’t even be allowed to see patients or have a license.'],
#  ['lSlKqgyE2Zo',
#   'Ugz6AQBHHhAtX9cdPnR4AaABAg',
#   'Ugz6AQBHHhAtX9cdPnR4AaABAg',
#   'Emory Elliott',
#   'UCXq5M8DVAQlX55rZ-1HqREQ',
#   "The negative bias is what you're talking about towards the end, there. Our brains are wired to remember and hold on to the bad things that happen instead of the good. \n\nSo sorry about that shit doctor, that was extremely unprofessional and insensitive. I hope you feel better, and fuck that guy."],
#  ['lSlKqgyE2Zo',
#   'UgzmrA6R9UuHBIYYmWV4AaABAg',
#   'UgzmrA6R9UuHBIYYmWV4AaABAg',
#   'Rede4trip',
#   'UCy6dVt-_KE1UJCUr46meT_Q',
#   'I am sooooo the same way about focusing on the negative at times. I am a teacher and every September our scores come back from the year before-it took me an entire month for my emotions to regulate about them this year. I know I am great at my job but damn I let that mess me up for so long. I was so defeatist, and it wasn’t even worth it. I get nothing from that attitude but the older I get the longer it takes to pull out of that thinking.  But I enjoy all the other times so much more as well as an adult. I feel the worth of the good times more. I hope you do as well.'],
#  ['lSlKqgyE2Zo',
#   'UgzImr_PGPXs52nLoAx4AaABAg',
#   'UgzImr_PGPXs52nLoAx4AaABAg',
#   'MARCELA Bukalo',
#   'UC_hISte6WW9yksrOAGyVyBQ',
#   'I have PCOS, had fibroids surgically removed, and a deformity in my tubes. We tried for 8 years naturally and I’ve had SIX rounds of IVF. I’ve had miscarriages, ectopic, chemical pregnancy. I gave birth to twins at 22 weeks and they didn’t make it. I feel you Christy. Endless appointments and trauma. I am currently almost five months pregnant with my lucky #6 IVF baby! Don’t give up! 🙌🏼'],
#  ['lSlKqgyE2Zo',
#   'UgxxcDuBbF7C611ooRB4AaABAg',
#   'UgxxcDuBbF7C611ooRB4AaABAg',
#   'saiiree yessenniia',
#   'UC8G4mgg7HlG096cG2bwWDHQ',
#   'WE NEED A NAME! I am so upset this happened to you. I can not believe this. A similar situation happened to me when I went in for my migraines, I’m talking devastating, painful ones. He took a look at my chart and just blamed it on my depression and anxiety. I was so freaking heart broken I just wanted to freaking figure out why I was getting these bad migraines. I had to fight it to get a referral for a neurologist. I cried so much. You are literal sunshine! ☀️ DONT let anyone bring you down. Love you so much! ❤️❤️❤️'],
#  ['lSlKqgyE2Zo',
#   'Ugz5PwhJOW7BqqgjGj14AaABAg',
#   'Ugz5PwhJOW7BqqgjGj14AaABAg',
#   'ifeelnakey',
#   'UC3AxADHL-gMZ8ssVZcX82xA',
#   'I swear \nWhen literally ANYONE else does a video of just like chit chat while I put my make up on I’m like yawwwwn\nBut when you do it I’m like ‘goo onnnn!!!’🙇🏼\u200d♀️'],
#  ['lSlKqgyE2Zo',
#   'UgwoJpm7t30Yr4qnD2t4AaABAg',
#   'UgwoJpm7t30Yr4qnD2t4AaABAg',
#   'Ky-Loren',
#   'UC1D47KVcWYKpG--IZssfHhg',
#   "I'd really love a PCOS video, Kristi!! The way you explain things is so easy to understand and I love when you get all informative!❤❤"],
#  ['lSlKqgyE2Zo',
#   'UgznzjWdGWGFG0V-lHZ4AaABAg',
#   'UgznzjWdGWGFG0V-lHZ4AaABAg',
#   'Meghan Minor',
#   'UCMo6RKNc1AqvhXOGXD_hzUQ',
#   'Would love to see a video about period cups, I have questions lol. Can you pee with them in? Also, is TSS still a concern when wearing a period cup?'],
#  ['lSlKqgyE2Zo',
#   'UgwQH8KQUAnQx8wzpWh4AaABAg',
#   'UgwQH8KQUAnQx8wzpWh4AaABAg',
#   'Scandie',
#   'UCUNhReEmgoWOHyrqDo-GzjQ',
#   'Yes! Do a menstrual cup video.'],
#  ['lSlKqgyE2Zo',
#   'UgwBRzycsnsCnhoI7FF4AaABAg',
#   'UgwBRzycsnsCnhoI7FF4AaABAg',
#   'Katerina K',
#   'UC3D_Wc8_7J_pjphfQnAHTPA',
#   'Omg my old gyno was THE BIGGEST DICK not the first appointments but when I did have a miscarriage and I went in to confirm that I did. He was awful. He even tried to say I wasn’t in the right place but it’s okay cause women can sometimes get confused because HIS STAFF COULDN’T FIND MY HISTORY!!! \n\nMy doctor now is a wonderful God send. There are good doctors out there and I don’t wanna be sexist but maybe try a woman doctor not a male. \n\nThat guy is a piece of shit and fuck him I hope his house burns down (not with him in it just all his stuff he loves BURNS TO THE GROUND!!!!) \n\nYou’re the best and you don’t deserve that treatment!! Medically, things will look up!!! All your dreams and goals will come true family & career wise.'],
#  ['lSlKqgyE2Zo',
#   'UgwJ8ui_amesFvZtx8p4AaABAg',
#   'UgwJ8ui_amesFvZtx8p4AaABAg',
#   'lynncrf',
#   'UCmaSu3GawupPRBqD1ExqbMw',
#   "Sadly, endos have a tendency to be complete idiots. My GP calls them them the accountants of medicine as they are obsessed with numbers and dismiss the patient's symptoms if the patient is even .1 inside the so-called normal range (ranges which BTW are constantly changing). It's why many people with hormone problems see GPs, internists, and DOs for their treatment as endos don't seem to help nor care. Also, since you mentioned salivary testing, I imagine you were tested for low/high cortisol. This is something endos don't get at all. I would suggest you try a DO for your issues. Also, you can get great info about the adrenals and thyroid at www.stopthethyroidmadness.com and www.hormonerestoration.com."],
#  ['lSlKqgyE2Zo',
#   'UgyJnL0hZWUDWQhS9th4AaABAg',
#   'UgyJnL0hZWUDWQhS9th4AaABAg',
#   'Jaime Grozier',
#   'UCdqaqw5h8gsVNvDWvETGhhg',
#   '❤️❤️❤️'],
#  ['lSlKqgyE2Zo',
#   'Ugzi3rnac7AlPUB5hyt4AaABAg',
#   'Ugzi3rnac7AlPUB5hyt4AaABAg',
#   'Natasha Danielle',
#   'UCBytCThsNsDCQ0HJNbM7SAQ',
#   'Broke my heart to see you upset in this. I feel like you’re legit my friend, let alone the other way around! Please know there’s no one doing better than you hating on you, they’re only projecting their own unhappiness. You’re so loved and valued. Everything you said in this video was real and true and we’re here for you. X'],
#  ['lSlKqgyE2Zo',
#   'UgxmeMhka5e_3m06iXZ4AaABAg',
#   'UgxmeMhka5e_3m06iXZ4AaABAg',
#   'Michelle Barlow',
#   'UCwCyi_ax7UVs3uJzoLji5aQ',
#   'We are the same age 😁'],
#  ['lSlKqgyE2Zo',
#   'UgwZXVt866WQ4UDMbQB4AaABAg',
#   'UgwZXVt866WQ4UDMbQB4AaABAg',
#   'Emily Alby',
#   'UCNVKdeZ5AaPgWpQSI7tiuIQ',
#   'At least at Ulta, they stop resetting planograms around Halloween because holiday is crazy enough, so usually brands don’t launch anything new until January'],
#  ['lSlKqgyE2Zo',
#   'UgzxG4BtKh1mAX4wF394AaABAg',
#   'UgzxG4BtKh1mAX4wF394AaABAg',
#   'Shelby Stevenson',
#   'UCGSKo5T6YNsKlGboHNSQMqA',
#   'This video was such an insight into your life. I absolutely loved it; I watched every minute. Also that doctor was totally inappropriate but I love the way you twisted it like don’t let that 201 person tear you down! Words I will try to live by. 💗😇'],
#  ['lSlKqgyE2Zo',
#   'Ugx3-PsoIibU8GW724p4AaABAg',
#   'Ugx3-PsoIibU8GW724p4AaABAg',
#   'Kerri Simonsen',
#   'UC1yNObi3scDTvrFWuOueYLw',
#   'It’s honestly straight up BULLSHIT how YouTube does! All for freaking money! But what do you expect? Everyone is all about money. Well, not everyone. But the companies and websites and shit.'],
#  ['lSlKqgyE2Zo',
#   'Ugzi0TEym0_FH6p2S194AaABAg',
#   'Ugzi0TEym0_FH6p2S194AaABAg',
#   'Hala Harara',
#   'UCrARuySxDHgbGazWAWVPh6A',
#   'YES! Kristi please make a video about PCOS!'],
#  ['lSlKqgyE2Zo',
#   'UgzlNTRiT3EjO7haCot4AaABAg',
#   'UgzlNTRiT3EjO7haCot4AaABAg',
#   'Aimee Clewell',
#   'UCWGN6FBdvET8TwtcSBHionA',
#   '💜💜'],
#  ['lSlKqgyE2Zo',
#   'UgwvZuauahMSkVnxYQ94AaABAg',
#   'UgwvZuauahMSkVnxYQ94AaABAg',
#   'Mikayla Fulper',
#   'UCoT3XpkTGyQOPsqcU76c-eg',
#   'Look up Kelly Hogan :)'],
#  ['lSlKqgyE2Zo',
#   'UgwiQJ-gGYHSZ271eAp4AaABAg',
#   'UgwiQJ-gGYHSZ271eAp4AaABAg',
#   'Jen S',
#   'UCp-nrxdVBXuuAIuiUrveK6A',
#   'I’ve been really in my head lately, too. Lots of things going on. Constantly fighting with my family, no support from anyone, busting my ass at work only to have my boss say I’m too slow. I feel like shit.'],
#  ['lSlKqgyE2Zo',
#   'UgzgfD9sulXarV9IjuV4AaABAg',
#   'UgzgfD9sulXarV9IjuV4AaABAg',
#   'Clarice Caulfield',
#   'UCZRU82IsXEZJvcs9-zdro-A',
#   "I hate how ppl get mad at creators who dont want to do something that won't make them money when it's not like ANYONE would go to work & not get paid! You do awesome videos and I feel you for the reasons you said."],
#  ['lSlKqgyE2Zo',
#   'UgyrgvaGUtTyyJu0B194AaABAg',
#   'UgyrgvaGUtTyyJu0B194AaABAg',
#   'Kathleen Kaffeine',
#   'UCi7rt4DBnwQhjF7XiO2mauQ',
#   'sending hugs :-)'],
#  ['lSlKqgyE2Zo',
#   'UgxuKCAbUi4lacYntUR4AaABAg',
#   'UgxuKCAbUi4lacYntUR4AaABAg',
#   'Diana Wiley',
#   'UCsU6D1dPjz5RdcsFLTSQeZw',
#   'Plz get another dr. You are amazing. If/when you choose be be a mom you will be awesome. You are my most favorite utuber. I absolutely love your creations.'],
#  ['lSlKqgyE2Zo',
#   'UgxhpKdTz-xpf6dqAkt4AaABAg',
#   'UgxhpKdTz-xpf6dqAkt4AaABAg',
#   'Lioness006',
#   'UC4HgtXkOAHqE1cB81btLXtA',
#   "I hope you complained about the doctor! I see a doctor in the MultiCare system and I love it. All the doctors I've seen in the last 10 years have been great. Franciscan sucked. MultiCare has MyChart and you can see your test results online as soon as they're available. \n\n\nHave you ever checked out NsomniaksDream? She was a NYX Face Awards contender a couple years ago and does all kinds of crazy effects makeup on her channel. She's an amazing artist."],
#  ['lSlKqgyE2Zo',
#   'UgxgCDLqaIndZQFiYGJ4AaABAg',
#   'UgxgCDLqaIndZQFiYGJ4AaABAg',
#   'Blessing Yemi-Ese',
#   'UCtUi2790fI4HfLMoJ8X4V0w',
#   'I adore your authenticity and I really appreciate your vulnerability 💕'],
#  ['lSlKqgyE2Zo',
#   'Ugz7ATKhmmYfdEU3ku94AaABAg',
#   'Ugz7ATKhmmYfdEU3ku94AaABAg',
#   'Jennifer Gardner',
#   'UCGkGUZillU2YFGIYV-WCT_A',
#   'I absolutely LOVE your bloopers ❤'],
#  ['lSlKqgyE2Zo',
#   'UgxQYBQxQY5MN8trTOZ4AaABAg',
#   'UgxQYBQxQY5MN8trTOZ4AaABAg',
#   'Rachael The Red',
#   'UC_EtRR5i8Wkf82U4S-7Ct_w',
#   "I am living for this look! It's like pearl studded, pink butterfly on your face!"],
#  ['lSlKqgyE2Zo',
#   'UgzDnP6cME2PbK5J3Vt4AaABAg',
#   'UgzDnP6cME2PbK5J3Vt4AaABAg',
#   'Jazmin Castañeda',
#   'UCS7RlsNV-9AfrGnOzpTlCjw',
#   'omg i just bought a cup, so hard to get it in. please do make a video !!'],
#  ['lSlKqgyE2Zo',
#   'UgzIw4eYTU73VuRfn3h4AaABAg',
#   'UgzIw4eYTU73VuRfn3h4AaABAg',
#   'Desiree De La Fuente',
#   'UCB8L7BR-0V_YTq7VguBebzg',
#   'Love the openness and honesty which is why I watch you. Keep it coming, you wouldn’t be called RawBeautyKristi for nothing, it’s meant to be RAW.'],
#  ['lSlKqgyE2Zo',
#   'UgzGZ4zXlqwrLQdBgIV4AaABAg',
#   'UgzGZ4zXlqwrLQdBgIV4AaABAg',
#   'Petty Perkins',
#   'UCyGES_qrjbaNIRSf067id9g',
#   "My husband gets treated that way by doctors all the time. One was so bad one time I wrote him a note about how much of a dick he was. \n\nAlso, I am so sorry about the infertility. I am 33 and both my husband and I are infertile. I struggled with it the same way you have so I have convinced myself that I'm good without kids. My doggos are my kids for now (one of them died 2 months ago so my heart is still broken.) \n\nI'm sorry that you are having a rough time. You are an amazing human being and I enjoy everything you put out there. Feel better and don't worry about Doctor Dickhead ❤"],
#  ['lSlKqgyE2Zo',
#   'UgxX6xk7OtYlRv8duGZ4AaABAg',
#   'UgxX6xk7OtYlRv8duGZ4AaABAg',
#   'daniella gonzalez',
#   'UCpLCRTunhd79JOCcsMDuhAw',
#   'I love you kristi!! I wish I could hug you bc I truly feel like were best friends ! ❤️'],
#  ['lSlKqgyE2Zo',
#   'Ugw97opXTuCd1UX_sx54AaABAg',
#   'Ugw97opXTuCd1UX_sx54AaABAg',
#   'Martha Villagomez',
#   'UCDdYAXy9Nf_jD7jlnVHMJEw',
#   "Sam got me on the Saalt cup, but yes, I'd love if you did cup videos! We need everyone on the cup train, man. This time, you ARE our real dad!!!! <3"],
#  ['lSlKqgyE2Zo',
#   'Ugw_3XS7muVtKpemQhx4AaABAg',
#   'Ugw_3XS7muVtKpemQhx4AaABAg',
#   'Cynthia Underwood',
#   'UCk7Whb8FsIGLEYj18bFOifQ',
#   'I’m so sorry... I hate when people are asshole garbage human beings.. ❤️ you!'],
#  ['lSlKqgyE2Zo',
#   'UgymAR8m70W9Nf-4agB4AaABAg',
#   'UgymAR8m70W9Nf-4agB4AaABAg',
#   'Jes Velmer',
#   'UCjS9I2KeaK3ApPyw9qw0dQg',
#   "Please do a PCOS video or a whole series! There are far more doctors like the one you saw that dismiss all of us with the condition. We all need to know everything we can so we can be own best advocates when faced with asshole doctors. The fact that he's convinced that infertility and diabetes is all there is to it shows he's uneducated. ♡"],
#  ['lSlKqgyE2Zo',
#   'UgwuofwYy_DdrYnfRhh4AaABAg',
#   'UgwuofwYy_DdrYnfRhh4AaABAg',
#   'Jennifer Shank',
#   'UCTyaxpaxbQ4WELcVkjdSi3w',
#   "PCOS, endometriosis.....numerous miscarriages...but I have two grown sons now. I would love to watch a video about pcos!! My periods were so bad, and I could bleed up to 3 weeks solid. You're talking heavy flow, cramps that make your legs go numb. I ended up having a hysterectomy. A complete one. When I had surgery,  the doctor said that I should've had surgery a long time ago because I had endometriosis everywhere."],
#  ['lSlKqgyE2Zo',
#   'Ugyt9uiBAPD4vHXDwut4AaABAg',
#   'Ugyt9uiBAPD4vHXDwut4AaABAg',
#   'Cassie Vail',
#   'UCtziGy2O9sjS-jL4WxO3E8Q',
#   'Love you Kristi!'],
#  ['lSlKqgyE2Zo',
#   'UgwtL1Nsn0wBOF3SI3h4AaABAg',
#   'UgwtL1Nsn0wBOF3SI3h4AaABAg',
#   'Marina Wakefield',
#   'UCBA2TLp_WcDrN_NuuP36Q3A',
#   'I am interested in the period cups! I already use them, but I like to hear other thoughts from other people about them.'],
#  ['lSlKqgyE2Zo',
#   'UgywoTBXTN_2agAde9F4AaABAg',
#   'UgywoTBXTN_2agAde9F4AaABAg',
#   'Mari Gomez',
#   'UCR86LtJvkNOEv2McClM2BrA',
#   "So a few things. One I LOVED this look! Had I had enough time to use this as inspo I would. I'm dressing up as Owlette from PJ Mask for my son and this would have been perfect!\nSecondly you're the best. Thank you for just being you. We're all human and have feelings but you have every right to feel the way you do! But always remember that's why you're RAWbeautyKristi. Because you're RAW. keep that head up beautiful!"],
#  ['lSlKqgyE2Zo',
#   'Ugy80goqdHyQdak0Djx4AaABAg',
#   'Ugy80goqdHyQdak0Djx4AaABAg',
#   'Christina L',
#   'UC0xJQ5IxMRqNQxh9lOosfzA',
#   'Report him immediately to his attending. I am totally not kidding. As someone with PCOS who developed cancer AND diabetes (yay life choices) , his behavior is completely unacceptable everywhere. Please, please, please, report him not only to his attending physician but the patient advocate of that healthcare system.'],
#  ['lSlKqgyE2Zo',
#   'UgzZm5TjYd4O99aM7pF4AaABAg',
#   'UgzZm5TjYd4O99aM7pF4AaABAg',
#   'BLWSquared',
#   'UCW6jTAdvYdXXMwPpUXtm4HQ',
#   'Please let this guy’s info public. As another woman who a) has PCOS b) deals with infertility and b) is also disabled, NO DOCTOR should EVER treat a patient like that. And he deserves to be ripped to shreds.'],
#  ['lSlKqgyE2Zo',
#   'UgyRd0sqzCSByXpB8d54AaABAg',
#   'UgyRd0sqzCSByXpB8d54AaABAg',
#   'Michelle Howrad',
#   'UCraNMXgEfzZUqUAukyx6PgA',
#   "I seriously appreciate the infertility segment. As I'm turning 22 in a mere 5 days..  and I'm completely infertile. I never wanted kids, but stripped of that choice, being denied that FUCKING SUCKS. My gyno blew off my symptoms for months and I ended up being emitted to the ER. Fuck male gynos honestly"],
#  ['lSlKqgyE2Zo',
#   'Ugwh-Cq5_iO8RX4hqiV4AaABAg',
#   'Ugwh-Cq5_iO8RX4hqiV4AaABAg',
#   'meghanMoment',
#   'UCoQsj6wL8mMICWMQnIvlKsg',
#   'Would love a period cup video!'],
#  ['lSlKqgyE2Zo',
#   'Ugx2N2S3JRr4YaW3oUV4AaABAg',
#   'Ugx2N2S3JRr4YaW3oUV4AaABAg',
#   'Rebecca Brooks',
#   'UCKxK7d_h1kFbIfMlV1wr7zQ',
#   'Ive had rude af doctors  too!! When your "infertile" some doctors can be fucking assholes'],
#  ['lSlKqgyE2Zo',
#   'UgxHFfS643L1OA_AFph4AaABAg',
#   'UgxHFfS643L1OA_AFph4AaABAg',
#   'Amanda Herald',
#   'UCVVX7l1Jo3H6F7b4bDomN2w',
#   'I’m so sorry you had that doctor experience. I work in the health care field and it really makes me mad at that doctor. \nOn the other hand, I applaud you for being so open about PCOS, it really does help others. I also have PCOS and helps me when you talk about everything.'],
#  ['lSlKqgyE2Zo',
#   'UgzcqYHjSMeahGeVoid4AaABAg',
#   'UgzcqYHjSMeahGeVoid4AaABAg',
#   'Christian Smith',
#   'UCe7_q4LGpHp66SkI7WrahQQ',
#   'Did some of those creators you mentioned that left the platform go someplace else specific (like another YouTube) ? Or are they just sharing on their own websites and such?'],
#  ['lSlKqgyE2Zo',
#   'Ugy19bwIDAN1LQsINBx4AaABAg',
#   'Ugy19bwIDAN1LQsINBx4AaABAg',
#   'Doobies 707',
#   'UCJl-IgsnsLRUyrBEHbnQKeQ',
#   'I think you’re just describing 30-35, I’m 31 and I am the same. I feel like a crazy ass ho so often'],
#  ['lSlKqgyE2Zo',
#   'UgxGVpZQllLdPodYqX94AaABAg',
#   'UgxGVpZQllLdPodYqX94AaABAg',
#   'Nicole Birlew',
#   'UC0VUyf5tPdwLIbG3yGsFMzg',
#   'I would love your opinion on whatever cups you’ve tried and your experiences!'],
#  ['lSlKqgyE2Zo',
#   'UgyOZOxrfebLay-ZQAN4AaABAg',
#   'UgyOZOxrfebLay-ZQAN4AaABAg',
#   'Olya Luperdo',
#   'UChDvHMPFhTujNajMRm20_sg',
#   "That's why I never-ever go to male doctors. They are so f*ing rude and unprofessional, always trying to make themselves so important and smart in front of patients. Only women, ONLY."],
#  ['lSlKqgyE2Zo',
#   'UgxGkSDARqDomxl0gAZ4AaABAg',
#   'UgxGkSDARqDomxl0gAZ4AaABAg',
#   'Peggy Greeby',
#   'UConlG6qLkgOgMnfJhmUAqwQ',
#   'Please no menstrual cups.  I watched another youtuber do one of these videos, and the visuals that came to my mind were awful.  Some things are better left alone.'],
#  ['lSlKqgyE2Zo',
#   'UgwB3B7u111a6SlHTFN4AaABAg',
#   'UgwB3B7u111a6SlHTFN4AaABAg',
#   'Samantha',
#   'UCg8nSgq80SRA0WJMdi2bZPw',
#   "The reason we focus on the negative is that our brains are actually naturally geared to do that for survival reasons. It's a shitty and useless biological reaction, the same as how stereotyping and putting things in categories is natural unfortunately. Also, the American health care system scares me so much, I have seen so many doctors in my life and I don't think I've ever had an experience as dismissive and rude as this one you just described. Like damn, I imagine you're paying HUNDREDS of dollars for a service from this doctor and to be treated like an inconvenience? Like you're not the one paying his bills? WTF"],
#  ['lSlKqgyE2Zo',
#   'UgyEf3yPgs2IjM3gXvR4AaABAg',
#   'UgyEf3yPgs2IjM3gXvR4AaABAg',
#   'Clarice Caulfield',
#   'UCZRU82IsXEZJvcs9-zdro-A',
#   "Omg I had the same conversation with myself when I was 31 !! Haha what a riot I'm so glad I wasn't the only one!! So since then I just stopped counting!"],
#  ['lSlKqgyE2Zo',
#   'UgyTeO80FqNL5h4A7_d4AaABAg',
#   'UgyTeO80FqNL5h4A7_d4AaABAg',
#   'Sparker',
#   'UCgIxgVvIuPZk4n-enn-RX-A',
#   'You should read Reddit’s thread on this video'],
#  ['lSlKqgyE2Zo',
#   'Ugz5xsIQu6cAvOMVVOZ4AaABAg',
#   'Ugz5xsIQu6cAvOMVVOZ4AaABAg',
#   'MSDM 66',
#   'UCSYiX-7Fgv-T4aWrblRkpeg',
#   'Aww 🥰 such a good video ! If we were real life friends I would totally confide in you about my issues ! Thank you for sharing'],
#  ['lSlKqgyE2Zo',
#   'UgxWPCCNkNO2T_hoXEh4AaABAg',
#   'UgxWPCCNkNO2T_hoXEh4AaABAg',
#   'Natasha Danielle',
#   'UCBytCThsNsDCQ0HJNbM7SAQ',
#   'I’d love to see your look whenever it’s ready. Don’t feel like you have to wait (or if you’d prefer do) but we’d support you whenever ❤️❤️❤️❤️❤️❤️'],
#  ['lSlKqgyE2Zo',
#   'UgxQE4rfS-UTAvdRslR4AaABAg',
#   'UgxQE4rfS-UTAvdRslR4AaABAg',
#   'Jessica Hill',
#   'UCuDQJTzJflrBb-AyBX0f4yw',
#   'Maybe that doctors mad because his peepee is small. What a loser. Don’t trip, chocolate chip. Some people are just miserable and want everyone else to be as well. You are such a beautiful person and soul, and u make so many people smile and laugh. Thank u for that, and if u ever need me to punch that idiot in the face, u just lemme know k'],
#  ['lSlKqgyE2Zo',
#   'UgxD5sPeXDjbOjJgocJ4AaABAg',
#   'UgxD5sPeXDjbOjJgocJ4AaABAg',
#   'JennaMorcombe',
#   'UCP5PsFEVm-nQWPhFtWyfLdA',
#   'YES to the period talk!'],
#  ['lSlKqgyE2Zo',
#   'UgxRX4zjgm_Wld_DrS14AaABAg',
#   'UgxRX4zjgm_Wld_DrS14AaABAg',
#   'Attitude Change',
#   'UCfwIuITrnJpFblpOwpQTh-w',
#   'I actually learned of the period cups from Safiya Nygaard. After she made her video I decided to get a Diva Cup and I love it. Its difficult at first but once you get the hang of it omg, its like you arent even on your period.'],
#  ['lSlKqgyE2Zo',
#   'UgxeVf7eXNOondNL2PZ4AaABAg',
#   'UgxeVf7eXNOondNL2PZ4AaABAg',
#   'Marlana Polis',
#   'UCHXR15P4ipthUD1U27nQuhg',
#   'The whole YouTube thing has got to be so frustrating. They have YouTube “kids” for a reason. Obviously 13 year olds are gonna pretend they’re 25 to watch certain videos on here, but that’s their parents job. It’s not fair to creators and this is the reason why I started buying merch and things from my faves cause y’all deserve it!'],
#  ['lSlKqgyE2Zo',
#   'Ugz3REnPypQObyk97E54AaABAg',
#   'Ugz3REnPypQObyk97E54AaABAg',
#   'All Things Beauty',
#   'UCJs38YMqSwjKbpJO1meWW6A',
#   "Dude my son and I have been pingponged from doctor to doctor bc they keep going to other practices. It's the worst."],
#  ['lSlKqgyE2Zo',
#   'UgyBNpmmyMaONfdTaN54AaABAg',
#   'UgyBNpmmyMaONfdTaN54AaABAg',
#   'Amy Slowik Grossman',
#   'UC5YElUARxzOhcG4gG2mfnsA',
#   '🤗  I’m so sorry this happened to you.  Why would he choose to go into that specialization if he had no bedside manner?  What a dick.'],
#  ['lSlKqgyE2Zo',
#   'UgyXeFHNhTbK7N_GQTl4AaABAg',
#   'UgyXeFHNhTbK7N_GQTl4AaABAg',
#   'Tazio B.',
#   'UCKw-im_Dcgl7uCbsdvtXjtw',
#   'I am in a similar situation, except I’ve always known I wouldn’t have kids due to a severe hereditary health condition. I was a foster parent for several years. You should really check out foster/ adoption. I think you would be great at it, and there are SOOO many kids that need help. In our state there are literally thousands of kids with no home. They need someone to care. Also, consider going on Seasonique full time, without breaks. After about 6 months, I STOPPED MY PERIOD. It is freakin awesome. You should ask your gyn about it.'],
#  ['lSlKqgyE2Zo',
#   'Ugzdd9RqgO9uzUB0ZSJ4AaABAg',
#   'Ugzdd9RqgO9uzUB0ZSJ4AaABAg',
#   'Carrie Meadows',
#   'UC8PCP_TYjfKNQrL9GlAkfnQ',
#   "You may totally talk about whatever the h#ll you want and I will watch it. So many people are saying this, and it's true: You're like a friend we have just never actually met in person. We would talk about all of this! I don't have PCOS but I get a painful ovarian cyst every month. Tried everything that gynecology has to offer short of surgery. They're very conservative on that. So although we don't have the same issues, I truly empathize with healthcare frustration, dealings with good and bad doctors, and trying to find a way to just have a good life while managing chronic conditions. It doesn't mean we're not grateful for the good days."],
#  ['lSlKqgyE2Zo',
#   'UgxuBkqhmM6iQy2rLvx4AaABAg',
#   'UgxuBkqhmM6iQy2rLvx4AaABAg',
#   'Kintsukuroi',
#   'UC-5X-F38DxXQMw2nL0Xl5Ew',
#   'Please please please keep "over" sharing. You help us so much!'],
#  ['lSlKqgyE2Zo',
#   'UgzkgWgUw2IqeG_Wi-14AaABAg',
#   'UgzkgWgUw2IqeG_Wi-14AaABAg',
#   'Harmony Joy',
#   'UC17XzFqQJuAAW2JcYVpuH6w',
#   'Please make a cup video!'],
#  ['lSlKqgyE2Zo',
#   'UgwTGnh0ypMnOvGaE7x4AaABAg',
#   'UgwTGnh0ypMnOvGaE7x4AaABAg',
#   'The Curvy Cuban',
#   'UCGaKsKHdduSRhci9myn2rvQ',
#   'I hope to GOD that you reported that docs behavior. Unacceptable for anyone to treat another person that way, especially a doctor who has taken an oath to do no harm. Disgusts me.'],
#  ['lSlKqgyE2Zo',
#   'UgwuQELzIGmBIrR4Kzp4AaABAg',
#   'UgwuQELzIGmBIrR4Kzp4AaABAg',
#   'Vicky Brown',
#   'UCBz51bUJ6CstpRYNgExicaw',
#   'Plz do a video about PCOS. I got diagnosed this year x'],
#  ['lSlKqgyE2Zo',
#   'UgyCOZ9Jc4VXAIsfJKp4AaABAg',
#   'UgyCOZ9Jc4VXAIsfJKp4AaABAg',
#   'Laura Lewis',
#   'UCEe2-shVTMtYxc5Z_cXiMEQ',
#   "YAS YAS YAS I LOVE MY PERIOD CUP!!! I used a tampon for 2 days this month and it was literally driving me insane the entire day(s). After using the cup I can't stand the feeling (I know, what is she talking about, you can feel a tampon) well now I do. I feel the cotton and it's so scratchy and drying and uncomfortable and I'm back on my cup today, wonderful. SPEAK THE TRUTH KRISTI!!!!"],
#  ['lSlKqgyE2Zo',
#   'UgwjwQ4zwR2lU_OZDnl4AaABAg',
#   'UgwjwQ4zwR2lU_OZDnl4AaABAg',
#   'Ashley Oliveira',
#   'UCM1GSnXrUOCp5lH7hYDx93g',
#   'Hi! I would love a video on your experience with period cups. I don’t know if this is just me and I think it might be because when I search for it online, I don’t really find anything. But have your cramps been waaaay worse using the cup? I think the cup is giving me more cramps.'],
#  ['lSlKqgyE2Zo',
#   'Ugw8E33NpQU9bpQZ6gJ4AaABAg',
#   'Ugw8E33NpQU9bpQZ6gJ4AaABAg',
#   'Retro Arts Clique',
#   'UCQekZgwpwC8hK_l7wStWKew',
#   "In life, many people will try to tear you down because they want to feel better about themselves. Your reaction is completely normal and you have the right to be emotional about it but at the end of the day, you have to remember that you're a tough bitch who has survived thousand of rough times and will do it again and again. \n\nalso this may sound cheesy but I agree with the quote 'The behavior of others towards you speaks about their character,  not about yours'"],
#  ['lSlKqgyE2Zo',
#   'Ugyqcc0HItSjcpCmRWt4AaABAg',
#   'Ugyqcc0HItSjcpCmRWt4AaABAg',
#   'Katrina Lizon',
#   'UCQFBCLpD8r7ThEqml-PTVfg',
#   'period cups are literally the BEST thing ever and i try to get every women i know to try it. best invention EVER'],
#  ['lSlKqgyE2Zo',
#   'UgwpwNycbNFYw6BlQzN4AaABAg',
#   'UgwpwNycbNFYw6BlQzN4AaABAg',
#   'Ms Mew',
#   'UCSwdpRAOmLald8d2RhQTObQ',
#   'I was diagnosed with PCOS at 24 and I’m now 48 and was diagnosed with type 2 diabetes last year🙄. I think I’m past the point of having strangers ask about kids and if they do I fake cry and make them feel shitty😬🤷🏻\u200d♀️'],
#  ['lSlKqgyE2Zo',
#   'UgxDN5ic1RbBA0aUaCV4AaABAg',
#   'UgxDN5ic1RbBA0aUaCV4AaABAg',
#   'Jennifer Bray',
#   'UCE5wQhaaZNlPdY8FyfLdVtA',
#   'Oh Kristie...  I wish I could give you a long genuine hug right now.'],
#  ['lSlKqgyE2Zo',
#   'UgyTU6415fT8AXC1x2h4AaABAg',
#   'UgyTU6415fT8AXC1x2h4AaABAg',
#   'Marycha Padilla Ochoa',
#   'UCCiQDGPw9ALCh_PkZsWWRXg',
#   "From working at a clinic I can tell you you should consider reporting this doctor to the manager of the office. Call the clinic and ask for the doctor in charge to make sure it gets back to him because if you don't it might never get to him. Hope this helps"],
#  ['lSlKqgyE2Zo',
#   'Ugwk5LmHAT__nYPFKkF4AaABAg',
#   'Ugwk5LmHAT__nYPFKkF4AaABAg',
#   'Kelly Lopez',
#   'UCrQkAV7jwdWzUUa_5iCvmDw',
#   'Dear Kristi, I am so sorry you went through such a horrible appt. I can relate to the pcos and infertility struggle since I struggle with this too and have been trying to get pregnant for over 5 years and have been through 2 ivf cycles so far. First of all, I love you. Second, please focus on yourself and getting yourself to a good place. It is already so hard to come to terms with certain things like infertility and to have someone rub it in your face is so shitty. Know that you are not alone, we love you, and you are amazing. ❤️🙏🏻💪🏻'],
#  ['lSlKqgyE2Zo',
#   'Ugxv3YhN_2Gv9TA_EY54AaABAg',
#   'Ugxv3YhN_2Gv9TA_EY54AaABAg',
#   'Carena Hall',
#   'UChT42OOxGnwGSnbVnm2BMZA',
#   'You are the cutest and the sweetest. You\'re like a lil cupcake that you see in a pile of cookies with beautiful frosting you just wanna hold really close to your face bc you love looking at it. \nI totally understand the way you feel about that doctor. I have the same reactions and feelings when it comes to my step mum. Its really hard to deal with things she says to me, but at the end of every day you really gotta look at yourself in the mirror and be like "they really tryna get under my skin? they really tryna tear me down? what happened to girl I used to know where she didn\'t let anyone tell her shit and get away with it. This won\'t stay with me but I will remember how I felt and how I choose to do better for myself and value the good shit I accomplish and the happiness I can create with people or for people that love me, or I love... \nEvery hardship is just another stone trying to break the barriers we keep to protect us from all the shit. \nIt will get better soon. You can always try to redo that appointment and go to your doctor for some actual important information you were looking for from the beginning. \nThere\'s always a light at the end of the tunnel, its just harder to see. I love you Kristi 🧡🧡'],
#  ['lSlKqgyE2Zo',
#   'UgwGaSBsrixpohPoo_14AaABAg',
#   'UgwGaSBsrixpohPoo_14AaABAg',
#   'LisaRSDMom3 Chris',
#   'UC7MI8ZM_10p5P_UPcm2dieA',
#   "Kristi, thank you for sharing your life with us. You are an amazing, strong women. Even if we don't have your exact health issues, it helps us struggling with our own. God bless you! Would love a menstrual cup video."],
#  ['lSlKqgyE2Zo',
#   'UgxQBedXsvuTdtKmVJp4AaABAg',
#   'UgxQBedXsvuTdtKmVJp4AaABAg',
#   'Jennifer Gardner',
#   'UCGkGUZillU2YFGIYV-WCT_A',
#   'That doctor was evil, no one should ever be spoken too that way!!'],
#  ['lSlKqgyE2Zo',
#   'UgyFvCqRaNRT7_rm9vp4AaABAg',
#   'UgyFvCqRaNRT7_rm9vp4AaABAg',
#   'just-so-darling',
#   'UCouoAVkdFMeHHpHIo7yk4gQ',
#   'Yes! Make a video on menstrual cups! I do the same thing with everyone I know! I love mine and more people need to know about it!'],
#  ['lSlKqgyE2Zo',
#   'Ugy_XJgXa5y05W-I57h4AaABAg',
#   'Ugy_XJgXa5y05W-I57h4AaABAg',
#   'Courtney Boyer',
#   'UCvPQbUXgKGvJnxInxu54qqA',
#   "You posted this video and the one with Manny's palette!! That's 2 Halloween looks. It doesn't have to be extravagant. 😊❤"],
#  ['lSlKqgyE2Zo',
#   'UgzeVCeoU7y2kwFEHgl4AaABAg',
#   'UgzeVCeoU7y2kwFEHgl4AaABAg',
#   'calliesimmer',
#   'UCvWMhUfXjD5QaykDukLoZ2Q',
#   "Kristi you are absolutely beautiful and an amazing person. Also, have you ever thought about livestreaming your VFX looks? It would be absolutely monumental to do the whole thing, but you could probably do pieces on Twitch or Mixer or something like that. Then there's no real chance of demonitization. Love you <3"],
#  ['lSlKqgyE2Zo',
#   'UgwGIDuEU54YV2OzOPp4AaABAg',
#   'UgwGIDuEU54YV2OzOPp4AaABAg',
#   'Adrienne Sadovsky',
#   'UCHbPr7PQ0skby24DvrUvBJw',
#   'I’m so sorry you went through that and I wish I could hug you in person. I hope you told your gp about this because she probably won’t want to send any other patients to him. You could also contact the AMA with a complaint. No other woman needs to go through that. Take care.'],
#  ['lSlKqgyE2Zo',
#   'Ugz5JXC1Ly_rPmEOezx4AaABAg',
#   'Ugz5JXC1Ly_rPmEOezx4AaABAg',
#   'Christina Adams',
#   'UCOYH_NLU3pfKtzVbU7XO3jg',
#   "Well because we are best friends,  I want to cry and also beat the shit out of that doctor. So sad and it pisses me off beyond belief. I can't imagine what I would even do if I experienced that I'm so sorry 😭😡🤬 We love you 💜💜💜"],
#  ['lSlKqgyE2Zo',
#   'UgywVpphmQcXyO9EKqV4AaABAg',
#   'UgywVpphmQcXyO9EKqV4AaABAg',
#   'Lorrie Lavallee',
#   'UChZhHGHx2dH5V1OjZgFGjhQ',
#   'I get it, I get you...you’re awesome...kids suck anyway lol fuck em!'],
#  ['lSlKqgyE2Zo',
#   'UgyMjiv3IiiAyTiJKrp4AaABAg',
#   'UgyMjiv3IiiAyTiJKrp4AaABAg',
#   'TheSecondofTwo',
#   'UCJ-xJ4cFQgrj33PmJuWa_gA',
#   'I hope you report that Dr. That is unacceptable!'],
#  ['lSlKqgyE2Zo',
#   'UgwdxKOhRru_pUjTqnl4AaABAg',
#   'UgwdxKOhRru_pUjTqnl4AaABAg',
#   'Sara Miller',
#   'UCgDVR44OXK-lPKtR0GLev9A',
#   'I would go report that doctor so unprofessional and gross'],
#  ['lSlKqgyE2Zo',
#   'UgwOorz4Sf1qJjMmtA94AaABAg',
#   'UgwOorz4Sf1qJjMmtA94AaABAg',
#   'Melissa Pullano',
#   'UCxTAugJ7cxt8QedTqokyyXA',
#   'I think you can complain!!! It’s tough to have PCOS. I myself had a hard time getting pregnant. And how dare a Dr talk to you like that.  I love watching your videos. You are real!!! Hope you are feeling better.'],
#  ['lSlKqgyE2Zo',
#   'Ugzdl3zTKv7jQZptL7R4AaABAg',
#   'Ugzdl3zTKv7jQZptL7R4AaABAg',
#   'doligd130780',
#   'UC-1C_6kCOuUwB1rL8h7zmUg',
#   'I was told I have PCOS, there is very little chance I get pregnant without hormone treatment and since I also had another rare illness which put me on high risk of getting blind, I was not able to take hormones at all.  I wad basically told I can start hormones, with risk of getting blind,  even if I wouldnt when i actually be pregnant I will have to stop my medicine I was on for the other illness as it would damage my baby and I could loose it, or i might for sure get blind while pregnant. SO we stopped trying. My condition got better with the other problem, no signs of worse so we decided to stop my medication. I was off for almost 2 years and we started to try to have a baby, 2 years almost, but no baby, so I gave up. We stopped trying, after few months we decided to risk and I go on hormones....2 weeks before my gyno appointment I found out I was pregnant! Now I have a little man who is 6, best boy ever! It also appears that not only I have PCOS but also endometriosis. SO you are never sure unless you dead :) You still can get pregnant and I know many cases like mine and yours when it happened. I truly wish you that!'],
#  ['lSlKqgyE2Zo',
#   'UgyOALdTBC3XERC9vRp4AaABAg',
#   'UgyOALdTBC3XERC9vRp4AaABAg',
#   'Victoria Vath',
#   'UC5pmXyvoqyfw7HdFMC8wEUg',
#   "I don't understand how anyone could say anything negative about you! You are an angel baby sweet open soul and a treasure! ❤"],
#  ['lSlKqgyE2Zo',
#   'Ugw8Pn-VUCSjxOCYKX94AaABAg',
#   'Ugw8Pn-VUCSjxOCYKX94AaABAg',
#   'Erica Lind',
#   'UC9g1JREd9rTJLAryEtWzfTg',
#   'this makeup would be perfect for a masquerade party\n\nps i love you rbk. we all go through it but you’ll get to the other side soon 💘'],
#  ['lSlKqgyE2Zo',
#   'Ugx7FsLfD0_ThhcYIYN4AaABAg',
#   'Ugx7FsLfD0_ThhcYIYN4AaABAg',
#   'Mary Gates',
#   'UC1Ezn47uBljL2Yq1rGWfDRQ',
#   'I actually love this look!! I was a little unsure where we were going to end up, but it looks like you’ve got an editorial butterfly resting on your nose and it’s so euphoria-esque and so magical'],
#  ['lSlKqgyE2Zo',
#   'UgyCXAudmd7kkj-DuFl4AaABAg',
#   'UgyCXAudmd7kkj-DuFl4AaABAg',
#   'Claire Benfer',
#   'UCH277TzlfsvPXsMKjqWweDg',
#   'can you review elizabeth arden makeup?'],
#  ['lSlKqgyE2Zo',
#   'Ugyh5DGmbcd5bK6nvRF4AaABAg',
#   'Ugyh5DGmbcd5bK6nvRF4AaABAg',
#   'kalyn bender',
#   'UCvCIQ8uqnhy8ujX2B-ufTng',
#   "You look kinda like a butterfly!! I see that more than an alien, you're beautiful!"],
#  ['lSlKqgyE2Zo',
#   'UgxURwn6FH34lwtbkjh4AaABAg',
#   'UgxURwn6FH34lwtbkjh4AaABAg',
#   'All Things Beauty',
#   'UCJs38YMqSwjKbpJO1meWW6A',
#   'Period cups are the fucking best. If nothing else, do LESS CRAMPS incentivize you?? Lol'],
#  ['lSlKqgyE2Zo',
#   'UgxhCNKCOx7IiSwTnp14AaABAg',
#   'UgxhCNKCOx7IiSwTnp14AaABAg',
#   'Shannon Moschides',
#   'UCgtQXgnaqes73Nc-a-9wIQw',
#   'Kristy, take your power back and consign him to the depths, where he belongs. Get your test results and find another decent Dr. 💜'],
#  ['lSlKqgyE2Zo',
#   'UgxtUIk7pQ8AhxT7aqh4AaABAg',
#   'UgxtUIk7pQ8AhxT7aqh4AaABAg',
#   'Susan Clark',
#   'UCIXDFY6lmm-GxI8BTHWRt4Q',
#   'Put a written complaint into the practice/hospital! Xxx'],
#  ['lSlKqgyE2Zo',
#   'UgwpfXCJoVdaL8cSdp94AaABAg',
#   'UgwpfXCJoVdaL8cSdp94AaABAg',
#   'Shannon Moschides',
#   'UCgtQXgnaqes73Nc-a-9wIQw',
#   'He is a failure as a Doctor and as a human being. What scum.'],
#  ['lSlKqgyE2Zo',
#   'UgzVaaSCc9ZEXj0VvdB4AaABAg',
#   'UgzVaaSCc9ZEXj0VvdB4AaABAg',
#   'AJ Weath',
#   'UCaGixV1_vVqrBFrSm8qt6rA',
#   'LITERALLY FUCK THAT DOUCHER DOCTOR FUCK YOU ARE POIFECTO'],
#  ['lSlKqgyE2Zo',
#   'Ugx17esuHyNovX69VvR4AaABAg',
#   'Ugx17esuHyNovX69VvR4AaABAg',
#   'Corrie Sites',
#   'UCBddsnW-V6uCGOk_1TEAGqA',
#   "You shouldn't let it go. That dr works for a practice, and he will see more patients that shouldn't have to go through what he put you through. You should tell someone what happened. If not for yourself, for the next young woman that walks into his office."],
#  ['lSlKqgyE2Zo',
#   'Ugw-VmF8vpbKS3YTMxV4AaABAg',
#   'Ugw-VmF8vpbKS3YTMxV4AaABAg',
#   'Lina Sandoval',
#   'UCprmXjQsoCBeS6cDlDuQADg',
#   'Omg I loveeeeee my menstrual cup! It’s such a game changer 😭'],
#  ['lSlKqgyE2Zo',
#   'UgwcVZ5IENZJDN3WDIZ4AaABAg',
#   'UgwcVZ5IENZJDN3WDIZ4AaABAg',
#   'Manda L',
#   'UCZ31LXboRiRmbIyJIqYW4kQ',
#   "I have a rare autoimmune disease called polymyositis and for the most part I have such a amazing doctors but last year when I first got diagnosed I had high cholesterol so they sent me to a specialist and he kept telling me how my life expectancy was very low that things are only going to get worse for me and I really literally contemplated suicide... I was a complete wreck because all of my other specialist had told me that I'm young and I'm going to get through this and even one day I can have a baby... I was sent to go see a psychiatrist because of this doctor that made me feel like I wasn't going to make it past next year... The doctor has had a strike on his record now and the other doctors that I see have all condemned him and no longer send any of their patient to him because of his bedside manner so I'm sorry that you had to go through this especially with something that we can't help ...our bodies are fighting ourselves and they need to have a little more compassion and when we ask questions we need the answers"],
#  ['lSlKqgyE2Zo',
#   'UgxDgvYmygOozxKunBB4AaABAg',
#   'UgxDgvYmygOozxKunBB4AaABAg',
#   'Contently Me',
#   'UC_bmU1Y3hWuS5oKVjLc-CIQ',
#   'Loved this look Kristi, love all your chatty videos and hope your feeling a little better  x'],
#  ['lSlKqgyE2Zo',
#   'Ugzi-FmPENO5I9zm2fx4AaABAg',
#   'Ugzi-FmPENO5I9zm2fx4AaABAg',
#   'Jackie Piazza',
#   'UC_vUy2VTEnDs4rs4-5c9l8A',
#   '💗'],
#  ['lSlKqgyE2Zo',
#   'UgyWtiCdf8v7F7WENMV4AaABAg',
#   'UgyWtiCdf8v7F7WENMV4AaABAg',
#   'Daphnie Starr',
#   'UCsiA-oq8ZfWbvX3JHaTEXwQ',
#   'Please make a PCOS video'],
#  ['lSlKqgyE2Zo',
#   'UgysjjPW6m9uKqXq-Ht4AaABAg',
#   'UgysjjPW6m9uKqXq-Ht4AaABAg',
#   'Minouk van der Velde',
#   'UCEtbTI3PRJlJXKsnsSH4i_Q',
#   'Well .........fuck!  If it even matters, I love ya'],
#  ['lSlKqgyE2Zo',
#   'UgwGqpSTJBvsCaJpOZt4AaABAg',
#   'UgwGqpSTJBvsCaJpOZt4AaABAg',
#   'Melanie gorniak',
#   'UCzlDKae9tzGbrqWTKOJAjyA',
#   'I honestly do wonder what you are doing how you are. I really do.'],
#  ['lSlKqgyE2Zo',
#   'UgxHgkKxqTAUQ4leHB14AaABAg',
#   'UgxHgkKxqTAUQ4leHB14AaABAg',
#   'Nicoletta Simone',
#   'UCozC0bFQd6eFhBMGF_SQ0cA',
#   'Oh my god, can’t get over that doctor!! I used to go with my sister to appointments, she has an undiagnosed condition, and the doctors would talk to her for five minutes and say all her symptoms were related to anxiety and I would go OFF on them for wasting our time. Made me so angry hearing that story, you needed someone there to back you up and speak up for you!! Love your videos!!❤️ don’t let that idiot get you down!'],
#  ['lSlKqgyE2Zo',
#   'UgysXlABagAp2y2OHwd4AaABAg',
#   'UgysXlABagAp2y2OHwd4AaABAg',
#   'Danielle DiMeo',
#   'UCZuau95j-_1s2ehb_Qwt4uA',
#   'omg i fully support the menstrual cup videos! honestly sam is the reason why i switched over to one and it’s so important to educate people and destigmatize having a period'],
#  ['lSlKqgyE2Zo',
#   'Ugx39efJt8Z3Q6t_sbB4AaABAg',
#   'Ugx39efJt8Z3Q6t_sbB4AaABAg',
#   'Molly Summers',
#   'UCbSO5A9MpAXp8f7t76GoRbw',
#   'Kristi, I really hope you see this. My friend was told for YEARS that she had PCOS, but she actually had Cushing disease. Her cortisol levels in her body caused her issues. It was diagnosed by an MRI of the brain. You should look into this for yourself. I’m so sorry about your experience with that doctor. I have had experienced like this with doctors before. Stay strong and don’t give up on your health!!!'],
#  ['lSlKqgyE2Zo',
#   'UgypezqumV2anO9ZcZd4AaABAg',
#   'UgypezqumV2anO9ZcZd4AaABAg',
#   'Carina Leon',
#   'UCyMGdcRVkEBMoAq4TfYoctA',
#   'And that is EXACTLY why I stopped doing makeup videos on my channel 😞 YouTube has really changed completely and it really sucks because there is people out there that really wanna do this as a career but since so many things changed it’s just not even worth doing it at all. People don’t understand that it takes so much time and effort to do just one video for literally NOTHING 😒 I wish we can just turn back time on YouTube 😞'],
#  ['lSlKqgyE2Zo',
#   'UgwHuNL_vAlO_w7f-zV4AaABAg',
#   'UgwHuNL_vAlO_w7f-zV4AaABAg',
#   'Jean M',
#   'UCSK87N9ewXL2QJy8LPpGtLQ',
#   'Your doctor experience is my own with almost every doctor I go to they are so fucking insensitive! I’m sorry that happened.'],
#  ['lSlKqgyE2Zo',
#   'Ugz6JJIaqR1UTfiqRJl4AaABAg',
#   'Ugz6JJIaqR1UTfiqRJl4AaABAg',
#   'Emily Johnson',
#   'UC9PQDe55COfk1v_h9c8NNPg',
#   "Hey Kristi, I wanted to tell you I would love a video on PCOS. \nI got my first period at 13. I was in so much pain I couldn't really leave my bed. My doctor at the time told me just to take pain killers before and during my period. \nWhen I was 18, I started seeing a new GP who said the same thing. I've now had overwhelmingly painful and heavy periods for 5 years and I feel like that's just how it is for me.\nAt 19, I started seeing my gyno, who thought I could have endometriosis but wasn't going to diagnose it until she had more information. I tried 3 different birth controls to help with the pain and heaviness and had multiple ultrasounds (internal and external).\nTwo months ago, I was in urgent care because I couldn't breathe through the pain. I decided to see a new gyno since, after 2 years, she wasn't doing anything other than throwing birth control at me (mind you, I'm engaged to a woman so I'm only on birth control for my pain. I currently have and IUD and have pain during ovulation and during menstruation. \nThe new gyno ran one test (an ultrasound where she filled my uterus, tubes, and ovaries while saline) and found small cysts covering my ovaries and multiple polyps. She diagnosed me with PCOS and polyps and suggested surgery and switching my birth control. 8 years, 3 doctors, and all it took was one test for me to have answers. \nDoctors are the worst about gynecological heath. The more you talk about it, the less alone people like me feel. So, I'm sorry that doctor was awful but I really appreciate you talking about it and I appreciate every time you talk about PCOS.\n<3"],
#  ['lSlKqgyE2Zo',
#   'Ugx2CPhpEtMttXlAI8p4AaABAg',
#   'Ugx2CPhpEtMttXlAI8p4AaABAg',
#   'Sophi Rome',
#   'UCMs_FkjE76DGqIVNsdVACQg',
#   "Give 👏🏼me👏🏼 that 👏🏼doctor's👏🏼 info"],
#  ['lSlKqgyE2Zo',
#   'UgwQSvH0wjXowbUhSup4AaABAg',
#   'UgwQSvH0wjXowbUhSup4AaABAg',
#   'Bridget Schmidt',
#   'UCdY6CUZLVxio-efbGTBrHIQ',
#   'I’m so sorry you had such a shitty experience with that doctor. I know how awful it feels to be invalidated and made to feel like your concerns aren’t important. It’s so disheartening when the person who is supposed to be helping you makes you feel like your symptoms aren’t worth their time when you’re the one who has to go home and live with them day after day.'],
#  ['lSlKqgyE2Zo',
#   'UgwsAk-01X_51PCgp5N4AaABAg',
#   'UgwsAk-01X_51PCgp5N4AaABAg',
#   'Brie Fredrick',
#   'UCsM6rBoO0nTGa4WhvrtbdzQ',
#   'Butterfly! You are a beautiful blushing butterfly 🦋'],
#  ['lSlKqgyE2Zo',
#   'UgxE6qyvqMo1sbd1iqF4AaABAg',
#   'UgxE6qyvqMo1sbd1iqF4AaABAg',
#   'Courtney Boyer',
#   'UCvPQbUXgKGvJnxInxu54qqA',
#   "I love you and Jordan Hanz so much 😭 I religiously watched you and Hanz's Halloween videos 😭❤"],
#  ['lSlKqgyE2Zo',
#   'UgxHK6ijF9XO8dVF_nh4AaABAg',
#   'UgxHK6ijF9XO8dVF_nh4AaABAg',
#   'LillJade',
#   'UCReid-Wu1FapZ-rqm3AN93w',
#   'Can I give you a hug??? I would so be there to make you feel better and to just tell you to vent out if you have to. If you need to ball your eyes out then do it. Your human, you have every right to say the truth of how reality is and how you feel about any situation your in. Although we’ve never met, who knows if we ever will, (hoping one day).  You are honestly very amazing and so humble. Love how blunt and honest you are. Love it. I’m here to support you and love you. Xoxo'],
#  ['lSlKqgyE2Zo',
#   'UgyrGTfrd7OQAfjFQ7l4AaABAg',
#   'UgyrGTfrd7OQAfjFQ7l4AaABAg',
#   'Natalie Blue',
#   'UCKg4sDV2DcCQHepDK8aTx9Q',
#   'Period cups are life!! I got the diva cup first but then tried the saalt cup and I will literally never go back! I bring it up and talk about them as often as I can! 😂'],
#  ['lSlKqgyE2Zo',
#   'Ugz3mEpgBco-ilZhZAR4AaABAg',
#   'Ugz3mEpgBco-ilZhZAR4AaABAg',
#   'Rita Romney',
#   'UCftVzchqPt0VVN7qDvCVl0Q',
#   "Kristi, I wok up at 4:00 a.m., and so I watched some You Tube, including this particular video.  When I fell back to sleep, you and your husband, and a little baby were in my dreams, along with an older daughter.  I was suppose to follow you on my motorcycle as we traveled somewhere and I was to hold your baby while doing so.  It was a WILD dream.  So funny!  You and your husband were so nice to me!  Have a nice weekend.  I won't be forgetting that dream any time soon : )"],
#  ['lSlKqgyE2Zo',
#   'UgwbPmmLVGvC-As6eTl4AaABAg',
#   'UgwbPmmLVGvC-As6eTl4AaABAg',
#   'Kenzie H',
#   'UCPpEVFq_uHNt_H-ui1KxdEQ',
#   'Me to my endocrinologist: “What are the chances, having premature ovarian failure, that I’d ever get pregnant?”\nEndocrinologist: “Start playing the lottery cuz you’ll have a better chance at that than every getting pregnant.”\n\nNot funny. Didn’t make me laugh. Just a dickhead, dumbass doctor. Thanks for sharing your story.'],
#  ['lSlKqgyE2Zo',
#   'UgwcFxCJla6MYclAL9h4AaABAg',
#   'UgwcFxCJla6MYclAL9h4AaABAg',
#   'Kelsea Williams',
#   'UCtVyF84FJlY8wt2JMRs0SyQ',
#   'Hey Kristi I don’t know if this is something you would consider but I would be MORE than happy to support you on a Patreon if you got one so that we could see more SFX content. Seriously I think you would get a lot of support if you started one. You’re one of my favorite creators and I love SFX so like I said I would gladly support it 🖤🖤'],
#  ['lSlKqgyE2Zo',
#   'Ugzc0IDkCtQL39Y4kaF4AaABAg',
#   'Ugzc0IDkCtQL39Y4kaF4AaABAg',
#   'hummingbored',
#   'UCE0RcgQ18NuzQHO6zIV3GLQ',
#   '"is this cute or or is this stupid? ... meh i dont care" wow i love RawConfidenceKristi\nalso, your makeup when you cut in to explain demonetization? gorgeous. the little overalls with the sweater? adorable. oh my god'],
#  ['lSlKqgyE2Zo',
#   'UgwCR9gp4bP8vXHAl_J4AaABAg',
#   'UgwCR9gp4bP8vXHAl_J4AaABAg',
#   'Victoria Porter',
#   'UCjFLcE7avzc-kvm1lcN5ExQ',
#   "I also struggle with infertility due to PCOS and we've been trying for several years. I'm so with you on the pretending or convincing yourself you dont want something. You aren't alone. I'm sorry. It freaking sucks."],
#  ['lSlKqgyE2Zo',
#   'Ugzv1QXWWRUUVv-BKQ14AaABAg',
#   'Ugzv1QXWWRUUVv-BKQ14AaABAg',
#   'JioDoes',
#   'UCz-pym53w0mD1osZLuXPpcQ',
#   'You should report him. My friend recently had to report a doctor. I hope this helps. Sorry to hear about what happened to you :( \n\nhttps://www.docinfo.org/report-a-doctor/'],
#  ['lSlKqgyE2Zo',
#   'UgwGbSupoj7WtbQWsUl4AaABAg',
#   'UgwGbSupoj7WtbQWsUl4AaABAg',
#   'Tova Ek',
#   'UCKQhHRdWQJKC2lWtUiVUHaA',
#   "Ok first off. You're not oversharing. You share as much as you like and that's that. Secondly, all of my doctor's appointments have been like that. I have ran out of clinics in tears due to dismissive and rude doctors who won't treat me. Years and years of mental health issues and I only ended up getting help when it was too late. It's disgusting."],
#  ['lSlKqgyE2Zo',
#   'Ugzc2gkUyi-p7ELizF14AaABAg',
#   'Ugzc2gkUyi-p7ELizF14AaABAg',
#   'Nana West',
#   'UCKR35u50QS0rpEdXARcZF8A',
#   "I've been a volunteer in my local hospital and the amount of doctors that couldn't even return my good morning/afternoon was ASTONISHING. Like, I'm not at all surprised at your experience (though outraged), even though we live on different continents."],
#  ['lSlKqgyE2Zo',
#   'UgwgUUAKyQ4Z_D1IafJ4AaABAg',
#   'UgwgUUAKyQ4Z_D1IafJ4AaABAg',
#   'Emma Roberts',
#   'UCmV6i6JKP6wKLdripLMwhKw',
#   'WHO IS THIS DOCTOR? I’ll sort him out for you Kristi. Xxxxx'],
#  ['lSlKqgyE2Zo',
#   'UgyoQA5-gGS-VNSq7LJ4AaABAg',
#   'UgyoQA5-gGS-VNSq7LJ4AaABAg',
#   'T L',
#   'UCWOF0icGpknygkP7EXVEAFA',
#   'Kristi, a friend recently had a child after 11 years of trying. If or when you are supposed to have a baby you will. Waiting sucks but you are so beautiful and real and funny. Chin up butter cup! You got this!'],
#  ['lSlKqgyE2Zo',
#   'UgwAOtzXEXsLLWXA7kV4AaABAg',
#   'UgwAOtzXEXsLLWXA7kV4AaABAg',
#   'Lauren Fisher',
#   'UCIdT9lgluE5XLFrSGsJBSCw',
# ...
#  ['lSlKqgyE2Zo',
#   'Ugy7QdhMIA685HFBPY14AaABAg',
#   'Ugy7QdhMIA685HFBPY14AaABAg',
#   'Brooke Emmons',
#   'UCzZOnYx99nBvc39OBECrbRw',
#   'I would love the period cup video! Samantha’s videos were so awesome, it would be great to get your opinion too.'],
#  ['lSlKqgyE2Zo',
#   'UgxPwlrJWo1Bd71_po54AaABAg',
#   'UgxPwlrJWo1Bd71_po54AaABAg',
#   'Karlene Sumner',
#   'UCJpdtZozHFvz9BPdGgPHZMQ',
#   "on the negative comment issue.....I always thought that the reason we can get 99 lovely remarks but 1 negative can affect us is because; in our minds it confirms a belief you already have fixated... and you may have never believed this before, and maybe you use to be able to shake it off, even then, it builds and grows and you allow this in your mind...then the next time that shit comment comes around, its a trigger point for you. Like a gun is the comment, well..that gun wont fire unless you're holding it. Drop the gun, be the gate keeper of your mind, and affirm that you are great and made unique for a reason!"],
#  ['lSlKqgyE2Zo',
#   'Ugw-x1W2p_IO94haqUR4AaABAg',
#   'Ugw-x1W2p_IO94haqUR4AaABAg',
#   'Claire Salas',
#   'UCVHhkxViosmQDPc3CYMxnZw',
#   'There’s a Friday the 13th in December just sayin..........Halloween videos 365 days a year are welcome 😬'],
#  ['lSlKqgyE2Zo',
#   'Ugwk8tyYoQi71V88QzZ4AaABAg',
#   'Ugwk8tyYoQi71V88QzZ4AaABAg',
#   'Shayna Weinstein',
#   'UCaZBxUY2lpQzzZZgikaDd8Q',
#   'I would report that doctor to the board.  He can get in a lot of trouble talking to you like that.'],
#  ['lSlKqgyE2Zo',
#   'UgyYUNNewivsWWi_Cdl4AaABAg',
#   'UgyYUNNewivsWWi_Cdl4AaABAg',
#   'Ida Björnberg',
#   'UCn1G_KcO-HfGBX4L40534Vg',
#   'I’m so sorry about this piece of absolute shit of a doctor. And from I’ve learned about fertility and pcos through holistic practitioners is that, pcos is not only a fertility issue, and some people only have it for a period of time in their lives, what is this doctor fucking talking about, I hate him. I don’t mean to be the person recommending stuff you didn’t ask for so I’m not going to. It breaks my heart when I hear so many people talk about their issues with fertility and their doctors don’t do shit to help because they are so focused on the one thing that they are specialized in and if they don’t know what else to do they just send you somewhere else, to a new doctor who doesn’t know what to do either. Maybe they could cooperate since our issues are not islands, our bodily functions are connected and nothing is an isolated issue. It’s like when they say that en iud is a local dose of hormone so it doesn’t affect the rest of the body, well why are the most common side effects acne and headaches then? Make it make sense!'],
#  ['lSlKqgyE2Zo',
#   'UgycqvdVxUXQuYDCuq94AaABAg',
#   'UgycqvdVxUXQuYDCuq94AaABAg',
#   'Mackenzie Cobb',
#   'UCf2SqRoaQq_yUawd57APZSw',
#   'You lost a year of your life? Have you met any Portuguese people? Have you gone to sniper school?'],
#  ['lSlKqgyE2Zo',
#   'Ugy3i5bmSfThyKTw7v94AaABAg',
#   'Ugy3i5bmSfThyKTw7v94AaABAg',
#   'Katie Durham',
#   'UCsbcfBlB-QPN9b5eJu3wTxg',
#   "I would love a video on PCOS! I was diagnosed a little over 7 yrs ago, right after I miscarried my first pregnancy. It took me 7 YEARS and 3 OBGYNs telling me I couldn't have children before I found an OB who would help me."],
#  ['lSlKqgyE2Zo',
#   'Ugw2j4L6kJNcOUlRlL54AaABAg',
#   'Ugw2j4L6kJNcOUlRlL54AaABAg',
#   'Kimberly',
#   'UCKNoqnM0r1F7ijJ4LNYsudg',
#   'Yes please do a video on the period cups plzz'],
#  ['lSlKqgyE2Zo',
#   'UgwNmtFnLcjuAsHF2rZ4AaABAg',
#   'UgwNmtFnLcjuAsHF2rZ4AaABAg',
#   'Kim Gossling',
#   'UCqtMn5WNcBuAY_8j5ryvbgQ',
#   "Why do the negative experiences stick with us? Same reason toddlers and animals act out... negative attention is the most intense form of attention.  Even though it may be for a 'bad' reason, it's an intense focus of attention on them.  Positive experiences may make us feel nice and warm & fuzzy inside,  but the negative experiences are more intense and hit us deeper."],
#  ['lSlKqgyE2Zo',
#   'UgzWNvLdVgZwXV4tpM14AaABAg',
#   'UgzWNvLdVgZwXV4tpM14AaABAg',
#   'Ashley Bishton',
#   'UCM2y8NnErrwuTGCKTAK-lEw',
#   'Cup Video please!! Which brand are you using now?'],
#  ['lSlKqgyE2Zo',
#   'Ugw5-ZrdkUVo5FDeHz14AaABAg',
#   'Ugw5-ZrdkUVo5FDeHz14AaABAg',
#   'MakeupwithCaitlin',
#   'UComVksJA60jDU3vBi0LlrJg',
#   "You are my favorite youtuber Kristi, so real, so NORMAL. You're gaining fame because you're what all (besides Kathleen) beauty gurus are missing. You are amazing and gorgeous and I LOVE your videos. You are exactly what youtube should be."],
#  ['lSlKqgyE2Zo',
#   'UgyAyI5zGflic1_MHWV4AaABAg',
#   'UgyAyI5zGflic1_MHWV4AaABAg',
#   'Lindsay Himmer',
#   'UCX0ioEU6ExAFn7rRydgBo1Q',
#   'That Dr doesn’t hate you. He’s indifferent. And often that’s worse than hate! He can’t even take the time and energy to hate you. He just doesn’t care. And that’s really messed up. Especially from someone in the medical profession. \n\nI’m so sorry he made you feel that way. \n\nAlso, you don’t need to justify your need make content that can be monetized! I know there are reasons, like you said, that aren’t money related. But even if money was the only thing, this is your job! You deserve to make money doing it! \n\nI love you!'],
#  ['lSlKqgyE2Zo',
#   'UgwxIDtJqNEfuptrdLh4AaABAg',
#   'UgwxIDtJqNEfuptrdLh4AaABAg',
#   'Stacie Rooney',
#   'UC6mK3CYs2aRScLtuDDXgRlw',
#   "OMG Kristi! I am so so sorry! There is nothing more frustrating than an asshole Dr.. I have experienced it too with Dr.'s. I am 43 I did not have PCOS, but I had Endometriosis. I went through so much so many Doctors before I was even diagnosed, I suffered with my periods from the time I was 12 when my periods started. I never got diagnosed til I was 21. Because of bad doctors. I could go on and on with you about it! I do care and just hang on it will get better. I'd report that SOB dr. too., just as an fyi. Thank you for sharing and I care. With love and support...Stacie"],
#  ['lSlKqgyE2Zo',
#   'UgwVSs0DkIk4L-fTCzJ4AaABAg',
#   'UgwVSs0DkIk4L-fTCzJ4AaABAg',
#   'FierceJadeMakeup',
#   'UCRKdDbuatQsq2LIibv5wkCQ',
#   'this is why glam and gore kind of stopped doing it too. sucks.'],
#  ['lSlKqgyE2Zo',
#   'Ugx-gjI0OPq6-j-jGOt4AaABAg',
#   'Ugx-gjI0OPq6-j-jGOt4AaABAg',
#   'Hope Amaral',
#   'UCGMMyVprlgqxPuK3uOPyRaw',
#   'People are the absolute best thing about life and the absolute worst thing about life.'],
#  ['lSlKqgyE2Zo',
#   'UgyLkUAKICPjXDE1icx4AaABAg',
#   'UgyLkUAKICPjXDE1icx4AaABAg',
#   'Jennifer Ford',
#   'UC-_RnB-9hH6NiXVoqx-sDhw',
#   'Period cup video is a great idea. I had a hysterectomy last year so I no longer need one but my daughters could still benefit from it.'],
#  ['lSlKqgyE2Zo',
#   'UgwUpLfBtwFcrz8JQ214AaABAg',
#   'UgwUpLfBtwFcrz8JQ214AaABAg',
#   'potato bunny',
#   'UC7Redb4nbC2YQlbGu5Ggwzw',
#   'Period cups are legit amazing'],
#  ['lSlKqgyE2Zo',
#   'UgxB8NcnvdFuaKYdrzp4AaABAg',
#   'UgxB8NcnvdFuaKYdrzp4AaABAg',
#   'Shannon',
#   'UCyAOayciIIvRLuU0uy9DUDQ',
#   'I have pcos, too.  I’m 37, and finally pregnant with our first child.  We did IVF, and it worked the first time, so fuck that doctor.  I tried different medications and IUI, and they didn’t work.  The thing that helps my pcos and keeps me from becoming diabetic is metformin.  I take it three times a day (500mg).  I don’t know if you’ve tried it, but it’ll regulate you and keep the cysts to a minimum.  Good luck with everything.'],
#  ['lSlKqgyE2Zo',
#   'UgyHh_RDhDxTdSdm2tt4AaABAg',
#   'UgyHh_RDhDxTdSdm2tt4AaABAg',
#   'Jessie Sliger',
#   'UC5Of2xUCL3k8JRFxAiri8fA',
#   'PLEASE DO A PERIOD CUP VIDEO'],
#  ['lSlKqgyE2Zo',
#   'UgwLv6f4soO1QAlf_RN4AaABAg',
#   'UgwLv6f4soO1QAlf_RN4AaABAg',
#   'kurtzbomb',
#   'UClu1cpHQ4lHgURBebHGDtIQ',
#   'Wow. I would send him a stern letter telling him what a piece of shit human being he is.'],
#  ['lSlKqgyE2Zo',
#   'Ugxj6MFSeaX4IfCUZBV4AaABAg',
#   'Ugxj6MFSeaX4IfCUZBV4AaABAg',
#   'Our Fam BAM',
#   'UC7VlgW_hHNV0zll2BhVN50A',
#   "Ok first of all I am so sorry that you had that experience because that should never happen but the sad truth is that there are docs out there with horrible bedside manners. It may not seem relevant but if I were you I would ABSOLUTELY reach out to that doctors practice manager and file a complaint. There may be other patients who had the problem too and if no one knows about it they cant fix it. Also I cant believe a practice would make you wait 6 months for a follow up appointment. If results were normal they should have called you to notify you and then if you still wanted the follow up to discuss further questions that's ok. I work in the medical field and I have seen staff and doctors treat people that way and it's simply disgusting. You never know what's going on in someone's life and a little compassion and understanding goes a long way. Again I'm so sorry that you had that horrible experience and I hope you can shake his words off and move past that experience. You are awesome!!!!!!!"],
#  ['lSlKqgyE2Zo',
#   'UgxYIydKovG7NVVccFN4AaABAg',
#   'UgxYIydKovG7NVVccFN4AaABAg',
#   'Audrey Swanson',
#   'UCHgEYXtKJM-79QEP8s6-uog',
#   "Kristi, I've never related more to your 201st example. I waitress and that scenario rang so true to me. It can be so hard to keep your head up when all you can think about is that 1 bad situation. Let this comment be the 202nd and just know that whatever you do with your life and your channel I'm here (as well as many others) and will support you no matter what. Have a great day girl, and Happy Halloween!! xo"],
#  ['lSlKqgyE2Zo',
#   'UgyJJLa9DzU3xwl6-1l4AaABAg',
#   'UgyJJLa9DzU3xwl6-1l4AaABAg',
#   'Chelsea Arrieta',
#   'UCoWUZArQ5mdU2QuTZZ0RzLw',
#   'Kristi, I love watching your content regardless of what it is. You are so genuine and authentic. It’s so refreshing!! Thank you for being you!!'],
#  ['lSlKqgyE2Zo',
#   'Ugy-Qwz7olB725JBshl4AaABAg',
#   'Ugy-Qwz7olB725JBshl4AaABAg',
#   'Shaena Reale',
#   'UC3ltZFwFFNellJCKfExuzGQ',
#   'Ugh.  I have infertility as well and spent years trying to figure out my problems.  I\'ve had MANY a doctor tell me what was the point of figuring out my issues if I didn\'t want to get pregnant, and that they wouldn\'t do any testing or anything until I wanted to get pregnant.  Many doctors basically "treated" my issues with birth control pills.  Um hello, I want to know WHY my body is acting the way it is acting and what can I do to correct the problems! Finally, when I actually did want to get pregnant, I had to go through the ringer with all the tests, the doctors, the fertility clinic to get a "diagnosis" of Unexplained infertility, and did the Clomid which didnt work, and then injectables that finally did work for me.    But guess what, all my same issues returned afterwards and I still don\'t know what\'s wrong with me and never will.  Doctors can be so rude.  Not everything is about having babies, sometimes we want to know why our bodies are doing what they are doing, and how can we feel better.   I\'m sorry you had to go through that.  Despite the fact the internet can be a negative place, there are still some positive places on the internet, and I joined an online community to help me through those hard times all filled with people who were in the same boat as me.  You\'re not alone <3.'],
#  ['lSlKqgyE2Zo',
#   'UgzL7tsXUZJdaJnXsBR4AaABAg',
#   'UgzL7tsXUZJdaJnXsBR4AaABAg',
#   'Cassidy Chaplin',
#   'UCLH6UK3ppvMpsGSig3Up6mw',
#   'I can’t tell you how many migraine specialists/neurologists who have been dismissive towards me. I am so sorry he was such a dick towards you.'],
#  ['lSlKqgyE2Zo',
#   'UgzgGJDlD8bR-KIX1Zt4AaABAg',
#   'UgzgGJDlD8bR-KIX1Zt4AaABAg',
#   'Kristin Mackey',
#   'UCUkvwjO4ApN5PKsls2dwRmA',
#   'Please tell me that you gave that doctor a horrible review.'],
#  ['lSlKqgyE2Zo',
#   'UgwxPwUoyCqudQS-aNt4AaABAg',
#   'UgwxPwUoyCqudQS-aNt4AaABAg',
#   'Ashley Henson',
#   'UCC4UbxUr1Z3Cu-gvvdL-oFw',
#   'Just sending you hugs from a fellow PCOSer'],
#  ['lSlKqgyE2Zo',
#   'UgyFbpQUBDWH--WgAkt4AaABAg',
#   'UgyFbpQUBDWH--WgAkt4AaABAg',
#   'SunnyMcleod',
#   'UCi-Lgmunc3p-XQ1bGe3qS-Q',
#   "As a woman, this has happened to me several times with doctors. And I'm in Canada! Male doctors (often) brush off feminine health issues because sadly medicine is all based on male anatomy. They don't give a shit about us until a man puts a baby in us (and those are words from a female doctor who spent 2 years diagnosing my Graves disease that everyone else brushed off) He's a piece of trash and on top of it insensitive. God damn! Can women just have worth outside of pushing men outta their cooch? Jesus it's no wonder you've been having such a hard time. I can fully understand that girl. Don't stop talking about this stuff. Us over 30 women gotta talk about this shit!"],
#  ['lSlKqgyE2Zo',
#   'UgxsM5jBcAj9bXIGUUp4AaABAg',
#   'UgxsM5jBcAj9bXIGUUp4AaABAg',
#   'Miranda Collier',
#   'UCtWA8s8g128yqET8rnu3OFA',
#   "Girl, I love all of your videos whether they're about looking at your crusty old lashes under a microscope or you just ranting or talking about something. You're amazing and you're a human too and you can do whatever you wanna do. ♡♡♡"],
#  ['lSlKqgyE2Zo',
#   'UgyuNqky4Jjz3fFA2cN4AaABAg',
#   'UgyuNqky4Jjz3fFA2cN4AaABAg',
#   'Sheridan Stinson',
#   'UCa7eWlb_40_V4tJIgxeLJCA',
#   'PLEASE do a video on pcos! i have it as well and would love to hear your experience'],
#  ['lSlKqgyE2Zo',
#   'UgzFOlE3wdDpxPkSdL14AaABAg',
#   'UgzFOlE3wdDpxPkSdL14AaABAg',
#   'Brittany Harris',
#   'UC15w1nw-VeWEKHeZkUJ0zcg',
#   'Sadly there are a lot of doctors like that :( I’m sorry! I’m other news... can I see this peanut covered pumpkin?'],
#  ['lSlKqgyE2Zo',
#   'Ugxmsi2kwzvN6-IyTGd4AaABAg',
#   'Ugxmsi2kwzvN6-IyTGd4AaABAg',
#   'Ali Miller',
#   'UCeoOFlvuYm3koIGm-iYLJQQ',
#   'I am so sorry you had to go through that experience with that piece of shit doctor!!!!!  This has made me so very angry! I want to talk to him up close...  \nI love you girl! You are beautiful strong women and I am so very glad to have you as my best friend that doesnt know who I am lol'],
#  ['lSlKqgyE2Zo',
#   'Ugwxh0JC3nQnpZci7fN4AaABAg',
#   'Ugwxh0JC3nQnpZci7fN4AaABAg',
#   'Ivy Fields',
#   'UC4fF_bbfMR8vPg68F-wRadw',
#   "I would really enjoy a video about period cups! I've been looking into different ones because I want to become more environmentally conscious."],
#  ['lSlKqgyE2Zo',
#   'Ugw5qQexVhKg85Ig0hN4AaABAg',
#   'Ugw5qQexVhKg85Ig0hN4AaABAg',
#   'The Shepherd Chronicles',
#   'UC357VvkgxCymQveXqWZfEjw',
#   "I would LOVE to see a period cup video. They creep me out and freak me out so i've never tried."],
#  ...]

# %%
df_comment_thread = pd.DataFrame(format_ok_comments,columns=['video_id','comment_thread_id','top_level_comment_id','author_display_name','author_channel_id','text_original'])

# %%
df_comment_thread
# Out:
#           video_id           comment_thread_id        top_level_comment_id  \
# 0      lSlKqgyE2Zo  UgyBkSueeWLhRQ8-FyR4AaABAg  UgyBkSueeWLhRQ8-FyR4AaABAg
# 1      lSlKqgyE2Zo  Ugz6AQBHHhAtX9cdPnR4AaABAg  Ugz6AQBHHhAtX9cdPnR4AaABAg
# 2      lSlKqgyE2Zo  UgzmrA6R9UuHBIYYmWV4AaABAg  UgzmrA6R9UuHBIYYmWV4AaABAg
# 3      lSlKqgyE2Zo  UgzImr_PGPXs52nLoAx4AaABAg  UgzImr_PGPXs52nLoAx4AaABAg
# 4      lSlKqgyE2Zo  UgxxcDuBbF7C611ooRB4AaABAg  UgxxcDuBbF7C611ooRB4AaABAg
# ...            ...                         ...                         ...
# 42332  8kElrRAa1ws  UgwSdanGKGsGd4DUmIl4AaABAg  UgwSdanGKGsGd4DUmIl4AaABAg
# 42333  8kElrRAa1ws  Ugy-wtIUI069bRoN9K14AaABAg  Ugy-wtIUI069bRoN9K14AaABAg
# 42334  8kElrRAa1ws  UgwtkQootxJ6rfJzvPh4AaABAg  UgwtkQootxJ6rfJzvPh4AaABAg
# 42335  8kElrRAa1ws  Ugz_Yj_AX5darh32Y7t4AaABAg  Ugz_Yj_AX5darh32Y7t4AaABAg
# 42336  8kElrRAa1ws  Ugx9T5pgiWFHmv6Glbl4AaABAg  Ugx9T5pgiWFHmv6Glbl4AaABAg
#
#       author_display_name         author_channel_id  \
# 0              luckydolly  UC4BuW8UZuS4WTjDtD3aY17A
# 1           Emory Elliott  UCXq5M8DVAQlX55rZ-1HqREQ
# 2               Rede4trip  UCy6dVt-_KE1UJCUr46meT_Q
# 3          MARCELA Bukalo  UC_hISte6WW9yksrOAGyVyBQ
# 4      saiiree yessenniia  UC8G4mgg7HlG096cG2bwWDHQ
# ...                   ...                       ...
# 42332              Bree e  UCxbprPK-QSbBE6Zdu8eQ7Bw
# 42333         Tonya Wykle  UClgzRcV9-SJl-pTbAyAUoZw
# 42334               Lesly  UCfzU2ed9ApsBbgor5BIdT1w
# 42335       Scarlet Black  UC3RHBku3ppkK4rcrZkub6JA
# 42336    Milkshake Nugget  UCyFb0sqS_sKWE4uPzy8PpMA
#
#                                            text_original
# 0      I have had the same experience with a doctor. ...
# 1      The negative bias is what you're talking about...
# 2      I am sooooo the same way about focusing on the...
# 3      I have PCOS, had fibroids surgically removed, ...
# 4      WE NEED A NAME! I am so upset this happened to...
# ...                                                  ...
# 42332  I love this mascara for real tho. It's easy to...
# 42333  Hello makeup world, nice video. Xoxo princess 🎈🎉🎊
# 42334                                              Song?
# 42335                    Thanos would love this mascara.
# 42336                                   I like raccoons.
#
# [42337 rows x 6 columns]

# %%
last_csv
# Out:
# 4

# %%
last_csv+=1
last_csv
# Out:
# 5

# %%
df_comment_thread.to_csv('data/get_comment_threads_output/df_comment_thread_{}.csv'.format(last_csv), index = False)

# %%
np.save('data/get_comment_threads_output/last_csv.npy',last_csv)

# %%
df = pd.read_csv('data/get_comment_threads_output/df_comment_thread_{}.csv'.format(last_csv))
df
# Out:
#           video_id           comment_thread_id        top_level_comment_id  \
# 0      lSlKqgyE2Zo  UgyBkSueeWLhRQ8-FyR4AaABAg  UgyBkSueeWLhRQ8-FyR4AaABAg
# 1      lSlKqgyE2Zo  Ugz6AQBHHhAtX9cdPnR4AaABAg  Ugz6AQBHHhAtX9cdPnR4AaABAg
# 2      lSlKqgyE2Zo  UgzmrA6R9UuHBIYYmWV4AaABAg  UgzmrA6R9UuHBIYYmWV4AaABAg
# 3      lSlKqgyE2Zo  UgzImr_PGPXs52nLoAx4AaABAg  UgzImr_PGPXs52nLoAx4AaABAg
# 4      lSlKqgyE2Zo  UgxxcDuBbF7C611ooRB4AaABAg  UgxxcDuBbF7C611ooRB4AaABAg
# ...            ...                         ...                         ...
# 42332  8kElrRAa1ws  UgwSdanGKGsGd4DUmIl4AaABAg  UgwSdanGKGsGd4DUmIl4AaABAg
# 42333  8kElrRAa1ws  Ugy-wtIUI069bRoN9K14AaABAg  Ugy-wtIUI069bRoN9K14AaABAg
# 42334  8kElrRAa1ws  UgwtkQootxJ6rfJzvPh4AaABAg  UgwtkQootxJ6rfJzvPh4AaABAg
# 42335  8kElrRAa1ws  Ugz_Yj_AX5darh32Y7t4AaABAg  Ugz_Yj_AX5darh32Y7t4AaABAg
# 42336  8kElrRAa1ws  Ugx9T5pgiWFHmv6Glbl4AaABAg  Ugx9T5pgiWFHmv6Glbl4AaABAg
#
#       author_display_name         author_channel_id  \
# 0              luckydolly  UC4BuW8UZuS4WTjDtD3aY17A
# 1           Emory Elliott  UCXq5M8DVAQlX55rZ-1HqREQ
# 2               Rede4trip  UCy6dVt-_KE1UJCUr46meT_Q
# 3          MARCELA Bukalo  UC_hISte6WW9yksrOAGyVyBQ
# 4      saiiree yessenniia  UC8G4mgg7HlG096cG2bwWDHQ
# ...                   ...                       ...
# 42332              Bree e  UCxbprPK-QSbBE6Zdu8eQ7Bw
# 42333         Tonya Wykle  UClgzRcV9-SJl-pTbAyAUoZw
# 42334               Lesly  UCfzU2ed9ApsBbgor5BIdT1w
# 42335       Scarlet Black  UC3RHBku3ppkK4rcrZkub6JA
# 42336    Milkshake Nugget  UCyFb0sqS_sKWE4uPzy8PpMA
#
#                                            text_original
# 0      I have had the same experience with a doctor. ...
# 1      The negative bias is what you're talking about...
# 2      I am sooooo the same way about focusing on the...
# 3      I have PCOS, had fibroids surgically removed, ...
# 4      WE NEED A NAME! I am so upset this happened to...
# ...                                                  ...
# 42332  I love this mascara for real tho. It's easy to...
# 42333  Hello makeup world, nice video. Xoxo princess 🎈🎉🎊
# 42334                                              Song?
# 42335                    Thanos would love this mascara.
# 42336                                   I like raccoons.
#
# [42337 rows x 6 columns]
